# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && unset MPLBACKEND && python analyze_reconstruction.py \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_path /share/project10/home/prelajarsela/Attention_based_reduction/gridsearch_results_FINAL/gridsearch_autoencoder_20250624_225515/combo_504/best_model.pth \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --attention_k 11 \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --endpoints os24 \
    --output_dir ./reconstruction_analysis_256

# %%
import pickle
from collections import Counter

def analyze_os_keys(data):
    """
    Analyze OS_6 and OS_24 keys in the dataset
    """
    total_items = len(data)
    
    # Track missing keys
    missing_os6 = 0
    missing_os24 = 0
    
    # Collect values when present
    os6_values = []
    os24_values = []
    
    # Analyze each dictionary
    for item in data:
        # Check OS_6
        if 'OS_6' not in item:
            missing_os6 += 1
        else:
            os6_values.append(item['OS_6'])
        
        # Check OS_24
        if 'OS_24' not in item:
            missing_os24 += 1
        else:
            os24_values.append(item['OS_24'])
    
    # Results
    print("🔍 OS_6 ANALYSIS:")
    print(f"Total items: {total_items}")
    print(f"Missing OS_6: {missing_os6} ({missing_os6/total_items*100:.1f}%)")
    print(f"Has OS_6: {len(os6_values)} ({len(os6_values)/total_items*100:.1f}%)")
    
    if os6_values:
        os6_counts = Counter(os6_values)
        print(f"OS_6 values: {dict(os6_counts)}")
    
    print("\n🔍 OS_24 ANALYSIS:")
    print(f"Missing OS_24: {missing_os24} ({missing_os24/total_items*100:.1f}%)")
    print(f"Has OS_24: {len(os24_values)} ({len(os24_values)/total_items*100:.1f}%)")
    
    if os24_values:
        os24_counts = Counter(os24_values)
        print(f"OS_24 values: {dict(os24_counts)}")
    
    return {
        'total': total_items,
        'os6_missing': missing_os6,
        'os24_missing': missing_os24,
        'os6_values': os6_counts if os6_values else {},
        'os24_values': os24_counts if os24_values else {}
    }

# Load your data (replace with your actual file path)
with open('/home/beshoy/CT-FM_features/APOLLO_w_PET_w_OS.pkl', 'rb') as f:
    data = pickle.load(f)

# Run analysis
results = analyze_os_keys(data)
# Out:
# 🔍 OS_6 ANALYSIS:
# Total items: 497
# Missing OS_6: 4 (0.8%)
# Has OS_6: 493 (99.2%)
# OS_6 values: {1.0: 309, 0.0: 184}
#
# 🔍 OS_24 ANALYSIS:
# Missing OS_24: 32 (6.4%)
# Has OS_24: 465 (93.6%)
# OS_24 values: {1.0: 107, 0.0: 358}

# %%
import torch

def check_feature_tensors_for_nan(data):
    """
    Check all feature tensors for NaN values
    """
    total_items = len(data)
    items_with_nan = 0
    nan_details = []
    
    print(f"🔍 Checking {total_items} items for NaN values in feature tensors...")
    
    for i, item in enumerate(data):
        if 'features' not in item:
            print(f"⚠️  Item {i}: No 'features' key found")
            continue
        
        features = item['features']
        item_has_nan = False
        
        # Check each tensor in features list
        for j, tensor in enumerate(features):
            if torch.isnan(tensor).any():
                if not item_has_nan:  # First NaN found in this item
                    items_with_nan += 1
                    item_has_nan = True
                
                nan_count = torch.isnan(tensor).sum().item()
                nan_details.append({
                    'item_index': i,
                    'tensor_index': j,
                    'nan_count': nan_count,
                    'tensor_size': tensor.numel(),
                    'patient_id': item.get('patient_id', 'unknown')
                })
    
    # Results
    print(f"\n📊 RESULTS:")
    print(f"Total items checked: {total_items}")
    print(f"Items with NaN: {items_with_nan}")
    print(f"Items without NaN: {total_items - items_with_nan}")
    print(f"Clean rate: {(total_items - items_with_nan)/total_items*100:.1f}%")
    
    if nan_details:
        print(f"\n❌ NaN DETAILS:")
        for detail in nan_details[:10]:  # Show first 10
            print(f"  Item {detail['item_index']} (Patient: {detail['patient_id']}): "
                  f"Tensor {detail['tensor_index']} has {detail['nan_count']}/{detail['tensor_size']} NaN values")
        
        if len(nan_details) > 10:
            print(f"  ... and {len(nan_details) - 10} more")
    else:
        print(f"\n✅ All feature tensors are clean (no NaN values found)!")
    
    return {
        'total_items': total_items,
        'items_with_nan': items_with_nan,
        'nan_details': nan_details
    }

# Quick version to run directly:
def quick_nan_check(data):
    """Quick one-liner version"""
    items_with_nan = 0
    for i, item in enumerate(data):
        if 'features' in item:
            if any(torch.isnan(tensor).any() for tensor in item['features']):
                items_with_nan += 1
    
    print(f"Items with NaN: {items_with_nan}/{len(data)}")
    print(f"Clean rate: {(len(data) - items_with_nan)/len(data)*100:.1f}%")
    return items_with_nan == 0

# Run the check (replace 'data' with your variable name)
results = check_feature_tensors_for_nan(data)
# or for quick check:
# is_clean = quick_nan_check(data)
# Out:
# 🔍 Checking 497 items for NaN values in feature tensors...
#
# 📊 RESULTS:
# Total items checked: 497
# Items with NaN: 2
# Items without NaN: 495
# Clean rate: 99.6%
#
# ❌ NaN DETAILS:
#   Item 484 (Patient: INT1010586): Tensor 90 has 512/512 NaN values
#   Item 484 (Patient: INT1010586): Tensor 91 has 512/512 NaN values
#   Item 492 (Patient: INT1010732): Tensor 88 has 512/512 NaN values
#   Item 492 (Patient: INT1010732): Tensor 89 has 512/512 NaN values
#   Item 492 (Patient: INT1010732): Tensor 90 has 512/512 NaN values
#   Item 492 (Patient: INT1010732): Tensor 91 has 512/512 NaN values
#   Item 492 (Patient: INT1010732): Tensor 92 has 512/512 NaN values
#   Item 492 (Patient: INT1010732): Tensor 93 has 512/512 NaN values
#   Item 492 (Patient: INT1010732): Tensor 94 has 512/512 NaN values
#   Item 492 (Patient: INT1010732): Tensor 95 has 512/512 NaN values

# %%
# !source ~/miniconda3/etc/profile.d/conda.sh && conda activate ABR && python main_autoencoder.py \
    --pkl_files /home/beshoy/CT-FM_features/APOLLO_w_PET_w_OS.pkl /home/beshoy/CT-FM_features/LUNG_RADIO_fast.pkl \
    --model_type autoencoder \
    --attention_k 11 \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 8.0 \
    --val_split 0.10 \
    --endpoints os24 \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# /home/beshoy/code-projects/Attention_based_reduction/utils/dataloader.py:25: UserWarning: WARNING: Patient INT1010586 excluded due to NaN values in feature tensor 90
#   warnings.warn(f"WARNING: Patient {patient_id} excluded due to NaN values in feature tensor {i}")
# /home/beshoy/code-projects/Attention_based_reduction/utils/dataloader.py:25: UserWarning: WARNING: Patient INT1010732 excluded due to NaN values in feature tensor 88
#   warnings.warn(f"WARNING: Patient {patient_id} excluded due to NaN values in feature tensor {i}")
# EXCLUDED 2 patients due to NaN values in features:
#   - Patient ID: INT1010586
#   - Patient ID: INT1010732
# Feature validation: kept 1048 patients, excluded 2 patients with NaN features
# Filtered patients: kept 1004, excluded 44 patients missing required endpoints
# Automatic split: Train 80%, Val 10%, Test 10%
# Stratification successful with endpoints: ['os24']
# Train samples: 802
# Validation samples: 101
# Test samples: 101
# Creating autoencoder model...
# Model parameters: 3,041,777
# Starting training...
# Starting training for 50 epochs...
# Model type: autoencoder
# Device: cuda
#   New best validation AUC: 0.6391
# Epoch 1/50 (0.83s)
#   Train Loss: 315.5201
#   Train Cosine Sim: 0.4607
#   Val Loss: 320.3751
#   Val Cosine Sim: 0.6792
#   Val OS24 AUC: 0.6391
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6688
# Epoch 2/50 (0.37s)
#   Train Loss: 282.5008
#   Train Cosine Sim: 0.7042
#   Val Loss: 291.5440
#   Val Cosine Sim: 0.7290
#   Val OS24 AUC: 0.6688
#   LR: 1.00e-03
#
# Epoch 3/50 (0.28s)
#   Train Loss: 251.8577
#   Train Cosine Sim: 0.7430
#   Val Loss: 251.6296
#   Val Cosine Sim: 0.7607
#   Val OS24 AUC: 0.6190
#   LR: 1.00e-03
#
# Epoch 4/50 (0.29s)
#   Train Loss: 222.0175
#   Train Cosine Sim: 0.7719
#   Val Loss: 210.0369
#   Val Cosine Sim: 0.7863
#   Val OS24 AUC: 0.6362
#   LR: 1.00e-03
#
# Epoch 5/50 (0.28s)
#   Train Loss: 191.3306
#   Train Cosine Sim: 0.7960
#   Val Loss: 177.0721
#   Val Cosine Sim: 0.8092
#   Val OS24 AUC: 0.6287
#   LR: 1.00e-03
#
# Epoch 6/50 (0.28s)
#   Train Loss: 162.3256
#   Train Cosine Sim: 0.8182
#   Val Loss: 147.4970
#   Val Cosine Sim: 0.8296
#   Val OS24 AUC: 0.6374
#   LR: 1.00e-03
#
# Epoch 7/50 (0.28s)
#   Train Loss: 138.6391
#   Train Cosine Sim: 0.8381
#   Val Loss: 142.1337
#   Val Cosine Sim: 0.8483
#   Val OS24 AUC: 0.6679
#   LR: 1.00e-03
#
# Epoch 8/50 (0.31s)
#   Train Loss: 120.8226
#   Train Cosine Sim: 0.8555
#   Val Loss: 119.5767
#   Val Cosine Sim: 0.8634
#   Val OS24 AUC: 0.6525
#   LR: 1.00e-03
#
# Epoch 9/50 (0.28s)
#   Train Loss: 107.0648
#   Train Cosine Sim: 0.8690
#   Val Loss: 97.6882
#   Val Cosine Sim: 0.8753
#   Val OS24 AUC: 0.6086
#   LR: 1.00e-03
#
# Epoch 10/50 (0.28s)
#   Train Loss: 97.3501
#   Train Cosine Sim: 0.8799
#   Val Loss: 91.3919
#   Val Cosine Sim: 0.8859
#   Val OS24 AUC: 0.6303
#   LR: 1.00e-03
#
# Epoch 11/50 (0.27s)
#   Train Loss: 86.2506
#   Train Cosine Sim: 0.8906
#   Val Loss: 84.6589
#   Val Cosine Sim: 0.8964
#   Val OS24 AUC: 0.6270
#   LR: 1.00e-03
#
# Epoch 12/50 (0.29s)
#   Train Loss: 78.1001
#   Train Cosine Sim: 0.9007
#   Val Loss: 78.2030
#   Val Cosine Sim: 0.9059
#   Val OS24 AUC: 0.6504
#   LR: 1.00e-03
#
# Epoch 13/50 (0.28s)
#   Train Loss: 71.6255
#   Train Cosine Sim: 0.9095
#   Val Loss: 73.1632
#   Val Cosine Sim: 0.9137
#   Val OS24 AUC: 0.6249
#   LR: 5.00e-04
#
# Epoch 14/50 (0.28s)
#   Train Loss: 66.4585
#   Train Cosine Sim: 0.9155
#   Val Loss: 66.3812
#   Val Cosine Sim: 0.9177
#   Val OS24 AUC: 0.6157
#   LR: 5.00e-04
#
# Epoch 15/50 (0.28s)
#   Train Loss: 63.4076
#   Train Cosine Sim: 0.9191
#   Val Loss: 61.0461
#   Val Cosine Sim: 0.9213
#   Val OS24 AUC: 0.6207
#   LR: 5.00e-04
#
# Epoch 16/50 (0.29s)
#   Train Loss: 63.2900
#   Train Cosine Sim: 0.9223
#   Val Loss: 59.4400
#   Val Cosine Sim: 0.9245
#   Val OS24 AUC: 0.6353
#   LR: 5.00e-04
#
# Epoch 17/50 (0.28s)
#   Train Loss: 59.6251
#   Train Cosine Sim: 0.9253
#   Val Loss: 57.7895
#   Val Cosine Sim: 0.9275
#   Val OS24 AUC: 0.6345
#   LR: 5.00e-04
#
# Epoch 18/50 (0.28s)
#   Train Loss: 57.8742
#   Train Cosine Sim: 0.9284
#   Val Loss: 57.2771
#   Val Cosine Sim: 0.9302
#   Val OS24 AUC: 0.6216
#   LR: 5.00e-04
#
# Epoch 19/50 (0.28s)
#   Train Loss: 55.8786
#   Train Cosine Sim: 0.9313
#   Val Loss: 54.5792
#   Val Cosine Sim: 0.9332
#   Val OS24 AUC: 0.6295
#   LR: 5.00e-04
#
# Epoch 20/50 (0.30s)
#   Train Loss: 53.4104
#   Train Cosine Sim: 0.9339
#   Val Loss: 51.6965
#   Val Cosine Sim: 0.9357
#   Val OS24 AUC: 0.6291
#   LR: 5.00e-04
#
# Epoch 21/50 (0.29s)
#   Train Loss: 52.0463
#   Train Cosine Sim: 0.9361
#   Val Loss: 51.2969
#   Val Cosine Sim: 0.9381
#   Val OS24 AUC: 0.6249
#   LR: 5.00e-04
#
# Early stopping triggered after 20 epochs without improvement
# Restored best weights
# Epoch 22/50 (0.28s)
#   Train Loss: 50.2271
#   Train Cosine Sim: 0.9387
#   Val Loss: 49.2912
#   Val Cosine Sim: 0.9404
#   Val OS24 AUC: 0.6295
#   LR: 5.00e-04
#
# Early stopping triggered!
# Training completed!
# Best validation AUC: 0.6688
# Evaluating on test set...
# Loaded best model from epoch 1
#
# Test Results:
# Test Loss: 289.6540
# Test Cosine Sim: 0.7317
# OS24 - AUC: 0.6274, Accuracy: 0.6139, F1: 0.2909
#
# ============================================================
# SKIPPING RECONSTRUCTION EVALUATION
# Use --reconstruction-evaluation flag to enable detailed analysis
# ============================================================
#
# Results saved to: ./results/autoencoder_20250704_173842/autoencoder_20250704_173913

# %%
# !source ~/miniconda3/etc/profile.d/conda.sh && conda activate ABR && python main_autoencoder.py \
    --pkl_files /home/beshoy/CT-FM_features/APOLLO_w_PET_w_OS.pkl /home/beshoy/CT-FM_features/LUNG_RADIO_fast.pkl \
    --model_type autoencoder \
    --attention_k 11 \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 8.0 \
    --val_split 0.15 \
    --endpoints os24 \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# /home/beshoy/code-projects/Attention_based_reduction/utils/dataloader.py:25: UserWarning: WARNING: Patient INT1010586 excluded due to NaN values in feature tensor 90
#   warnings.warn(f"WARNING: Patient {patient_id} excluded due to NaN values in feature tensor {i}")
# /home/beshoy/code-projects/Attention_based_reduction/utils/dataloader.py:25: UserWarning: WARNING: Patient INT1010732 excluded due to NaN values in feature tensor 88
#   warnings.warn(f"WARNING: Patient {patient_id} excluded due to NaN values in feature tensor {i}")
# EXCLUDED 2 patients due to NaN values in features:
#   - Patient ID: INT1010586
#   - Patient ID: INT1010732
# Feature validation: kept 1048 patients, excluded 2 patients with NaN features
# Filtered patients: kept 1004, excluded 44 patients missing required endpoints
# Automatic split: Train 70%, Val 15%, Test 15%
# Stratification successful with endpoints: ['os24']
# Train samples: 702
# Validation samples: 151
# Test samples: 151
# Creating autoencoder model...
# Model parameters: 3,041,777
# Starting training...
# Starting training for 50 epochs...
# Model type: autoencoder
# Device: cuda
#   New best validation AUC: 0.5847
# Epoch 1/50 (0.75s)
#   Train Loss: 317.8988
#   Train Cosine Sim: 0.4247
#   Val Loss: 321.1274
#   Val Cosine Sim: 0.6674
#   Val OS24 AUC: 0.5847
#   LR: 1.00e-03
#
#   New best validation AUC: 0.5935
# Epoch 2/50 (0.36s)
#   Train Loss: 288.8756
#   Train Cosine Sim: 0.6924
#   Val Loss: 299.7529
#   Val Cosine Sim: 0.7213
#   Val OS24 AUC: 0.5935
#   LR: 1.00e-03
#
# Epoch 3/50 (0.26s)
#   Train Loss: 261.1672
#   Train Cosine Sim: 0.7322
#   Val Loss: 256.8919
#   Val Cosine Sim: 0.7496
#   Val OS24 AUC: 0.5870
#   LR: 1.00e-03
#
#   New best validation AUC: 0.5974
# Epoch 4/50 (0.34s)
#   Train Loss: 234.3155
#   Train Cosine Sim: 0.7591
#   Val Loss: 222.4985
#   Val Cosine Sim: 0.7728
#   Val OS24 AUC: 0.5974
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6176
# Epoch 5/50 (0.35s)
#   Train Loss: 207.1803
#   Train Cosine Sim: 0.7814
#   Val Loss: 188.4549
#   Val Cosine Sim: 0.7945
#   Val OS24 AUC: 0.6176
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6232
# Epoch 6/50 (0.35s)
#   Train Loss: 180.0556
#   Train Cosine Sim: 0.8023
#   Val Loss: 166.4360
#   Val Cosine Sim: 0.8141
#   Val OS24 AUC: 0.6232
#   LR: 1.00e-03
#
# Epoch 7/50 (0.26s)
#   Train Loss: 157.0714
#   Train Cosine Sim: 0.8210
#   Val Loss: 145.0180
#   Val Cosine Sim: 0.8317
#   Val OS24 AUC: 0.6124
#   LR: 1.00e-03
#
# Epoch 8/50 (0.26s)
#   Train Loss: 137.2041
#   Train Cosine Sim: 0.8384
#   Val Loss: 130.3146
#   Val Cosine Sim: 0.8488
#   Val OS24 AUC: 0.6217
#   LR: 1.00e-03
#
# Epoch 9/50 (0.27s)
#   Train Loss: 121.4094
#   Train Cosine Sim: 0.8533
#   Val Loss: 111.5903
#   Val Cosine Sim: 0.8606
#   Val OS24 AUC: 0.5956
#   LR: 1.00e-03
#
# Epoch 10/50 (0.28s)
#   Train Loss: 107.9724
#   Train Cosine Sim: 0.8659
#   Val Loss: 107.0981
#   Val Cosine Sim: 0.8741
#   Val OS24 AUC: 0.6222
#   LR: 1.00e-03
#
# Epoch 11/50 (0.26s)
#   Train Loss: 96.2994
#   Train Cosine Sim: 0.8775
#   Val Loss: 87.4326
#   Val Cosine Sim: 0.8848
#   Val OS24 AUC: 0.6172
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6252
# Epoch 12/50 (0.34s)
#   Train Loss: 86.5491
#   Train Cosine Sim: 0.8879
#   Val Loss: 83.6873
#   Val Cosine Sim: 0.8939
#   Val OS24 AUC: 0.6252
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6385
# Epoch 13/50 (0.37s)
#   Train Loss: 77.9348
#   Train Cosine Sim: 0.8974
#   Val Loss: 77.9266
#   Val Cosine Sim: 0.9026
#   Val OS24 AUC: 0.6385
#   LR: 1.00e-03
#
# Epoch 14/50 (0.26s)
#   Train Loss: 72.3827
#   Train Cosine Sim: 0.9061
#   Val Loss: 76.0426
#   Val Cosine Sim: 0.9096
#   Val OS24 AUC: 0.6047
#   LR: 1.00e-03
#
# Epoch 15/50 (0.26s)
#   Train Loss: 67.7416
#   Train Cosine Sim: 0.9127
#   Val Loss: 65.8929
#   Val Cosine Sim: 0.9177
#   Val OS24 AUC: 0.6234
#   LR: 1.00e-03
#
# Epoch 16/50 (0.27s)
#   Train Loss: 64.1667
#   Train Cosine Sim: 0.9191
#   Val Loss: 60.7004
#   Val Cosine Sim: 0.9229
#   Val OS24 AUC: 0.6194
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6439
# Epoch 17/50 (0.35s)
#   Train Loss: 59.1418
#   Train Cosine Sim: 0.9240
#   Val Loss: 63.3109
#   Val Cosine Sim: 0.9284
#   Val OS24 AUC: 0.6439
#   LR: 1.00e-03
#
# Epoch 18/50 (0.26s)
#   Train Loss: 55.8794
#   Train Cosine Sim: 0.9293
#   Val Loss: 52.6159
#   Val Cosine Sim: 0.9329
#   Val OS24 AUC: 0.6433
#   LR: 1.00e-03
#
# Epoch 19/50 (0.26s)
#   Train Loss: 52.0840
#   Train Cosine Sim: 0.9337
#   Val Loss: 51.4446
#   Val Cosine Sim: 0.9377
#   Val OS24 AUC: 0.6355
#   LR: 1.00e-03
#
# Epoch 20/50 (0.26s)
#   Train Loss: 48.9849
#   Train Cosine Sim: 0.9386
#   Val Loss: 47.4622
#   Val Cosine Sim: 0.9423
#   Val OS24 AUC: 0.6437
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6529
# Epoch 21/50 (0.35s)
#   Train Loss: 46.1274
#   Train Cosine Sim: 0.9433
#   Val Loss: 45.6440
#   Val Cosine Sim: 0.9470
#   Val OS24 AUC: 0.6529
#   LR: 1.00e-03
#
# Epoch 22/50 (0.26s)
#   Train Loss: 43.4239
#   Train Cosine Sim: 0.9476
#   Val Loss: 42.1123
#   Val Cosine Sim: 0.9509
#   Val OS24 AUC: 0.6454
#   LR: 1.00e-03
#
# Epoch 23/50 (0.26s)
#   Train Loss: 41.8438
#   Train Cosine Sim: 0.9515
#   Val Loss: 41.0089
#   Val Cosine Sim: 0.9543
#   Val OS24 AUC: 0.6476
#   LR: 1.00e-03
#
# Epoch 24/50 (0.26s)
#   Train Loss: 38.4763
#   Train Cosine Sim: 0.9549
#   Val Loss: 37.0453
#   Val Cosine Sim: 0.9575
#   Val OS24 AUC: 0.6474
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6698
# Epoch 25/50 (0.36s)
#   Train Loss: 36.7279
#   Train Cosine Sim: 0.9582
#   Val Loss: 38.0003
#   Val Cosine Sim: 0.9606
#   Val OS24 AUC: 0.6698
#   LR: 1.00e-03
#
# Epoch 26/50 (0.28s)
#   Train Loss: 34.0914
#   Train Cosine Sim: 0.9614
#   Val Loss: 36.1463
#   Val Cosine Sim: 0.9637
#   Val OS24 AUC: 0.6372
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6719
# Epoch 27/50 (0.34s)
#   Train Loss: 32.0322
#   Train Cosine Sim: 0.9642
#   Val Loss: 32.0983
#   Val Cosine Sim: 0.9663
#   Val OS24 AUC: 0.6719
#   LR: 1.00e-03
#
# Epoch 28/50 (0.26s)
#   Train Loss: 30.3440
#   Train Cosine Sim: 0.9669
#   Val Loss: 32.2577
#   Val Cosine Sim: 0.9690
#   Val OS24 AUC: 0.6487
#   LR: 1.00e-03
#
# Epoch 29/50 (0.26s)
#   Train Loss: 29.3101
#   Train Cosine Sim: 0.9696
#   Val Loss: 29.1361
#   Val Cosine Sim: 0.9713
#   Val OS24 AUC: 0.6325
#   LR: 1.00e-03
#
# Epoch 30/50 (0.28s)
#   Train Loss: 27.2649
#   Train Cosine Sim: 0.9720
#   Val Loss: 28.6392
#   Val Cosine Sim: 0.9735
#   Val OS24 AUC: 0.6278
#   LR: 1.00e-03
#
# Epoch 31/50 (0.26s)
#   Train Loss: 25.3427
#   Train Cosine Sim: 0.9743
#   Val Loss: 28.4910
#   Val Cosine Sim: 0.9759
#   Val OS24 AUC: 0.6237
#   LR: 1.00e-03
#
# Epoch 32/50 (0.26s)
#   Train Loss: 24.4688
#   Train Cosine Sim: 0.9763
#   Val Loss: 24.1525
#   Val Cosine Sim: 0.9778
#   Val OS24 AUC: 0.5474
#   LR: 1.00e-03
#
# Epoch 33/50 (0.27s)
#   Train Loss: 22.8453
#   Train Cosine Sim: 0.9781
#   Val Loss: 23.4755
#   Val Cosine Sim: 0.9797
#   Val OS24 AUC: 0.6170
#   LR: 1.00e-03
#
# Epoch 34/50 (0.27s)
#   Train Loss: 21.4340
#   Train Cosine Sim: 0.9799
#   Val Loss: 21.5514
#   Val Cosine Sim: 0.9811
#   Val OS24 AUC: 0.5267
#   LR: 1.00e-03
#
# Epoch 35/50 (0.26s)
#   Train Loss: 20.5898
#   Train Cosine Sim: 0.9816
#   Val Loss: 21.1402
#   Val Cosine Sim: 0.9831
#   Val OS24 AUC: 0.6446
#   LR: 1.00e-03
#
# Epoch 36/50 (0.26s)
#   Train Loss: 18.9202
#   Train Cosine Sim: 0.9831
#   Val Loss: 23.2806
#   Val Cosine Sim: 0.9843
#   Val OS24 AUC: 0.5705
#   LR: 1.00e-03
#
# Epoch 37/50 (0.26s)
#   Train Loss: 18.1858
#   Train Cosine Sim: 0.9844
#   Val Loss: 22.0432
#   Val Cosine Sim: 0.9856
#   Val OS24 AUC: 0.6381
#   LR: 1.00e-03
#
# Epoch 38/50 (0.27s)
#   Train Loss: 17.2820
#   Train Cosine Sim: 0.9855
#   Val Loss: 18.6026
#   Val Cosine Sim: 0.9869
#   Val OS24 AUC: 0.6107
#   LR: 5.00e-04
#
# Epoch 39/50 (0.26s)
#   Train Loss: 16.2718
#   Train Cosine Sim: 0.9866
#   Val Loss: 17.3132
#   Val Cosine Sim: 0.9875
#   Val OS24 AUC: 0.6131
#   LR: 5.00e-04
#
# Epoch 40/50 (0.26s)
#   Train Loss: 16.2920
#   Train Cosine Sim: 0.9872
#   Val Loss: 17.7564
#   Val Cosine Sim: 0.9881
#   Val OS24 AUC: 0.6469
#   LR: 5.00e-04
#
# Epoch 41/50 (0.26s)
#   Train Loss: 15.0041
#   Train Cosine Sim: 0.9877
#   Val Loss: 17.4514
#   Val Cosine Sim: 0.9884
#   Val OS24 AUC: 0.6327
#   LR: 5.00e-04
#
# Epoch 42/50 (0.27s)
#   Train Loss: 14.5913
#   Train Cosine Sim: 0.9882
#   Val Loss: 15.8574
#   Val Cosine Sim: 0.9891
#   Val OS24 AUC: 0.6058
#   LR: 5.00e-04
#
# Epoch 43/50 (0.26s)
#   Train Loss: 14.3970
#   Train Cosine Sim: 0.9888
#   Val Loss: 16.9234
#   Val Cosine Sim: 0.9896
#   Val OS24 AUC: 0.6288
#   LR: 5.00e-04
#
# Epoch 44/50 (0.26s)
#   Train Loss: 13.8736
#   Train Cosine Sim: 0.9892
#   Val Loss: 16.1643
#   Val Cosine Sim: 0.9900
#   Val OS24 AUC: 0.6172
#   LR: 5.00e-04
#
# Epoch 45/50 (0.26s)
#   Train Loss: 13.6184
#   Train Cosine Sim: 0.9896
#   Val Loss: 15.1616
#   Val Cosine Sim: 0.9904
#   Val OS24 AUC: 0.5875
#   LR: 5.00e-04
#
# Epoch 46/50 (0.26s)
#   Train Loss: 13.4298
#   Train Cosine Sim: 0.9899
#   Val Loss: 15.6283
#   Val Cosine Sim: 0.9908
#   Val OS24 AUC: 0.6058
#   LR: 5.00e-04
#
# Early stopping triggered after 20 epochs without improvement
# Restored best weights
# Epoch 47/50 (0.27s)
#   Train Loss: 12.5571
#   Train Cosine Sim: 0.9905
#   Val Loss: 15.6904
#   Val Cosine Sim: 0.9912
#   Val OS24 AUC: 0.6043
#   LR: 5.00e-04
#
# Early stopping triggered!
# Training completed!
# Best validation AUC: 0.6719
# Evaluating on test set...
# Loaded best model from epoch 26
#
# Test Results:
# Test Loss: 31.2261
# Test Cosine Sim: 0.9663
# OS24 - AUC: 0.7122, Accuracy: 0.5497, F1: 0.5467
#
# ============================================================
# SKIPPING RECONSTRUCTION EVALUATION
# Use --reconstruction-evaluation flag to enable detailed analysis
# ============================================================
#
# Results saved to: ./results/autoencoder_20250704_173755/autoencoder_20250704_173825

# %%
# !source ~/miniconda3/etc/profile.d/conda.sh && conda activate ABR && python main_autoencoder.py \
    --pkl_files /home/beshoy/CT-FM_features/APOLLO_w_PET_w_OS.pkl /home/beshoy/CT-FM_features/LUNG_RADIO_fast.pkl \
    --model_type autoencoder \
    --attention_k 11 \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 8.0 \
    --val_split 0.20 \
    --endpoints os24 \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# /home/beshoy/code-projects/Attention_based_reduction/utils/dataloader.py:25: UserWarning: WARNING: Patient INT1010586 excluded due to NaN values in feature tensor 90
#   warnings.warn(f"WARNING: Patient {patient_id} excluded due to NaN values in feature tensor {i}")
# /home/beshoy/code-projects/Attention_based_reduction/utils/dataloader.py:25: UserWarning: WARNING: Patient INT1010732 excluded due to NaN values in feature tensor 88
#   warnings.warn(f"WARNING: Patient {patient_id} excluded due to NaN values in feature tensor {i}")
# EXCLUDED 2 patients due to NaN values in features:
#   - Patient ID: INT1010586
#   - Patient ID: INT1010732
# Feature validation: kept 1048 patients, excluded 2 patients with NaN features
# Filtered patients: kept 1004, excluded 44 patients missing required endpoints
# Automatic split: Train 60%, Val 20%, Test 20%
# Stratification successful with endpoints: ['os24']
# Train samples: 602
# Validation samples: 201
# Test samples: 201
# Creating autoencoder model...
# Model parameters: 3,041,777
# Starting training...
# Starting training for 50 epochs...
# Model type: autoencoder
# Device: cuda
#   New best validation AUC: 0.5542
# Epoch 1/50 (0.78s)
#   Train Loss: 319.1919
#   Train Cosine Sim: 0.4000
#   Val Loss: 320.8290
#   Val Cosine Sim: 0.6571
#   Val OS24 AUC: 0.5542
#   LR: 1.00e-03
#
#   New best validation AUC: 0.5981
# Epoch 2/50 (0.32s)
#   Train Loss: 293.2068
#   Train Cosine Sim: 0.6835
#   Val Loss: 305.9619
#   Val Cosine Sim: 0.7124
#   Val OS24 AUC: 0.5981
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6117
# Epoch 3/50 (0.32s)
#   Train Loss: 269.8443
#   Train Cosine Sim: 0.7245
#   Val Loss: 280.1017
#   Val Cosine Sim: 0.7397
#   Val OS24 AUC: 0.6117
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6362
# Epoch 4/50 (0.33s)
#   Train Loss: 246.9415
#   Train Cosine Sim: 0.7493
#   Val Loss: 254.7306
#   Val Cosine Sim: 0.7620
#   Val OS24 AUC: 0.6362
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6394
# Epoch 5/50 (0.32s)
#   Train Loss: 224.5106
#   Train Cosine Sim: 0.7712
#   Val Loss: 219.4249
#   Val Cosine Sim: 0.7812
#   Val OS24 AUC: 0.6394
#   LR: 1.00e-03
#
# Epoch 6/50 (0.24s)
#   Train Loss: 201.6725
#   Train Cosine Sim: 0.7896
#   Val Loss: 200.0843
#   Val Cosine Sim: 0.7982
#   Val OS24 AUC: 0.6259
#   LR: 1.00e-03
#
# Epoch 7/50 (0.24s)
#   Train Loss: 178.6625
#   Train Cosine Sim: 0.8072
#   Val Loss: 175.6903
#   Val Cosine Sim: 0.8137
#   Val OS24 AUC: 0.6085
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6448
# Epoch 8/50 (0.34s)
#   Train Loss: 157.7741
#   Train Cosine Sim: 0.8228
#   Val Loss: 152.9378
#   Val Cosine Sim: 0.8292
#   Val OS24 AUC: 0.6448
#   LR: 1.00e-03
#
# Epoch 9/50 (0.26s)
#   Train Loss: 139.0479
#   Train Cosine Sim: 0.8378
#   Val Loss: 133.8095
#   Val Cosine Sim: 0.8447
#   Val OS24 AUC: 0.6273
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6482
# Epoch 10/50 (0.33s)
#   Train Loss: 125.0384
#   Train Cosine Sim: 0.8516
#   Val Loss: 122.9497
#   Val Cosine Sim: 0.8565
#   Val OS24 AUC: 0.6482
#   LR: 1.00e-03
#
# Epoch 11/50 (0.25s)
#   Train Loss: 112.0708
#   Train Cosine Sim: 0.8632
#   Val Loss: 104.7257
#   Val Cosine Sim: 0.8682
#   Val OS24 AUC: 0.6358
#   LR: 1.00e-03
#
# Epoch 12/50 (0.26s)
#   Train Loss: 101.7829
#   Train Cosine Sim: 0.8741
#   Val Loss: 99.4330
#   Val Cosine Sim: 0.8782
#   Val OS24 AUC: 0.6445
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6569
# Epoch 13/50 (0.33s)
#   Train Loss: 92.8089
#   Train Cosine Sim: 0.8838
#   Val Loss: 90.2966
#   Val Cosine Sim: 0.8868
#   Val OS24 AUC: 0.6569
#   LR: 1.00e-03
#
# Epoch 14/50 (0.25s)
#   Train Loss: 83.4420
#   Train Cosine Sim: 0.8919
#   Val Loss: 80.8312
#   Val Cosine Sim: 0.8953
#   Val OS24 AUC: 0.6454
#   LR: 1.00e-03
#
# Epoch 15/50 (0.25s)
#   Train Loss: 76.9747
#   Train Cosine Sim: 0.8998
#   Val Loss: 75.4362
#   Val Cosine Sim: 0.9026
#   Val OS24 AUC: 0.6203
#   LR: 1.00e-03
#
# Epoch 16/50 (0.25s)
#   Train Loss: 72.4302
#   Train Cosine Sim: 0.9070
#   Val Loss: 69.8864
#   Val Cosine Sim: 0.9099
#   Val OS24 AUC: 0.6303
#   LR: 1.00e-03
#
# Epoch 17/50 (0.26s)
#   Train Loss: 67.0552
#   Train Cosine Sim: 0.9136
#   Val Loss: 65.5777
#   Val Cosine Sim: 0.9159
#   Val OS24 AUC: 0.6367
#   LR: 1.00e-03
#
# Epoch 18/50 (0.25s)
#   Train Loss: 62.8932
#   Train Cosine Sim: 0.9193
#   Val Loss: 63.0139
#   Val Cosine Sim: 0.9216
#   Val OS24 AUC: 0.6381
#   LR: 1.00e-03
#
# Epoch 19/50 (0.25s)
#   Train Loss: 58.9596
#   Train Cosine Sim: 0.9243
#   Val Loss: 60.5017
#   Val Cosine Sim: 0.9265
#   Val OS24 AUC: 0.6367
#   LR: 1.00e-03
#
# Epoch 20/50 (0.26s)
#   Train Loss: 55.3659
#   Train Cosine Sim: 0.9293
#   Val Loss: 55.9925
#   Val Cosine Sim: 0.9310
#   Val OS24 AUC: 0.6551
#   LR: 1.00e-03
#
# Epoch 21/50 (0.28s)
#   Train Loss: 52.1463
#   Train Cosine Sim: 0.9338
#   Val Loss: 51.8989
#   Val Cosine Sim: 0.9357
#   Val OS24 AUC: 0.6323
#   LR: 1.00e-03
#
# Epoch 22/50 (0.25s)
#   Train Loss: 49.0808
#   Train Cosine Sim: 0.9384
#   Val Loss: 49.4842
#   Val Cosine Sim: 0.9401
#   Val OS24 AUC: 0.6309
#   LR: 1.00e-03
#
# Epoch 23/50 (0.24s)
#   Train Loss: 46.8702
#   Train Cosine Sim: 0.9427
#   Val Loss: 48.4180
#   Val Cosine Sim: 0.9440
#   Val OS24 AUC: 0.6000
#   LR: 1.00e-03
#
# Epoch 24/50 (0.25s)
#   Train Loss: 43.9910
#   Train Cosine Sim: 0.9464
#   Val Loss: 45.0061
#   Val Cosine Sim: 0.9473
#   Val OS24 AUC: 0.6254
#   LR: 5.00e-04
#
# Epoch 25/50 (0.25s)
#   Train Loss: 41.4409
#   Train Cosine Sim: 0.9491
#   Val Loss: 43.7892
#   Val Cosine Sim: 0.9494
#   Val OS24 AUC: 0.6414
#   LR: 5.00e-04
#
#   New best validation AUC: 0.6606
# Epoch 26/50 (0.34s)
#   Train Loss: 40.4318
#   Train Cosine Sim: 0.9508
#   Val Loss: 41.3307
#   Val Cosine Sim: 0.9511
#   Val OS24 AUC: 0.6606
#   LR: 5.00e-04
#
# Epoch 27/50 (0.25s)
#   Train Loss: 40.0638
#   Train Cosine Sim: 0.9527
#   Val Loss: 40.9621
#   Val Cosine Sim: 0.9529
#   Val OS24 AUC: 0.6499
#   LR: 5.00e-04
#
# Epoch 28/50 (0.25s)
#   Train Loss: 38.5263
#   Train Cosine Sim: 0.9542
#   Val Loss: 40.4475
#   Val Cosine Sim: 0.9545
#   Val OS24 AUC: 0.6504
#   LR: 5.00e-04
#
# Epoch 29/50 (0.24s)
#   Train Loss: 37.2278
#   Train Cosine Sim: 0.9557
#   Val Loss: 39.2200
#   Val Cosine Sim: 0.9560
#   Val OS24 AUC: 0.6600
#   LR: 5.00e-04
#
# Epoch 30/50 (0.26s)
#   Train Loss: 35.9265
#   Train Cosine Sim: 0.9574
#   Val Loss: 37.0418
#   Val Cosine Sim: 0.9578
#   Val OS24 AUC: 0.6280
#   LR: 5.00e-04
#
# Epoch 31/50 (0.25s)
#   Train Loss: 34.7372
#   Train Cosine Sim: 0.9590
#   Val Loss: 36.1752
#   Val Cosine Sim: 0.9593
#   Val OS24 AUC: 0.6336
#   LR: 5.00e-04
#
# Epoch 32/50 (0.25s)
#   Train Loss: 34.3258
#   Train Cosine Sim: 0.9606
#   Val Loss: 35.2388
#   Val Cosine Sim: 0.9607
#   Val OS24 AUC: 0.6262
#   LR: 5.00e-04
#
# Epoch 33/50 (0.25s)
#   Train Loss: 33.0231
#   Train Cosine Sim: 0.9620
#   Val Loss: 33.8165
#   Val Cosine Sim: 0.9622
#   Val OS24 AUC: 0.6555
#   LR: 5.00e-04
#
# Epoch 34/50 (0.25s)
#   Train Loss: 31.9785
#   Train Cosine Sim: 0.9634
#   Val Loss: 33.0620
#   Val Cosine Sim: 0.9639
#   Val OS24 AUC: 0.6227
#   LR: 5.00e-04
#
# Epoch 35/50 (0.26s)
#   Train Loss: 31.0548
#   Train Cosine Sim: 0.9648
#   Val Loss: 32.8629
#   Val Cosine Sim: 0.9650
#   Val OS24 AUC: 0.5457
#   LR: 5.00e-04
#
# Epoch 36/50 (0.25s)
#   Train Loss: 30.3875
#   Train Cosine Sim: 0.9661
#   Val Loss: 31.4309
#   Val Cosine Sim: 0.9662
#   Val OS24 AUC: 0.6074
#   LR: 5.00e-04
#
# Epoch 37/50 (0.25s)
#   Train Loss: 29.9687
#   Train Cosine Sim: 0.9671
#   Val Loss: 31.2099
#   Val Cosine Sim: 0.9673
#   Val OS24 AUC: 0.5260
#   LR: 2.50e-04
#
# Epoch 38/50 (0.24s)
#   Train Loss: 28.7524
#   Train Cosine Sim: 0.9680
#   Val Loss: 30.6171
#   Val Cosine Sim: 0.9681
#   Val OS24 AUC: 0.5707
#   LR: 2.50e-04
#
# Epoch 39/50 (0.26s)
#   Train Loss: 28.3644
#   Train Cosine Sim: 0.9687
#   Val Loss: 30.4640
#   Val Cosine Sim: 0.9687
#   Val OS24 AUC: 0.6146
#   LR: 2.50e-04
#
# Epoch 40/50 (0.27s)
#   Train Loss: 28.0453
#   Train Cosine Sim: 0.9693
#   Val Loss: 29.9291
#   Val Cosine Sim: 0.9692
#   Val OS24 AUC: 0.6304
#   LR: 2.50e-04
#
# Epoch 41/50 (0.25s)
#   Train Loss: 27.3374
#   Train Cosine Sim: 0.9699
#   Val Loss: 29.4553
#   Val Cosine Sim: 0.9697
#   Val OS24 AUC: 0.6203
#   LR: 2.50e-04
#
# Epoch 42/50 (0.25s)
#   Train Loss: 27.6789
#   Train Cosine Sim: 0.9702
#   Val Loss: 29.4625
#   Val Cosine Sim: 0.9703
#   Val OS24 AUC: 0.6345
#   LR: 2.50e-04
#
# Epoch 43/50 (0.25s)
#   Train Loss: 26.9592
#   Train Cosine Sim: 0.9709
#   Val Loss: 29.8068
#   Val Cosine Sim: 0.9708
#   Val OS24 AUC: 0.6182
#   LR: 2.50e-04
#
# Epoch 44/50 (0.27s)
#   Train Loss: 26.5085
#   Train Cosine Sim: 0.9715
#   Val Loss: 29.1828
#   Val Cosine Sim: 0.9714
#   Val OS24 AUC: 0.6031
#   LR: 2.50e-04
#
# Epoch 45/50 (0.25s)
#   Train Loss: 25.9842
#   Train Cosine Sim: 0.9718
#   Val Loss: 28.0324
#   Val Cosine Sim: 0.9718
#   Val OS24 AUC: 0.6362
#   LR: 2.50e-04
#
# Early stopping triggered after 20 epochs without improvement
# Restored best weights
# Epoch 46/50 (0.25s)
#   Train Loss: 25.5357
#   Train Cosine Sim: 0.9724
#   Val Loss: 27.9798
#   Val Cosine Sim: 0.9724
#   Val OS24 AUC: 0.6040
#   LR: 2.50e-04
#
# Early stopping triggered!
# Training completed!
# Best validation AUC: 0.6606
# Evaluating on test set...
# Loaded best model from epoch 25
#
# Test Results:
# Test Loss: 40.3847
# Test Cosine Sim: 0.9524
# OS24 - AUC: 0.6798, Accuracy: 0.5920, F1: 0.5900
#
# ============================================================
# SKIPPING RECONSTRUCTION EVALUATION
# Use --reconstruction-evaluation flag to enable detailed analysis
# ============================================================
#
# Results saved to: ./results/autoencoder_20250704_160221/autoencoder_20250704_160252

# %%
# !source ~/miniconda3/etc/profile.d/conda.sh && conda activate ABR && python main_autoencoder.py \
    --pkl_files /home/beshoy/CT-FM_features/INT.pkl /home/beshoy/CT-FM_features/LUNG_RADIO_fast.pkl /home/beshoy/CT-FM_features/GHD.pkl /home/beshoy/CT-FM_features/VHIO.pkl /home/beshoy/CT-FM_features/SZMC.pkl \
    --train_test_split_json /home/beshoy/CT-FM_features/train_test_split_w_LR.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 100 \
    --batch_size 128 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 10.0 \ 
    --val_split 0.20 \
    --endpoints os24 \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# Feature validation: kept 1310 patients, excluded 0 patients with NaN features
# Filtered patients: kept 1234, excluded 76 patients missing required endpoints
# Stratification successful with endpoints: ['os24']
# Train samples: 904
# Validation samples: 226
# Test samples: 104
# Creating autoencoder model...
# Model parameters: 6,013,169
# Starting training...
# Starting training for 100 epochs...
# Model type: autoencoder
# Device: cuda
#   New best validation loss: 332.7836
# Epoch 1/100 (0.96s)
#   Train Loss: 329.7264
#   Train Cosine Sim: 0.3489
#   Val Loss: 332.7836
#   Val Cosine Sim: 0.6255
#   Val OS24 AUC: 0.5243
#   LR: 1.00e-03
#
#   New best validation loss: 322.1438
# Epoch 2/100 (0.54s)
#   Train Loss: 308.0706
#   Train Cosine Sim: 0.6727
#   Val Loss: 322.1438
#   Val Cosine Sim: 0.7094
#   Val OS24 AUC: 0.5304
#   LR: 1.00e-03
#
#   New best validation loss: 300.3691
# Epoch 3/100 (0.50s)
#   Train Loss: 286.3739
#   Train Cosine Sim: 0.7196
#   Val Loss: 300.3691
#   Val Cosine Sim: 0.7352
#   Val OS24 AUC: 0.5923
#   LR: 1.00e-03
#
#   New best validation loss: 270.8698
# Epoch 4/100 (0.51s)
#   Train Loss: 265.9397
#   Train Cosine Sim: 0.7426
#   Val Loss: 270.8698
#   Val Cosine Sim: 0.7553
#   Val OS24 AUC: 0.6066
#   LR: 1.00e-03
#
#   New best validation loss: 244.4599
# Epoch 5/100 (0.50s)
#   Train Loss: 245.4940
#   Train Cosine Sim: 0.7627
#   Val Loss: 244.4599
#   Val Cosine Sim: 0.7725
#   Val OS24 AUC: 0.5985
#   LR: 1.00e-03
#
#   New best validation loss: 220.3486
# Epoch 6/100 (0.51s)
#   Train Loss: 224.9282
#   Train Cosine Sim: 0.7786
#   Val Loss: 220.3486
#   Val Cosine Sim: 0.7880
#   Val OS24 AUC: 0.6117
#   LR: 1.00e-03
#
#   New best validation loss: 200.7922
# Epoch 7/100 (0.50s)
#   Train Loss: 203.9888
#   Train Cosine Sim: 0.7940
#   Val Loss: 200.7922
#   Val Cosine Sim: 0.8019
#   Val OS24 AUC: 0.6215
#   LR: 1.00e-03
#
#   New best validation loss: 181.7611
# Epoch 8/100 (0.51s)
#   Train Loss: 185.6262
#   Train Cosine Sim: 0.8079
#   Val Loss: 181.7611
#   Val Cosine Sim: 0.8156
#   Val OS24 AUC: 0.6199
#   LR: 1.00e-03
#
#   New best validation loss: 163.3410
# Epoch 9/100 (0.50s)
#   Train Loss: 168.2811
#   Train Cosine Sim: 0.8216
#   Val Loss: 163.3410
#   Val Cosine Sim: 0.8291
#   Val OS24 AUC: 0.6148
#   LR: 1.00e-03
#
#   New best validation loss: 145.2517
# Epoch 10/100 (0.54s)
#   Train Loss: 152.8141
#   Train Cosine Sim: 0.8338
#   Val Loss: 145.2517
#   Val Cosine Sim: 0.8401
#   Val OS24 AUC: 0.6114
#   LR: 1.00e-03
#
#   New best validation loss: 135.9074
# Epoch 11/100 (0.52s)
#   Train Loss: 139.8938
#   Train Cosine Sim: 0.8447
#   Val Loss: 135.9074
#   Val Cosine Sim: 0.8509
#   Val OS24 AUC: 0.6095
#   LR: 1.00e-03
#
#   New best validation loss: 108.7248
# Epoch 12/100 (0.51s)
#   Train Loss: 129.6084
#   Train Cosine Sim: 0.8555
#   Val Loss: 108.7248
#   Val Cosine Sim: 0.8603
#   Val OS24 AUC: 0.6199
#   LR: 1.00e-03
#
# Epoch 13/100 (0.38s)
#   Train Loss: 121.5346
#   Train Cosine Sim: 0.8627
#   Val Loss: 121.5535
#   Val Cosine Sim: 0.8683
#   Val OS24 AUC: 0.6415
#   LR: 1.00e-03
#
#   New best validation loss: 99.4112
# Epoch 14/100 (0.51s)
#   Train Loss: 110.6860
#   Train Cosine Sim: 0.8719
#   Val Loss: 99.4112
#   Val Cosine Sim: 0.8762
#   Val OS24 AUC: 0.6442
#   LR: 1.00e-03
#
#   New best validation loss: 97.8705
# Epoch 15/100 (0.54s)
#   Train Loss: 103.8209
#   Train Cosine Sim: 0.8790
#   Val Loss: 97.8705
#   Val Cosine Sim: 0.8833
#   Val OS24 AUC: 0.6123
#   LR: 1.00e-03
#
# Epoch 16/100 (0.38s)
#   Train Loss: 96.9743
#   Train Cosine Sim: 0.8866
#   Val Loss: 98.4194
#   Val Cosine Sim: 0.8880
#   Val OS24 AUC: 0.5426
#   LR: 1.00e-03
#
#   New best validation loss: 88.1134
# Epoch 17/100 (0.52s)
#   Train Loss: 90.0967
#   Train Cosine Sim: 0.8923
#   Val Loss: 88.1134
#   Val Cosine Sim: 0.8951
#   Val OS24 AUC: 0.6261
#   LR: 1.00e-03
#
# Epoch 18/100 (0.38s)
#   Train Loss: 86.0090
#   Train Cosine Sim: 0.8980
#   Val Loss: 96.0634
#   Val Cosine Sim: 0.9014
#   Val OS24 AUC: 0.6530
#   LR: 1.00e-03
#
#   New best validation loss: 75.8614
# Epoch 19/100 (0.53s)
#   Train Loss: 81.4867
#   Train Cosine Sim: 0.9028
#   Val Loss: 75.8614
#   Val Cosine Sim: 0.9068
#   Val OS24 AUC: 0.6232
#   LR: 1.00e-03
#
# Epoch 20/100 (0.39s)
#   Train Loss: 76.5749
#   Train Cosine Sim: 0.9079
#   Val Loss: 85.6962
#   Val Cosine Sim: 0.9113
#   Val OS24 AUC: 0.6815
#   LR: 1.00e-03
#
#   New best validation loss: 72.7978
# Epoch 21/100 (0.53s)
#   Train Loss: 76.2131
#   Train Cosine Sim: 0.9131
#   Val Loss: 72.7978
#   Val Cosine Sim: 0.9159
#   Val OS24 AUC: 0.6484
#   LR: 1.00e-03
#
# Epoch 22/100 (0.39s)
#   Train Loss: 74.2898
#   Train Cosine Sim: 0.9169
#   Val Loss: 73.2416
#   Val Cosine Sim: 0.9198
#   Val OS24 AUC: 0.6451
#   LR: 1.00e-03
#
#   New best validation loss: 70.8736
# Epoch 23/100 (0.52s)
#   Train Loss: 66.0102
#   Train Cosine Sim: 0.9217
#   Val Loss: 70.8736
#   Val Cosine Sim: 0.9234
#   Val OS24 AUC: 0.6484
#   LR: 1.00e-03
#
#   New best validation loss: 66.4133
# Epoch 24/100 (0.51s)
#   Train Loss: 64.5027
#   Train Cosine Sim: 0.9250
#   Val Loss: 66.4133
#   Val Cosine Sim: 0.9268
#   Val OS24 AUC: 0.6490
#   LR: 1.00e-03
#
#   New best validation loss: 65.1998
# Epoch 25/100 (0.54s)
#   Train Loss: 60.5079
#   Train Cosine Sim: 0.9287
#   Val Loss: 65.1998
#   Val Cosine Sim: 0.9302
#   Val OS24 AUC: 0.6578
#   LR: 1.00e-03
#
#   New best validation loss: 57.1064
# Epoch 26/100 (0.52s)
#   Train Loss: 58.0900
#   Train Cosine Sim: 0.9320
#   Val Loss: 57.1064
#   Val Cosine Sim: 0.9338
#   Val OS24 AUC: 0.6633
#   LR: 1.00e-03
#
#   New best validation loss: 53.5772
# Epoch 27/100 (0.54s)
#   Train Loss: 56.0789
#   Train Cosine Sim: 0.9341
#   Val Loss: 53.5772
#   Val Cosine Sim: 0.9371
#   Val OS24 AUC: 0.6542
#   LR: 1.00e-03
#
# Epoch 28/100 (0.38s)
#   Train Loss: 52.4622
#   Train Cosine Sim: 0.9388
#   Val Loss: 66.8718
#   Val Cosine Sim: 0.9388
#   Val OS24 AUC: 0.5940
#   LR: 1.00e-03
#
# Epoch 29/100 (0.38s)
#   Train Loss: 52.9097
#   Train Cosine Sim: 0.9416
#   Val Loss: 55.3670
#   Val Cosine Sim: 0.9428
#   Val OS24 AUC: 0.6667
#   LR: 1.00e-03
#
#   New best validation loss: 51.5654
# Epoch 30/100 (0.53s)
#   Train Loss: 48.8277
#   Train Cosine Sim: 0.9445
#   Val Loss: 51.5654
#   Val Cosine Sim: 0.9460
#   Val OS24 AUC: 0.6527
#   LR: 1.00e-03
#
# Epoch 31/100 (0.38s)
#   Train Loss: 48.6951
#   Train Cosine Sim: 0.9466
#   Val Loss: 62.6240
#   Val Cosine Sim: 0.9486
#   Val OS24 AUC: 0.6007
#   LR: 1.00e-03
#
# Epoch 32/100 (0.39s)
#   Train Loss: 46.5402
#   Train Cosine Sim: 0.9498
#   Val Loss: 54.6093
#   Val Cosine Sim: 0.9510
#   Val OS24 AUC: 0.6209
#   LR: 1.00e-03
#
#   New best validation loss: 44.6486
# Epoch 33/100 (0.52s)
#   Train Loss: 44.2419
#   Train Cosine Sim: 0.9521
#   Val Loss: 44.6486
#   Val Cosine Sim: 0.9534
#   Val OS24 AUC: 0.6518
#   LR: 1.00e-03
#
# Epoch 34/100 (0.38s)
#   Train Loss: 42.8303
#   Train Cosine Sim: 0.9547
#   Val Loss: 46.3142
#   Val Cosine Sim: 0.9553
#   Val OS24 AUC: 0.6751
#   LR: 1.00e-03
#
#   New best validation loss: 41.7363
# Epoch 35/100 (0.53s)
#   Train Loss: 42.0574
#   Train Cosine Sim: 0.9564
#   Val Loss: 41.7363
#   Val Cosine Sim: 0.9574
#   Val OS24 AUC: 0.6511
#   LR: 1.00e-03
#
#   New best validation loss: 40.1802
# Epoch 36/100 (0.51s)
#   Train Loss: 39.4156
#   Train Cosine Sim: 0.9587
#   Val Loss: 40.1802
#   Val Cosine Sim: 0.9598
#   Val OS24 AUC: 0.6334
#   LR: 1.00e-03
#
# Epoch 37/100 (0.39s)
#   Train Loss: 38.9521
#   Train Cosine Sim: 0.9608
#   Val Loss: 44.4386
#   Val Cosine Sim: 0.9616
#   Val OS24 AUC: 0.6389
#   LR: 1.00e-03
#
#   New best validation loss: 40.1404
# Epoch 38/100 (0.51s)
#   Train Loss: 37.0592
#   Train Cosine Sim: 0.9623
#   Val Loss: 40.1404
#   Val Cosine Sim: 0.9635
#   Val OS24 AUC: 0.6363
#   LR: 1.00e-03
#
#   New best validation loss: 39.8929
# Epoch 39/100 (0.51s)
#   Train Loss: 36.1869
#   Train Cosine Sim: 0.9648
#   Val Loss: 39.8929
#   Val Cosine Sim: 0.9652
#   Val OS24 AUC: 0.6076
#   LR: 1.00e-03
#
# Epoch 40/100 (0.38s)
#   Train Loss: 33.2420
#   Train Cosine Sim: 0.9663
#   Val Loss: 42.3291
#   Val Cosine Sim: 0.9672
#   Val OS24 AUC: 0.6246
#   LR: 1.00e-03
#
#   New best validation loss: 36.3693
# Epoch 41/100 (0.52s)
#   Train Loss: 32.5614
#   Train Cosine Sim: 0.9669
#   Val Loss: 36.3693
#   Val Cosine Sim: 0.9689
#   Val OS24 AUC: 0.6656
#   LR: 1.00e-03
#
# Epoch 42/100 (0.40s)
#   Train Loss: 33.8315
#   Train Cosine Sim: 0.9699
#   Val Loss: 48.2819
#   Val Cosine Sim: 0.9706
#   Val OS24 AUC: 0.6340
#   LR: 1.00e-03
#
# Epoch 43/100 (0.38s)
#   Train Loss: 29.1320
#   Train Cosine Sim: 0.9715
#   Val Loss: 47.5162
#   Val Cosine Sim: 0.9723
#   Val OS24 AUC: 0.6299
#   LR: 1.00e-03
#
#   New best validation loss: 32.8792
# Epoch 44/100 (0.52s)
#   Train Loss: 28.6679
#   Train Cosine Sim: 0.9729
#   Val Loss: 32.8792
#   Val Cosine Sim: 0.9738
#   Val OS24 AUC: 0.6021
#   LR: 1.00e-03
#
# Epoch 45/100 (0.39s)
#   Train Loss: 27.8098
#   Train Cosine Sim: 0.9745
#   Val Loss: 41.6289
#   Val Cosine Sim: 0.9751
#   Val OS24 AUC: 0.6310
#   LR: 1.00e-03
#
# Epoch 46/100 (0.37s)
#   Train Loss: 27.5378
#   Train Cosine Sim: 0.9759
#   Val Loss: 33.1315
#   Val Cosine Sim: 0.9764
#   Val OS24 AUC: 0.6427
#   LR: 1.00e-03
#
#   New best validation loss: 27.6006
# Epoch 47/100 (0.52s)
#   Train Loss: 26.6452
#   Train Cosine Sim: 0.9765
#   Val Loss: 27.6006
#   Val Cosine Sim: 0.9776
#   Val OS24 AUC: 0.6529
#   LR: 1.00e-03
#
# Epoch 48/100 (0.40s)
#   Train Loss: 25.1808
#   Train Cosine Sim: 0.9781
#   Val Loss: 34.9713
#   Val Cosine Sim: 0.9787
#   Val OS24 AUC: 0.5634
#   LR: 1.00e-03
#
# Epoch 49/100 (0.37s)
#   Train Loss: 25.1403
#   Train Cosine Sim: 0.9791
#   Val Loss: 43.9477
#   Val Cosine Sim: 0.9797
#   Val OS24 AUC: 0.6120
#   LR: 1.00e-03
#
# Epoch 50/100 (0.40s)
#   Train Loss: 22.8042
#   Train Cosine Sim: 0.9803
#   Val Loss: 27.9072
#   Val Cosine Sim: 0.9809
#   Val OS24 AUC: 0.6252
#   LR: 1.00e-03
#
# Epoch 51/100 (0.39s)
#   Train Loss: 22.0633
#   Train Cosine Sim: 0.9816
#   Val Loss: 32.9765
#   Val Cosine Sim: 0.9820
#   Val OS24 AUC: 0.6395
#   LR: 1.00e-03
#
# Epoch 52/100 (0.37s)
#   Train Loss: 21.5069
#   Train Cosine Sim: 0.9827
#   Val Loss: 28.9877
#   Val Cosine Sim: 0.9830
#   Val OS24 AUC: 0.6722
#   LR: 1.00e-03
#
# Epoch 53/100 (0.38s)
#   Train Loss: 21.7064
#   Train Cosine Sim: 0.9834
#   Val Loss: 31.5239
#   Val Cosine Sim: 0.9838
#   Val OS24 AUC: 0.6261
#   LR: 1.00e-03
#
#   New best validation loss: 27.0064
# Epoch 54/100 (0.52s)
#   Train Loss: 20.2411
#   Train Cosine Sim: 0.9842
#   Val Loss: 27.0064
#   Val Cosine Sim: 0.9848
#   Val OS24 AUC: 0.6538
#   LR: 1.00e-03
#
#   New best validation loss: 22.6138
# Epoch 55/100 (0.52s)
#   Train Loss: 19.0611
#   Train Cosine Sim: 0.9850
#   Val Loss: 22.6138
#   Val Cosine Sim: 0.9856
#   Val OS24 AUC: 0.6299
#   LR: 1.00e-03
#
# Epoch 56/100 (0.39s)
#   Train Loss: 18.4216
#   Train Cosine Sim: 0.9857
#   Val Loss: 34.1622
#   Val Cosine Sim: 0.9864
#   Val OS24 AUC: 0.6460
#   LR: 1.00e-03
#
#   New best validation loss: 21.6112
# Epoch 57/100 (0.51s)
#   Train Loss: 18.3807
#   Train Cosine Sim: 0.9861
#   Val Loss: 21.6112
#   Val Cosine Sim: 0.9870
#   Val OS24 AUC: 0.6549
#   LR: 1.00e-03
#
#   New best validation loss: 20.7041
# Epoch 58/100 (0.52s)
#   Train Loss: 19.5316
#   Train Cosine Sim: 0.9872
#   Val Loss: 20.7041
#   Val Cosine Sim: 0.9877
#   Val OS24 AUC: 0.6639
#   LR: 1.00e-03
#
# Epoch 59/100 (0.38s)
#   Train Loss: 16.5232
#   Train Cosine Sim: 0.9881
#   Val Loss: 22.9533
#   Val Cosine Sim: 0.9882
#   Val OS24 AUC: 0.5756
#   LR: 1.00e-03
#
# Epoch 60/100 (0.38s)
#   Train Loss: 16.2542
#   Train Cosine Sim: 0.9880
#   Val Loss: 21.9685
#   Val Cosine Sim: 0.9886
#   Val OS24 AUC: 0.6159
#   LR: 1.00e-03
#
# Epoch 61/100 (0.39s)
#   Train Loss: 15.8898
#   Train Cosine Sim: 0.9891
#   Val Loss: 22.9285
#   Val Cosine Sim: 0.9894
#   Val OS24 AUC: 0.6554
#   LR: 1.00e-03
#
#   New best validation loss: 20.4409
# Epoch 62/100 (0.51s)
#   Train Loss: 15.3516
#   Train Cosine Sim: 0.9896
#   Val Loss: 20.4409
#   Val Cosine Sim: 0.9899
#   Val OS24 AUC: 0.6149
#   LR: 1.00e-03
#
#   New best validation loss: 19.4455
# Epoch 63/100 (0.52s)
#   Train Loss: 14.5408
#   Train Cosine Sim: 0.9902
#   Val Loss: 19.4455
#   Val Cosine Sim: 0.9905
#   Val OS24 AUC: 0.6471
#   LR: 1.00e-03
#
# Epoch 64/100 (0.38s)
#   Train Loss: 14.6687
#   Train Cosine Sim: 0.9905
#   Val Loss: 56.9402
#   Val Cosine Sim: 0.9908
#   Val OS24 AUC: 0.5790
#   LR: 1.00e-03
#
# Epoch 65/100 (0.38s)
#   Train Loss: 13.8849
#   Train Cosine Sim: 0.9912
#   Val Loss: 38.0791
#   Val Cosine Sim: 0.9913
#   Val OS24 AUC: 0.5705
#   LR: 1.00e-03
#
# Epoch 66/100 (0.39s)
#   Train Loss: 14.0919
#   Train Cosine Sim: 0.9913
#   Val Loss: 25.5373
#   Val Cosine Sim: 0.9917
#   Val OS24 AUC: 0.6465
#   LR: 1.00e-03
#
#   New best validation loss: 18.7132
# Epoch 67/100 (0.51s)
#   Train Loss: 14.3522
#   Train Cosine Sim: 0.9918
#   Val Loss: 18.7132
#   Val Cosine Sim: 0.9919
#   Val OS24 AUC: 0.6564
#   LR: 1.00e-03
#
# Epoch 68/100 (0.38s)
#   Train Loss: 14.2710
#   Train Cosine Sim: 0.9920
#   Val Loss: 39.0689
#   Val Cosine Sim: 0.9923
#   Val OS24 AUC: 0.6225
#   LR: 1.00e-03
#
# Epoch 69/100 (0.39s)
#   Train Loss: 12.1406
#   Train Cosine Sim: 0.9923
#   Val Loss: 38.1715
#   Val Cosine Sim: 0.9925
#   Val OS24 AUC: 0.6277
#   LR: 1.00e-03
#
# Epoch 70/100 (0.38s)
#   Train Loss: 12.4407
#   Train Cosine Sim: 0.9926
#   Val Loss: 29.8103
#   Val Cosine Sim: 0.9929
#   Val OS24 AUC: 0.6467
#   LR: 1.00e-03
#
# Epoch 71/100 (0.38s)
#   Train Loss: 12.0549
#   Train Cosine Sim: 0.9930
#   Val Loss: 22.1781
#   Val Cosine Sim: 0.9932
#   Val OS24 AUC: 0.6570
#   LR: 1.00e-03
#
# Epoch 72/100 (0.40s)
#   Train Loss: 11.7216
#   Train Cosine Sim: 0.9933
#   Val Loss: 19.9935
#   Val Cosine Sim: 0.9934
#   Val OS24 AUC: 0.6387
#   LR: 1.00e-03
#
#   New best validation loss: 18.1385
# Epoch 73/100 (0.51s)
#   Train Loss: 10.9875
#   Train Cosine Sim: 0.9931
#   Val Loss: 18.1385
#   Val Cosine Sim: 0.9937
#   Val OS24 AUC: 0.6232
#   LR: 1.00e-03
#
# Epoch 74/100 (0.39s)
#   Train Loss: 11.2713
#   Train Cosine Sim: 0.9933
#   Val Loss: 26.3214
#   Val Cosine Sim: 0.9940
#   Val OS24 AUC: 0.6208
#   LR: 1.00e-03
#
#   New best validation loss: 16.4158
# Epoch 75/100 (0.55s)
#   Train Loss: 11.9216
#   Train Cosine Sim: 0.9932
#   Val Loss: 16.4158
#   Val Cosine Sim: 0.9942
#   Val OS24 AUC: 0.6201
#   LR: 1.00e-03
#
# Epoch 76/100 (0.38s)
#   Train Loss: 11.4689
#   Train Cosine Sim: 0.9940
#   Val Loss: 22.5697
#   Val Cosine Sim: 0.9935
#   Val OS24 AUC: 0.5796
#   LR: 1.00e-03
#
# Epoch 77/100 (0.41s)
#   Train Loss: 11.8877
#   Train Cosine Sim: 0.9946
#   Val Loss: 19.0845
#   Val Cosine Sim: 0.9946
#   Val OS24 AUC: 0.5235
#   LR: 1.00e-03
#
#   New best validation loss: 15.2213
# Epoch 78/100 (0.51s)
#   Train Loss: 10.8460
#   Train Cosine Sim: 0.9948
#   Val Loss: 15.2213
#   Val Cosine Sim: 0.9948
#   Val OS24 AUC: 0.6072
#   LR: 1.00e-03
#
# Epoch 79/100 (0.38s)
#   Train Loss: 10.6556
#   Train Cosine Sim: 0.9946
#   Val Loss: 17.7625
#   Val Cosine Sim: 0.9949
#   Val OS24 AUC: 0.5709
#   LR: 1.00e-03
#
# Epoch 80/100 (0.40s)
#   Train Loss: 10.9929
#   Train Cosine Sim: 0.9950
#   Val Loss: 17.6025
#   Val Cosine Sim: 0.9949
#   Val OS24 AUC: 0.6572
#   LR: 1.00e-03
#
#   New best validation loss: 15.1341
# Epoch 81/100 (0.52s)
#   Train Loss: 10.3547
#   Train Cosine Sim: 0.9950
#   Val Loss: 15.1341
#   Val Cosine Sim: 0.9952
#   Val OS24 AUC: 0.6385
#   LR: 1.00e-03
#
# Epoch 82/100 (0.40s)
#   Train Loss: 9.6643
#   Train Cosine Sim: 0.9953
#   Val Loss: 15.6129
#   Val Cosine Sim: 0.9953
#   Val OS24 AUC: 0.6736
#   LR: 1.00e-03
#
# Epoch 83/100 (0.38s)
#   Train Loss: 9.5424
#   Train Cosine Sim: 0.9953
#   Val Loss: 22.5910
#   Val Cosine Sim: 0.9954
#   Val OS24 AUC: 0.6620
#   LR: 1.00e-03
#
# Epoch 84/100 (0.38s)
#   Train Loss: 10.1049
#   Train Cosine Sim: 0.9948
#   Val Loss: 28.9628
#   Val Cosine Sim: 0.9953
#   Val OS24 AUC: 0.6609
#   LR: 1.00e-03
#
# Epoch 85/100 (0.39s)
#   Train Loss: 8.9347
#   Train Cosine Sim: 0.9953
#   Val Loss: 16.3105
#   Val Cosine Sim: 0.9955
#   Val OS24 AUC: 0.6603
#   LR: 1.00e-03
#
# Epoch 86/100 (0.38s)
#   Train Loss: 9.4942
#   Train Cosine Sim: 0.9953
#   Val Loss: 19.9464
#   Val Cosine Sim: 0.9956
#   Val OS24 AUC: 0.6295
#   LR: 1.00e-03
#
# Epoch 87/100 (0.37s)
#   Train Loss: 8.8709
#   Train Cosine Sim: 0.9951
#   Val Loss: 25.3741
#   Val Cosine Sim: 0.9958
#   Val OS24 AUC: 0.6426
#   LR: 1.00e-03
#
# Epoch 88/100 (0.38s)
#   Train Loss: 8.4153
#   Train Cosine Sim: 0.9957
#   Val Loss: 16.8739
#   Val Cosine Sim: 0.9958
#   Val OS24 AUC: 0.6366
#   LR: 1.00e-03
#
# Epoch 89/100 (0.38s)
#   Train Loss: 8.3967
#   Train Cosine Sim: 0.9958
#   Val Loss: 16.0803
#   Val Cosine Sim: 0.9960
#   Val OS24 AUC: 0.6483
#   LR: 1.00e-03
#
# Epoch 90/100 (0.38s)
#   Train Loss: 9.0523
#   Train Cosine Sim: 0.9961
#   Val Loss: 22.5045
#   Val Cosine Sim: 0.9960
#   Val OS24 AUC: 0.6545
#   LR: 1.00e-03
#
# Epoch 91/100 (0.39s)
#   Train Loss: 8.9045
#   Train Cosine Sim: 0.9960
#   Val Loss: 17.3659
#   Val Cosine Sim: 0.9961
#   Val OS24 AUC: 0.6364
#   LR: 1.00e-03
#
# Epoch 92/100 (0.38s)
#   Train Loss: 10.1452
#   Train Cosine Sim: 0.9957
#   Val Loss: 19.8570
#   Val Cosine Sim: 0.9962
#   Val OS24 AUC: 0.6299
#   LR: 5.00e-04
#
# Epoch 93/100 (0.38s)
#   Train Loss: 10.4387
#   Train Cosine Sim: 0.9955
#   Val Loss: 16.2788
#   Val Cosine Sim: 0.9963
#   Val OS24 AUC: 0.5934
#   LR: 5.00e-04
#
#   New best validation loss: 14.4248
# Epoch 94/100 (0.54s)
#   Train Loss: 8.2760
#   Train Cosine Sim: 0.9962
#   Val Loss: 14.4248
#   Val Cosine Sim: 0.9963
#   Val OS24 AUC: 0.6399
#   LR: 5.00e-04
#
# Epoch 95/100 (0.37s)
#   Train Loss: 7.2826
#   Train Cosine Sim: 0.9962
#   Val Loss: 14.5320
#   Val Cosine Sim: 0.9963
#   Val OS24 AUC: 0.6696
#   LR: 5.00e-04
#
# Epoch 96/100 (0.37s)
#   Train Loss: 7.1365
#   Train Cosine Sim: 0.9961
#   Val Loss: 26.2300
#   Val Cosine Sim: 0.9963
#   Val OS24 AUC: 0.6422
#   LR: 5.00e-04
#
# Epoch 97/100 (0.40s)
#   Train Loss: 8.4769
#   Train Cosine Sim: 0.9960
#   Val Loss: 15.7093
#   Val Cosine Sim: 0.9963
#   Val OS24 AUC: 0.6407
#   LR: 5.00e-04
#
# Epoch 98/100 (0.38s)
#   Train Loss: 7.1899
#   Train Cosine Sim: 0.9963
#   Val Loss: 24.7556
#   Val Cosine Sim: 0.9964
#   Val OS24 AUC: 0.6196
#   LR: 5.00e-04
#
# Epoch 99/100 (0.38s)
#   Train Loss: 9.1420
#   Train Cosine Sim: 0.9961
#   Val Loss: 18.4511
#   Val Cosine Sim: 0.9964
#   Val OS24 AUC: 0.6484
#   LR: 5.00e-04
#
# Epoch 100/100 (0.39s)
#   Train Loss: 7.0146
#   Train Cosine Sim: 0.9963
#   Val Loss: 15.8784
#   Val Cosine Sim: 0.9964
#   Val OS24 AUC: 0.6287
#   LR: 5.00e-04
#
# Training completed!
# Best validation loss: 14.4248
# Evaluating on test set...
# Loaded best model from epoch 93
#
# Test Results:
# Test Loss: 15.3627
# Test Cosine Sim: 0.9962
# OS24 - AUC: 0.4770, Accuracy: 0.6154, F1: 0.2593
#
# ============================================================
# SKIPPING RECONSTRUCTION EVALUATION
# Use --reconstruction-evaluation flag to enable detailed analysis
# ============================================================
#
# Results saved to: ./results/autoencoder_20250704_175430/autoencoder_20250704_175505

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/LUNG_RADIO_fast.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split_w_LR.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)

# %%
# !source ~/miniconda3/etc/profile.d/conda.sh && conda activate ABR && python main_autoencoder.py \
    --pkl_files /home/beshoy/CT-FM_features/OLD/VHIO_w_TNM.pkl /home/beshoy/CT-FM_features/OLD/INT_w_TNM.pkl /home/beshoy/CT-FM_features/OLD/GHD_w_TNM.pkl /home/beshoy/CT-FM_features/OLD/SZMC_w_TNM.pkl \
    --train_test_split_json /home/beshoy/CT-FM_features/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 128 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 3.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# ^C
# Traceback (most recent call last):
#   File "/home/beshoy/code-projects/Attention_based_reduction/main_autoencoder.py", line 244, in <module>
#     main()
#   File "/home/beshoy/code-projects/Attention_based_reduction/main_autoencoder.py", line 65, in main
#     train_loader, val_loader, test_loader, class_weights = create_data_loaders(
#                                                            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/beshoy/code-projects/Attention_based_reduction/utils/dataloader.py", line 532, in create_data_loaders
#     all_data = load_pkl_files(pkl_files)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/beshoy/code-projects/Attention_based_reduction/utils/dataloader.py", line 166, in load_pkl_files
#     center_data = pickle.load(f)
#                   ^^^^^^^^^^^^^^
#   File "/home/beshoy/miniconda3/envs/ABR/lib/python3.11/site-packages/torch/storage.py", line 530, in _load_from_bytes
#     return torch.load(io.BytesIO(b), weights_only=False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/beshoy/miniconda3/envs/ABR/lib/python3.11/site-packages/torch/serialization.py", line 1472, in load
#     mmap = config.load.mmap
#            ^^^^^^^^^^^^^^^^
#   File "/home/beshoy/miniconda3/envs/ABR/lib/python3.11/site-packages/torch/utils/_config_module.py", line 775, in __getattr__
#     return self._config.__getattr__(self._prefix + name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/beshoy/miniconda3/envs/ABR/lib/python3.11/site-packages/torch/utils/_config_module.py", line 376, in __getattr__
#     alias_val = self._get_alias_val(config)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/beshoy/miniconda3/envs/ABR/lib/python3.11/site-packages/torch/utils/_config_module.py", line 425, in _get_alias_val
#     def _get_alias_val(self, entry: _ConfigEntry) -> Any:
#
# KeyboardInterrupt

# %%
# !source ~/miniconda3/etc/profile.d/conda.sh && conda activate ABR && python main_autoencoder.py \
    --pkl_files /home/beshoy/CT-FM_features/VHIO.pkl /home/beshoy/CT-FM_features/INT.pkl /home/beshoy/CT-FM_features/GHD.pkl /home/beshoy/CT-FM_features/SZMC.pkl \
    --train_test_split_json /home/beshoy/CT-FM_features/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 3.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# Filtered patients: kept 693, excluded 64 patients missing required endpoints
# Stratification successful with endpoints: ['os24']
# Train samples: 471
# Validation samples: 118
# Test samples: 104
# Creating autoencoder model...
# Model parameters: 5,930,993
# Starting training...
# Starting training for 50 epochs...
# Model type: autoencoder
# Device: cuda
#   New best validation AUC: 0.5042
# Epoch 1/50 (0.67s)
#   Train Loss: 322.3872
#   Train Cosine Sim: 0.3496
#   Val Loss: 323.7358
#   Val Cosine Sim: 0.6297
#   Val OS24 AUC: 0.5042
#   LR: 1.00e-03
#
#   New best validation AUC: 0.5151
# Epoch 2/50 (0.30s)
#   Train Loss: 301.1518
#   Train Cosine Sim: 0.6673
#   Val Loss: 314.0607
#   Val Cosine Sim: 0.7046
#   Val OS24 AUC: 0.5151
#   LR: 1.00e-03
#
#   New best validation AUC: 0.5736
# Epoch 3/50 (0.30s)
#   Train Loss: 281.1984
#   Train Cosine Sim: 0.7167
#   Val Loss: 297.9332
#   Val Cosine Sim: 0.7329
#   Val OS24 AUC: 0.5736
#   LR: 1.00e-03
#
# Epoch 4/50 (0.16s)
#   Train Loss: 263.5110
#   Train Cosine Sim: 0.7420
#   Val Loss: 276.2821
#   Val Cosine Sim: 0.7552
#   Val OS24 AUC: 0.4979
#   LR: 1.00e-03
#
# Epoch 5/50 (0.16s)
#   Train Loss: 245.1951
#   Train Cosine Sim: 0.7626
#   Val Loss: 238.7086
#   Val Cosine Sim: 0.7736
#   Val OS24 AUC: 0.5443
#   LR: 1.00e-03
#
# Epoch 6/50 (0.16s)
#   Train Loss: 225.4213
#   Train Cosine Sim: 0.7797
#   Val Loss: 208.4716
#   Val Cosine Sim: 0.7890
#   Val OS24 AUC: 0.5008
#   LR: 1.00e-03
#
# Epoch 7/50 (0.16s)
#   Train Loss: 205.2599
#   Train Cosine Sim: 0.7948
#   Val Loss: 178.6708
#   Val Cosine Sim: 0.8033
#   Val OS24 AUC: 0.4795
#   LR: 1.00e-03
#
# Epoch 8/50 (0.16s)
#   Train Loss: 184.5084
#   Train Cosine Sim: 0.8082
#   Val Loss: 163.5844
#   Val Cosine Sim: 0.8157
#   Val OS24 AUC: 0.4707
#   LR: 1.00e-03
#
# Epoch 9/50 (0.16s)
#   Train Loss: 165.4636
#   Train Cosine Sim: 0.8215
#   Val Loss: 155.9344
#   Val Cosine Sim: 0.8287
#   Val OS24 AUC: 0.5021
#   LR: 1.00e-03
#
#   New best validation AUC: 0.5844
# Epoch 10/50 (0.30s)
#   Train Loss: 148.8604
#   Train Cosine Sim: 0.8339
#   Val Loss: 147.2719
#   Val Cosine Sim: 0.8402
#   Val OS24 AUC: 0.5844
#   LR: 1.00e-03
#
# Epoch 11/50 (0.16s)
#   Train Loss: 134.0156
#   Train Cosine Sim: 0.8450
#   Val Loss: 138.1963
#   Val Cosine Sim: 0.8514
#   Val OS24 AUC: 0.5715
#   LR: 1.00e-03
#
# Epoch 12/50 (0.16s)
#   Train Loss: 122.7367
#   Train Cosine Sim: 0.8555
#   Val Loss: 112.9788
#   Val Cosine Sim: 0.8612
#   Val OS24 AUC: 0.5171
#   LR: 1.00e-03
#
# Epoch 13/50 (0.15s)
#   Train Loss: 115.0751
#   Train Cosine Sim: 0.8654
#   Val Loss: 106.3164
#   Val Cosine Sim: 0.8698
#   Val OS24 AUC: 0.5577
#   LR: 1.00e-03
#
# Epoch 14/50 (0.15s)
#   Train Loss: 102.6410
#   Train Cosine Sim: 0.8735
#   Val Loss: 100.8921
#   Val Cosine Sim: 0.8783
#   Val OS24 AUC: 0.5589
#   LR: 1.00e-03
#
# Epoch 15/50 (0.15s)
#   Train Loss: 96.1390
#   Train Cosine Sim: 0.8819
#   Val Loss: 89.2324
#   Val Cosine Sim: 0.8862
#   Val OS24 AUC: 0.5594
#   LR: 1.00e-03
#
# Epoch 16/50 (0.15s)
#   Train Loss: 88.4557
#   Train Cosine Sim: 0.8893
#   Val Loss: 81.7696
#   Val Cosine Sim: 0.8931
#   Val OS24 AUC: 0.5707
#   LR: 1.00e-03
#
#   New best validation AUC: 0.5995
# Epoch 17/50 (0.30s)
#   Train Loss: 80.3046
#   Train Cosine Sim: 0.8957
#   Val Loss: 73.4717
#   Val Cosine Sim: 0.8990
#   Val OS24 AUC: 0.5995
#   LR: 1.00e-03
#
# Epoch 18/50 (0.16s)
#   Train Loss: 74.7609
#   Train Cosine Sim: 0.9020
#   Val Loss: 73.6174
#   Val Cosine Sim: 0.9052
#   Val OS24 AUC: 0.5803
#   LR: 1.00e-03
#
# Epoch 19/50 (0.16s)
#   Train Loss: 69.5404
#   Train Cosine Sim: 0.9081
#   Val Loss: 68.0083
#   Val Cosine Sim: 0.9113
#   Val OS24 AUC: 0.4845
#   LR: 1.00e-03
#
# Epoch 20/50 (0.16s)
#   Train Loss: 66.1317
#   Train Cosine Sim: 0.9134
#   Val Loss: 65.3281
#   Val Cosine Sim: 0.9165
#   Val OS24 AUC: 0.4582
#   LR: 1.00e-03
#
# Epoch 21/50 (0.16s)
#   Train Loss: 63.0076
#   Train Cosine Sim: 0.9184
#   Val Loss: 60.4878
#   Val Cosine Sim: 0.9210
#   Val OS24 AUC: 0.5000
#   LR: 1.00e-03
#
# Epoch 22/50 (0.16s)
#   Train Loss: 58.0427
#   Train Cosine Sim: 0.9231
#   Val Loss: 57.0650
#   Val Cosine Sim: 0.9254
#   Val OS24 AUC: 0.4900
#   LR: 1.00e-03
#
# Epoch 23/50 (0.16s)
#   Train Loss: 57.3184
#   Train Cosine Sim: 0.9275
#   Val Loss: 54.2938
#   Val Cosine Sim: 0.9298
#   Val OS24 AUC: 0.5443
#   LR: 1.00e-03
#
# Epoch 24/50 (0.15s)
#   Train Loss: 53.3418
#   Train Cosine Sim: 0.9316
#   Val Loss: 54.1579
#   Val Cosine Sim: 0.9335
#   Val OS24 AUC: 0.4854
#   LR: 1.00e-03
#
# Epoch 25/50 (0.15s)
#   Train Loss: 50.7480
#   Train Cosine Sim: 0.9350
#   Val Loss: 48.1075
#   Val Cosine Sim: 0.9366
#   Val OS24 AUC: 0.5146
#   LR: 1.00e-03
#
# Epoch 26/50 (0.15s)
#   Train Loss: 47.9812
#   Train Cosine Sim: 0.9385
#   Val Loss: 46.3449
#   Val Cosine Sim: 0.9401
#   Val OS24 AUC: 0.4849
#   LR: 1.00e-03
#
# Epoch 27/50 (0.15s)
#   Train Loss: 44.7915
#   Train Cosine Sim: 0.9416
#   Val Loss: 44.7261
#   Val Cosine Sim: 0.9432
#   Val OS24 AUC: 0.5130
#   LR: 1.00e-03
#
# Epoch 28/50 (0.15s)
#   Train Loss: 43.0374
#   Train Cosine Sim: 0.9449
#   Val Loss: 43.4866
#   Val Cosine Sim: 0.9467
#   Val OS24 AUC: 0.5347
#   LR: 5.00e-04
#
# Epoch 29/50 (0.15s)
#   Train Loss: 41.5986
#   Train Cosine Sim: 0.9476
#   Val Loss: 41.6441
#   Val Cosine Sim: 0.9482
#   Val OS24 AUC: 0.4933
#   LR: 5.00e-04
#
# Epoch 30/50 (0.15s)
#   Train Loss: 41.0889
#   Train Cosine Sim: 0.9491
#   Val Loss: 40.7329
#   Val Cosine Sim: 0.9495
#   Val OS24 AUC: 0.4590
#   LR: 5.00e-04
#
# Epoch 31/50 (0.15s)
#   Train Loss: 39.5696
#   Train Cosine Sim: 0.9501
#   Val Loss: 38.8808
#   Val Cosine Sim: 0.9510
#   Val OS24 AUC: 0.4716
#   LR: 5.00e-04
#
# Epoch 32/50 (0.15s)
#   Train Loss: 39.7848
#   Train Cosine Sim: 0.9519
#   Val Loss: 38.3921
#   Val Cosine Sim: 0.9526
#   Val OS24 AUC: 0.4854
#   LR: 5.00e-04
#
# Epoch 33/50 (0.15s)
#   Train Loss: 37.6981
#   Train Cosine Sim: 0.9536
#   Val Loss: 37.7321
#   Val Cosine Sim: 0.9541
#   Val OS24 AUC: 0.5192
#   LR: 5.00e-04
#
# Epoch 34/50 (0.15s)
#   Train Loss: 37.6516
#   Train Cosine Sim: 0.9548
#   Val Loss: 36.9610
#   Val Cosine Sim: 0.9553
#   Val OS24 AUC: 0.4703
#   LR: 5.00e-04
#
# Epoch 35/50 (0.15s)
#   Train Loss: 35.6562
#   Train Cosine Sim: 0.9561
#   Val Loss: 35.9010
#   Val Cosine Sim: 0.9568
#   Val OS24 AUC: 0.5155
#   LR: 5.00e-04
#
# Epoch 36/50 (0.15s)
#   Train Loss: 35.5081
#   Train Cosine Sim: 0.9570
#   Val Loss: 34.8938
#   Val Cosine Sim: 0.9578
#   Val OS24 AUC: 0.4557
#   LR: 5.00e-04
#
# Early stopping triggered after 20 epochs without improvement
# Restored best weights
# Epoch 37/50 (0.15s)
#   Train Loss: 33.1932
#   Train Cosine Sim: 0.9581
#   Val Loss: 33.5506
#   Val Cosine Sim: 0.9590
#   Val OS24 AUC: 0.5347
#   LR: 5.00e-04
#
# Early stopping triggered!
# Training completed!
# Best validation AUC: 0.5995
# Evaluating on test set...
# Loaded best model from epoch 16
#
# Test Results:
# Test Loss: 72.4081
# Test Cosine Sim: 0.9008
# OS24 - AUC: 0.4851, Accuracy: 0.7596, F1: 0.0000
#
# ============================================================
# SKIPPING RECONSTRUCTION EVALUATION
# Use --reconstruction-evaluation flag to enable detailed analysis
# ============================================================
#
# Results saved to: ./results/autoencoder_20250704_154032/autoencoder_20250704_154052

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && unset MPLBACKEND && python analyze_reconstruction.py \
    --model_path /share/project10/home/prelajarsela/Attention_based_reduction/gridsearch_results_FINAL/gridsearch_autoencoder_20250624_225515/combo_504/best_model.pth \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --attention_k 11 \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --endpoints os24

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/LUNG_RADIO_fast.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 11 \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 8.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python extract_features.py \
    --model_path /share/project10/home/prelajarsela/Attention_based_reduction/gridsearch_results_FINAL/gridsearch_autoencoder_20250624_225515/combo_504/best_model.pth \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --output_csv /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/I3LUNG_reduced_features_BEST.csv \
    --attention_k 11 \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --endpoints os24

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 3.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints os6 \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 100 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints stage_t \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
#   New best validation loss: 21.3605
# Epoch 86/100 (0.81s)
#   Train Loss: 22.1671
#   Train Cosine Sim: 0.9883
#   Val Loss: 21.3605
#   Val Cosine Sim: 0.9891
#   Val STAGE_T Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 20.8089
# Epoch 87/100 (0.85s)
#   Train Loss: 22.4138
#   Train Cosine Sim: 0.9885
#   Val Loss: 20.8089
#   Val Cosine Sim: 0.9891
#   Val STAGE_T Acc: 0.2927
#   LR: 1.00e-03
#
#   New best validation loss: 20.5409
# Epoch 88/100 (0.88s)
#   Train Loss: 22.0745
#   Train Cosine Sim: 0.9890
#   Val Loss: 20.5409
#   Val Cosine Sim: 0.9892
#   Val STAGE_T Acc: 0.2927
#   LR: 1.00e-03
#
#   New best validation loss: 20.2977
# Epoch 89/100 (0.87s)
#   Train Loss: 21.2613
#   Train Cosine Sim: 0.9889
#   Val Loss: 20.2977
#   Val Cosine Sim: 0.9894
#   Val STAGE_T Acc: 0.2276
#   LR: 1.00e-03
#
#   New best validation loss: 20.1453
# Epoch 90/100 (0.89s)
#   Train Loss: 21.0994
#   Train Cosine Sim: 0.9891
#   Val Loss: 20.1453
#   Val Cosine Sim: 0.9898
#   Val STAGE_T Acc: 0.3171
#   LR: 1.00e-03
#
#   New best validation loss: 20.1342
# Epoch 91/100 (0.90s)
#   Train Loss: 21.7701
#   Train Cosine Sim: 0.9889
#   Val Loss: 20.1342
#   Val Cosine Sim: 0.9900
#   Val STAGE_T Acc: 0.3089
#   LR: 1.00e-03
#
# Epoch 92/100 (0.68s)
#   Train Loss: 21.1688
#   Train Cosine Sim: 0.9900
#   Val Loss: 20.7398
#   Val Cosine Sim: 0.9899
#   Val STAGE_T Acc: 0.2846
#   LR: 1.00e-03
#
# Epoch 93/100 (0.64s)
#   Train Loss: 20.6704
#   Train Cosine Sim: 0.9896
#   Val Loss: 20.4035
#   Val Cosine Sim: 0.9902
#   Val STAGE_T Acc: 0.3252
#   LR: 1.00e-03
#
# Epoch 94/100 (0.57s)
#   Train Loss: 21.0145
#   Train Cosine Sim: 0.9894
#   Val Loss: 20.3691
#   Val Cosine Sim: 0.9904
#   Val STAGE_T Acc: 0.3089
#   LR: 1.00e-03
#
# Epoch 95/100 (0.55s)
#   Train Loss: 20.1779
#   Train Cosine Sim: 0.9904
#   Val Loss: 20.2663
#   Val Cosine Sim: 0.9904
#   Val STAGE_T Acc: 0.2927
#   LR: 1.00e-03
#
#   New best validation loss: 19.6831
# Epoch 96/100 (0.73s)
#   Train Loss: 20.6671
#   Train Cosine Sim: 0.9898
#   Val Loss: 19.6831
#   Val Cosine Sim: 0.9907
#   Val STAGE_T Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 19.4256
# Epoch 97/100 (0.75s)
#   Train Loss: 20.4275
#   Train Cosine Sim: 0.9904
#   Val Loss: 19.4256
#   Val Cosine Sim: 0.9908
#   Val STAGE_T Acc: 0.3089
#   LR: 1.00e-03
#
# Epoch 98/100 (0.61s)
#   Train Loss: 20.1955
#   Train Cosine Sim: 0.9903
#   Val Loss: 19.5671
#   Val Cosine Sim: 0.9908
#   Val STAGE_T Acc: 0.3496
#   LR: 1.00e-03
#
# Epoch 99/100 (0.59s)
#   Train Loss: 20.2512
#   Train Cosine Sim: 0.9908
#   Val Loss: 19.5603
#   Val Cosine Sim: 0.9910
#   Val STAGE_T Acc: 0.3496
#   LR: 1.00e-03
#
# Epoch 100/100 (0.60s)
#   Train Loss: 20.3002
#   Train Cosine Sim: 0.9904
#   Val Loss: 19.4392
#   Val Cosine Sim: 0.9910
#   Val STAGE_T Acc: 0.3496
#   LR: 1.00e-03
#
# Training completed!
# Best validation loss: 19.4256
# Evaluating on test set...
# Loaded best model from epoch 96
#
# Test Results:
# Test Loss: 18.8398
# Test Cosine Sim: 0.9913
# STAGE_T - Accuracy: 0.3178, F1: 0.2944
#
# Results saved to: ./results/autoencoder_20250625_100550/autoencoder_20250625_100618

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 100 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints stage_n \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Epoch 86/100 (0.63s)
#   Train Loss: 11.8773
#   Train Cosine Sim: 0.9885
#   Val Loss: 10.9117
#   Val Cosine Sim: 0.9893
#   Val STAGE_N Acc: 0.3496
#   LR: 1.00e-03
#
# Epoch 87/100 (0.60s)
#   Train Loss: 11.6764
#   Train Cosine Sim: 0.9891
#   Val Loss: 10.9410
#   Val Cosine Sim: 0.9896
#   Val STAGE_N Acc: 0.3171
#   LR: 1.00e-03
#
#   New best validation loss: 10.5343
# Epoch 88/100 (0.84s)
#   Train Loss: 11.7410
#   Train Cosine Sim: 0.9894
#   Val Loss: 10.5343
#   Val Cosine Sim: 0.9899
#   Val STAGE_N Acc: 0.3333
#   LR: 1.00e-03
#
#   New best validation loss: 10.3985
# Epoch 89/100 (0.80s)
#   Train Loss: 12.0606
#   Train Cosine Sim: 0.9897
#   Val Loss: 10.3985
#   Val Cosine Sim: 0.9900
#   Val STAGE_N Acc: 0.3089
#   LR: 1.00e-03
#
#   New best validation loss: 10.0173
# Epoch 90/100 (0.84s)
#   Train Loss: 11.3113
#   Train Cosine Sim: 0.9897
#   Val Loss: 10.0173
#   Val Cosine Sim: 0.9901
#   Val STAGE_N Acc: 0.3659
#   LR: 1.00e-03
#
#   New best validation loss: 9.4610
# Epoch 91/100 (0.83s)
#   Train Loss: 10.7753
#   Train Cosine Sim: 0.9900
#   Val Loss: 9.4610
#   Val Cosine Sim: 0.9903
#   Val STAGE_N Acc: 0.3659
#   LR: 1.00e-03
#
# Epoch 92/100 (0.65s)
#   Train Loss: 10.8333
#   Train Cosine Sim: 0.9895
#   Val Loss: 9.4972
#   Val Cosine Sim: 0.9905
#   Val STAGE_N Acc: 0.3659
#   LR: 1.00e-03
#
# Epoch 93/100 (0.58s)
#   Train Loss: 10.9805
#   Train Cosine Sim: 0.9896
#   Val Loss: 9.7830
#   Val Cosine Sim: 0.9906
#   Val STAGE_N Acc: 0.3008
#   LR: 1.00e-03
#
# Epoch 94/100 (0.53s)
#   Train Loss: 10.9263
#   Train Cosine Sim: 0.9899
#   Val Loss: 9.5337
#   Val Cosine Sim: 0.9907
#   Val STAGE_N Acc: 0.3089
#   LR: 1.00e-03
#
# Epoch 95/100 (0.51s)
#   Train Loss: 10.5855
#   Train Cosine Sim: 0.9903
#   Val Loss: 10.3381
#   Val Cosine Sim: 0.9904
#   Val STAGE_N Acc: 0.3902
#   LR: 1.00e-03
#
# Epoch 96/100 (0.49s)
#   Train Loss: 11.1717
#   Train Cosine Sim: 0.9902
#   Val Loss: 9.9072
#   Val Cosine Sim: 0.9906
#   Val STAGE_N Acc: 0.3984
#   LR: 1.00e-03
#
# Epoch 97/100 (0.57s)
#   Train Loss: 10.5197
#   Train Cosine Sim: 0.9900
#   Val Loss: 9.5580
#   Val Cosine Sim: 0.9906
#   Val STAGE_N Acc: 0.3496
#   LR: 1.00e-03
#
# Epoch 98/100 (0.52s)
#   Train Loss: 10.1595
#   Train Cosine Sim: 0.9904
#   Val Loss: 9.6121
#   Val Cosine Sim: 0.9908
#   Val STAGE_N Acc: 0.3821
#   LR: 1.00e-03
#
#   New best validation loss: 9.3549
# Epoch 99/100 (0.68s)
#   Train Loss: 10.1090
#   Train Cosine Sim: 0.9906
#   Val Loss: 9.3549
#   Val Cosine Sim: 0.9909
#   Val STAGE_N Acc: 0.3902
#   LR: 1.00e-03
#
# Epoch 100/100 (0.53s)
#   Train Loss: 11.0742
#   Train Cosine Sim: 0.9903
#   Val Loss: 9.4456
#   Val Cosine Sim: 0.9911
#   Val STAGE_N Acc: 0.4228
#   LR: 1.00e-03
#
# Training completed!
# Best validation loss: 9.3549
# Evaluating on test set...
# Loaded best model from epoch 98
#
# Test Results:
# Test Loss: 9.0437
# Test Cosine Sim: 0.9914
# STAGE_N - Accuracy: 0.3364, F1: 0.3086
#
# Results saved to: ./results/autoencoder_20250625_100744/autoencoder_20250625_100811

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 100 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints stage_m \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python gridsearch.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --endpoints os24 \
    --model_type autoencoder \
    --save_dir ./gridsearch_results
# Out:
#   New best validation loss: 274.5007
# Epoch 32/50 (0.37s)
#   Train Loss: 254.1179
#   Train Cosine Sim: 0.7346
#   Val Loss: 274.5007
#   Val Cosine Sim: 0.7409
#   Val OS24 AUC: 0.5698
#   LR: 1.00e-04
#
#   New best validation loss: 271.8943
# Epoch 33/50 (0.36s)
#   Train Loss: 251.6065
#   Train Cosine Sim: 0.7369
#   Val Loss: 271.8943
#   Val Cosine Sim: 0.7427
#   Val OS24 AUC: 0.5656
#   LR: 1.00e-04
#
#   New best validation loss: 271.1156
# Epoch 34/50 (0.37s)
#   Train Loss: 249.4521
#   Train Cosine Sim: 0.7386
#   Val Loss: 271.1156
#   Val Cosine Sim: 0.7447
#   Val OS24 AUC: 0.5648
#   LR: 1.00e-04
#
# ^C
# Traceback (most recent call last):
#   File "/share/project10/home/prelajarsela/Attention_based_reduction/gridsearch.py", line 346, in <module>
#     main()
#   File "/share/project10/home/prelajarsela/Attention_based_reduction/gridsearch.py", line 332, in main
#     results_df = grid_search.run_search(max_epochs=50)  # Shorter epochs for grid search
#   File "/share/project10/home/prelajarsela/Attention_based_reduction/gridsearch.py", line 125, in run_search
#     history = train_model(
#   File "/share/project10/home/prelajarsela/Attention_based_reduction/utils/train_loop.py", line 424, in train_model
#     val_losses, val_metrics = evaluate_model(
#   File "/share/project10/home/prelajarsela/Attention_based_reduction/utils/train_loop.py", line 217, in evaluate_model
#     for batch in dataloader:
#   File "/share/project10/home/prelajarsela/.conda/envs/ABR/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 733, in __next__
#     data = self._next_data()
#   File "/share/project10/home/prelajarsela/.conda/envs/ABR/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 789, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/share/project10/home/prelajarsela/.conda/envs/ABR/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 52, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/share/project10/home/prelajarsela/.conda/envs/ABR/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 52, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/share/project10/home/prelajarsela/Attention_based_reduction/utils/dataloader.py", line 71, in __getitem__
#     features = torch.stack(patient['features'])  # Shape: (176, 512)
# KeyboardInterrupt

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 11 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 100 \
    --batch_size 128 \
    --learning_rate 1e-2 \
    --weight_decay 1e-3 \
    --reconstruction_weight 1.0 \
    --prediction_weight 4.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 100 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 4.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 44 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 100 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 4.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)

# %% [markdown]
# # ML Prediction from Reduced Features
#
# ## This notebook predicts clinical endpoints from autoencoder-extracted features using scikit-learn.
#
# ## Configuration

# %%
# CONFIGURATION - CHANGE THESE
TARGET_ENDPOINT = 'OS_6'  # Options: 'OS_6', 'OS_24', 'STAGE_T', 'STAGE_N', 'STAGE_M'
FEATURES_CSV = '/share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/I3LUNG_reduced_features_AUC_sel.csv' #'/share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/I3LUNG_reduced_features.csv'
TRAIN_TEST_JSON = '/share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json'
VAL_SPLIT = 0.2

print(f"Target endpoint: {TARGET_ENDPOINT}")

# %% [markdown]
# ## Imports and Setup

# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score, accuracy_score, roc_curve, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
def load_data(csv_path: str, train_test_json: str):
    """Load features and apply train/test split"""
    # Load features
    df = pd.read_csv(csv_path)
    print(f"Loaded {len(df)} patients with {len([c for c in df.columns if c.startswith('feature_')])} features")
    
    # Load train/test split
    with open(train_test_json, 'r') as f:
        split_data = json.load(f)
    
    # Filter for target endpoint availability
    df = df.dropna(subset=[TARGET_ENDPOINT])
    print(f"After filtering for {TARGET_ENDPOINT}: {len(df)} patients")
    
    # Apply train/test split
    train_subjects = set(split_data['TRAIN_SET'])
    test_subjects = set(split_data['TEST_SET'])
    
    train_df = df[df['Subject'].isin(train_subjects)].copy()
    test_df = df[df['Subject'].isin(test_subjects)].copy()
    
    return train_df, test_df

def stratified_split_by_center(train_df, test_size=0.2):
    """Split train into train/val with center stratification"""
    strat_labels = []
    for _, row in train_df.iterrows():
        center = row['Center']
        label = int(row[TARGET_ENDPOINT])
        if TARGET_ENDPOINT in ['STAGE_T', 'STAGE_N']:
            label = int(label > 0)
        strat_labels.append(f"{center}_{label}")
    
    try:
        train_idx, val_idx = train_test_split(
            range(len(train_df)), test_size=test_size, 
            stratify=strat_labels, random_state=42
        )
        print("Using stratified split by center and label")
    except ValueError:
        train_idx, val_idx = train_test_split(
            range(len(train_df)), test_size=test_size, random_state=42
        )
        print("Using random split (stratification failed)")
    
    return train_df.iloc[train_idx], train_df.iloc[val_idx]

def prepare_features(df):
    """Extract features and targets"""
    feature_cols = [col for col in df.columns if col.startswith('feature_')]
    X = df[feature_cols].values
    y = df[TARGET_ENDPOINT].values
    
    # Convert to binary for staging endpoints
    if TARGET_ENDPOINT in ['STAGE_T', 'STAGE_N']:
        y = (y > 0).astype(int)
    
    return X, y.astype(int)

# Load and split data
train_df, test_df = load_data(FEATURES_CSV, TRAIN_TEST_JSON)
train_df, val_df = stratified_split_by_center(train_df, VAL_SPLIT)

print(f"\nDataset sizes:")
print(f"  Train: {len(train_df)}")
print(f"  Val: {len(val_df)}")
print(f"  Test: {len(test_df)}")

# %% [markdown]
# ## Feature Preparation and EDA

# %%
# Prepare features
X_train, y_train = prepare_features(train_df)
X_val, y_val = prepare_features(val_df)
X_test, y_test = prepare_features(test_df)

print(f"Feature dimensions: {X_train.shape[1]}")
print(f"Class distributions:")
print(f"  Train: {np.bincount(y_train)} (class 0: {np.bincount(y_train)[0]}, class 1: {np.bincount(y_train)[1]})")
print(f"  Val: {np.bincount(y_val)} (class 0: {np.bincount(y_val)[0]}, class 1: {np.bincount(y_val)[1]})")
print(f"  Test: {np.bincount(y_test)} (class 0: {np.bincount(y_test)[0]}, class 1: {np.bincount(y_test)[1]})")

# %%
# Visualize class distribution
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
datasets = [('Train', y_train), ('Val', y_val), ('Test', y_test)]

for i, (name, y) in enumerate(datasets):
    counts = np.bincount(y)
    axes[i].bar(['Class 0', 'Class 1'], counts, alpha=0.7)
    axes[i].set_title(f'{name} Set - {TARGET_ENDPOINT}')
    axes[i].set_ylabel('Count')
    for j, count in enumerate(counts):
        axes[i].text(j, count + 0.5, str(count), ha='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model Definition and Grid Search

# %%
def remove_correlated_features(X_train, X_val, X_test, threshold=0.95):
    """Remove highly correlated features using Spearman correlation"""
    from scipy.stats import spearmanr
    
    # Calculate Spearman correlation matrix
    corr_matrix = np.abs(spearmanr(X_train).correlation)
    
    # Find features to remove
    upper_tri = np.triu(np.ones_like(corr_matrix, dtype=bool), k=1)
    high_corr_pairs = np.where((corr_matrix > threshold) & upper_tri)
    features_to_remove = set()
    
    for i, j in zip(high_corr_pairs[0], high_corr_pairs[1]):
        # Remove the feature with lower variance
        if np.var(X_train[:, i]) < np.var(X_train[:, j]):
            features_to_remove.add(i)
        else:
            features_to_remove.add(j)
    
    # Keep features
    keep_features = [i for i in range(X_train.shape[1]) if i not in features_to_remove]
    
    print(f"Removed {len(features_to_remove)} highly correlated features (threshold={threshold})")
    print(f"Kept {len(keep_features)} features")
    
    return X_train[:, keep_features], X_val[:, keep_features], X_test[:, keep_features]

def create_pipelines():
    """Create ML pipelines with feature selection and regularization"""
    from sklearn.feature_selection import SelectKBest, f_classif, RFE
    from sklearn.ensemble import ExtraTreesClassifier, GradientBoostingClassifier
    from sklearn.linear_model import ElasticNet
    from sklearn.naive_bayes import GaussianNB
    
    pipelines = {
        'LogisticRegression_L1': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=50)),
            ('clf', LogisticRegression(random_state=42, max_iter=2000, penalty='l1', solver='liblinear'))
        ]),
        'LogisticRegression_L2': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=50)),
            ('clf', LogisticRegression(random_state=42, max_iter=2000, penalty='l2'))
        ]),
        'ElasticNet': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=50)),
            ('clf', LogisticRegression(random_state=42, max_iter=2000, penalty='elasticnet', solver='saga', l1_ratio=0.5))
        ]),
        'RandomForest': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=100)),
            ('clf', RandomForestClassifier(random_state=42, n_jobs=-1))
        ]),
        'ExtraTrees': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=100)),
            ('clf', ExtraTreesClassifier(random_state=42, n_jobs=-1))
        ]),
        'GradientBoosting': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=80)),
            ('clf', GradientBoostingClassifier(random_state=42))
        ]),
        'SVM_RBF': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=60)),
            ('clf', SVC(random_state=42, probability=True, kernel='rbf'))
        ]),
        'SVM_Linear': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=60)),
            ('clf', SVC(random_state=42, probability=True, kernel='linear'))
        ])
    }
    
    param_grids = {
        'LogisticRegression_L1': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__C': [0.001, 0.01, 0.1, 1.0]
        },
        'LogisticRegression_L2': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__C': [0.001, 0.01, 0.1, 1.0]
        },
        'ElasticNet': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__C': [0.001, 0.01, 0.1, 1.0],
            'clf__l1_ratio': [0.1, 0.5, 0.9]
        },
        'RandomForest': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__n_estimators': [50, 100],
            'clf__max_depth': [3, 5, 10],
            'clf__min_samples_split': [10, 20],
            'clf__min_samples_leaf': [5, 10]
        },
        'ExtraTrees': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__n_estimators': [50, 100],
            'clf__max_depth': [3, 5, 10],
            'clf__min_samples_split': [10, 20],
            'clf__min_samples_leaf': [5, 10]
        },
        'GradientBoosting': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__n_estimators': [50, 100],
            'clf__max_depth': [3, 5],
            'clf__learning_rate': [0.01, 0.1, 0.2],
            'clf__min_samples_split': [10, 20]
        },
        'SVM_RBF': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__C': [0.001, 0.01, 0.1, 1.0],
            'clf__gamma': ['scale', 'auto']
        },
        'SVM_Linear': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__C': [0.001, 0.01, 0.1, 1.0]
        }
    }
    
    return pipelines, param_grids

def evaluate_model(model, X, y):
    """Evaluate model and return metrics"""
    y_pred = model.predict(X)
    y_prob = model.predict_proba(X)[:, 1]
    
    auc = roc_auc_score(y, y_prob) if len(np.unique(y)) > 1 else 0.5
    acc = accuracy_score(y, y_pred)
    
    return {'auc': auc, 'accuracy': acc, 'y_pred': y_pred, 'y_prob': y_prob}

pipelines, param_grids = create_pipelines()
print("Created pipelines for:", list(pipelines.keys()))

# %% [markdown]
# ## Training and Evaluation

# %%
results = {}
best_models = {}
cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Grid search for each algorithm
for name, pipeline in pipelines.items():
    print(f"\n{'='*50}")
    print(f"Training {name}...")
    
    # Grid search with cross-validation
    grid_search = GridSearchCV(
        pipeline, param_grids[name], cv=cv, 
        scoring='roc_auc', n_jobs=-1, verbose=0
    )
    
    grid_search.fit(X_train, y_train)
    best_model = grid_search.best_estimator_
    best_models[name] = best_model
    
    # Evaluate on all sets
    train_metrics = evaluate_model(best_model, X_train, y_train)
    val_metrics = evaluate_model(best_model, X_val, y_val)
    test_metrics = evaluate_model(best_model, X_test, y_test)
    
    results[name] = {
        'best_params': grid_search.best_params_,
        'train_auc': train_metrics['auc'],
        'val_auc': val_metrics['auc'], 
        'test_auc': test_metrics['auc'],
        'train_acc': train_metrics['accuracy'],
        'val_acc': val_metrics['accuracy'],
        'test_acc': test_metrics['accuracy'],
        'train_pred': train_metrics['y_pred'],
        'val_pred': val_metrics['y_pred'],
        'test_pred': test_metrics['y_pred'],
        'train_prob': train_metrics['y_prob'],
        'val_prob': val_metrics['y_prob'],
        'test_prob': test_metrics['y_prob']
    }
    
    print(f"Best params: {grid_search.best_params_}")
    print(f"AUCs - Train: {train_metrics['auc']:.3f}, Val: {val_metrics['auc']:.3f}, Test: {test_metrics['auc']:.3f}")
    print(f"Accs - Train: {train_metrics['accuracy']:.3f}, Val: {val_metrics['accuracy']:.3f}, Test: {test_metrics['accuracy']:.3f}")

# %% [markdown]
# ## Results Summary

# %%
# Create results summary
summary_df = pd.DataFrame({
    'Model': list(results.keys()),
    'Train_AUC': [results[m]['train_auc'] for m in results.keys()],
    'Val_AUC': [results[m]['val_auc'] for m in results.keys()],
    'Test_AUC': [results[m]['test_auc'] for m in results.keys()],
    'Train_Acc': [results[m]['train_acc'] for m in results.keys()],
    'Val_Acc': [results[m]['val_acc'] for m in results.keys()],
    'Test_Acc': [results[m]['test_acc'] for m in results.keys()]
})

print(f"Results Summary for {TARGET_ENDPOINT}:")
print("="*60)
print(summary_df.round(3).to_string(index=False))

best_model_name = summary_df.loc[summary_df['Val_AUC'].idxmax(), 'Model']
print(f"\nBest model by validation AUC: {best_model_name}")

# %% [markdown]
# ## Visualization

# %%
# Plot performance comparison
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# AUC comparison
x_pos = np.arange(len(summary_df))
width = 0.25

axes[0].bar(x_pos - width, summary_df['Train_AUC'], width, label='Train', alpha=0.8)
axes[0].bar(x_pos, summary_df['Val_AUC'], width, label='Val', alpha=0.8)
axes[0].bar(x_pos + width, summary_df['Test_AUC'], width, label='Test', alpha=0.8)
axes[0].set_xlabel('Model')
axes[0].set_ylabel('AUC')
axes[0].set_title(f'AUC Comparison - {TARGET_ENDPOINT}')
axes[0].set_xticks(x_pos)
axes[0].set_xticklabels(summary_df['Model'], rotation=45)
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Accuracy comparison  
axes[1].bar(x_pos - width, summary_df['Train_Acc'], width, label='Train', alpha=0.8)
axes[1].bar(x_pos, summary_df['Val_Acc'], width, label='Val', alpha=0.8)
axes[1].bar(x_pos + width, summary_df['Test_Acc'], width, label='Test', alpha=0.8)
axes[1].set_xlabel('Model')
axes[1].set_ylabel('Accuracy')
axes[1].set_title(f'Accuracy Comparison - {TARGET_ENDPOINT}')
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(summary_df['Model'], rotation=45)
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## OS_6 (dim: 256)

# %%
# ROC curves for best model
best_result = results[best_model_name]

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
datasets = [('Train', y_train, best_result['train_prob']), 
            ('Val', y_val, best_result['val_prob']),
            ('Test', y_test, best_result['test_prob'])]

for i, (name, y_true, y_prob) in enumerate(datasets):
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc = roc_auc_score(y_true, y_prob)
    
    axes[i].plot(fpr, tpr, linewidth=3, label=f'ROC (AUC = {roc_auc:.3f})')
    axes[i].plot([0, 1], [0, 1], 'k--', alpha=0.5)
    axes[i].set_xlim([0.0, 1.0])
    axes[i].set_ylim([0.0, 1.05])
    axes[i].set_xlabel('False Positive Rate')
    axes[i].set_ylabel('True Positive Rate')
    axes[i].set_title(f'{name} Set - {best_model_name}')
    axes[i].legend()
    axes[i].grid(True, alpha=0.3)

plt.suptitle(f'ROC Curves for {TARGET_ENDPOINT}', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## OS_24 (dim: 256)

# %%
# ROC curves for best model
best_result = results[best_model_name]

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
datasets = [('Train', y_train, best_result['train_prob']), 
            ('Val', y_val, best_result['val_prob']),
            ('Test', y_test, best_result['test_prob'])]

for i, (name, y_true, y_prob) in enumerate(datasets):
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc = roc_auc_score(y_true, y_prob)
    
    axes[i].plot(fpr, tpr, linewidth=3, label=f'ROC (AUC = {roc_auc:.3f})')
    axes[i].plot([0, 1], [0, 1], 'k--', alpha=0.5)
    axes[i].set_xlim([0.0, 1.0])
    axes[i].set_ylim([0.0, 1.05])
    axes[i].set_xlabel('False Positive Rate')
    axes[i].set_ylabel('True Positive Rate')
    axes[i].set_title(f'{name} Set - {best_model_name}')
    axes[i].legend()
    axes[i].grid(True, alpha=0.3)

plt.suptitle(f'ROC Curves for {TARGET_ENDPOINT}', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## OS_6 (dim: 512)

# %%
# ROC curves for best model
best_result = results[best_model_name]

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
datasets = [('Train', y_train, best_result['train_prob']), 
            ('Val', y_val, best_result['val_prob']),
            ('Test', y_test, best_result['test_prob'])]

for i, (name, y_true, y_prob) in enumerate(datasets):
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc = roc_auc_score(y_true, y_prob)
    
    axes[i].plot(fpr, tpr, linewidth=3, label=f'ROC (AUC = {roc_auc:.3f})')
    axes[i].plot([0, 1], [0, 1], 'k--', alpha=0.5)
    axes[i].set_xlim([0.0, 1.0])
    axes[i].set_ylim([0.0, 1.05])
    axes[i].set_xlabel('False Positive Rate')
    axes[i].set_ylabel('True Positive Rate')
    axes[i].set_title(f'{name} Set - {best_model_name}')
    axes[i].legend()
    axes[i].grid(True, alpha=0.3)

plt.suptitle(f'ROC Curves for {TARGET_ENDPOINT}', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## OS_24 (dim: 512)

# %%
# ROC curves for best model
best_result = results[best_model_name]

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
datasets = [('Train', y_train, best_result['train_prob']), 
            ('Val', y_val, best_result['val_prob']),
            ('Test', y_test, best_result['test_prob'])]

for i, (name, y_true, y_prob) in enumerate(datasets):
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc = roc_auc_score(y_true, y_prob)
    
    axes[i].plot(fpr, tpr, linewidth=3, label=f'ROC (AUC = {roc_auc:.3f})')
    axes[i].plot([0, 1], [0, 1], 'k--', alpha=0.5)
    axes[i].set_xlim([0.0, 1.0])
    axes[i].set_ylim([0.0, 1.05])
    axes[i].set_xlabel('False Positive Rate')
    axes[i].set_ylabel('True Positive Rate')
    axes[i].set_title(f'{name} Set - {best_model_name}')
    axes[i].legend()
    axes[i].grid(True, alpha=0.3)

plt.suptitle(f'ROC Curves for {TARGET_ENDPOINT}', fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Confusion matrices for best model
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
datasets = [('Train', y_train, best_result['train_pred']), 
            ('Val', y_val, best_result['val_pred']),
            ('Test', y_test, best_result['test_pred'])]

for i, (name, y_true, y_pred) in enumerate(datasets):
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[i],
               xticklabels=['Negative', 'Positive'],
               yticklabels=['Negative', 'Positive'])
    axes[i].set_title(f'{name} Set - {best_model_name}')
    axes[i].set_xlabel('Predicted')
    axes[i].set_ylabel('Actual')

plt.suptitle(f'Confusion Matrices for {TARGET_ENDPOINT}', fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Save results to JSON
final_results = {
    'target_endpoint': TARGET_ENDPOINT,
    'dataset_sizes': {'train': len(train_df), 'val': len(val_df), 'test': len(test_df)},
    'feature_dims': X_train.shape[1],
    'best_model': best_model_name,
    'summary': summary_df.to_dict('records')
}

output_file = f'ml_results_{TARGET_ENDPOINT}.json'
with open(output_file, 'w') as f:
    json.dump(final_results, f, indent=2)

print(f"Results saved to: {output_file}")
print(f"\nFinal Summary for {TARGET_ENDPOINT}:")
print(f"Best model: {best_model_name}")
print(f"Test AUC: {results[best_model_name]['test_auc']:.3f}")
print(f"Test Accuracy: {results[best_model_name]['test_acc']:.3f}")
