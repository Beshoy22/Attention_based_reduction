# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && unset MPLBACKEND && python analyze_reconstruction.py \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_path /share/project10/home/prelajarsela/Attention_based_reduction/gridsearch_results_FINAL/gridsearch_autoencoder_20250624_225515/combo_504/best_model.pth \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --attention_k 11 \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --endpoints os24 \
    --output_dir ./reconstruction_analysis_256
# Out:
# Loading train/test split...
# JSON contains: 1550 train + 274 test IDs
# Initializing analyzer (this will show actual data availability)...
# 📊 DATA AVAILABILITY REPORT:
#    PKL files contain: 757 patients total
#    JSON train set: 1550 patients (638 available, 912 missing)
#    JSON test set: 274 patients (114 available, 160 missing)
#    ✅ ACTUAL SPLIT: 640 train, 114 test patients
#    ⚠️  Some patients in JSON don't have embeddings in PKL files
#
# ============================================================
# RECONSTRUCTION QUALITY ANALYSIS
# ============================================================
# Note: Baselines computed from TRAINING data, evaluation on TEST data only
# Computing baseline statistics from TRAINING data only...
# Computing statistics from 640 training patients...
# ✅ Statistics computed from 640 training samples
# 🧪 Analyzing reconstruction quality on 114 TEST patients...
# ✅ Evaluating reconstruction on 114 test samples
# Computing metrics for model reconstruction...
# Computing metrics for mean baseline...
# /share/project10/home/prelajarsela/.conda/envs/ABR/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /share/project10/home/prelajarsela/.conda/envs/ABR/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Computing metrics for median baseline...
# Computing metrics for mode baseline...
# Comparison report saved to: ./reconstruction_analysis_256/reconstruction_comparison.csv
#
# Reconstruction Quality Comparison:
#               Method  cosine_similarity  cosine_similarity_std       mse     rmse      mae  euclidean_distance  euclidean_distance_std  pearson_correlation  pearson_correlation_std  explained_variance
# Model Reconstruction           0.994504               0.002106  3.970885 1.992708 1.512149          147.786606               22.872452             0.605626                  0.20444            0.984606
#        Mean Baseline           0.988880               0.005109  7.260891 2.694604 2.021257          197.049973               45.438404             0.000000                  0.00000            0.971572
#      Median Baseline           0.988770               0.005415  7.327919 2.707013 2.014375          197.375137               48.103039             0.000000                  0.00000            0.971313
#        Mode Baseline           0.977722               0.007885 14.420230 3.797398 2.900278          280.226044               51.846935             0.000000                  0.00000            0.959798
# Metrics comparison plot saved to: ./reconstruction_analysis_256/metrics_comparison.png
#
# ============================================================
# FEATURE-WISE ANALYSIS (on test data)
# ============================================================
# Analyzing feature-wise reconstruction performance on test data...
# Mean MSE per feature: 3.970886 ± 4.045284
# Mean correlation per feature: 0.6056 ± 0.2044
#
# Detailed results saved to: ./reconstruction_analysis_256/detailed_results.json
# Analysis complete! Results saved to: ./reconstruction_analysis_256
#
# ============================================================
# METHODOLOGY SUMMARY
# ============================================================
# ✅ Baselines (mean, median, mode) computed from TRAINING data only
# ✅ Model evaluation performed on TEST data only
# ✅ No data leakage between train and test sets
# ✅ Rigorous evaluation methodology following best practices

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/LUNG_RADIO_fast.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split_w_LR.json \
    --model_type autoencoder \
    --attention_k 11\ \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 8.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# Stratification successful with endpoints: ['os24']
# Train samples: 967
# Validation samples: 226
# Test samples: 104
# Creating autoencoder model...
# Model parameters: 3,041,777
# Starting training...
# Starting training for 50 epochs...
# Model type: autoencoder
# Device: cuda
#   New best validation AUC: 0.6032
# Epoch 1/50 (1.13s)
#   Train Loss: 312.7451
#   Train Cosine Sim: 0.4995
#   Val Loss: 314.3781
#   Val Cosine Sim: 0.6872
#   Val OS24 AUC: 0.6032
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6599
# Epoch 2/50 (0.48s)
#   Train Loss: 273.1021
#   Train Cosine Sim: 0.7055
#   Val Loss: 279.7429
#   Val Cosine Sim: 0.7267
#   Val OS24 AUC: 0.6599
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6816
# Epoch 3/50 (0.48s)
#   Train Loss: 237.1588
#   Train Cosine Sim: 0.7394
#   Val Loss: 242.0011
#   Val Cosine Sim: 0.7547
#   Val OS24 AUC: 0.6816
#   LR: 1.00e-03
#
# Epoch 4/50 (0.40s)
#   Train Loss: 204.3155
#   Train Cosine Sim: 0.7656
#   Val Loss: 202.3107
#   Val Cosine Sim: 0.7793
#   Val OS24 AUC: 0.6573
#   LR: 1.00e-03
#
# Epoch 5/50 (0.39s)
#   Train Loss: 176.1592
#   Train Cosine Sim: 0.7892
#   Val Loss: 171.9879
#   Val Cosine Sim: 0.8011
#   Val OS24 AUC: 0.6584
#   LR: 1.00e-03
#
# Epoch 6/50 (0.38s)
#   Train Loss: 151.7855
#   Train Cosine Sim: 0.8102
#   Val Loss: 151.8702
#   Val Cosine Sim: 0.8203
#   Val OS24 AUC: 0.6650
#   LR: 1.00e-03
#
# Epoch 7/50 (0.37s)
#   Train Loss: 132.2481
#   Train Cosine Sim: 0.8285
#   Val Loss: 126.7787
#   Val Cosine Sim: 0.8372
#   Val OS24 AUC: 0.6560
#   LR: 1.00e-03
#
# Epoch 8/50 (0.38s)
#   Train Loss: 117.7439
#   Train Cosine Sim: 0.8443
#   Val Loss: 114.3604
#   Val Cosine Sim: 0.8518
#   Val OS24 AUC: 0.6378
#   LR: 1.00e-03
#
# Epoch 9/50 (0.39s)
#   Train Loss: 105.1409
#   Train Cosine Sim: 0.8574
#   Val Loss: 103.5035
#   Val Cosine Sim: 0.8640
#   Val OS24 AUC: 0.6679
#   LR: 1.00e-03
#
# Epoch 10/50 (0.39s)
#   Train Loss: 95.9906
#   Train Cosine Sim: 0.8687
#   Val Loss: 94.1527
#   Val Cosine Sim: 0.8745
#   Val OS24 AUC: 0.6320
#   LR: 1.00e-03
#
# Epoch 11/50 (0.39s)
#   Train Loss: 87.8362
#   Train Cosine Sim: 0.8783
#   Val Loss: 85.9989
#   Val Cosine Sim: 0.8839
#   Val OS24 AUC: 0.6736
#   LR: 1.00e-03
#
# Epoch 12/50 (0.38s)
#   Train Loss: 80.9799
#   Train Cosine Sim: 0.8873
#   Val Loss: 79.3536
#   Val Cosine Sim: 0.8920
#   Val OS24 AUC: 0.6741
#   LR: 1.00e-03
#
# Epoch 13/50 (0.37s)
#   Train Loss: 75.8263
#   Train Cosine Sim: 0.8951
#   Val Loss: 73.1695
#   Val Cosine Sim: 0.8994
#   Val OS24 AUC: 0.6702
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6848
# Epoch 14/50 (0.48s)
#   Train Loss: 70.6566
#   Train Cosine Sim: 0.9018
#   Val Loss: 69.1400
#   Val Cosine Sim: 0.9057
#   Val OS24 AUC: 0.6848
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6882
# Epoch 15/50 (0.48s)
#   Train Loss: 66.7279
#   Train Cosine Sim: 0.9080
#   Val Loss: 65.3501
#   Val Cosine Sim: 0.9119
#   Val OS24 AUC: 0.6882
#   LR: 1.00e-03
#
# Epoch 16/50 (0.40s)
#   Train Loss: 63.1353
#   Train Cosine Sim: 0.9141
#   Val Loss: 61.6133
#   Val Cosine Sim: 0.9176
#   Val OS24 AUC: 0.6777
#   LR: 1.00e-03
#
# Epoch 17/50 (0.38s)
#   Train Loss: 59.8971
#   Train Cosine Sim: 0.9190
#   Val Loss: 58.1009
#   Val Cosine Sim: 0.9229
#   Val OS24 AUC: 0.6767
#   LR: 1.00e-03
#
# Epoch 18/50 (0.38s)
#   Train Loss: 56.3944
#   Train Cosine Sim: 0.9246
#   Val Loss: 55.2125
#   Val Cosine Sim: 0.9279
#   Val OS24 AUC: 0.6785
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6918
# Epoch 19/50 (0.47s)
#   Train Loss: 53.8341
#   Train Cosine Sim: 0.9295
#   Val Loss: 52.2977
#   Val Cosine Sim: 0.9327
#   Val OS24 AUC: 0.6918
#   LR: 1.00e-03
#
# Epoch 20/50 (0.40s)
#   Train Loss: 50.7298
#   Train Cosine Sim: 0.9340
#   Val Loss: 51.7060
#   Val Cosine Sim: 0.9366
#   Val OS24 AUC: 0.6410
#   LR: 1.00e-03
#
# Epoch 21/50 (0.39s)
#   Train Loss: 48.7163
#   Train Cosine Sim: 0.9383
#   Val Loss: 46.0980
#   Val Cosine Sim: 0.9412
#   Val OS24 AUC: 0.6856
#   LR: 1.00e-03
#
# Epoch 22/50 (0.39s)
#   Train Loss: 45.9929
#   Train Cosine Sim: 0.9424
#   Val Loss: 43.3911
#   Val Cosine Sim: 0.9453
#   Val OS24 AUC: 0.6868
#   LR: 1.00e-03
#
# Epoch 23/50 (0.39s)
#   Train Loss: 43.4326
#   Train Cosine Sim: 0.9462
#   Val Loss: 41.6397
#   Val Cosine Sim: 0.9490
#   Val OS24 AUC: 0.6691
#   LR: 1.00e-03
#
# Epoch 24/50 (0.38s)
#   Train Loss: 40.9110
#   Train Cosine Sim: 0.9502
#   Val Loss: 39.8822
#   Val Cosine Sim: 0.9527
#   Val OS24 AUC: 0.6747
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6938
# Epoch 25/50 (0.47s)
#   Train Loss: 39.2277
#   Train Cosine Sim: 0.9536
#   Val Loss: 37.0564
#   Val Cosine Sim: 0.9560
#   Val OS24 AUC: 0.6938
#   LR: 1.00e-03
#
#   New best validation AUC: 0.7002
# Epoch 26/50 (0.49s)
#   Train Loss: 37.2039
#   Train Cosine Sim: 0.9565
#   Val Loss: 34.5819
#   Val Cosine Sim: 0.9590
#   Val OS24 AUC: 0.7002
#   LR: 1.00e-03
#
# Epoch 27/50 (0.39s)
#   Train Loss: 34.8959
#   Train Cosine Sim: 0.9598
#   Val Loss: 33.0618
#   Val Cosine Sim: 0.9620
#   Val OS24 AUC: 0.6996
#   LR: 1.00e-03
#
# Epoch 28/50 (0.39s)
#   Train Loss: 32.8526
#   Train Cosine Sim: 0.9626
#   Val Loss: 31.1147
#   Val Cosine Sim: 0.9648
#   Val OS24 AUC: 0.6909
#   LR: 1.00e-03
#
# Epoch 29/50 (0.63s)
#   Train Loss: 30.9458
#   Train Cosine Sim: 0.9651
#   Val Loss: 29.6582
#   Val Cosine Sim: 0.9673
#   Val OS24 AUC: 0.6739
#   LR: 1.00e-03
#
#   New best validation AUC: 0.7071
# Epoch 30/50 (0.60s)
#   Train Loss: 29.0153
#   Train Cosine Sim: 0.9675
#   Val Loss: 27.6319
#   Val Cosine Sim: 0.9698
#   Val OS24 AUC: 0.7071
#   LR: 1.00e-03
#
# Epoch 31/50 (0.49s)
#   Train Loss: 27.8143
#   Train Cosine Sim: 0.9702
#   Val Loss: 26.3580
#   Val Cosine Sim: 0.9724
#   Val OS24 AUC: 0.7046
#   LR: 1.00e-03
#
# Epoch 32/50 (0.49s)
#   Train Loss: 26.2695
#   Train Cosine Sim: 0.9725
#   Val Loss: 25.4988
#   Val Cosine Sim: 0.9743
#   Val OS24 AUC: 0.7016
#   LR: 1.00e-03
#
# Epoch 33/50 (0.48s)
#   Train Loss: 25.1012
#   Train Cosine Sim: 0.9745
#   Val Loss: 23.3835
#   Val Cosine Sim: 0.9762
#   Val OS24 AUC: 0.6999
#   LR: 1.00e-03
#
# Epoch 34/50 (0.47s)
#   Train Loss: 24.0542
#   Train Cosine Sim: 0.9763
#   Val Loss: 22.3720
#   Val Cosine Sim: 0.9782
#   Val OS24 AUC: 0.6890
#   LR: 1.00e-03
#
# Epoch 35/50 (0.48s)
#   Train Loss: 22.8175
#   Train Cosine Sim: 0.9782
#   Val Loss: 21.3911
#   Val Cosine Sim: 0.9799
#   Val OS24 AUC: 0.6605
#   LR: 1.00e-03
#
#   New best validation AUC: 0.7252
# Epoch 36/50 (0.58s)
#   Train Loss: 21.6076
#   Train Cosine Sim: 0.9797
#   Val Loss: 20.1684
#   Val Cosine Sim: 0.9814
#   Val OS24 AUC: 0.7252
#   LR: 1.00e-03
#
# Epoch 37/50 (0.49s)
#   Train Loss: 20.6707
#   Train Cosine Sim: 0.9809
#   Val Loss: 19.2099
#   Val Cosine Sim: 0.9828
#   Val OS24 AUC: 0.7196
#   LR: 1.00e-03
#
# Epoch 38/50 (0.49s)
#   Train Loss: 19.7139
#   Train Cosine Sim: 0.9822
#   Val Loss: 18.4335
#   Val Cosine Sim: 0.9838
#   Val OS24 AUC: 0.7205
#   LR: 1.00e-03
#
# Epoch 39/50 (0.49s)
#   Train Loss: 18.5790
#   Train Cosine Sim: 0.9834
#   Val Loss: 17.7618
#   Val Cosine Sim: 0.9852
#   Val OS24 AUC: 0.6983
#   LR: 1.00e-03
#
# Epoch 40/50 (0.84s)
#   Train Loss: 17.7898
#   Train Cosine Sim: 0.9846
#   Val Loss: 16.1937
#   Val Cosine Sim: 0.9861
#   Val OS24 AUC: 0.6994
#   LR: 1.00e-03
#
# Epoch 41/50 (0.54s)
#   Train Loss: 17.7060
#   Train Cosine Sim: 0.9856
#   Val Loss: 15.9707
#   Val Cosine Sim: 0.9871
#   Val OS24 AUC: 0.7098
#   LR: 1.00e-03
#
# Epoch 42/50 (0.54s)
#   Train Loss: 16.8939
#   Train Cosine Sim: 0.9863
#   Val Loss: 16.2215
#   Val Cosine Sim: 0.9879
#   Val OS24 AUC: 0.6908
#   LR: 1.00e-03
#
# Epoch 43/50 (0.54s)
#   Train Loss: 16.0597
#   Train Cosine Sim: 0.9873
#   Val Loss: 15.4465
#   Val Cosine Sim: 0.9887
#   Val OS24 AUC: 0.6973
#   LR: 1.00e-03
#
# Epoch 44/50 (0.55s)
#   Train Loss: 15.4826
#   Train Cosine Sim: 0.9880
#   Val Loss: 14.6841
#   Val Cosine Sim: 0.9894
#   Val OS24 AUC: 0.6920
#   LR: 1.00e-03
#
# Epoch 45/50 (0.54s)
#   Train Loss: 14.6391
#   Train Cosine Sim: 0.9884
#   Val Loss: 14.8948
#   Val Cosine Sim: 0.9897
#   Val OS24 AUC: 0.6898
#   LR: 1.00e-03
#
# Epoch 46/50 (0.54s)
#   Train Loss: 14.4139
#   Train Cosine Sim: 0.9890
#   Val Loss: 13.6878
#   Val Cosine Sim: 0.9904
#   Val OS24 AUC: 0.7036
#   LR: 1.00e-03
#
# Epoch 47/50 (0.55s)
#   Train Loss: 14.0214
#   Train Cosine Sim: 0.9896
#   Val Loss: 13.8343
#   Val Cosine Sim: 0.9909
#   Val OS24 AUC: 0.7089
#   LR: 5.00e-04
#
# Epoch 48/50 (0.55s)
#   Train Loss: 12.9977
#   Train Cosine Sim: 0.9902
#   Val Loss: 13.4328
#   Val Cosine Sim: 0.9911
#   Val OS24 AUC: 0.7067
#   LR: 5.00e-04
#
# Epoch 49/50 (0.53s)
#   Train Loss: 13.1438
#   Train Cosine Sim: 0.9904
#   Val Loss: 12.8415
#   Val Cosine Sim: 0.9914
#   Val OS24 AUC: 0.7218
#   LR: 5.00e-04
#
# Epoch 50/50 (0.49s)
#   Train Loss: 13.1117
#   Train Cosine Sim: 0.9905
#   Val Loss: 12.9503
#   Val Cosine Sim: 0.9916
#   Val OS24 AUC: 0.7011
#   LR: 5.00e-04
# Training completed!
# Best validation AUC: 0.7252
# Evaluating on test set...
# Loaded best model from epoch 35
#
# Test Results:
# Test Loss: 19.3500
# Test Cosine Sim: 0.9814
# OS24 - AUC: 0.5808, Accuracy: 0.7500, F1: 0.1333
#
# Results saved to: ./results/autoencoder_20250626_155350/autoencoder_20250626_155415

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/LUNG_RADIO_fast.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split_w_LR.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# Stratification successful with endpoints: ['os24']
# Train samples: 967
# Validation samples: 226
# Test samples: 104
# Creating autoencoder model...
# Model parameters: 6,013,169
# Starting training...
# Starting training for 50 epochs...
# Model type: autoencoder
# Device: cuda
#   New best validation AUC: 0.6327
# Epoch 1/50 (1.41s)
#   Train Loss: 312.2660
#   Train Cosine Sim: 0.4926
#   Val Loss: 311.7772
#   Val Cosine Sim: 0.6863
#   Val OS24 AUC: 0.6327
#   LR: 1.00e-03
#
# Epoch 2/50 (0.46s)
#   Train Loss: 272.7166
#   Train Cosine Sim: 0.7039
#   Val Loss: 269.4284
#   Val Cosine Sim: 0.7269
#   Val OS24 AUC: 0.6086
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6375
# Epoch 3/50 (0.63s)
#   Train Loss: 236.0154
#   Train Cosine Sim: 0.7389
#   Val Loss: 233.2303
#   Val Cosine Sim: 0.7547
#   Val OS24 AUC: 0.6375
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6415
# Epoch 4/50 (0.63s)
#   Train Loss: 202.1216
#   Train Cosine Sim: 0.7658
#   Val Loss: 198.5940
#   Val Cosine Sim: 0.7794
#   Val OS24 AUC: 0.6415
#   LR: 1.00e-03
#
# Epoch 5/50 (0.49s)
#   Train Loss: 172.6961
#   Train Cosine Sim: 0.7896
#   Val Loss: 163.5814
#   Val Cosine Sim: 0.8016
#   Val OS24 AUC: 0.6341
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6424
# Epoch 6/50 (0.64s)
#   Train Loss: 148.1965
#   Train Cosine Sim: 0.8106
#   Val Loss: 144.4228
#   Val Cosine Sim: 0.8208
#   Val OS24 AUC: 0.6424
#   LR: 1.00e-03
#
# Epoch 7/50 (0.46s)
#   Train Loss: 129.4045
#   Train Cosine Sim: 0.8289
#   Val Loss: 125.0032
#   Val Cosine Sim: 0.8376
#   Val OS24 AUC: 0.6049
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6434
# Epoch 8/50 (0.64s)
#   Train Loss: 113.5179
#   Train Cosine Sim: 0.8444
#   Val Loss: 109.6685
#   Val Cosine Sim: 0.8520
#   Val OS24 AUC: 0.6434
#   LR: 1.00e-03
#
# Epoch 9/50 (0.47s)
#   Train Loss: 100.9361
#   Train Cosine Sim: 0.8575
#   Val Loss: 98.2088
#   Val Cosine Sim: 0.8641
#   Val OS24 AUC: 0.6404
#   LR: 1.00e-03
#
# Epoch 10/50 (0.48s)
#   Train Loss: 91.2541
#   Train Cosine Sim: 0.8687
#   Val Loss: 88.8764
#   Val Cosine Sim: 0.8747
#   Val OS24 AUC: 0.6315
#   LR: 1.00e-03
#
# Epoch 11/50 (0.46s)
#   Train Loss: 83.4011
#   Train Cosine Sim: 0.8789
#   Val Loss: 81.1075
#   Val Cosine Sim: 0.8840
#   Val OS24 AUC: 0.6353
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6459
# Epoch 12/50 (0.63s)
#   Train Loss: 77.4357
#   Train Cosine Sim: 0.8876
#   Val Loss: 75.9427
#   Val Cosine Sim: 0.8921
#   Val OS24 AUC: 0.6459
#   LR: 1.00e-03
#
# Epoch 13/50 (0.47s)
#   Train Loss: 72.3517
#   Train Cosine Sim: 0.8953
#   Val Loss: 70.5116
#   Val Cosine Sim: 0.8991
#   Val OS24 AUC: 0.6334
#   LR: 1.00e-03
#
# Epoch 14/50 (0.48s)
#   Train Loss: 67.2036
#   Train Cosine Sim: 0.9017
#   Val Loss: 67.9383
#   Val Cosine Sim: 0.9049
#   Val OS24 AUC: 0.6379
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6490
# Epoch 15/50 (0.64s)
#   Train Loss: 63.7305
#   Train Cosine Sim: 0.9076
#   Val Loss: 61.9565
#   Val Cosine Sim: 0.9112
#   Val OS24 AUC: 0.6490
#   LR: 1.00e-03
#
# Epoch 16/50 (0.46s)
#   Train Loss: 60.2755
#   Train Cosine Sim: 0.9135
#   Val Loss: 58.2358
#   Val Cosine Sim: 0.9170
#   Val OS24 AUC: 0.6254
#   LR: 1.00e-03
#
# Epoch 17/50 (0.61s)
#   Train Loss: 56.8431
#   Train Cosine Sim: 0.9182
#   Val Loss: 54.3285
#   Val Cosine Sim: 0.9222
#   Val OS24 AUC: 0.6368
#   LR: 1.00e-03
#
# Epoch 18/50 (0.46s)
#   Train Loss: 52.9778
#   Train Cosine Sim: 0.9237
#   Val Loss: 50.9192
#   Val Cosine Sim: 0.9269
#   Val OS24 AUC: 0.6362
#   LR: 1.00e-03
#
# Epoch 19/50 (0.48s)
#   Train Loss: 49.7264
#   Train Cosine Sim: 0.9286
#   Val Loss: 48.0660
#   Val Cosine Sim: 0.9315
#   Val OS24 AUC: 0.6265
#   LR: 1.00e-03
#
# Epoch 20/50 (0.48s)
#   Train Loss: 46.9109
#   Train Cosine Sim: 0.9332
#   Val Loss: 45.5749
#   Val Cosine Sim: 0.9360
#   Val OS24 AUC: 0.6322
#   LR: 1.00e-03
#
# Epoch 21/50 (0.47s)
#   Train Loss: 44.3975
#   Train Cosine Sim: 0.9375
#   Val Loss: 42.7465
#   Val Cosine Sim: 0.9405
#   Val OS24 AUC: 0.6255
#   LR: 1.00e-03
#
# Epoch 22/50 (0.46s)
#   Train Loss: 42.0449
#   Train Cosine Sim: 0.9416
#   Val Loss: 40.5757
#   Val Cosine Sim: 0.9442
#   Val OS24 AUC: 0.6334
#   LR: 1.00e-03
#
# Epoch 23/50 (0.47s)
#   Train Loss: 39.3624
#   Train Cosine Sim: 0.9451
#   Val Loss: 37.2998
#   Val Cosine Sim: 0.9478
#   Val OS24 AUC: 0.6388
#   LR: 1.00e-03
#
# Epoch 24/50 (0.47s)
#   Train Loss: 37.1324
#   Train Cosine Sim: 0.9489
#   Val Loss: 36.1071
#   Val Cosine Sim: 0.9514
#   Val OS24 AUC: 0.6124
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6524
# Epoch 25/50 (0.61s)
#   Train Loss: 34.8525
#   Train Cosine Sim: 0.9525
#   Val Loss: 33.1909
#   Val Cosine Sim: 0.9549
#   Val OS24 AUC: 0.6524
#   LR: 1.00e-03
#
# Epoch 26/50 (0.44s)
#   Train Loss: 32.7525
#   Train Cosine Sim: 0.9557
#   Val Loss: 31.2072
#   Val Cosine Sim: 0.9580
#   Val OS24 AUC: 0.6161
#   LR: 1.00e-03
#
# Epoch 27/50 (0.46s)
#   Train Loss: 30.9247
#   Train Cosine Sim: 0.9585
#   Val Loss: 29.1416
#   Val Cosine Sim: 0.9608
#   Val OS24 AUC: 0.6238
#   LR: 1.00e-03
#
# Epoch 28/50 (0.55s)
#   Train Loss: 29.2928
#   Train Cosine Sim: 0.9615
#   Val Loss: 27.1903
#   Val Cosine Sim: 0.9635
#   Val OS24 AUC: 0.6484
#   LR: 1.00e-03
#
# Epoch 29/50 (0.46s)
#   Train Loss: 27.6579
#   Train Cosine Sim: 0.9639
#   Val Loss: 25.7655
#   Val Cosine Sim: 0.9661
#   Val OS24 AUC: 0.6432
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6532
# Epoch 30/50 (0.99s)
#   Train Loss: 25.4074
#   Train Cosine Sim: 0.9666
#   Val Loss: 24.2437
#   Val Cosine Sim: 0.9684
#   Val OS24 AUC: 0.6532
#   LR: 1.00e-03
#
# Epoch 31/50 (0.48s)
#   Train Loss: 24.1700
#   Train Cosine Sim: 0.9688
#   Val Loss: 22.4499
#   Val Cosine Sim: 0.9708
#   Val OS24 AUC: 0.6421
#   LR: 1.00e-03
#
# Epoch 32/50 (0.47s)
#   Train Loss: 22.9881
#   Train Cosine Sim: 0.9711
#   Val Loss: 21.0664
#   Val Cosine Sim: 0.9730
#   Val OS24 AUC: 0.6442
#   LR: 1.00e-03
#
# Epoch 33/50 (0.46s)
#   Train Loss: 21.1972
#   Train Cosine Sim: 0.9730
#   Val Loss: 19.9173
#   Val Cosine Sim: 0.9747
#   Val OS24 AUC: 0.6410
#   LR: 1.00e-03
#
# Epoch 34/50 (0.46s)
#   Train Loss: 19.9098
#   Train Cosine Sim: 0.9751
#   Val Loss: 18.3382
#   Val Cosine Sim: 0.9768
#   Val OS24 AUC: 0.6516
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6543
# Epoch 35/50 (0.61s)
#   Train Loss: 18.7289
#   Train Cosine Sim: 0.9767
#   Val Loss: 17.0029
#   Val Cosine Sim: 0.9784
#   Val OS24 AUC: 0.6543
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6621
# Epoch 36/50 (0.62s)
#   Train Loss: 17.7563
#   Train Cosine Sim: 0.9784
#   Val Loss: 16.0966
#   Val Cosine Sim: 0.9801
#   Val OS24 AUC: 0.6621
#   LR: 1.00e-03
#
# Epoch 37/50 (0.48s)
#   Train Loss: 17.9923
#   Train Cosine Sim: 0.9796
#   Val Loss: 15.4800
#   Val Cosine Sim: 0.9812
#   Val OS24 AUC: 0.6325
#   LR: 1.00e-03
#
# Epoch 38/50 (0.86s)
#   Train Loss: 16.5405
#   Train Cosine Sim: 0.9809
#   Val Loss: 16.5468
#   Val Cosine Sim: 0.9811
#   Val OS24 AUC: 0.6477
#   LR: 1.00e-03
#
# Epoch 39/50 (0.46s)
#   Train Loss: 15.5081
#   Train Cosine Sim: 0.9818
#   Val Loss: 13.7498
#   Val Cosine Sim: 0.9834
#   Val OS24 AUC: 0.6447
#   LR: 1.00e-03
#
# Epoch 40/50 (0.47s)
#   Train Loss: 14.7076
#   Train Cosine Sim: 0.9832
#   Val Loss: 13.0002
#   Val Cosine Sim: 0.9845
#   Val OS24 AUC: 0.6398
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6684
# Epoch 41/50 (0.60s)
#   Train Loss: 13.9325
#   Train Cosine Sim: 0.9841
#   Val Loss: 12.3250
#   Val Cosine Sim: 0.9854
#   Val OS24 AUC: 0.6684
#   LR: 1.00e-03
#
# Epoch 42/50 (0.46s)
#   Train Loss: 13.6537
#   Train Cosine Sim: 0.9849
#   Val Loss: 11.8329
#   Val Cosine Sim: 0.9864
#   Val OS24 AUC: 0.6439
#   LR: 1.00e-03
#
# Epoch 43/50 (0.46s)
#   Train Loss: 12.7010
#   Train Cosine Sim: 0.9858
#   Val Loss: 10.9292
#   Val Cosine Sim: 0.9871
#   Val OS24 AUC: 0.6529
#   LR: 1.00e-03
#
# Epoch 44/50 (0.46s)
#   Train Loss: 12.4245
#   Train Cosine Sim: 0.9865
#   Val Loss: 10.4792
#   Val Cosine Sim: 0.9878
#   Val OS24 AUC: 0.6570
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6700
# Epoch 45/50 (0.62s)
#   Train Loss: 11.7740
#   Train Cosine Sim: 0.9869
#   Val Loss: 9.8498
#   Val Cosine Sim: 0.9883
#   Val OS24 AUC: 0.6700
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6803
# Epoch 46/50 (0.60s)
#   Train Loss: 11.1814
#   Train Cosine Sim: 0.9880
#   Val Loss: 9.8387
#   Val Cosine Sim: 0.9890
#   Val OS24 AUC: 0.6803
#   LR: 1.00e-03
#
# Epoch 47/50 (0.46s)
#   Train Loss: 10.8764
#   Train Cosine Sim: 0.9883
#   Val Loss: 9.1714
#   Val Cosine Sim: 0.9894
#   Val OS24 AUC: 0.6735
#   LR: 1.00e-03
#
# Epoch 48/50 (0.46s)
#   Train Loss: 10.5030
#   Train Cosine Sim: 0.9889
#   Val Loss: 9.0643
#   Val Cosine Sim: 0.9900
#   Val OS24 AUC: 0.6778
#   LR: 1.00e-03
#
# Epoch 49/50 (0.45s)
#   Train Loss: 10.1388
#   Train Cosine Sim: 0.9894
#   Val Loss: 8.7628
#   Val Cosine Sim: 0.9904
#   Val OS24 AUC: 0.6696
#   LR: 1.00e-03
#   New best validation AUC: 0.6820
# Epoch 50/50 (0.61s)
#   Train Loss: 9.9844
#   Train Cosine Sim: 0.9897
#   Val Loss: 8.1858
#   Val Cosine Sim: 0.9907
#   Val OS24 AUC: 0.6820
#   LR: 1.00e-03
#
# Training completed!
# Best validation AUC: 0.6820
# Evaluating on test set...
# Loaded best model from epoch 49
#
# Test Results:
# Test Loss: 8.6565
# Test Cosine Sim: 0.9905
# OS24 - AUC: 0.4861, Accuracy: 0.7404, F1: 0.1818
#
# Results saved to: ./results/autoencoder_20250626_155820/autoencoder_20250626_155846

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# Stratification successful with endpoints: ['os24']
# Train samples: 522
# Validation samples: 118
# Test samples: 104
# Creating autoencoder model...
# Model parameters: 6,013,169
# Starting training...
# Starting training for 50 epochs...
# Model type: autoencoder
# Device: cuda
#   New best validation AUC: 0.6359
# Epoch 1/50 (0.87s)
#   Train Loss: 323.7172
#   Train Cosine Sim: 0.3729
#   Val Loss: 322.2661
#   Val Cosine Sim: 0.6373
#   Val OS24 AUC: 0.6359
#   LR: 1.00e-03
#
# Epoch 2/50 (0.26s)
#   Train Loss: 299.1913
#   Train Cosine Sim: 0.6618
#   Val Loss: 306.8900
#   Val Cosine Sim: 0.6982
#   Val OS24 AUC: 0.6041
#   LR: 1.00e-03
#
# Epoch 3/50 (0.21s)
#   Train Loss: 274.8188
#   Train Cosine Sim: 0.7038
#   Val Loss: 274.5112
#   Val Cosine Sim: 0.7215
#   Val OS24 AUC: 0.5272
#   LR: 1.00e-03
#
# Epoch 4/50 (0.21s)
#   Train Loss: 254.2530
#   Train Cosine Sim: 0.7267
#   Val Loss: 250.1137
#   Val Cosine Sim: 0.7393
#   Val OS24 AUC: 0.5803
#   LR: 1.00e-03
#
# Epoch 5/50 (0.21s)
#   Train Loss: 231.7436
#   Train Cosine Sim: 0.7437
#   Val Loss: 229.6379
#   Val Cosine Sim: 0.7546
#   Val OS24 AUC: 0.5778
#   LR: 1.00e-03
#
# Epoch 6/50 (0.21s)
#   Train Loss: 212.0549
#   Train Cosine Sim: 0.7600
#   Val Loss: 210.3613
#   Val Cosine Sim: 0.7692
#   Val OS24 AUC: 0.5351
#   LR: 1.00e-03
#
# Epoch 7/50 (0.21s)
#   Train Loss: 192.5634
#   Train Cosine Sim: 0.7748
#   Val Loss: 193.8949
#   Val Cosine Sim: 0.7827
#   Val OS24 AUC: 0.5903
#   LR: 1.00e-03
#
# Epoch 8/50 (0.21s)
#   Train Loss: 172.4300
#   Train Cosine Sim: 0.7888
#   Val Loss: 166.8608
#   Val Cosine Sim: 0.7967
#   Val OS24 AUC: 0.6304
#   LR: 1.00e-03
#
# Epoch 9/50 (0.22s)
#   Train Loss: 158.0429
#   Train Cosine Sim: 0.8023
#   Val Loss: 153.4350
#   Val Cosine Sim: 0.8092
#   Val OS24 AUC: 0.6058
#   LR: 1.00e-03
#
# Epoch 10/50 (0.24s)
#   Train Loss: 142.4723
#   Train Cosine Sim: 0.8144
#   Val Loss: 142.2705
#   Val Cosine Sim: 0.8204
#   Val OS24 AUC: 0.6091
#   LR: 1.00e-03
#
# Epoch 11/50 (0.23s)
#   Train Loss: 131.5479
#   Train Cosine Sim: 0.8255
#   Val Loss: 127.8992
#   Val Cosine Sim: 0.8315
#   Val OS24 AUC: 0.6087
#   LR: 1.00e-03
#
# Epoch 12/50 (0.21s)
#   Train Loss: 119.9357
#   Train Cosine Sim: 0.8357
#   Val Loss: 117.6358
#   Val Cosine Sim: 0.8413
#   Val OS24 AUC: 0.6338
#   LR: 5.00e-04
#
#   New best validation AUC: 0.6509
# Epoch 13/50 (0.36s)
#   Train Loss: 114.2936
#   Train Cosine Sim: 0.8433
#   Val Loss: 113.1661
#   Val Cosine Sim: 0.8465
#   Val OS24 AUC: 0.6509
#   LR: 5.00e-04
#
# Epoch 14/50 (0.22s)
#   Train Loss: 109.7455
#   Train Cosine Sim: 0.8481
#   Val Loss: 112.2894
#   Val Cosine Sim: 0.8506
#   Val OS24 AUC: 0.6008
#   LR: 5.00e-04
#
# Epoch 15/50 (0.24s)
#   Train Loss: 106.5763
#   Train Cosine Sim: 0.8523
#   Val Loss: 108.4477
#   Val Cosine Sim: 0.8545
#   Val OS24 AUC: 0.5853
#   LR: 5.00e-04
#
# Epoch 16/50 (0.22s)
#   Train Loss: 103.4556
#   Train Cosine Sim: 0.8557
#   Val Loss: 105.0472
#   Val Cosine Sim: 0.8583
#   Val OS24 AUC: 0.5811
#   LR: 5.00e-04
#
# Epoch 17/50 (0.22s)
#   Train Loss: 101.0501
#   Train Cosine Sim: 0.8597
#   Val Loss: 102.4640
#   Val Cosine Sim: 0.8619
#   Val OS24 AUC: 0.5832
#   LR: 5.00e-04
#
# Epoch 18/50 (0.22s)
#   Train Loss: 98.1256
#   Train Cosine Sim: 0.8632
#   Val Loss: 100.2438
#   Val Cosine Sim: 0.8653
#   Val OS24 AUC: 0.5732
#   LR: 5.00e-04
#
# Epoch 19/50 (0.22s)
#   Train Loss: 94.6518
#   Train Cosine Sim: 0.8666
#   Val Loss: 95.0183
#   Val Cosine Sim: 0.8685
#   Val OS24 AUC: 0.6225
#   LR: 5.00e-04
#
#   New best validation AUC: 0.6522
# Epoch 20/50 (0.37s)
#   Train Loss: 92.0653
#   Train Cosine Sim: 0.8697
#   Val Loss: 91.8369
#   Val Cosine Sim: 0.8715
#   Val OS24 AUC: 0.6522
#   LR: 5.00e-04
#
# Epoch 21/50 (0.23s)
#   Train Loss: 89.4647
#   Train Cosine Sim: 0.8719
#   Val Loss: 90.0502
#   Val Cosine Sim: 0.8743
#   Val OS24 AUC: 0.6150
#   LR: 5.00e-04
#
# Epoch 22/50 (0.24s)
#   Train Loss: 87.2428
#   Train Cosine Sim: 0.8752
#   Val Loss: 87.8774
#   Val Cosine Sim: 0.8771
#   Val OS24 AUC: 0.5560
#   LR: 5.00e-04
#
# Epoch 23/50 (0.23s)
#   Train Loss: 85.9995
#   Train Cosine Sim: 0.8779
#   Val Loss: 86.3521
#   Val Cosine Sim: 0.8796
#   Val OS24 AUC: 0.5711
#   LR: 5.00e-04
#
# Epoch 24/50 (0.24s)
#   Train Loss: 82.8876
#   Train Cosine Sim: 0.8804
#   Val Loss: 86.7240
#   Val Cosine Sim: 0.8821
#   Val OS24 AUC: 0.5895
#   LR: 5.00e-04
#
# Epoch 25/50 (0.23s)
#   Train Loss: 81.5443
#   Train Cosine Sim: 0.8826
#   Val Loss: 82.6020
#   Val Cosine Sim: 0.8848
#   Val OS24 AUC: 0.6217
#   LR: 5.00e-04
#
# Epoch 26/50 (0.23s)
#   Train Loss: 79.7250
#   Train Cosine Sim: 0.8854
#   Val Loss: 79.2784
#   Val Cosine Sim: 0.8872
#   Val OS24 AUC: 0.6325
#   LR: 5.00e-04
#
# Epoch 27/50 (0.23s)
#   Train Loss: 77.8001
#   Train Cosine Sim: 0.8878
#   Val Loss: 76.9482
#   Val Cosine Sim: 0.8894
#   Val OS24 AUC: 0.6242
#   LR: 5.00e-04
#
# Epoch 28/50 (0.23s)
#   Train Loss: 76.8649
#   Train Cosine Sim: 0.8899
#   Val Loss: 75.7314
#   Val Cosine Sim: 0.8915
#   Val OS24 AUC: 0.6350
#   LR: 5.00e-04
#
# Epoch 29/50 (0.24s)
#   Train Loss: 75.3605
#   Train Cosine Sim: 0.8923
#   Val Loss: 74.9632
#   Val Cosine Sim: 0.8936
#   Val OS24 AUC: 0.6141
#   LR: 5.00e-04
#
# Epoch 30/50 (0.26s)
#   Train Loss: 73.1592
#   Train Cosine Sim: 0.8941
#   Val Loss: 74.1763
#   Val Cosine Sim: 0.8954
#   Val OS24 AUC: 0.5506
#   LR: 5.00e-04
#
# Epoch 31/50 (0.22s)
#   Train Loss: 72.2834
#   Train Cosine Sim: 0.8956
#   Val Loss: 71.8704
#   Val Cosine Sim: 0.8974
#   Val OS24 AUC: 0.5794
#   LR: 2.50e-04
#
# Epoch 32/50 (0.21s)
#   Train Loss: 70.1117
#   Train Cosine Sim: 0.8974
#   Val Loss: 70.7510
#   Val Cosine Sim: 0.8984
#   Val OS24 AUC: 0.5924
#   LR: 2.50e-04
#
#   New best validation AUC: 0.6693
# Epoch 33/50 (0.36s)
#   Train Loss: 69.8006
#   Train Cosine Sim: 0.8982
#   Val Loss: 69.6040
#   Val Cosine Sim: 0.8994
#   Val OS24 AUC: 0.6693
#   LR: 2.50e-04
#
# Epoch 34/50 (0.21s)
#   Train Loss: 69.6275
#   Train Cosine Sim: 0.8992
#   Val Loss: 68.8064
#   Val Cosine Sim: 0.9005
#   Val OS24 AUC: 0.6618
#   LR: 2.50e-04
#
# Epoch 35/50 (0.21s)
#   Train Loss: 69.1601
#   Train Cosine Sim: 0.9003
#   Val Loss: 68.7428
#   Val Cosine Sim: 0.9014
#   Val OS24 AUC: 0.6676
#   LR: 2.50e-04
#
# Epoch 36/50 (0.21s)
#   Train Loss: 68.3376
#   Train Cosine Sim: 0.9012
#   Val Loss: 68.0366
#   Val Cosine Sim: 0.9024
#   Val OS24 AUC: 0.6664
#   LR: 2.50e-04
#
# Epoch 37/50 (0.22s)
#   Train Loss: 68.2354
#   Train Cosine Sim: 0.9022
#   Val Loss: 67.7399
#   Val Cosine Sim: 0.9033
#   Val OS24 AUC: 0.6543
#   LR: 2.50e-04
#
# Epoch 38/50 (0.22s)
#   Train Loss: 67.2528
#   Train Cosine Sim: 0.9029
#   Val Loss: 66.9591
#   Val Cosine Sim: 0.9043
#   Val OS24 AUC: 0.6559
#   LR: 2.50e-04
#
# Epoch 39/50 (0.22s)
#   Train Loss: 66.5333
#   Train Cosine Sim: 0.9038
#   Val Loss: 66.4654
#   Val Cosine Sim: 0.9052
#   Val OS24 AUC: 0.6049
#   LR: 2.50e-04
#
# Epoch 40/50 (0.22s)
#   Train Loss: 65.5347
#   Train Cosine Sim: 0.9048
#   Val Loss: 65.3292
#   Val Cosine Sim: 0.9061
#   Val OS24 AUC: 0.5828
#   LR: 2.50e-04
#
# Epoch 41/50 (0.22s)
#   Train Loss: 64.8000
#   Train Cosine Sim: 0.9062
#   Val Loss: 65.0887
#   Val Cosine Sim: 0.9069
#   Val OS24 AUC: 0.5882
#   LR: 2.50e-04
#
# Epoch 42/50 (0.21s)
#   Train Loss: 64.2798
#   Train Cosine Sim: 0.9067
#   Val Loss: 64.5610
#   Val Cosine Sim: 0.9077
#   Val OS24 AUC: 0.6028
#   LR: 2.50e-04
#
# Epoch 43/50 (0.40s)
#   Train Loss: 63.6366
#   Train Cosine Sim: 0.9076
#   Val Loss: 63.8050
#   Val Cosine Sim: 0.9086
#   Val OS24 AUC: 0.6417
#   LR: 2.50e-04
#
# Epoch 44/50 (0.21s)
#   Train Loss: 63.2219
#   Train Cosine Sim: 0.9084
#   Val Loss: 63.0864
#   Val Cosine Sim: 0.9095
#   Val OS24 AUC: 0.6413
#   LR: 1.25e-04
#
# Epoch 45/50 (0.19s)
#   Train Loss: 63.3972
#   Train Cosine Sim: 0.9089
#   Val Loss: 63.1255
#   Val Cosine Sim: 0.9100
#   Val OS24 AUC: 0.6363
#   LR: 1.25e-04
#
# Epoch 46/50 (0.19s)
#   Train Loss: 64.7070
#   Train Cosine Sim: 0.9093
#   Val Loss: 63.7668
#   Val Cosine Sim: 0.9104
#   Val OS24 AUC: 0.6559
#   LR: 1.25e-04
#
# Epoch 47/50 (0.19s)
#   Train Loss: 62.5925
#   Train Cosine Sim: 0.9098
#   Val Loss: 63.9218
#   Val Cosine Sim: 0.9108
#   Val OS24 AUC: 0.6530
#   LR: 1.25e-04
#
# Epoch 48/50 (0.19s)
#   Train Loss: 63.2359
#   Train Cosine Sim: 0.9105
#   Val Loss: 62.9516
#   Val Cosine Sim: 0.9113
#   Val OS24 AUC: 0.6438
#   LR: 1.25e-04
#
#   New best validation AUC: 0.6777
# Epoch 49/50 (0.34s)
#   Train Loss: 62.0160
#   Train Cosine Sim: 0.9108
#   Val Loss: 61.9134
#   Val Cosine Sim: 0.9117
#   Val OS24 AUC: 0.6777
#   LR: 1.25e-04
#
# Epoch 50/50 (0.19s)
#   Train Loss: 61.6030
#   Train Cosine Sim: 0.9112
#   Val Loss: 61.3800
#   Val Cosine Sim: 0.9122
#   Val OS24 AUC: 0.6714
#   LR: 1.25e-04
#
# Training completed!
# Best validation AUC: 0.6777
# Evaluating on test set...
# Loaded best model from epoch 48
#
# Test Results:
# Test Loss: 61.4687
# Test Cosine Sim: 0.9116
# OS24 - AUC: 0.6496, Accuracy: 0.7596, F1: 0.1935
#
# Results saved to: ./results/autoencoder_20250626_155444/autoencoder_20250626_155501

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && unset MPLBACKEND && python analyze_reconstruction.py \
    --model_path /share/project10/home/prelajarsela/Attention_based_reduction/gridsearch_results_FINAL/gridsearch_autoencoder_20250624_225515/combo_504/best_model.pth \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --attention_k 11 \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --endpoints os24

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/LUNG_RADIO_fast.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 11 \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 8.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# Stratification successful with endpoints: ['os24']
# Train samples: 522
# Validation samples: 118
# Test samples: 104
# Creating autoencoder model...
# Model parameters: 3,041,777
# Starting training...
# Starting training for 50 epochs...
# Model type: autoencoder
# Device: cuda
#   New best validation AUC: 0.4737
# Epoch 1/50 (1.13s)
#   Train Loss: 326.4054
#   Train Cosine Sim: 0.3807
#   Val Loss: 328.6370
#   Val Cosine Sim: 0.6422
#   Val OS24 AUC: 0.4737
#   LR: 1.00e-03
#
#   New best validation AUC: 0.5071
# Epoch 2/50 (0.36s)
#   Train Loss: 300.4253
#   Train Cosine Sim: 0.6649
#   Val Loss: 316.9499
#   Val Cosine Sim: 0.6973
#   Val OS24 AUC: 0.5071
#   LR: 1.00e-03
#
#   New best validation AUC: 0.5280
# Epoch 3/50 (0.36s)
#   Train Loss: 278.6347
#   Train Cosine Sim: 0.7050
#   Val Loss: 291.2252
#   Val Cosine Sim: 0.7201
#   Val OS24 AUC: 0.5280
#   LR: 1.00e-03
#
#   New best validation AUC: 0.5330
# Epoch 4/50 (0.36s)
#   Train Loss: 256.4196
#   Train Cosine Sim: 0.7262
#   Val Loss: 268.8198
#   Val Cosine Sim: 0.7377
#   Val OS24 AUC: 0.5330
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6070
# Epoch 5/50 (0.36s)
#   Train Loss: 235.9198
#   Train Cosine Sim: 0.7437
#   Val Loss: 247.3353
#   Val Cosine Sim: 0.7536
#   Val OS24 AUC: 0.6070
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6375
# Epoch 6/50 (0.36s)
#   Train Loss: 217.1984
#   Train Cosine Sim: 0.7594
#   Val Loss: 225.0635
#   Val Cosine Sim: 0.7683
#   Val OS24 AUC: 0.6375
#   LR: 1.00e-03
#
# Epoch 7/50 (0.27s)
#   Train Loss: 197.0454
#   Train Cosine Sim: 0.7735
#   Val Loss: 202.2187
#   Val Cosine Sim: 0.7821
#   Val OS24 AUC: 0.5535
#   LR: 1.00e-03
#
# Epoch 8/50 (0.27s)
#   Train Loss: 181.5876
#   Train Cosine Sim: 0.7879
#   Val Loss: 183.5180
#   Val Cosine Sim: 0.7951
#   Val OS24 AUC: 0.6120
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6522
# Epoch 9/50 (0.36s)
#   Train Loss: 165.4734
#   Train Cosine Sim: 0.8004
#   Val Loss: 163.9827
#   Val Cosine Sim: 0.8075
#   Val OS24 AUC: 0.6522
#   LR: 1.00e-03
#
# Epoch 10/50 (0.27s)
#   Train Loss: 150.8525
#   Train Cosine Sim: 0.8123
#   Val Loss: 147.9625
#   Val Cosine Sim: 0.8192
#   Val OS24 AUC: 0.5798
#   LR: 1.00e-03
#
# Epoch 11/50 (0.26s)
#   Train Loss: 139.2687
#   Train Cosine Sim: 0.8237
#   Val Loss: 137.2071
#   Val Cosine Sim: 0.8297
#   Val OS24 AUC: 0.5209
#   LR: 1.00e-03
#
# Epoch 12/50 (0.27s)
#   Train Loss: 128.2708
#   Train Cosine Sim: 0.8336
#   Val Loss: 130.6312
#   Val Cosine Sim: 0.8382
#   Val OS24 AUC: 0.5686
#   LR: 1.00e-03
#
# Epoch 13/50 (0.27s)
#   Train Loss: 119.4287
#   Train Cosine Sim: 0.8427
#   Val Loss: 120.4518
#   Val Cosine Sim: 0.8481
#   Val OS24 AUC: 0.5640
#   LR: 1.00e-03
#
# Epoch 14/50 (0.31s)
#   Train Loss: 112.0054
#   Train Cosine Sim: 0.8516
#   Val Loss: 114.1856
#   Val Cosine Sim: 0.8559
#   Val OS24 AUC: 0.5844
#   LR: 1.00e-03
#
# Epoch 15/50 (0.26s)
#   Train Loss: 104.9369
#   Train Cosine Sim: 0.8594
#   Val Loss: 108.4740
#   Val Cosine Sim: 0.8634
#   Val OS24 AUC: 0.5648
#   LR: 1.00e-03
#
# Epoch 16/50 (0.26s)
#   Train Loss: 99.6627
#   Train Cosine Sim: 0.8662
#   Val Loss: 100.7740
#   Val Cosine Sim: 0.8701
#   Val OS24 AUC: 0.5013
#   LR: 1.00e-03
#
# Epoch 17/50 (0.27s)
#   Train Loss: 96.9088
#   Train Cosine Sim: 0.8723
#   Val Loss: 95.2562
#   Val Cosine Sim: 0.8762
#   Val OS24 AUC: 0.5360
#   LR: 1.00e-03
#
# Epoch 18/50 (0.27s)
#   Train Loss: 89.8282
#   Train Cosine Sim: 0.8781
#   Val Loss: 93.4520
#   Val Cosine Sim: 0.8815
#   Val OS24 AUC: 0.5155
#   LR: 1.00e-03
#
# Epoch 19/50 (0.27s)
#   Train Loss: 86.6861
#   Train Cosine Sim: 0.8834
#   Val Loss: 89.7968
#   Val Cosine Sim: 0.8861
#   Val OS24 AUC: 0.4992
#   LR: 1.00e-03
#
# Epoch 20/50 (0.27s)
#   Train Loss: 83.9257
#   Train Cosine Sim: 0.8870
#   Val Loss: 88.5856
#   Val Cosine Sim: 0.8894
#   Val OS24 AUC: 0.5176
#   LR: 5.00e-04
#
# Epoch 21/50 (0.26s)
#   Train Loss: 81.4263
#   Train Cosine Sim: 0.8914
#   Val Loss: 81.8028
#   Val Cosine Sim: 0.8931
#   Val OS24 AUC: 0.5435
#   LR: 5.00e-04
#
# Epoch 22/50 (0.26s)
#   Train Loss: 78.9228
#   Train Cosine Sim: 0.8936
#   Val Loss: 80.6389
#   Val Cosine Sim: 0.8953
#   Val OS24 AUC: 0.5711
#   LR: 5.00e-04
#
# Epoch 23/50 (0.26s)
#   Train Loss: 79.1450
#   Train Cosine Sim: 0.8955
#   Val Loss: 80.0402
#   Val Cosine Sim: 0.8974
#   Val OS24 AUC: 0.5736
#   LR: 5.00e-04
#
# Epoch 24/50 (0.27s)
#   Train Loss: 75.3678
#   Train Cosine Sim: 0.8977
#   Val Loss: 77.4696
#   Val Cosine Sim: 0.8993
#   Val OS24 AUC: 0.5702
#   LR: 5.00e-04
#
# Epoch 25/50 (0.27s)
#   Train Loss: 74.2658
#   Train Cosine Sim: 0.8995
#   Val Loss: 76.2250
#   Val Cosine Sim: 0.9013
#   Val OS24 AUC: 0.5038
#   LR: 5.00e-04
#
# Epoch 26/50 (0.27s)
#   Train Loss: 74.5763
#   Train Cosine Sim: 0.9014
#   Val Loss: 75.2202
#   Val Cosine Sim: 0.9033
#   Val OS24 AUC: 0.4916
#   LR: 5.00e-04
#
# Epoch 27/50 (0.27s)
#   Train Loss: 72.7906
#   Train Cosine Sim: 0.9036
#   Val Loss: 73.6537
#   Val Cosine Sim: 0.9052
#   Val OS24 AUC: 0.5075
#   LR: 5.00e-04
#
# Epoch 28/50 (0.27s)
#   Train Loss: 71.5726
#   Train Cosine Sim: 0.9055
#   Val Loss: 72.3903
#   Val Cosine Sim: 0.9069
#   Val OS24 AUC: 0.5569
#   LR: 5.00e-04
#
# Early stopping triggered after 20 epochs without improvement
# Restored best weights
# Epoch 29/50 (0.27s)
#   Train Loss: 70.3842
#   Train Cosine Sim: 0.9071
#   Val Loss: 70.9496
#   Val Cosine Sim: 0.9090
#   Val OS24 AUC: 0.5673
#   LR: 5.00e-04
#
# Early stopping triggered!
# Training completed!
# Best validation AUC: 0.6522
# Evaluating on test set...
# Loaded best model from epoch 8
#
# Test Results:
# Test Loss: 160.8475
# Test Cosine Sim: 0.8078
# OS24 - AUC: 0.5716, Accuracy: 0.7500, F1: 0.0714
#
# Results saved to: ./results/autoencoder_20250626_103726/autoencoder_20250626_103752

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python extract_features.py \
    --model_path /share/project10/home/prelajarsela/Attention_based_reduction/gridsearch_results_FINAL/gridsearch_autoencoder_20250624_225515/combo_504/best_model.pth \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --output_csv /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/I3LUNG_reduced_features_BEST.csv \
    --attention_k 11 \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --endpoints os24
# Out:
# Loading model from: /share/project10/home/prelajarsela/Attention_based_reduction/gridsearch_results_FINAL/gridsearch_autoencoder_20250624_225515/combo_504/best_model.pth
# Processing 4 pkl files...
# Extracted features for 757 patients
# Feature dimensions: 256
# Results saved to: /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/I3LUNG_reduced_features_BEST.csv
#
# Data availability summary:
#   OS_6: 740/757 (97.8%)
#   OS_24: 693/757 (91.5%)
#   STAGE_T: 720/757 (95.1%)
#   STAGE_N: 720/757 (95.1%)
#   STAGE_M: 720/757 (95.1%)

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 256 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 3.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# Traceback (most recent call last):
#   File "/share/project10/home/prelajarsela/Attention_based_reduction/main_autoencoder.py", line 191, in <module>
#     main()
#   File "/share/project10/home/prelajarsela/Attention_based_reduction/main_autoencoder.py", line 49, in main
#     train_loader, val_loader, test_loader, class_weights = create_data_loaders(
#   File "/share/project10/home/prelajarsela/Attention_based_reduction/utils/dataloader.py", line 388, in create_data_loaders
#     train_val_data, test_data = apply_train_test_split(all_data, split_json)
# NameError: name 'apply_train_test_split' is not defined. Did you mean: 'train_test_split'?

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# Stratification successful with endpoints: ['os24']
# Train samples: 522
# Validation samples: 118
# Test samples: 104
# Creating autoencoder model...
# Model parameters: 6,013,169
# Starting training...
# Starting training for 50 epochs...
# Model type: autoencoder
# Device: cuda
#   New best validation AUC: 0.6359
# Epoch 1/50 (0.91s)
#   Train Loss: 323.7172
#   Train Cosine Sim: 0.3729
#   Val Loss: 322.2661
#   Val Cosine Sim: 0.6373
#   Val OS24 AUC: 0.6359
#   LR: 1.00e-03
#
# Epoch 2/50 (0.21s)
#   Train Loss: 299.1913
#   Train Cosine Sim: 0.6618
#   Val Loss: 306.8900
#   Val Cosine Sim: 0.6982
#   Val OS24 AUC: 0.6041
#   LR: 1.00e-03
#
# Epoch 3/50 (0.21s)
#   Train Loss: 274.8188
#   Train Cosine Sim: 0.7038
#   Val Loss: 274.5112
#   Val Cosine Sim: 0.7215
#   Val OS24 AUC: 0.5272
#   LR: 1.00e-03
#
# Epoch 4/50 (0.21s)
#   Train Loss: 254.2530
#   Train Cosine Sim: 0.7267
#   Val Loss: 250.1137
#   Val Cosine Sim: 0.7393
#   Val OS24 AUC: 0.5803
#   LR: 1.00e-03
#
# Epoch 5/50 (0.20s)
#   Train Loss: 231.7436
#   Train Cosine Sim: 0.7437
#   Val Loss: 229.6379
#   Val Cosine Sim: 0.7546
#   Val OS24 AUC: 0.5778
#   LR: 1.00e-03
#
# Epoch 6/50 (0.21s)
#   Train Loss: 212.0549
#   Train Cosine Sim: 0.7600
#   Val Loss: 210.3613
#   Val Cosine Sim: 0.7692
#   Val OS24 AUC: 0.5351
#   LR: 1.00e-03
#
# Epoch 7/50 (0.24s)
#   Train Loss: 192.5634
#   Train Cosine Sim: 0.7748
#   Val Loss: 193.8949
#   Val Cosine Sim: 0.7827
#   Val OS24 AUC: 0.5903
#   LR: 1.00e-03
#
# Epoch 8/50 (0.24s)
#   Train Loss: 172.4300
#   Train Cosine Sim: 0.7888
#   Val Loss: 166.8608
#   Val Cosine Sim: 0.7967
#   Val OS24 AUC: 0.6304
#   LR: 1.00e-03
#
# Epoch 9/50 (0.25s)
#   Train Loss: 158.0429
#   Train Cosine Sim: 0.8023
#   Val Loss: 153.4350
#   Val Cosine Sim: 0.8092
#   Val OS24 AUC: 0.6058
#   LR: 1.00e-03
#
# Epoch 10/50 (0.24s)
#   Train Loss: 142.4723
#   Train Cosine Sim: 0.8144
#   Val Loss: 142.2705
#   Val Cosine Sim: 0.8204
#   Val OS24 AUC: 0.6091
#   LR: 1.00e-03
#
# Epoch 11/50 (0.23s)
#   Train Loss: 131.5479
#   Train Cosine Sim: 0.8255
#   Val Loss: 127.8992
#   Val Cosine Sim: 0.8315
#   Val OS24 AUC: 0.6087
#   LR: 1.00e-03
#
# Epoch 12/50 (0.23s)
#   Train Loss: 119.9357
#   Train Cosine Sim: 0.8357
#   Val Loss: 117.6358
#   Val Cosine Sim: 0.8413
#   Val OS24 AUC: 0.6338
#   LR: 5.00e-04
#
#   New best validation AUC: 0.6509
# Epoch 13/50 (0.38s)
#   Train Loss: 114.2936
#   Train Cosine Sim: 0.8433
#   Val Loss: 113.1661
#   Val Cosine Sim: 0.8465
#   Val OS24 AUC: 0.6509
#   LR: 5.00e-04
#
# Epoch 14/50 (0.23s)
#   Train Loss: 109.7455
#   Train Cosine Sim: 0.8481
#   Val Loss: 112.2894
#   Val Cosine Sim: 0.8506
#   Val OS24 AUC: 0.6008
#   LR: 5.00e-04
#
# Epoch 15/50 (0.25s)
#   Train Loss: 106.5763
#   Train Cosine Sim: 0.8523
#   Val Loss: 108.4477
#   Val Cosine Sim: 0.8545
#   Val OS24 AUC: 0.5853
#   LR: 5.00e-04
#
# Epoch 16/50 (0.24s)
#   Train Loss: 103.4556
#   Train Cosine Sim: 0.8557
#   Val Loss: 105.0472
#   Val Cosine Sim: 0.8583
#   Val OS24 AUC: 0.5811
#   LR: 5.00e-04
#
# Epoch 17/50 (0.23s)
#   Train Loss: 101.0501
#   Train Cosine Sim: 0.8597
#   Val Loss: 102.4640
#   Val Cosine Sim: 0.8619
#   Val OS24 AUC: 0.5832
#   LR: 5.00e-04
#
# Epoch 18/50 (0.23s)
#   Train Loss: 98.1256
#   Train Cosine Sim: 0.8632
#   Val Loss: 100.2438
#   Val Cosine Sim: 0.8653
#   Val OS24 AUC: 0.5732
#   LR: 5.00e-04
#
# Epoch 19/50 (0.23s)
#   Train Loss: 94.6518
#   Train Cosine Sim: 0.8666
#   Val Loss: 95.0183
#   Val Cosine Sim: 0.8685
#   Val OS24 AUC: 0.6225
#   LR: 5.00e-04
#
#   New best validation AUC: 0.6522
# Epoch 20/50 (0.38s)
#   Train Loss: 92.0653
#   Train Cosine Sim: 0.8697
#   Val Loss: 91.8369
#   Val Cosine Sim: 0.8715
#   Val OS24 AUC: 0.6522
#   LR: 5.00e-04
#
# Epoch 21/50 (0.22s)
#   Train Loss: 89.4647
#   Train Cosine Sim: 0.8719
#   Val Loss: 90.0502
#   Val Cosine Sim: 0.8743
#   Val OS24 AUC: 0.6150
#   LR: 5.00e-04
#
# Epoch 22/50 (0.24s)
#   Train Loss: 87.2428
#   Train Cosine Sim: 0.8752
#   Val Loss: 87.8774
#   Val Cosine Sim: 0.8771
#   Val OS24 AUC: 0.5560
#   LR: 5.00e-04
#
# Epoch 23/50 (0.24s)
#   Train Loss: 85.9995
#   Train Cosine Sim: 0.8779
#   Val Loss: 86.3521
#   Val Cosine Sim: 0.8796
#   Val OS24 AUC: 0.5711
#   LR: 5.00e-04
#
# Epoch 24/50 (0.24s)
#   Train Loss: 82.8876
#   Train Cosine Sim: 0.8804
#   Val Loss: 86.7240
#   Val Cosine Sim: 0.8821
#   Val OS24 AUC: 0.5895
#   LR: 5.00e-04
#
# Epoch 25/50 (0.26s)
#   Train Loss: 81.5443
#   Train Cosine Sim: 0.8826
#   Val Loss: 82.6020
#   Val Cosine Sim: 0.8848
#   Val OS24 AUC: 0.6217
#   LR: 5.00e-04
#
# Epoch 26/50 (0.24s)
#   Train Loss: 79.7250
#   Train Cosine Sim: 0.8854
#   Val Loss: 79.2784
#   Val Cosine Sim: 0.8872
#   Val OS24 AUC: 0.6325
#   LR: 5.00e-04
#
# Epoch 27/50 (0.24s)
#   Train Loss: 77.8001
#   Train Cosine Sim: 0.8878
#   Val Loss: 76.9482
#   Val Cosine Sim: 0.8894
#   Val OS24 AUC: 0.6242
#   LR: 5.00e-04
#
# Epoch 28/50 (0.24s)
#   Train Loss: 76.8649
#   Train Cosine Sim: 0.8899
#   Val Loss: 75.7314
#   Val Cosine Sim: 0.8915
#   Val OS24 AUC: 0.6350
#   LR: 5.00e-04
#
# Epoch 29/50 (0.24s)
#   Train Loss: 75.3605
#   Train Cosine Sim: 0.8923
#   Val Loss: 74.9632
#   Val Cosine Sim: 0.8936
#   Val OS24 AUC: 0.6141
#   LR: 5.00e-04
#
# Epoch 30/50 (0.26s)
#   Train Loss: 73.1592
#   Train Cosine Sim: 0.8941
#   Val Loss: 74.1763
#   Val Cosine Sim: 0.8954
#   Val OS24 AUC: 0.5506
#   LR: 5.00e-04
#
# Epoch 31/50 (0.24s)
#   Train Loss: 72.2834
#   Train Cosine Sim: 0.8956
#   Val Loss: 71.8704
#   Val Cosine Sim: 0.8974
#   Val OS24 AUC: 0.5794
#   LR: 2.50e-04
#
# Epoch 32/50 (0.24s)
#   Train Loss: 70.1117
#   Train Cosine Sim: 0.8974
#   Val Loss: 70.7510
#   Val Cosine Sim: 0.8984
#   Val OS24 AUC: 0.5924
#   LR: 2.50e-04
#
#   New best validation AUC: 0.6693
# Epoch 33/50 (0.38s)
#   Train Loss: 69.8006
#   Train Cosine Sim: 0.8982
#   Val Loss: 69.6040
#   Val Cosine Sim: 0.8994
#   Val OS24 AUC: 0.6693
#   LR: 2.50e-04
#
# Epoch 34/50 (0.23s)
#   Train Loss: 69.6275
#   Train Cosine Sim: 0.8992
#   Val Loss: 68.8064
#   Val Cosine Sim: 0.9005
#   Val OS24 AUC: 0.6618
#   LR: 2.50e-04
#
# Epoch 35/50 (0.23s)
#   Train Loss: 69.1601
#   Train Cosine Sim: 0.9003
#   Val Loss: 68.7428
#   Val Cosine Sim: 0.9014
#   Val OS24 AUC: 0.6676
#   LR: 2.50e-04
#
# Epoch 36/50 (0.24s)
#   Train Loss: 68.3376
#   Train Cosine Sim: 0.9012
#   Val Loss: 68.0366
#   Val Cosine Sim: 0.9024
#   Val OS24 AUC: 0.6664
#   LR: 2.50e-04
#
# Epoch 37/50 (0.24s)
#   Train Loss: 68.2354
#   Train Cosine Sim: 0.9022
#   Val Loss: 67.7399
#   Val Cosine Sim: 0.9033
#   Val OS24 AUC: 0.6543
#   LR: 2.50e-04
#
# Epoch 38/50 (0.25s)
#   Train Loss: 67.2528
#   Train Cosine Sim: 0.9029
#   Val Loss: 66.9591
#   Val Cosine Sim: 0.9043
#   Val OS24 AUC: 0.6559
#   LR: 2.50e-04
#
# Epoch 39/50 (0.24s)
#   Train Loss: 66.5333
#   Train Cosine Sim: 0.9038
#   Val Loss: 66.4654
#   Val Cosine Sim: 0.9052
#   Val OS24 AUC: 0.6049
#   LR: 2.50e-04
#
# Epoch 40/50 (0.24s)
#   Train Loss: 65.5347
#   Train Cosine Sim: 0.9048
#   Val Loss: 65.3292
#   Val Cosine Sim: 0.9061
#   Val OS24 AUC: 0.5828
#   LR: 2.50e-04
#
# Epoch 41/50 (0.24s)
#   Train Loss: 64.8000
#   Train Cosine Sim: 0.9062
#   Val Loss: 65.0887
#   Val Cosine Sim: 0.9069
#   Val OS24 AUC: 0.5882
#   LR: 2.50e-04
#
# Epoch 42/50 (0.24s)
#   Train Loss: 64.2798
#   Train Cosine Sim: 0.9067
#   Val Loss: 64.5610
#   Val Cosine Sim: 0.9077
#   Val OS24 AUC: 0.6028
#   LR: 2.50e-04
#
# Epoch 43/50 (0.24s)
#   Train Loss: 63.6366
#   Train Cosine Sim: 0.9076
#   Val Loss: 63.8050
#   Val Cosine Sim: 0.9086
#   Val OS24 AUC: 0.6417
#   LR: 2.50e-04
#
# Epoch 44/50 (0.23s)
#   Train Loss: 63.2219
#   Train Cosine Sim: 0.9084
#   Val Loss: 63.0864
#   Val Cosine Sim: 0.9095
#   Val OS24 AUC: 0.6413
#   LR: 1.25e-04
#
# Epoch 45/50 (0.23s)
#   Train Loss: 63.3972
#   Train Cosine Sim: 0.9089
#   Val Loss: 63.1255
#   Val Cosine Sim: 0.9100
#   Val OS24 AUC: 0.6363
#   LR: 1.25e-04
#
# Epoch 46/50 (0.23s)
#   Train Loss: 64.7070
#   Train Cosine Sim: 0.9093
#   Val Loss: 63.7668
#   Val Cosine Sim: 0.9104
#   Val OS24 AUC: 0.6559
#   LR: 1.25e-04
#
# Epoch 47/50 (0.23s)
#   Train Loss: 62.5925
#   Train Cosine Sim: 0.9098
#   Val Loss: 63.9218
#   Val Cosine Sim: 0.9108
#   Val OS24 AUC: 0.6530
#   LR: 1.25e-04
#
# Epoch 48/50 (0.23s)
#   Train Loss: 63.2359
#   Train Cosine Sim: 0.9105
#   Val Loss: 62.9516
#   Val Cosine Sim: 0.9113
#   Val OS24 AUC: 0.6438
#   LR: 1.25e-04
#
#   New best validation AUC: 0.6777
# Epoch 49/50 (0.39s)
#   Train Loss: 62.0160
#   Train Cosine Sim: 0.9108
#   Val Loss: 61.9134
#   Val Cosine Sim: 0.9117
#   Val OS24 AUC: 0.6777
#   LR: 1.25e-04
#
# Epoch 50/50 (0.23s)
#   Train Loss: 61.6030
#   Train Cosine Sim: 0.9112
#   Val Loss: 61.3800
#   Val Cosine Sim: 0.9122
#   Val OS24 AUC: 0.6714
#   LR: 1.25e-04
#
# Training completed!
# Best validation AUC: 0.6777
# Evaluating on test set...
# Loaded best model from epoch 48
# Test Results:
# Test Loss: 61.4687
# Test Cosine Sim: 0.9116
# OS24 - AUC: 0.6496, Accuracy: 0.7596, F1: 0.1935
#
# Results saved to: ./results/autoencoder_20250624_154414/autoencoder_20250624_154429

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# Stratification successful with endpoints: ['os24']
# Train samples: 522
# Validation samples: 118
# Test samples: 104
# Creating autoencoder model...
# Model parameters: 6,013,169
# Starting training...
# Starting training for 50 epochs...
# Model type: autoencoder
# Device: cuda
# Epoch 1/50 (0.94s)
#   Train Loss: 323.7172
#   Train Cosine Sim: 0.3729
#   Val Loss: 322.2661
#   Val Cosine Sim: 0.6373
#   Val OS24 AUC: 0.6359
#   LR: 1.00e-03
#
# Epoch 2/50 (0.41s)
#   Train Loss: 299.1913
#   Train Cosine Sim: 0.6618
#   Val Loss: 306.8900
#   Val Cosine Sim: 0.6982
#   Val OS24 AUC: 0.6041
#   LR: 1.00e-03
#
# Epoch 3/50 (0.42s)
#   Train Loss: 274.8188
#   Train Cosine Sim: 0.7038
#   Val Loss: 274.5112
#   Val Cosine Sim: 0.7215
#   Val OS24 AUC: 0.5272
#   LR: 1.00e-03
#
# Epoch 4/50 (0.42s)
#   Train Loss: 254.2530
#   Train Cosine Sim: 0.7267
#   Val Loss: 250.1137
#   Val Cosine Sim: 0.7393
#   Val OS24 AUC: 0.5803
#   LR: 1.00e-03
#
# Epoch 5/50 (0.41s)
#   Train Loss: 231.7436
#   Train Cosine Sim: 0.7437
#   Val Loss: 229.6379
#   Val Cosine Sim: 0.7546
#   Val OS24 AUC: 0.5778
#   LR: 1.00e-03
#
# Epoch 6/50 (0.41s)
#   Train Loss: 212.0549
#   Train Cosine Sim: 0.7600
#   Val Loss: 210.3613
#   Val Cosine Sim: 0.7692
#   Val OS24 AUC: 0.5351
#   LR: 1.00e-03
#
# Epoch 7/50 (0.42s)
#   Train Loss: 192.5634
#   Train Cosine Sim: 0.7748
#   Val Loss: 193.8949
#   Val Cosine Sim: 0.7827
#   Val OS24 AUC: 0.5903
#   LR: 1.00e-03
#
# Epoch 8/50 (0.40s)
#   Train Loss: 172.4300
#   Train Cosine Sim: 0.7888
#   Val Loss: 166.8608
#   Val Cosine Sim: 0.7967
#   Val OS24 AUC: 0.6304
#   LR: 1.00e-03
#
# Epoch 9/50 (0.41s)
#   Train Loss: 158.0429
#   Train Cosine Sim: 0.8023
#   Val Loss: 153.4350
#   Val Cosine Sim: 0.8092
#   Val OS24 AUC: 0.6058
#   LR: 1.00e-03
#
# Epoch 10/50 (0.39s)
#   Train Loss: 142.4723
#   Train Cosine Sim: 0.8144
#   Val Loss: 142.2705
#   Val Cosine Sim: 0.8204
#   Val OS24 AUC: 0.6091
#   LR: 1.00e-03
#
# Epoch 11/50 (0.39s)
#   Train Loss: 131.5479
#   Train Cosine Sim: 0.8255
#   Val Loss: 127.8992
#   Val Cosine Sim: 0.8315
#   Val OS24 AUC: 0.6087
#   LR: 1.00e-03
#
# Epoch 12/50 (0.39s)
#   Train Loss: 119.9357
#   Train Cosine Sim: 0.8357
#   Val Loss: 117.6358
#   Val Cosine Sim: 0.8413
#   Val OS24 AUC: 0.6338
#   LR: 1.00e-03
#
# Epoch 13/50 (0.38s)
#   Train Loss: 112.8119
#   Train Cosine Sim: 0.8451
#   Val Loss: 109.5054
#   Val Cosine Sim: 0.8504
#   Val OS24 AUC: 0.6442
#   LR: 1.00e-03
#
# Epoch 14/50 (0.37s)
#   Train Loss: 104.8748
#   Train Cosine Sim: 0.8538
#   Val Loss: 106.6048
#   Val Cosine Sim: 0.8578
#   Val OS24 AUC: 0.5932
#   LR: 1.00e-03
#
# Epoch 15/50 (0.39s)
#   Train Loss: 98.7946
#   Train Cosine Sim: 0.8609
#   Val Loss: 100.7207
#   Val Cosine Sim: 0.8644
#   Val OS24 AUC: 0.5514
#   LR: 1.00e-03
#
# Epoch 16/50 (0.39s)
#   Train Loss: 93.6780
#   Train Cosine Sim: 0.8669
#   Val Loss: 93.9850
#   Val Cosine Sim: 0.8707
#   Val OS24 AUC: 0.5385
#   LR: 1.00e-03
#
# Epoch 17/50 (0.39s)
#   Train Loss: 89.7242
#   Train Cosine Sim: 0.8733
#   Val Loss: 89.9275
#   Val Cosine Sim: 0.8767
#   Val OS24 AUC: 0.5640
#   LR: 1.00e-03
#
# Epoch 18/50 (0.38s)
#   Train Loss: 85.4425
#   Train Cosine Sim: 0.8789
#   Val Loss: 89.4812
#   Val Cosine Sim: 0.8815
#   Val OS24 AUC: 0.5803
#   LR: 1.00e-03
#
# Epoch 19/50 (0.38s)
#   Train Loss: 80.8709
#   Train Cosine Sim: 0.8840
#   Val Loss: 80.1963
#   Val Cosine Sim: 0.8866
#   Val OS24 AUC: 0.6099
#   LR: 1.00e-03
#
# Epoch 20/50 (0.39s)
#   Train Loss: 77.7659
#   Train Cosine Sim: 0.8885
#   Val Loss: 76.2085
#   Val Cosine Sim: 0.8911
#   Val OS24 AUC: 0.6375
#   LR: 1.00e-03
#
# Epoch 21/50 (0.37s)
#   Train Loss: 74.2466
#   Train Cosine Sim: 0.8922
#   Val Loss: 73.4005
#   Val Cosine Sim: 0.8951
#   Val OS24 AUC: 0.6350
#   LR: 1.00e-03
#
# Epoch 22/50 (0.38s)
#   Train Loss: 71.3034
#   Train Cosine Sim: 0.8967
#   Val Loss: 70.4243
#   Val Cosine Sim: 0.8994
#   Val OS24 AUC: 0.6150
#   LR: 1.00e-03
#
# Epoch 23/50 (0.38s)
#   Train Loss: 69.4095
#   Train Cosine Sim: 0.9007
#   Val Loss: 67.7656
#   Val Cosine Sim: 0.9032
#   Val OS24 AUC: 0.6074
#   LR: 1.00e-03
#
# Epoch 24/50 (0.24s)
#   Train Loss: 66.2187
#   Train Cosine Sim: 0.9044
#   Val Loss: 70.6272
#   Val Cosine Sim: 0.9067
#   Val OS24 AUC: 0.5957
#   LR: 1.00e-03
#
# Epoch 25/50 (0.39s)
#   Train Loss: 63.9040
#   Train Cosine Sim: 0.9076
#   Val Loss: 64.0407
#   Val Cosine Sim: 0.9103
#   Val OS24 AUC: 0.6329
#   LR: 1.00e-03
#
# Epoch 26/50 (0.38s)
#   Train Loss: 62.0681
#   Train Cosine Sim: 0.9114
#   Val Loss: 60.1607
#   Val Cosine Sim: 0.9137
#   Val OS24 AUC: 0.6292
#   LR: 1.00e-03
#
# Epoch 27/50 (0.38s)
#   Train Loss: 59.2821
#   Train Cosine Sim: 0.9146
#   Val Loss: 57.9072
#   Val Cosine Sim: 0.9168
#   Val OS24 AUC: 0.6384
#   LR: 1.00e-03
#
# Epoch 28/50 (0.38s)
#   Train Loss: 58.1847
#   Train Cosine Sim: 0.9177
#   Val Loss: 56.2513
#   Val Cosine Sim: 0.9197
#   Val OS24 AUC: 0.6200
#   LR: 1.00e-03
#
# Epoch 29/50 (0.38s)
#   Train Loss: 55.9597
#   Train Cosine Sim: 0.9207
#   Val Loss: 55.1902
#   Val Cosine Sim: 0.9225
#   Val OS24 AUC: 0.5472
#   LR: 1.00e-03
#
# Epoch 30/50 (0.38s)
#   Train Loss: 54.0157
#   Train Cosine Sim: 0.9233
#   Val Loss: 53.0389
#   Val Cosine Sim: 0.9252
#   Val OS24 AUC: 0.5790
#   LR: 1.00e-03
#
# Epoch 31/50 (0.38s)
#   Train Loss: 52.5121
#   Train Cosine Sim: 0.9257
#   Val Loss: 51.5772
#   Val Cosine Sim: 0.9279
#   Val OS24 AUC: 0.5949
#   LR: 1.00e-03
#
# Epoch 32/50 (0.38s)
#   Train Loss: 50.1554
#   Train Cosine Sim: 0.9285
#   Val Loss: 49.4806
#   Val Cosine Sim: 0.9303
#   Val OS24 AUC: 0.5803
#   LR: 1.00e-03
#
# Epoch 33/50 (0.39s)
#   Train Loss: 48.6039
#   Train Cosine Sim: 0.9310
#   Val Loss: 47.1786
#   Val Cosine Sim: 0.9331
#   Val OS24 AUC: 0.6572
#   LR: 1.00e-03
#
# Epoch 34/50 (0.38s)
#   Train Loss: 47.1626
#   Train Cosine Sim: 0.9337
#   Val Loss: 45.5520
#   Val Cosine Sim: 0.9358
#   Val OS24 AUC: 0.6568
#   LR: 1.00e-03
#
# Epoch 35/50 (0.38s)
#   Train Loss: 46.1983
#   Train Cosine Sim: 0.9363
#   Val Loss: 44.7827
#   Val Cosine Sim: 0.9382
#   Val OS24 AUC: 0.6288
#   LR: 1.00e-03
#
# Epoch 36/50 (0.37s)
#   Train Loss: 44.9147
#   Train Cosine Sim: 0.9387
#   Val Loss: 43.8213
#   Val Cosine Sim: 0.9404
#   Val OS24 AUC: 0.6526
#   LR: 1.00e-03
#
# Epoch 37/50 (0.38s)
#   Train Loss: 43.4642
#   Train Cosine Sim: 0.9408
#   Val Loss: 42.4108
#   Val Cosine Sim: 0.9426
#   Val OS24 AUC: 0.6334
#   LR: 1.00e-03
#
# Epoch 38/50 (0.38s)
#   Train Loss: 41.7593
#   Train Cosine Sim: 0.9429
#   Val Loss: 40.2555
#   Val Cosine Sim: 0.9449
#   Val OS24 AUC: 0.6647
#   LR: 1.00e-03
#
# Epoch 39/50 (0.39s)
#   Train Loss: 40.7226
#   Train Cosine Sim: 0.9450
#   Val Loss: 38.9443
#   Val Cosine Sim: 0.9469
#   Val OS24 AUC: 0.6380
#   LR: 1.00e-03
#
# Epoch 40/50 (0.41s)
#   Train Loss: 39.6082
#   Train Cosine Sim: 0.9472
#   Val Loss: 38.8584
#   Val Cosine Sim: 0.9489
#   Val OS24 AUC: 0.6108
#   LR: 1.00e-03
#
# Epoch 41/50 (0.38s)
#   Train Loss: 37.5662
#   Train Cosine Sim: 0.9495
#   Val Loss: 37.2874
#   Val Cosine Sim: 0.9509
#   Val OS24 AUC: 0.6309
#   LR: 1.00e-03
#
# Epoch 42/50 (0.38s)
#   Train Loss: 36.2898
#   Train Cosine Sim: 0.9511
#   Val Loss: 35.1620
#   Val Cosine Sim: 0.9527
#   Val OS24 AUC: 0.6396
#   LR: 1.00e-03
#
# Epoch 43/50 (0.37s)
#   Train Loss: 34.8228
#   Train Cosine Sim: 0.9530
#   Val Loss: 34.1054
#   Val Cosine Sim: 0.9548
#   Val OS24 AUC: 0.6158
#   LR: 1.00e-03
#
# Epoch 44/50 (0.38s)
#   Train Loss: 33.7306
#   Train Cosine Sim: 0.9550
#   Val Loss: 33.2215
#   Val Cosine Sim: 0.9567
#   Val OS24 AUC: 0.5598
#   LR: 1.00e-03
#
# Epoch 45/50 (0.38s)
#   Train Loss: 33.1648
#   Train Cosine Sim: 0.9567
#   Val Loss: 31.7954
#   Val Cosine Sim: 0.9585
#   Val OS24 AUC: 0.5982
#   LR: 1.00e-03
#
# Epoch 46/50 (0.38s)
#   Train Loss: 33.0699
#   Train Cosine Sim: 0.9583
#   Val Loss: 30.1823
#   Val Cosine Sim: 0.9601
#   Val OS24 AUC: 0.5677
#   LR: 1.00e-03
#
# Epoch 47/50 (0.23s)
#   Train Loss: 31.9715
#   Train Cosine Sim: 0.9599
#   Val Loss: 30.6620
#   Val Cosine Sim: 0.9608
#   Val OS24 AUC: 0.5054
#   LR: 1.00e-03
#
# Epoch 48/50 (0.38s)
#   Train Loss: 31.1866
#   Train Cosine Sim: 0.9613
#   Val Loss: 29.3310
#   Val Cosine Sim: 0.9628
#   Val OS24 AUC: 0.6388
#   LR: 1.00e-03
#
# Epoch 49/50 (0.37s)
#   Train Loss: 30.1282
#   Train Cosine Sim: 0.9627
#   Val Loss: 28.0657
#   Val Cosine Sim: 0.9644
#   Val OS24 AUC: 0.6171
#   LR: 1.00e-03
#
# Epoch 50/50 (0.38s)
#   Train Loss: 28.6805
#   Train Cosine Sim: 0.9637
#   Val Loss: 26.4531
#   Val Cosine Sim: 0.9655
#   Val OS24 AUC: 0.6350
#   LR: 1.00e-03
#
# Training completed!
# Best validation loss: 26.4531
# Evaluating on test set...
# Loaded best model from epoch 49
#
# Test Results:
# Test Loss: 26.4406
# Test Cosine Sim: 0.9655
# OS24 - AUC: 0.5868, Accuracy: 0.7212, F1: 0.0645
#
# Results saved to: ./results/autoencoder_20250624_134530/autoencoder_20250624_134545

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints os6 \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# Stratification successful with endpoints: ['os6']
# Train samples: 514
# Validation samples: 126
# Test samples: 112
# Creating autoencoder model...
# Model parameters: 6,013,169
# Starting training...
# Starting training for 50 epochs...
# Model type: autoencoder
# Device: cuda
# Epoch 1/50 (1.66s)
#   Train Loss: 321.5627
#   Train Cosine Sim: 0.3767
#   Val Loss: 323.4326
#   Val Cosine Sim: 0.6341
#   Val OS6 AUC: 0.5312
#   LR: 1.00e-03
#
# Epoch 2/50 (0.40s)
#   Train Loss: 293.6528
#   Train Cosine Sim: 0.6624
#   Val Loss: 304.8902
#   Val Cosine Sim: 0.6985
#   Val OS6 AUC: 0.5716
#   LR: 1.00e-03
#
# Epoch 3/50 (0.38s)
#   Train Loss: 274.8964
#   Train Cosine Sim: 0.7054
#   Val Loss: 279.2225
#   Val Cosine Sim: 0.7223
#   Val OS6 AUC: 0.5559
#   LR: 1.00e-03
#
# Epoch 4/50 (0.39s)
#   Train Loss: 252.3966
#   Train Cosine Sim: 0.7271
#   Val Loss: 262.9414
#   Val Cosine Sim: 0.7395
#   Val OS6 AUC: 0.5811
#   LR: 1.00e-03
#
# Epoch 5/50 (0.40s)
#   Train Loss: 232.1424
#   Train Cosine Sim: 0.7450
#   Val Loss: 238.9432
#   Val Cosine Sim: 0.7547
#   Val OS6 AUC: 0.6125
#   LR: 1.00e-03
#
# Epoch 6/50 (0.38s)
#   Train Loss: 210.2779
#   Train Cosine Sim: 0.7601
#   Val Loss: 215.3275
#   Val Cosine Sim: 0.7689
#   Val OS6 AUC: 0.5834
#   LR: 1.00e-03
#
# Epoch 7/50 (0.38s)
#   Train Loss: 193.5261
#   Train Cosine Sim: 0.7744
#   Val Loss: 194.6381
#   Val Cosine Sim: 0.7827
#   Val OS6 AUC: 0.5447
#   LR: 1.00e-03
#
# Epoch 8/50 (0.39s)
#   Train Loss: 176.7328
#   Train Cosine Sim: 0.7879
#   Val Loss: 173.6569
#   Val Cosine Sim: 0.7949
#   Val OS6 AUC: 0.5276
#   LR: 1.00e-03
#
# Epoch 9/50 (0.39s)
#   Train Loss: 161.7108
#   Train Cosine Sim: 0.8005
#   Val Loss: 162.2507
#   Val Cosine Sim: 0.8066
#   Val OS6 AUC: 0.5663
#   LR: 1.00e-03
#
# Epoch 10/50 (0.41s)
#   Train Loss: 146.7139
#   Train Cosine Sim: 0.8118
#   Val Loss: 148.2663
#   Val Cosine Sim: 0.8173
#   Val OS6 AUC: 0.5548
#   LR: 1.00e-03
#
# Epoch 11/50 (0.40s)
#   Train Loss: 136.3417
#   Train Cosine Sim: 0.8225
#   Val Loss: 131.7242
#   Val Cosine Sim: 0.8277
#   Val OS6 AUC: 0.5436
#   LR: 1.00e-03
#
# Epoch 12/50 (0.40s)
#   Train Loss: 123.7068
#   Train Cosine Sim: 0.8319
#   Val Loss: 128.5992
#   Val Cosine Sim: 0.8373
#   Val OS6 AUC: 0.5604
#   LR: 1.00e-03
#
# Epoch 13/50 (0.39s)
#   Train Loss: 116.2187
#   Train Cosine Sim: 0.8405
#   Val Loss: 119.2428
#   Val Cosine Sim: 0.8463
#   Val OS6 AUC: 0.5651
#   LR: 1.00e-03
#
# Epoch 14/50 (0.38s)
#   Train Loss: 109.1894
#   Train Cosine Sim: 0.8489
#   Val Loss: 117.5248
#   Val Cosine Sim: 0.8535
#   Val OS6 AUC: 0.5548
#   LR: 1.00e-03
#
# Epoch 15/50 (0.39s)
#   Train Loss: 102.0784
#   Train Cosine Sim: 0.8562
#   Val Loss: 110.2225
#   Val Cosine Sim: 0.8606
#   Val OS6 AUC: 0.5324
#   LR: 1.00e-03
#
# Epoch 16/50 (0.39s)
#   Train Loss: 95.2164
#   Train Cosine Sim: 0.8623
#   Val Loss: 103.0998
#   Val Cosine Sim: 0.8671
#   Val OS6 AUC: 0.5254
#   LR: 1.00e-03
#
# Epoch 17/50 (0.39s)
#   Train Loss: 90.6108
#   Train Cosine Sim: 0.8683
#   Val Loss: 96.7526
#   Val Cosine Sim: 0.8735
#   Val OS6 AUC: 0.5643
#   LR: 1.00e-03
#
# Epoch 18/50 (0.39s)
#   Train Loss: 88.1140
#   Train Cosine Sim: 0.8760
#   Val Loss: 95.5903
#   Val Cosine Sim: 0.8785
#   Val OS6 AUC: 0.5545
#   LR: 1.00e-03
#
# Epoch 19/50 (0.47s)
#   Train Loss: 83.5078
#   Train Cosine Sim: 0.8801
#   Val Loss: 89.3927
#   Val Cosine Sim: 0.8828
#   Val OS6 AUC: 0.5436
#   LR: 1.00e-03
#
# Epoch 20/50 (0.40s)
#   Train Loss: 78.3126
#   Train Cosine Sim: 0.8852
#   Val Loss: 83.2541
#   Val Cosine Sim: 0.8875
#   Val OS6 AUC: 0.5424
#   LR: 1.00e-03
#
# Epoch 21/50 (0.40s)
#   Train Loss: 75.2320
#   Train Cosine Sim: 0.8900
#   Val Loss: 79.3138
#   Val Cosine Sim: 0.8919
#   Val OS6 AUC: 0.5329
#   LR: 1.00e-03
#
# Epoch 22/50 (0.42s)
#   Train Loss: 73.0971
#   Train Cosine Sim: 0.8941
#   Val Loss: 76.9397
#   Val Cosine Sim: 0.8960
#   Val OS6 AUC: 0.5402
#   LR: 1.00e-03
#
# Epoch 23/50 (0.41s)
#   Train Loss: 70.4857
#   Train Cosine Sim: 0.8978
#   Val Loss: 74.7353
#   Val Cosine Sim: 0.8995
#   Val OS6 AUC: 0.5338
#   LR: 1.00e-03
#
# Epoch 24/50 (0.38s)
#   Train Loss: 67.3814
#   Train Cosine Sim: 0.9012
#   Val Loss: 70.3865
#   Val Cosine Sim: 0.9034
#   Val OS6 AUC: 0.5542
#   LR: 1.00e-03
#
# Epoch 25/50 (0.24s)
#   Train Loss: 65.6826
#   Train Cosine Sim: 0.9048
#   Val Loss: 70.9038
#   Val Cosine Sim: 0.9069
#   Val OS6 AUC: 0.5514
#   LR: 1.00e-03
#
# Epoch 26/50 (0.39s)
#   Train Loss: 63.7191
#   Train Cosine Sim: 0.9075
#   Val Loss: 66.2147
#   Val Cosine Sim: 0.9106
#   Val OS6 AUC: 0.5509
#   LR: 1.00e-03
#
# Epoch 27/50 (0.40s)
#   Train Loss: 61.3047
#   Train Cosine Sim: 0.9115
#   Val Loss: 65.4883
#   Val Cosine Sim: 0.9136
#   Val OS6 AUC: 0.5312
#   LR: 1.00e-03
#
# Epoch 28/50 (0.40s)
#   Train Loss: 59.4681
#   Train Cosine Sim: 0.9149
#   Val Loss: 62.7975
#   Val Cosine Sim: 0.9165
#   Val OS6 AUC: 0.5125
#   LR: 1.00e-03
#
# Epoch 29/50 (0.40s)
#   Train Loss: 56.7846
#   Train Cosine Sim: 0.9179
#   Val Loss: 61.0121
#   Val Cosine Sim: 0.9191
#   Val OS6 AUC: 0.5144
#   LR: 1.00e-03
#
# Epoch 30/50 (0.43s)
#   Train Loss: 55.5615
#   Train Cosine Sim: 0.9201
#   Val Loss: 58.8226
#   Val Cosine Sim: 0.9217
#   Val OS6 AUC: 0.4982
#   LR: 1.00e-03
#
# Epoch 31/50 (0.38s)
#   Train Loss: 53.4967
#   Train Cosine Sim: 0.9217
#   Val Loss: 55.9200
#   Val Cosine Sim: 0.9243
#   Val OS6 AUC: 0.5354
#   LR: 1.00e-03
#
# Epoch 32/50 (0.38s)
#   Train Loss: 51.7310
#   Train Cosine Sim: 0.9240
#   Val Loss: 53.7563
#   Val Cosine Sim: 0.9270
#   Val OS6 AUC: 0.5531
#   LR: 1.00e-03
#
# Epoch 33/50 (0.39s)
#   Train Loss: 49.3456
#   Train Cosine Sim: 0.9277
#   Val Loss: 51.5259
#   Val Cosine Sim: 0.9300
#   Val OS6 AUC: 0.5615
#   LR: 1.00e-03
#
# Epoch 34/50 (0.25s)
#   Train Loss: 48.3692
#   Train Cosine Sim: 0.9314
#   Val Loss: 51.5874
#   Val Cosine Sim: 0.9326
#   Val OS6 AUC: 0.5528
#   LR: 1.00e-03
#
# Epoch 35/50 (0.39s)
#   Train Loss: 46.1600
#   Train Cosine Sim: 0.9338
#   Val Loss: 49.0266
#   Val Cosine Sim: 0.9351
#   Val OS6 AUC: 0.5495
#   LR: 1.00e-03
#
# Epoch 36/50 (0.39s)
#   Train Loss: 45.3147
#   Train Cosine Sim: 0.9354
#   Val Loss: 47.7796
#   Val Cosine Sim: 0.9374
#   Val OS6 AUC: 0.5623
#   LR: 1.00e-03
#
# Epoch 37/50 (0.38s)
#   Train Loss: 44.2784
#   Train Cosine Sim: 0.9389
#   Val Loss: 46.0262
#   Val Cosine Sim: 0.9398
#   Val OS6 AUC: 0.5671
#   LR: 1.00e-03
#
# Epoch 38/50 (0.39s)
#   Train Loss: 42.4443
#   Train Cosine Sim: 0.9398
#   Val Loss: 45.5549
#   Val Cosine Sim: 0.9420
#   Val OS6 AUC: 0.5548
#   LR: 1.00e-03
#
# Epoch 39/50 (0.40s)
#   Train Loss: 41.2775
#   Train Cosine Sim: 0.9425
#   Val Loss: 43.3403
#   Val Cosine Sim: 0.9439
#   Val OS6 AUC: 0.5391
#   LR: 1.00e-03
#
# Epoch 40/50 (0.39s)
#   Train Loss: 39.2975
#   Train Cosine Sim: 0.9447
#   Val Loss: 42.0184
#   Val Cosine Sim: 0.9461
#   Val OS6 AUC: 0.5360
#   LR: 1.00e-03
#
# Epoch 41/50 (0.39s)
#   Train Loss: 37.8945
#   Train Cosine Sim: 0.9466
#   Val Loss: 41.4833
#   Val Cosine Sim: 0.9480
#   Val OS6 AUC: 0.5399
#   LR: 1.00e-03
#
# Epoch 42/50 (0.40s)
#   Train Loss: 36.9017
#   Train Cosine Sim: 0.9474
#   Val Loss: 40.4200
#   Val Cosine Sim: 0.9500
#   Val OS6 AUC: 0.5469
#   LR: 1.00e-03
#
# Epoch 43/50 (0.39s)
#   Train Loss: 35.9874
#   Train Cosine Sim: 0.9505
#   Val Loss: 38.6503
#   Val Cosine Sim: 0.9516
#   Val OS6 AUC: 0.5430
#   LR: 1.00e-03
#
# Epoch 44/50 (0.43s)
#   Train Loss: 35.5975
#   Train Cosine Sim: 0.9512
#   Val Loss: 37.2534
#   Val Cosine Sim: 0.9537
#   Val OS6 AUC: 0.5450
#   LR: 1.00e-03
#
# Epoch 45/50 (0.44s)
#   Train Loss: 33.5808
#   Train Cosine Sim: 0.9542
#   Val Loss: 32.4808
#   Val Cosine Sim: 0.9551
#   Val OS6 AUC: 0.5296
#   LR: 1.00e-03
#
# Epoch 46/50 (0.26s)
#   Train Loss: 33.3454
#   Train Cosine Sim: 0.9545
#   Val Loss: 33.3434
#   Val Cosine Sim: 0.9572
#   Val OS6 AUC: 0.5220
#   LR: 1.00e-03
#
# Epoch 47/50 (0.25s)
#   Train Loss: 31.2471
#   Train Cosine Sim: 0.9573
#   Val Loss: 32.6622
#   Val Cosine Sim: 0.9587
#   Val OS6 AUC: 0.5310
#   LR: 1.00e-03
#
# Epoch 48/50 (0.40s)
#   Train Loss: 30.6840
#   Train Cosine Sim: 0.9574
#   Val Loss: 31.8536
#   Val Cosine Sim: 0.9602
#   Val OS6 AUC: 0.5570
#   LR: 1.00e-03
#
# Epoch 49/50 (0.39s)
#   Train Loss: 29.5369
#   Train Cosine Sim: 0.9602
#   Val Loss: 30.9236
#   Val Cosine Sim: 0.9617
#   Val OS6 AUC: 0.5646
#   LR: 1.00e-03
#
# Epoch 50/50 (0.42s)
#   Train Loss: 28.2182
#   Train Cosine Sim: 0.9623
#   Val Loss: 30.6655
#   Val Cosine Sim: 0.9634
#   Val OS6 AUC: 0.5548
#   LR: 1.00e-03
#
# Training completed!
# Best validation loss: 30.6655
# Evaluating on test set...
# Loaded best model from epoch 49
#
# Test Results:
# Test Loss: 29.7365
# Test Cosine Sim: 0.9640
# OS6 - AUC: 0.4516, Accuracy: 0.6607, F1: 0.7935
#
# Results saved to: ./results/autoencoder_20250624_134608/autoencoder_20250624_134624

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 100 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints stage_t \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cpu
# Creating data loaders...
# Stratification successful with endpoints: ['stage_t']
# Train samples: 517
# Validation samples: 123
# Test samples: 107
# Creating autoencoder model...
# Model parameters: 6,054,645
# Starting training...
# Starting training for 100 epochs...
# Model type: autoencoder
# Device: cpu
#   New best validation loss: 332.8708
# Epoch 1/100 (0.94s)
#   Train Loss: 334.7590
#   Train Cosine Sim: 0.3737
#   Val Loss: 332.8708
#   Val Cosine Sim: 0.6360
#   Val STAGE_T Acc: 0.1382
#   LR: 1.00e-03
#
#   New best validation loss: 318.0161
# Epoch 2/100 (0.75s)
#   Train Loss: 308.3173
#   Train Cosine Sim: 0.6608
#   Val Loss: 318.0161
#   Val Cosine Sim: 0.6960
#   Val STAGE_T Acc: 0.1463
#   LR: 1.00e-03
#
#   New best validation loss: 293.2038
# Epoch 3/100 (0.84s)
#   Train Loss: 285.0062
#   Train Cosine Sim: 0.7036
#   Val Loss: 293.2038
#   Val Cosine Sim: 0.7203
#   Val STAGE_T Acc: 0.2114
#   LR: 1.00e-03
#
#   New best validation loss: 268.2487
# Epoch 4/100 (0.82s)
#   Train Loss: 263.6630
#   Train Cosine Sim: 0.7251
#   Val Loss: 268.2487
#   Val Cosine Sim: 0.7378
#   Val STAGE_T Acc: 0.2358
#   LR: 1.00e-03
#
#   New best validation loss: 255.7369
# Epoch 5/100 (0.78s)
#   Train Loss: 243.7138
#   Train Cosine Sim: 0.7428
#   Val Loss: 255.7369
#   Val Cosine Sim: 0.7527
#   Val STAGE_T Acc: 0.2195
#   LR: 1.00e-03
#
#   New best validation loss: 230.6901
# Epoch 6/100 (0.80s)
#   Train Loss: 225.4380
#   Train Cosine Sim: 0.7592
#   Val Loss: 230.6901
#   Val Cosine Sim: 0.7673
#   Val STAGE_T Acc: 0.1789
#   LR: 1.00e-03
#
#   New best validation loss: 209.0976
# Epoch 7/100 (0.78s)
#   Train Loss: 206.7083
#   Train Cosine Sim: 0.7728
#   Val Loss: 209.0976
#   Val Cosine Sim: 0.7808
#   Val STAGE_T Acc: 0.1870
#   LR: 1.00e-03
#
#   New best validation loss: 194.4292
# Epoch 8/100 (0.82s)
#   Train Loss: 190.3785
#   Train Cosine Sim: 0.7866
#   Val Loss: 194.4292
#   Val Cosine Sim: 0.7930
#   Val STAGE_T Acc: 0.2683
#   LR: 1.00e-03
#
#   New best validation loss: 175.1614
# Epoch 9/100 (0.85s)
#   Train Loss: 173.5960
#   Train Cosine Sim: 0.7985
#   Val Loss: 175.1614
#   Val Cosine Sim: 0.8053
#   Val STAGE_T Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 158.8600
# Epoch 10/100 (0.93s)
#   Train Loss: 158.1253
#   Train Cosine Sim: 0.8093
#   Val Loss: 158.8600
#   Val Cosine Sim: 0.8167
#   Val STAGE_T Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 148.8205
# Epoch 11/100 (0.85s)
#   Train Loss: 147.6344
#   Train Cosine Sim: 0.8211
#   Val Loss: 148.8205
#   Val Cosine Sim: 0.8269
#   Val STAGE_T Acc: 0.3171
#   LR: 1.00e-03
#
#   New best validation loss: 137.9019
# Epoch 12/100 (0.82s)
#   Train Loss: 136.5148
#   Train Cosine Sim: 0.8317
#   Val Loss: 137.9019
#   Val Cosine Sim: 0.8369
#   Val STAGE_T Acc: 0.2683
#   LR: 1.00e-03
#
#   New best validation loss: 126.0630
# Epoch 13/100 (0.89s)
#   Train Loss: 127.7147
#   Train Cosine Sim: 0.8412
#   Val Loss: 126.0630
#   Val Cosine Sim: 0.8460
#   Val STAGE_T Acc: 0.2602
#   LR: 1.00e-03
#
#   New best validation loss: 119.9730
# Epoch 14/100 (0.85s)
#   Train Loss: 119.2206
#   Train Cosine Sim: 0.8491
#   Val Loss: 119.9730
#   Val Cosine Sim: 0.8540
#   Val STAGE_T Acc: 0.3008
#   LR: 1.00e-03
#
#   New best validation loss: 115.1027
# Epoch 15/100 (0.86s)
#   Train Loss: 112.4514
#   Train Cosine Sim: 0.8575
#   Val Loss: 115.1027
#   Val Cosine Sim: 0.8609
#   Val STAGE_T Acc: 0.3496
#   LR: 1.00e-03
#
#   New best validation loss: 109.0087
# Epoch 16/100 (0.94s)
#   Train Loss: 106.5561
#   Train Cosine Sim: 0.8640
#   Val Loss: 109.0087
#   Val Cosine Sim: 0.8674
#   Val STAGE_T Acc: 0.3496
#   LR: 1.00e-03
#
#   New best validation loss: 107.2239
# Epoch 17/100 (0.94s)
#   Train Loss: 103.6212
#   Train Cosine Sim: 0.8703
#   Val Loss: 107.2239
#   Val Cosine Sim: 0.8737
#   Val STAGE_T Acc: 0.2927
#   LR: 1.00e-03
#
#   New best validation loss: 106.9740
# Epoch 18/100 (0.81s)
#   Train Loss: 98.7654
#   Train Cosine Sim: 0.8757
#   Val Loss: 106.9740
#   Val Cosine Sim: 0.8785
#   Val STAGE_T Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 103.2334
# Epoch 19/100 (0.90s)
#   Train Loss: 94.6367
#   Train Cosine Sim: 0.8813
#   Val Loss: 103.2334
#   Val Cosine Sim: 0.8836
#   Val STAGE_T Acc: 0.2764
#   LR: 1.00e-03
#
#   New best validation loss: 93.8104
# Epoch 20/100 (0.90s)
#   Train Loss: 90.5285
#   Train Cosine Sim: 0.8856
#   Val Loss: 93.8104
#   Val Cosine Sim: 0.8881
#   Val STAGE_T Acc: 0.2602
#   LR: 1.00e-03
#
#   New best validation loss: 90.7329
# Epoch 21/100 (1.49s)
#   Train Loss: 87.1905
#   Train Cosine Sim: 0.8896
#   Val Loss: 90.7329
#   Val Cosine Sim: 0.8920
#   Val STAGE_T Acc: 0.2764
#   LR: 1.00e-03
#
#   New best validation loss: 84.6516
# Epoch 22/100 (0.93s)
#   Train Loss: 83.3661
#   Train Cosine Sim: 0.8940
#   Val Loss: 84.6516
#   Val Cosine Sim: 0.8964
#   Val STAGE_T Acc: 0.2602
#   LR: 1.00e-03
#
#   New best validation loss: 81.8721
# Epoch 23/100 (0.76s)
#   Train Loss: 81.5999
#   Train Cosine Sim: 0.8987
#   Val Loss: 81.8721
#   Val Cosine Sim: 0.9003
#   Val STAGE_T Acc: 0.2358
#   LR: 1.00e-03
#
#   New best validation loss: 78.8947
# Epoch 24/100 (0.74s)
#   Train Loss: 78.4565
#   Train Cosine Sim: 0.9015
#   Val Loss: 78.8947
#   Val Cosine Sim: 0.9039
#   Val STAGE_T Acc: 0.2683
#   LR: 1.00e-03
#
#   New best validation loss: 75.9927
# Epoch 25/100 (0.72s)
#   Train Loss: 76.1542
#   Train Cosine Sim: 0.9059
#   Val Loss: 75.9927
#   Val Cosine Sim: 0.9076
#   Val STAGE_T Acc: 0.2927
#   LR: 1.00e-03
#
#   New best validation loss: 73.9344
# Epoch 26/100 (0.71s)
#   Train Loss: 74.3597
#   Train Cosine Sim: 0.9087
#   Val Loss: 73.9344
#   Val Cosine Sim: 0.9109
#   Val STAGE_T Acc: 0.2764
#   LR: 1.00e-03
#
#   New best validation loss: 72.2873
# Epoch 27/100 (0.99s)
#   Train Loss: 71.7901
#   Train Cosine Sim: 0.9118
#   Val Loss: 72.2873
#   Val Cosine Sim: 0.9142
#   Val STAGE_T Acc: 0.2114
#   LR: 1.00e-03
#
#   New best validation loss: 70.8663
# Epoch 28/100 (0.94s)
#   Train Loss: 69.2761
#   Train Cosine Sim: 0.9151
#   Val Loss: 70.8663
#   Val Cosine Sim: 0.9173
#   Val STAGE_T Acc: 0.2195
#   LR: 1.00e-03
#
#   New best validation loss: 68.9378
# Epoch 29/100 (0.95s)
#   Train Loss: 67.3821
#   Train Cosine Sim: 0.9186
#   Val Loss: 68.9378
#   Val Cosine Sim: 0.9205
#   Val STAGE_T Acc: 0.2033
#   LR: 1.00e-03
#
#   New best validation loss: 65.6164
# Epoch 30/100 (1.06s)
#   Train Loss: 65.1852
#   Train Cosine Sim: 0.9218
#   Val Loss: 65.6164
#   Val Cosine Sim: 0.9233
#   Val STAGE_T Acc: 0.1789
#   LR: 1.00e-03
#
#   New best validation loss: 63.8253
# Epoch 31/100 (1.21s)
#   Train Loss: 63.6362
#   Train Cosine Sim: 0.9245
#   Val Loss: 63.8253
#   Val Cosine Sim: 0.9261
#   Val STAGE_T Acc: 0.2602
#   LR: 1.00e-03
#
#   New best validation loss: 62.7527
# Epoch 32/100 (1.10s)
#   Train Loss: 62.1811
#   Train Cosine Sim: 0.9277
#   Val Loss: 62.7527
#   Val Cosine Sim: 0.9289
#   Val STAGE_T Acc: 0.2195
#   LR: 1.00e-03
#
#   New best validation loss: 60.3423
# Epoch 33/100 (1.09s)
#   Train Loss: 60.7786
#   Train Cosine Sim: 0.9296
#   Val Loss: 60.3423
#   Val Cosine Sim: 0.9315
#   Val STAGE_T Acc: 0.2927
#   LR: 1.00e-03
#
#   New best validation loss: 59.0356
# Epoch 34/100 (0.97s)
#   Train Loss: 58.4653
#   Train Cosine Sim: 0.9327
#   Val Loss: 59.0356
#   Val Cosine Sim: 0.9341
#   Val STAGE_T Acc: 0.3089
#   LR: 1.00e-03
#
#   New best validation loss: 57.6501
# Epoch 35/100 (1.09s)
#   Train Loss: 57.3733
#   Train Cosine Sim: 0.9354
#   Val Loss: 57.6501
#   Val Cosine Sim: 0.9366
#   Val STAGE_T Acc: 0.2846
#   LR: 1.00e-03
#
#   New best validation loss: 55.7402
# Epoch 36/100 (0.95s)
#   Train Loss: 55.1490
#   Train Cosine Sim: 0.9375
#   Val Loss: 55.7402
#   Val Cosine Sim: 0.9387
#   Val STAGE_T Acc: 0.2927
#   LR: 1.00e-03
#
#   New best validation loss: 54.4769
# Epoch 37/100 (0.90s)
#   Train Loss: 54.9304
#   Train Cosine Sim: 0.9391
#   Val Loss: 54.4769
#   Val Cosine Sim: 0.9408
#   Val STAGE_T Acc: 0.2602
#   LR: 1.00e-03
#
#   New best validation loss: 52.8503
# Epoch 38/100 (0.83s)
#   Train Loss: 53.4928
#   Train Cosine Sim: 0.9417
#   Val Loss: 52.8503
#   Val Cosine Sim: 0.9432
#   Val STAGE_T Acc: 0.2195
#   LR: 1.00e-03
#
#   New best validation loss: 51.8824
# Epoch 39/100 (0.84s)
#   Train Loss: 51.7718
#   Train Cosine Sim: 0.9440
#   Val Loss: 51.8824
#   Val Cosine Sim: 0.9453
#   Val STAGE_T Acc: 0.1382
#   LR: 1.00e-03
#
#   New best validation loss: 50.8231
# Epoch 40/100 (0.83s)
#   Train Loss: 50.1306
#   Train Cosine Sim: 0.9464
#   Val Loss: 50.8231
#   Val Cosine Sim: 0.9474
#   Val STAGE_T Acc: 0.2276
#   LR: 1.00e-03
#
#   New best validation loss: 49.4855
# Epoch 41/100 (0.85s)
#   Train Loss: 49.4008
#   Train Cosine Sim: 0.9483
#   Val Loss: 49.4855
#   Val Cosine Sim: 0.9493
#   Val STAGE_T Acc: 0.2114
#   LR: 1.00e-03
#   New best validation loss: 48.0578
# Epoch 42/100 (0.75s)
#   Train Loss: 47.5991
#   Train Cosine Sim: 0.9502
#   Val Loss: 48.0578
#   Val Cosine Sim: 0.9512
#   Val STAGE_T Acc: 0.2114
#   LR: 1.00e-03
#
#   New best validation loss: 47.3353
# Epoch 43/100 (0.81s)
#   Train Loss: 46.7547
#   Train Cosine Sim: 0.9519
#   Val Loss: 47.3353
#   Val Cosine Sim: 0.9534
#   Val STAGE_T Acc: 0.2114
#   LR: 1.00e-03
#
#   New best validation loss: 45.2511
# Epoch 44/100 (0.73s)
#   Train Loss: 44.9721
#   Train Cosine Sim: 0.9540
#   Val Loss: 45.2511
#   Val Cosine Sim: 0.9550
#   Val STAGE_T Acc: 0.2358
#   LR: 1.00e-03
#
#   New best validation loss: 43.7244
# Epoch 45/100 (0.72s)
#   Train Loss: 43.8814
#   Train Cosine Sim: 0.9556
#   Val Loss: 43.7244
#   Val Cosine Sim: 0.9572
#   Val STAGE_T Acc: 0.2276
#   LR: 1.00e-03
#
#   New best validation loss: 42.7391
# Epoch 46/100 (0.73s)
#   Train Loss: 43.4420
#   Train Cosine Sim: 0.9581
#   Val Loss: 42.7391
#   Val Cosine Sim: 0.9593
#   Val STAGE_T Acc: 0.1951
#   LR: 1.00e-03
#
#   New best validation loss: 41.9279
# Epoch 47/100 (0.74s)
#   Train Loss: 42.6390
#   Train Cosine Sim: 0.9593
#   Val Loss: 41.9279
#   Val Cosine Sim: 0.9607
#   Val STAGE_T Acc: 0.1789
#   LR: 1.00e-03
#
#   New best validation loss: 40.7473
# Epoch 48/100 (0.73s)
#   Train Loss: 40.4268
#   Train Cosine Sim: 0.9611
#   Val Loss: 40.7473
#   Val Cosine Sim: 0.9619
#   Val STAGE_T Acc: 0.1382
#   LR: 1.00e-03
#
#   New best validation loss: 39.2716
# Epoch 49/100 (0.73s)
#   Train Loss: 39.6108
#   Train Cosine Sim: 0.9625
#   Val Loss: 39.2716
#   Val Cosine Sim: 0.9634
#   Val STAGE_T Acc: 0.1301
#   LR: 1.00e-03
#
#   New best validation loss: 38.4169
# Epoch 50/100 (0.73s)
#   Train Loss: 39.7295
#   Train Cosine Sim: 0.9637
#   Val Loss: 38.4169
#   Val Cosine Sim: 0.9650
#   Val STAGE_T Acc: 0.1789
#   LR: 1.00e-03
#
#   New best validation loss: 36.6889
# Epoch 51/100 (0.76s)
#   Train Loss: 37.8945
#   Train Cosine Sim: 0.9650
#   Val Loss: 36.6889
#   Val Cosine Sim: 0.9660
#   Val STAGE_T Acc: 0.2358
#   LR: 1.00e-03
#
#   New best validation loss: 36.4141
# Epoch 52/100 (0.82s)
#   Train Loss: 36.9795
#   Train Cosine Sim: 0.9667
#   Val Loss: 36.4141
#   Val Cosine Sim: 0.9673
#   Val STAGE_T Acc: 0.1951
#   LR: 1.00e-03
#
#   New best validation loss: 36.0654
# Epoch 53/100 (0.88s)
#   Train Loss: 36.5756
#   Train Cosine Sim: 0.9681
#   Val Loss: 36.0654
#   Val Cosine Sim: 0.9686
#   Val STAGE_T Acc: 0.1545
#   LR: 1.00e-03
#
#   New best validation loss: 35.9394
# Epoch 54/100 (0.95s)
#   Train Loss: 35.0049
#   Train Cosine Sim: 0.9696
#   Val Loss: 35.9394
#   Val Cosine Sim: 0.9703
#   Val STAGE_T Acc: 0.1138
#   LR: 1.00e-03
#
#   New best validation loss: 35.4417
# Epoch 55/100 (0.89s)
#   Train Loss: 34.7580
#   Train Cosine Sim: 0.9710
#   Val Loss: 35.4417
#   Val Cosine Sim: 0.9714
#   Val STAGE_T Acc: 0.1545
#   LR: 1.00e-03
#
#   New best validation loss: 34.5627
# Epoch 56/100 (0.88s)
#   Train Loss: 33.8092
#   Train Cosine Sim: 0.9722
#   Val Loss: 34.5627
#   Val Cosine Sim: 0.9725
#   Val STAGE_T Acc: 0.1220
#   LR: 1.00e-03
#
#   New best validation loss: 33.6964
# Epoch 57/100 (0.88s)
#   Train Loss: 33.8891
#   Train Cosine Sim: 0.9723
#   Val Loss: 33.6964
#   Val Cosine Sim: 0.9734
#   Val STAGE_T Acc: 0.1138
#   LR: 1.00e-03
#
#   New best validation loss: 33.1621
# Epoch 58/100 (0.85s)
#   Train Loss: 32.8313
#   Train Cosine Sim: 0.9731
#   Val Loss: 33.1621
#   Val Cosine Sim: 0.9741
#   Val STAGE_T Acc: 0.1220
#   LR: 1.00e-03
#
#   New best validation loss: 32.6505
# Epoch 59/100 (0.81s)
#   Train Loss: 32.0397
#   Train Cosine Sim: 0.9741
#   Val Loss: 32.6505
#   Val Cosine Sim: 0.9752
#   Val STAGE_T Acc: 0.1382
#   LR: 1.00e-03
#
#   New best validation loss: 30.7799
# Epoch 60/100 (0.81s)
#   Train Loss: 31.4453
#   Train Cosine Sim: 0.9757
#   Val Loss: 30.7799
#   Val Cosine Sim: 0.9763
#   Val STAGE_T Acc: 0.1626
#   LR: 1.00e-03
#
#   New best validation loss: 30.0665
# Epoch 61/100 (0.82s)
#   Train Loss: 30.3316
#   Train Cosine Sim: 0.9763
#   Val Loss: 30.0665
#   Val Cosine Sim: 0.9771
#   Val STAGE_T Acc: 0.1789
#   LR: 1.00e-03
#
#   New best validation loss: 29.5093
# Epoch 62/100 (0.86s)
#   Train Loss: 29.5860
#   Train Cosine Sim: 0.9771
#   Val Loss: 29.5093
#   Val Cosine Sim: 0.9784
#   Val STAGE_T Acc: 0.1870
#   LR: 1.00e-03
#
#   New best validation loss: 28.9828
# Epoch 63/100 (0.83s)
#   Train Loss: 29.2935
#   Train Cosine Sim: 0.9783
#   Val Loss: 28.9828
#   Val Cosine Sim: 0.9792
#   Val STAGE_T Acc: 0.2195
#   LR: 1.00e-03
#
#   New best validation loss: 28.4681
# Epoch 64/100 (0.81s)
#   Train Loss: 28.0929
#   Train Cosine Sim: 0.9792
#   Val Loss: 28.4681
#   Val Cosine Sim: 0.9798
#   Val STAGE_T Acc: 0.2764
#   LR: 1.00e-03
#
#   New best validation loss: 27.6765
# Epoch 65/100 (0.74s)
#   Train Loss: 27.9315
#   Train Cosine Sim: 0.9801
#   Val Loss: 27.6765
#   Val Cosine Sim: 0.9807
#   Val STAGE_T Acc: 0.2358
#   LR: 1.00e-03
#
#   New best validation loss: 27.1916
# Epoch 66/100 (0.70s)
#   Train Loss: 29.7491
#   Train Cosine Sim: 0.9808
#   Val Loss: 27.1916
#   Val Cosine Sim: 0.9814
#   Val STAGE_T Acc: 0.2114
#   LR: 1.00e-03
#
# Epoch 67/100 (0.54s)
#   Train Loss: 29.1503
#   Train Cosine Sim: 0.9812
#   Val Loss: 28.1413
#   Val Cosine Sim: 0.9812
#   Val STAGE_T Acc: 0.2276
#   LR: 1.00e-03
#
#   New best validation loss: 26.8938
# Epoch 68/100 (0.68s)
#   Train Loss: 30.6363
#   Train Cosine Sim: 0.9814
#   Val Loss: 26.8938
#   Val Cosine Sim: 0.9821
#   Val STAGE_T Acc: 0.2683
#   LR: 1.00e-03
#
# Epoch 69/100 (0.58s)
#   Train Loss: 27.9084
#   Train Cosine Sim: 0.9814
#   Val Loss: 27.2951
#   Val Cosine Sim: 0.9826
#   Val STAGE_T Acc: 0.2764
#   LR: 1.00e-03
#
# Epoch 70/100 (0.54s)
#   Train Loss: 26.9586
#   Train Cosine Sim: 0.9828
#   Val Loss: 27.4898
#   Val Cosine Sim: 0.9834
#   Val STAGE_T Acc: 0.2358
#   LR: 1.00e-03
#
#   New best validation loss: 25.6911
# Epoch 71/100 (0.68s)
#   Train Loss: 25.9532
#   Train Cosine Sim: 0.9836
#   Val Loss: 25.6911
#   Val Cosine Sim: 0.9839
#   Val STAGE_T Acc: 0.2033
#   LR: 1.00e-03
#
#   New best validation loss: 25.0462
# Epoch 72/100 (0.69s)
#   Train Loss: 25.9116
#   Train Cosine Sim: 0.9840
#   Val Loss: 25.0462
#   Val Cosine Sim: 0.9844
#   Val STAGE_T Acc: 0.1707
#   LR: 1.00e-03
#
#   New best validation loss: 24.0633
# Epoch 73/100 (0.71s)
#   Train Loss: 24.9954
#   Train Cosine Sim: 0.9843
#   Val Loss: 24.0633
#   Val Cosine Sim: 0.9849
#   Val STAGE_T Acc: 0.2033
#   LR: 1.00e-03
#
# Epoch 74/100 (0.58s)
#   Train Loss: 24.8908
#   Train Cosine Sim: 0.9852
#   Val Loss: 24.0640
#   Val Cosine Sim: 0.9856
#   Val STAGE_T Acc: 0.1870
#   LR: 1.00e-03
#
#   New best validation loss: 23.4639
# Epoch 75/100 (0.71s)
#   Train Loss: 24.8425
#   Train Cosine Sim: 0.9854
#   Val Loss: 23.4639
#   Val Cosine Sim: 0.9860
#   Val STAGE_T Acc: 0.3333
#   LR: 1.00e-03
#
#   New best validation loss: 22.9367
# Epoch 76/100 (0.80s)
#   Train Loss: 23.6794
#   Train Cosine Sim: 0.9858
#   Val Loss: 22.9367
#   Val Cosine Sim: 0.9863
#   Val STAGE_T Acc: 0.3333
#   LR: 1.00e-03
#
#   New best validation loss: 22.9031
# Epoch 77/100 (0.87s)
#   Train Loss: 25.2317
#   Train Cosine Sim: 0.9853
#   Val Loss: 22.9031
#   Val Cosine Sim: 0.9867
#   Val STAGE_T Acc: 0.3252
#   LR: 1.00e-03
#
# Epoch 78/100 (0.67s)
#   Train Loss: 24.4602
#   Train Cosine Sim: 0.9859
#   Val Loss: 24.0723
#   Val Cosine Sim: 0.9860
#   Val STAGE_T Acc: 0.2276
#   LR: 1.00e-03
#
# Epoch 79/100 (0.75s)
#   Train Loss: 23.8756
#   Train Cosine Sim: 0.9862
#   Val Loss: 23.1449
#   Val Cosine Sim: 0.9864
#   Val STAGE_T Acc: 0.1870
#   LR: 1.00e-03
#
# Epoch 80/100 (0.71s)
#   Train Loss: 24.6961
#   Train Cosine Sim: 0.9862
#   Val Loss: 23.9149
#   Val Cosine Sim: 0.9869
#   Val STAGE_T Acc: 0.2195
#   LR: 1.00e-03
#
# Epoch 81/100 (0.68s)
#   Train Loss: 23.4156
#   Train Cosine Sim: 0.9869
#   Val Loss: 22.9032
#   Val Cosine Sim: 0.9875
#   Val STAGE_T Acc: 0.2033
#   LR: 1.00e-03
#
#   New best validation loss: 22.4259
# Epoch 82/100 (0.89s)
#   Train Loss: 22.9327
#   Train Cosine Sim: 0.9873
#   Val Loss: 22.4259
#   Val Cosine Sim: 0.9880
#   Val STAGE_T Acc: 0.3171
#   LR: 1.00e-03
#
#   New best validation loss: 21.8166
# Epoch 83/100 (0.93s)
#   Train Loss: 23.5831
#   Train Cosine Sim: 0.9880
#   Val Loss: 21.8166
#   Val Cosine Sim: 0.9881
#   Val STAGE_T Acc: 0.3089
#   LR: 1.00e-03
#
#   New best validation loss: 21.8164
# Epoch 84/100 (0.91s)
#   Train Loss: 22.6286
#   Train Cosine Sim: 0.9881
#   Val Loss: 21.8164
#   Val Cosine Sim: 0.9886
#   Val STAGE_T Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 21.7051
# Epoch 85/100 (0.86s)
#   Train Loss: 21.8780
#   Train Cosine Sim: 0.9888
#   Val Loss: 21.7051
#   Val Cosine Sim: 0.9888
#   Val STAGE_T Acc: 0.3089
#   LR: 1.00e-03
#   New best validation loss: 21.3605
# Epoch 86/100 (0.81s)
#   Train Loss: 22.1671
#   Train Cosine Sim: 0.9883
#   Val Loss: 21.3605
#   Val Cosine Sim: 0.9891
#   Val STAGE_T Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 20.8089
# Epoch 87/100 (0.85s)
#   Train Loss: 22.4138
#   Train Cosine Sim: 0.9885
#   Val Loss: 20.8089
#   Val Cosine Sim: 0.9891
#   Val STAGE_T Acc: 0.2927
#   LR: 1.00e-03
#
#   New best validation loss: 20.5409
# Epoch 88/100 (0.88s)
#   Train Loss: 22.0745
#   Train Cosine Sim: 0.9890
#   Val Loss: 20.5409
#   Val Cosine Sim: 0.9892
#   Val STAGE_T Acc: 0.2927
#   LR: 1.00e-03
#
#   New best validation loss: 20.2977
# Epoch 89/100 (0.87s)
#   Train Loss: 21.2613
#   Train Cosine Sim: 0.9889
#   Val Loss: 20.2977
#   Val Cosine Sim: 0.9894
#   Val STAGE_T Acc: 0.2276
#   LR: 1.00e-03
#
#   New best validation loss: 20.1453
# Epoch 90/100 (0.89s)
#   Train Loss: 21.0994
#   Train Cosine Sim: 0.9891
#   Val Loss: 20.1453
#   Val Cosine Sim: 0.9898
#   Val STAGE_T Acc: 0.3171
#   LR: 1.00e-03
#
#   New best validation loss: 20.1342
# Epoch 91/100 (0.90s)
#   Train Loss: 21.7701
#   Train Cosine Sim: 0.9889
#   Val Loss: 20.1342
#   Val Cosine Sim: 0.9900
#   Val STAGE_T Acc: 0.3089
#   LR: 1.00e-03
#
# Epoch 92/100 (0.68s)
#   Train Loss: 21.1688
#   Train Cosine Sim: 0.9900
#   Val Loss: 20.7398
#   Val Cosine Sim: 0.9899
#   Val STAGE_T Acc: 0.2846
#   LR: 1.00e-03
#
# Epoch 93/100 (0.64s)
#   Train Loss: 20.6704
#   Train Cosine Sim: 0.9896
#   Val Loss: 20.4035
#   Val Cosine Sim: 0.9902
#   Val STAGE_T Acc: 0.3252
#   LR: 1.00e-03
#
# Epoch 94/100 (0.57s)
#   Train Loss: 21.0145
#   Train Cosine Sim: 0.9894
#   Val Loss: 20.3691
#   Val Cosine Sim: 0.9904
#   Val STAGE_T Acc: 0.3089
#   LR: 1.00e-03
#
# Epoch 95/100 (0.55s)
#   Train Loss: 20.1779
#   Train Cosine Sim: 0.9904
#   Val Loss: 20.2663
#   Val Cosine Sim: 0.9904
#   Val STAGE_T Acc: 0.2927
#   LR: 1.00e-03
#
#   New best validation loss: 19.6831
# Epoch 96/100 (0.73s)
#   Train Loss: 20.6671
#   Train Cosine Sim: 0.9898
#   Val Loss: 19.6831
#   Val Cosine Sim: 0.9907
#   Val STAGE_T Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 19.4256
# Epoch 97/100 (0.75s)
#   Train Loss: 20.4275
#   Train Cosine Sim: 0.9904
#   Val Loss: 19.4256
#   Val Cosine Sim: 0.9908
#   Val STAGE_T Acc: 0.3089
#   LR: 1.00e-03
#
# Epoch 98/100 (0.61s)
#   Train Loss: 20.1955
#   Train Cosine Sim: 0.9903
#   Val Loss: 19.5671
#   Val Cosine Sim: 0.9908
#   Val STAGE_T Acc: 0.3496
#   LR: 1.00e-03
#
# Epoch 99/100 (0.59s)
#   Train Loss: 20.2512
#   Train Cosine Sim: 0.9908
#   Val Loss: 19.5603
#   Val Cosine Sim: 0.9910
#   Val STAGE_T Acc: 0.3496
#   LR: 1.00e-03
#
# Epoch 100/100 (0.60s)
#   Train Loss: 20.3002
#   Train Cosine Sim: 0.9904
#   Val Loss: 19.4392
#   Val Cosine Sim: 0.9910
#   Val STAGE_T Acc: 0.3496
#   LR: 1.00e-03
#
# Training completed!
# Best validation loss: 19.4256
# Evaluating on test set...
# Loaded best model from epoch 96
#
# Test Results:
# Test Loss: 18.8398
# Test Cosine Sim: 0.9913
# STAGE_T - Accuracy: 0.3178, F1: 0.2944
#
# Results saved to: ./results/autoencoder_20250625_100550/autoencoder_20250625_100618

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 100 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints stage_n \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cpu
# Creating data loaders...
# Stratification successful with endpoints: ['stage_n']
# Train samples: 517
# Validation samples: 123
# Test samples: 107
# Creating autoencoder model...
# Model parameters: 6,013,268
# Starting training...
# Starting training for 100 epochs...
# Model type: autoencoder
# Device: cpu
#   New best validation loss: 323.6765
# Epoch 1/100 (0.91s)
#   Train Loss: 321.8686
#   Train Cosine Sim: 0.3741
#   Val Loss: 323.6765
#   Val Cosine Sim: 0.6313
#   Val STAGE_N Acc: 0.4390
#   LR: 1.00e-03
#
#   New best validation loss: 301.8457
# Epoch 2/100 (0.76s)
#   Train Loss: 298.3548
#   Train Cosine Sim: 0.6625
#   Val Loss: 301.8457
#   Val Cosine Sim: 0.6972
#   Val STAGE_N Acc: 0.4472
#   LR: 1.00e-03
#
#   New best validation loss: 274.2363
# Epoch 3/100 (0.71s)
#   Train Loss: 276.2037
#   Train Cosine Sim: 0.7043
#   Val Loss: 274.2363
#   Val Cosine Sim: 0.7202
#   Val STAGE_N Acc: 0.4228
#   LR: 1.00e-03
#
#   New best validation loss: 257.2335
# Epoch 4/100 (0.66s)
#   Train Loss: 253.6002
#   Train Cosine Sim: 0.7260
#   Val Loss: 257.2335
#   Val Cosine Sim: 0.7380
#   Val STAGE_N Acc: 0.3984
#   LR: 1.00e-03
#
#   New best validation loss: 237.5243
# Epoch 5/100 (0.65s)
#   Train Loss: 234.5695
#   Train Cosine Sim: 0.7431
#   Val Loss: 237.5243
#   Val Cosine Sim: 0.7532
#   Val STAGE_N Acc: 0.3740
#   LR: 1.00e-03
#
#   New best validation loss: 222.3835
# Epoch 6/100 (0.85s)
#   Train Loss: 215.0270
#   Train Cosine Sim: 0.7585
#   Val Loss: 222.3835
#   Val Cosine Sim: 0.7673
#   Val STAGE_N Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 199.9976
# Epoch 7/100 (0.80s)
#   Train Loss: 194.6888
#   Train Cosine Sim: 0.7720
#   Val Loss: 199.9976
#   Val Cosine Sim: 0.7803
#   Val STAGE_N Acc: 0.2846
#   LR: 1.00e-03
#
#   New best validation loss: 181.6924
# Epoch 8/100 (0.82s)
#   Train Loss: 181.1739
#   Train Cosine Sim: 0.7859
#   Val Loss: 181.6924
#   Val Cosine Sim: 0.7926
#   Val STAGE_N Acc: 0.3089
#   LR: 1.00e-03
#
#   New best validation loss: 168.5579
# Epoch 9/100 (0.81s)
#   Train Loss: 162.1605
#   Train Cosine Sim: 0.7978
#   Val Loss: 168.5579
#   Val Cosine Sim: 0.8051
#   Val STAGE_N Acc: 0.3496
#   LR: 1.00e-03
#
#   New best validation loss: 154.1780
# Epoch 10/100 (0.83s)
#   Train Loss: 150.1421
#   Train Cosine Sim: 0.8100
#   Val Loss: 154.1780
#   Val Cosine Sim: 0.8166
#   Val STAGE_N Acc: 0.3008
#   LR: 1.00e-03
#
#   New best validation loss: 136.8919
# Epoch 11/100 (0.67s)
#   Train Loss: 137.6815
#   Train Cosine Sim: 0.8213
#   Val Loss: 136.8919
#   Val Cosine Sim: 0.8277
#   Val STAGE_N Acc: 0.2846
#   LR: 1.00e-03
#
#   New best validation loss: 128.4815
# Epoch 12/100 (0.69s)
#   Train Loss: 129.9478
#   Train Cosine Sim: 0.8304
#   Val Loss: 128.4815
#   Val Cosine Sim: 0.8368
#   Val STAGE_N Acc: 0.3008
#   LR: 1.00e-03
#
#   New best validation loss: 123.3422
# Epoch 13/100 (0.69s)
#   Train Loss: 118.8465
#   Train Cosine Sim: 0.8393
#   Val Loss: 123.3422
#   Val Cosine Sim: 0.8453
#   Val STAGE_N Acc: 0.2927
#   LR: 1.00e-03
#
#   New best validation loss: 119.7958
# Epoch 14/100 (0.69s)
#   Train Loss: 111.4853
#   Train Cosine Sim: 0.8480
#   Val Loss: 119.7958
#   Val Cosine Sim: 0.8535
#   Val STAGE_N Acc: 0.2846
#   LR: 1.00e-03
#
#   New best validation loss: 107.3948
# Epoch 15/100 (0.70s)
#   Train Loss: 103.4898
#   Train Cosine Sim: 0.8559
#   Val Loss: 107.3948
#   Val Cosine Sim: 0.8607
#   Val STAGE_N Acc: 0.2764
#   LR: 1.00e-03
#
#   New best validation loss: 100.9163
# Epoch 16/100 (0.70s)
#   Train Loss: 98.8753
#   Train Cosine Sim: 0.8631
#   Val Loss: 100.9163
#   Val Cosine Sim: 0.8674
#   Val STAGE_N Acc: 0.3496
#   LR: 1.00e-03
#
#   New best validation loss: 94.2181
# Epoch 17/100 (0.72s)
#   Train Loss: 93.7036
#   Train Cosine Sim: 0.8688
#   Val Loss: 94.2181
#   Val Cosine Sim: 0.8726
#   Val STAGE_N Acc: 0.2927
#   LR: 1.00e-03
#
#   New best validation loss: 88.9145
# Epoch 18/100 (0.69s)
#   Train Loss: 87.6044
#   Train Cosine Sim: 0.8746
#   Val Loss: 88.9145
#   Val Cosine Sim: 0.8777
#   Val STAGE_N Acc: 0.3089
#   LR: 1.00e-03
#
#   New best validation loss: 86.0207
# Epoch 19/100 (0.70s)
#   Train Loss: 83.9168
#   Train Cosine Sim: 0.8798
#   Val Loss: 86.0207
#   Val Cosine Sim: 0.8825
#   Val STAGE_N Acc: 0.3333
#   LR: 1.00e-03
#
#   New best validation loss: 80.8255
# Epoch 20/100 (0.70s)
#   Train Loss: 79.9970
#   Train Cosine Sim: 0.8844
#   Val Loss: 80.8255
#   Val Cosine Sim: 0.8873
#   Val STAGE_N Acc: 0.3333
#   LR: 1.00e-03
#
#   New best validation loss: 77.5709
# Epoch 21/100 (0.70s)
#   Train Loss: 76.8714
#   Train Cosine Sim: 0.8894
#   Val Loss: 77.5709
#   Val Cosine Sim: 0.8920
#   Val STAGE_N Acc: 0.3577
#   LR: 1.00e-03
#
#   New best validation loss: 75.2649
# Epoch 22/100 (0.74s)
#   Train Loss: 75.6045
#   Train Cosine Sim: 0.8928
#   Val Loss: 75.2649
#   Val Cosine Sim: 0.8963
#   Val STAGE_N Acc: 0.3821
#   LR: 1.00e-03
#
#   New best validation loss: 75.1373
# Epoch 23/100 (0.82s)
#   Train Loss: 73.7192
#   Train Cosine Sim: 0.8963
#   Val Loss: 75.1373
#   Val Cosine Sim: 0.8998
#   Val STAGE_N Acc: 0.3496
#   LR: 1.00e-03
#
#   New best validation loss: 73.0804
# Epoch 24/100 (0.84s)
#   Train Loss: 69.0540
#   Train Cosine Sim: 0.9012
#   Val Loss: 73.0804
#   Val Cosine Sim: 0.9038
#   Val STAGE_N Acc: 0.3089
#   LR: 1.00e-03
#
#   New best validation loss: 68.0570
# Epoch 25/100 (0.81s)
#   Train Loss: 67.0518
#   Train Cosine Sim: 0.9047
#   Val Loss: 68.0570
#   Val Cosine Sim: 0.9069
#   Val STAGE_N Acc: 0.2846
#   LR: 1.00e-03
#
#   New best validation loss: 64.2029
# Epoch 26/100 (0.83s)
#   Train Loss: 63.5107
#   Train Cosine Sim: 0.9086
#   Val Loss: 64.2029
#   Val Cosine Sim: 0.9106
#   Val STAGE_N Acc: 0.3171
#   LR: 1.00e-03
#
#   New best validation loss: 61.8733
# Epoch 27/100 (0.86s)
#   Train Loss: 61.9723
#   Train Cosine Sim: 0.9112
#   Val Loss: 61.8733
#   Val Cosine Sim: 0.9138
#   Val STAGE_N Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 59.6295
# Epoch 28/100 (0.84s)
#   Train Loss: 60.5492
#   Train Cosine Sim: 0.9140
#   Val Loss: 59.6295
#   Val Cosine Sim: 0.9170
#   Val STAGE_N Acc: 0.3008
#   LR: 1.00e-03
#
#   New best validation loss: 57.4693
# Epoch 29/100 (1.05s)
#   Train Loss: 58.1632
#   Train Cosine Sim: 0.9173
#   Val Loss: 57.4693
#   Val Cosine Sim: 0.9198
#   Val STAGE_N Acc: 0.3008
#   LR: 1.00e-03
#
#   New best validation loss: 56.0321
# Epoch 30/100 (1.00s)
#   Train Loss: 56.5596
#   Train Cosine Sim: 0.9206
#   Val Loss: 56.0321
#   Val Cosine Sim: 0.9229
#   Val STAGE_N Acc: 0.3333
#   LR: 1.00e-03
#
#   New best validation loss: 54.1961
# Epoch 31/100 (0.98s)
#   Train Loss: 53.9114
#   Train Cosine Sim: 0.9238
#   Val Loss: 54.1961
#   Val Cosine Sim: 0.9260
#   Val STAGE_N Acc: 0.2764
#   LR: 1.00e-03
#
#   New best validation loss: 52.4752
# Epoch 32/100 (0.87s)
#   Train Loss: 53.3153
#   Train Cosine Sim: 0.9256
#   Val Loss: 52.4752
#   Val Cosine Sim: 0.9287
#   Val STAGE_N Acc: 0.3089
#   LR: 1.00e-03
#
#   New best validation loss: 51.3623
# Epoch 33/100 (0.92s)
#   Train Loss: 52.2285
#   Train Cosine Sim: 0.9287
#   Val Loss: 51.3623
#   Val Cosine Sim: 0.9312
#   Val STAGE_N Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 49.7347
# Epoch 34/100 (0.82s)
#   Train Loss: 49.0377
#   Train Cosine Sim: 0.9319
#   Val Loss: 49.7347
#   Val Cosine Sim: 0.9336
#   Val STAGE_N Acc: 0.3984
#   LR: 1.00e-03
#
#   New best validation loss: 48.5116
# Epoch 35/100 (0.74s)
#   Train Loss: 47.4192
#   Train Cosine Sim: 0.9344
#   Val Loss: 48.5116
#   Val Cosine Sim: 0.9359
#   Val STAGE_N Acc: 0.3008
#   LR: 1.00e-03
#
#   New best validation loss: 46.2145
# Epoch 36/100 (0.73s)
#   Train Loss: 46.7168
#   Train Cosine Sim: 0.9361
#   Val Loss: 46.2145
#   Val Cosine Sim: 0.9383
#   Val STAGE_N Acc: 0.3577
#   LR: 1.00e-03
#
#   New best validation loss: 45.3884
# Epoch 37/100 (0.99s)
#   Train Loss: 46.8348
#   Train Cosine Sim: 0.9387
#   Val Loss: 45.3884
#   Val Cosine Sim: 0.9404
#   Val STAGE_N Acc: 0.3740
#   LR: 1.00e-03
#
# Epoch 38/100 (0.76s)
#   Train Loss: 45.4013
#   Train Cosine Sim: 0.9405
#   Val Loss: 45.5599
#   Val Cosine Sim: 0.9423
#   Val STAGE_N Acc: 0.4715
#   LR: 1.00e-03
#
#   New best validation loss: 42.7677
# Epoch 39/100 (1.12s)
#   Train Loss: 42.2146
#   Train Cosine Sim: 0.9430
#   Val Loss: 42.7677
#   Val Cosine Sim: 0.9443
#   Val STAGE_N Acc: 0.3171
#   LR: 1.00e-03
#
#   New best validation loss: 40.2228
# Epoch 40/100 (1.00s)
#   Train Loss: 40.6005
#   Train Cosine Sim: 0.9450
#   Val Loss: 40.2228
#   Val Cosine Sim: 0.9467
#   Val STAGE_N Acc: 0.2764
#   LR: 1.00e-03
#
#   New best validation loss: 39.1025
# Epoch 41/100 (0.99s)
#   Train Loss: 39.4659
#   Train Cosine Sim: 0.9473
#   Val Loss: 39.1025
#   Val Cosine Sim: 0.9492
#   Val STAGE_N Acc: 0.3089
#   LR: 1.00e-03
#   New best validation loss: 38.5356
# Epoch 42/100 (0.90s)
#   Train Loss: 38.4841
#   Train Cosine Sim: 0.9494
#   Val Loss: 38.5356
#   Val Cosine Sim: 0.9515
#   Val STAGE_N Acc: 0.3333
#   LR: 1.00e-03
#
#   New best validation loss: 38.0934
# Epoch 43/100 (0.88s)
#   Train Loss: 38.0996
#   Train Cosine Sim: 0.9519
#   Val Loss: 38.0934
#   Val Cosine Sim: 0.9532
#   Val STAGE_N Acc: 0.3333
#   LR: 1.00e-03
#
#   New best validation loss: 36.2708
# Epoch 44/100 (0.79s)
#   Train Loss: 37.1160
#   Train Cosine Sim: 0.9522
#   Val Loss: 36.2708
#   Val Cosine Sim: 0.9548
#   Val STAGE_N Acc: 0.3496
#   LR: 1.00e-03
#
#   New best validation loss: 34.2469
# Epoch 45/100 (0.91s)
#   Train Loss: 34.9058
#   Train Cosine Sim: 0.9547
#   Val Loss: 34.2469
#   Val Cosine Sim: 0.9565
#   Val STAGE_N Acc: 0.3415
#   LR: 1.00e-03
#
#   New best validation loss: 33.1564
# Epoch 46/100 (0.86s)
#   Train Loss: 33.9589
#   Train Cosine Sim: 0.9563
#   Val Loss: 33.1564
#   Val Cosine Sim: 0.9583
#   Val STAGE_N Acc: 0.3496
#   LR: 1.00e-03
#
#   New best validation loss: 31.7822
# Epoch 47/100 (0.84s)
#   Train Loss: 32.4550
#   Train Cosine Sim: 0.9585
#   Val Loss: 31.7822
#   Val Cosine Sim: 0.9600
#   Val STAGE_N Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 30.8681
# Epoch 48/100 (0.77s)
#   Train Loss: 32.1825
#   Train Cosine Sim: 0.9605
#   Val Loss: 30.8681
#   Val Cosine Sim: 0.9615
#   Val STAGE_N Acc: 0.3659
#   LR: 1.00e-03
#
# Epoch 49/100 (0.61s)
#   Train Loss: 32.1403
#   Train Cosine Sim: 0.9611
#   Val Loss: 31.1449
#   Val Cosine Sim: 0.9628
#   Val STAGE_N Acc: 0.3577
#   LR: 1.00e-03
#
#   New best validation loss: 29.4432
# Epoch 50/100 (0.72s)
#   Train Loss: 29.3326
#   Train Cosine Sim: 0.9625
#   Val Loss: 29.4432
#   Val Cosine Sim: 0.9636
#   Val STAGE_N Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 29.0479
# Epoch 51/100 (0.83s)
#   Train Loss: 30.0069
#   Train Cosine Sim: 0.9639
#   Val Loss: 29.0479
#   Val Cosine Sim: 0.9655
#   Val STAGE_N Acc: 0.3252
#   LR: 1.00e-03
#
# Epoch 52/100 (0.62s)
#   Train Loss: 28.1020
#   Train Cosine Sim: 0.9662
#   Val Loss: 29.2265
#   Val Cosine Sim: 0.9667
#   Val STAGE_N Acc: 0.3415
#   LR: 1.00e-03
#
#   New best validation loss: 26.1961
# Epoch 53/100 (0.80s)
#   Train Loss: 27.3440
#   Train Cosine Sim: 0.9667
#   Val Loss: 26.1961
#   Val Cosine Sim: 0.9679
#   Val STAGE_N Acc: 0.3333
#   LR: 1.00e-03
#
#   New best validation loss: 25.2024
# Epoch 54/100 (0.72s)
#   Train Loss: 27.1966
#   Train Cosine Sim: 0.9674
#   Val Loss: 25.2024
#   Val Cosine Sim: 0.9693
#   Val STAGE_N Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 24.4213
# Epoch 55/100 (0.71s)
#   Train Loss: 25.5270
#   Train Cosine Sim: 0.9688
#   Val Loss: 24.4213
#   Val Cosine Sim: 0.9705
#   Val STAGE_N Acc: 0.3008
#   LR: 1.00e-03
#
#   New best validation loss: 23.2006
# Epoch 56/100 (0.72s)
#   Train Loss: 24.8534
#   Train Cosine Sim: 0.9703
#   Val Loss: 23.2006
#   Val Cosine Sim: 0.9718
#   Val STAGE_N Acc: 0.3008
#   LR: 1.00e-03
#
#   New best validation loss: 22.6121
# Epoch 57/100 (0.75s)
#   Train Loss: 23.9243
#   Train Cosine Sim: 0.9719
#   Val Loss: 22.6121
#   Val Cosine Sim: 0.9729
#   Val STAGE_N Acc: 0.2602
#   LR: 1.00e-03
#
# Epoch 58/100 (0.56s)
#   Train Loss: 22.7080
#   Train Cosine Sim: 0.9732
#   Val Loss: 22.7354
#   Val Cosine Sim: 0.9742
#   Val STAGE_N Acc: 0.3089
#   LR: 1.00e-03
#
#   New best validation loss: 21.8122
# Epoch 59/100 (0.74s)
#   Train Loss: 22.2082
#   Train Cosine Sim: 0.9743
#   Val Loss: 21.8122
#   Val Cosine Sim: 0.9754
#   Val STAGE_N Acc: 0.3089
#   LR: 1.00e-03
#
#   New best validation loss: 21.2197
# Epoch 60/100 (0.73s)
#   Train Loss: 21.7794
#   Train Cosine Sim: 0.9754
#   Val Loss: 21.2197
#   Val Cosine Sim: 0.9763
#   Val STAGE_N Acc: 0.3740
#   LR: 1.00e-03
#
#   New best validation loss: 20.2276
# Epoch 61/100 (0.76s)
#   Train Loss: 21.2521
#   Train Cosine Sim: 0.9761
#   Val Loss: 20.2276
#   Val Cosine Sim: 0.9772
#   Val STAGE_N Acc: 0.3089
#   LR: 1.00e-03
#
#   New best validation loss: 19.4342
# Epoch 62/100 (0.86s)
#   Train Loss: 19.9879
#   Train Cosine Sim: 0.9775
#   Val Loss: 19.4342
#   Val Cosine Sim: 0.9781
#   Val STAGE_N Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 18.4224
# Epoch 63/100 (0.81s)
#   Train Loss: 19.4546
#   Train Cosine Sim: 0.9776
#   Val Loss: 18.4224
#   Val Cosine Sim: 0.9790
#   Val STAGE_N Acc: 0.3902
#   LR: 1.00e-03
#
#   New best validation loss: 18.0559
# Epoch 64/100 (0.81s)
#   Train Loss: 18.9929
#   Train Cosine Sim: 0.9785
#   Val Loss: 18.0559
#   Val Cosine Sim: 0.9800
#   Val STAGE_N Acc: 0.3740
#   LR: 1.00e-03
#
#   New best validation loss: 17.2225
# Epoch 65/100 (0.86s)
#   Train Loss: 18.2880
#   Train Cosine Sim: 0.9799
#   Val Loss: 17.2225
#   Val Cosine Sim: 0.9806
#   Val STAGE_N Acc: 0.3821
#   LR: 1.00e-03
#
#   New best validation loss: 16.8840
# Epoch 66/100 (0.84s)
#   Train Loss: 17.3844
#   Train Cosine Sim: 0.9805
#   Val Loss: 16.8840
#   Val Cosine Sim: 0.9811
#   Val STAGE_N Acc: 0.3496
#   LR: 1.00e-03
#
#   New best validation loss: 16.4469
# Epoch 67/100 (0.84s)
#   Train Loss: 17.1653
#   Train Cosine Sim: 0.9808
#   Val Loss: 16.4469
#   Val Cosine Sim: 0.9819
#   Val STAGE_N Acc: 0.3252
#   LR: 1.00e-03
#
#   New best validation loss: 16.3041
# Epoch 68/100 (0.94s)
#   Train Loss: 16.3558
#   Train Cosine Sim: 0.9821
#   Val Loss: 16.3041
#   Val Cosine Sim: 0.9828
#   Val STAGE_N Acc: 0.3496
#   LR: 1.00e-03
#
#   New best validation loss: 15.5819
# Epoch 69/100 (0.89s)
#   Train Loss: 16.2502
#   Train Cosine Sim: 0.9825
#   Val Loss: 15.5819
#   Val Cosine Sim: 0.9832
#   Val STAGE_N Acc: 0.3496
#   LR: 1.00e-03
#
#   New best validation loss: 15.0973
# Epoch 70/100 (0.96s)
#   Train Loss: 15.9253
#   Train Cosine Sim: 0.9829
#   Val Loss: 15.0973
#   Val Cosine Sim: 0.9838
#   Val STAGE_N Acc: 0.3740
#   LR: 1.00e-03
#
# Epoch 71/100 (0.71s)
#   Train Loss: 16.5712
#   Train Cosine Sim: 0.9827
#   Val Loss: 15.2603
#   Val Cosine Sim: 0.9843
#   Val STAGE_N Acc: 0.3659
#   LR: 1.00e-03
#
#   New best validation loss: 14.1182
# Epoch 72/100 (0.81s)
#   Train Loss: 14.6882
#   Train Cosine Sim: 0.9843
#   Val Loss: 14.1182
#   Val Cosine Sim: 0.9849
#   Val STAGE_N Acc: 0.3740
#   LR: 1.00e-03
#
#   New best validation loss: 13.7027
# Epoch 73/100 (0.96s)
#   Train Loss: 14.2006
#   Train Cosine Sim: 0.9850
#   Val Loss: 13.7027
#   Val Cosine Sim: 0.9855
#   Val STAGE_N Acc: 0.3821
#   LR: 1.00e-03
#
#   New best validation loss: 13.4663
# Epoch 74/100 (0.90s)
#   Train Loss: 14.5426
#   Train Cosine Sim: 0.9854
#   Val Loss: 13.4663
#   Val Cosine Sim: 0.9860
#   Val STAGE_N Acc: 0.3740
#   LR: 1.00e-03
#
#   New best validation loss: 13.1919
# Epoch 75/100 (0.93s)
#   Train Loss: 14.0964
#   Train Cosine Sim: 0.9852
#   Val Loss: 13.1919
#   Val Cosine Sim: 0.9862
#   Val STAGE_N Acc: 0.3415
#   LR: 1.00e-03
#
#   New best validation loss: 12.9021
# Epoch 76/100 (0.82s)
#   Train Loss: 13.4823
#   Train Cosine Sim: 0.9862
#   Val Loss: 12.9021
#   Val Cosine Sim: 0.9866
#   Val STAGE_N Acc: 0.3821
#   LR: 1.00e-03
#
#   New best validation loss: 12.7467
# Epoch 77/100 (0.72s)
#   Train Loss: 13.1992
#   Train Cosine Sim: 0.9863
#   Val Loss: 12.7467
#   Val Cosine Sim: 0.9869
#   Val STAGE_N Acc: 0.3659
#   LR: 1.00e-03
#
#   New best validation loss: 12.6455
# Epoch 78/100 (0.70s)
#   Train Loss: 13.1807
#   Train Cosine Sim: 0.9867
#   Val Loss: 12.6455
#   Val Cosine Sim: 0.9874
#   Val STAGE_N Acc: 0.3902
#   LR: 1.00e-03
#
#   New best validation loss: 11.8639
# Epoch 79/100 (0.76s)
#   Train Loss: 13.0095
#   Train Cosine Sim: 0.9873
#   Val Loss: 11.8639
#   Val Cosine Sim: 0.9877
#   Val STAGE_N Acc: 0.3659
#   LR: 1.00e-03
#
# Epoch 80/100 (0.62s)
#   Train Loss: 13.2494
#   Train Cosine Sim: 0.9867
#   Val Loss: 12.2907
#   Val Cosine Sim: 0.9878
#   Val STAGE_N Acc: 0.3415
#   LR: 1.00e-03
#
# Epoch 81/100 (0.60s)
#   Train Loss: 12.5699
#   Train Cosine Sim: 0.9872
#   Val Loss: 12.1293
#   Val Cosine Sim: 0.9881
#   Val STAGE_N Acc: 0.3496
#   LR: 1.00e-03
#
#   New best validation loss: 11.4813
# Epoch 82/100 (0.84s)
#   Train Loss: 12.8666
#   Train Cosine Sim: 0.9877
#   Val Loss: 11.4813
#   Val Cosine Sim: 0.9885
#   Val STAGE_N Acc: 0.3333
#   LR: 1.00e-03
#
#   New best validation loss: 11.4321
# Epoch 83/100 (0.85s)
#   Train Loss: 12.4874
#   Train Cosine Sim: 0.9882
#   Val Loss: 11.4321
#   Val Cosine Sim: 0.9887
#   Val STAGE_N Acc: 0.3740
#   LR: 1.00e-03
#
# Epoch 84/100 (0.62s)
#   Train Loss: 13.0575
#   Train Cosine Sim: 0.9879
#   Val Loss: 11.5510
#   Val Cosine Sim: 0.9887
#   Val STAGE_N Acc: 0.3333
#   LR: 1.00e-03
#
#   New best validation loss: 10.9065
# Epoch 85/100 (0.83s)
#   Train Loss: 12.3038
#   Train Cosine Sim: 0.9886
#   Val Loss: 10.9065
#   Val Cosine Sim: 0.9890
#   Val STAGE_N Acc: 0.3252
#   LR: 1.00e-03
# Epoch 86/100 (0.63s)
#   Train Loss: 11.8773
#   Train Cosine Sim: 0.9885
#   Val Loss: 10.9117
#   Val Cosine Sim: 0.9893
#   Val STAGE_N Acc: 0.3496
#   LR: 1.00e-03
#
# Epoch 87/100 (0.60s)
#   Train Loss: 11.6764
#   Train Cosine Sim: 0.9891
#   Val Loss: 10.9410
#   Val Cosine Sim: 0.9896
#   Val STAGE_N Acc: 0.3171
#   LR: 1.00e-03
#
#   New best validation loss: 10.5343
# Epoch 88/100 (0.84s)
#   Train Loss: 11.7410
#   Train Cosine Sim: 0.9894
#   Val Loss: 10.5343
#   Val Cosine Sim: 0.9899
#   Val STAGE_N Acc: 0.3333
#   LR: 1.00e-03
#
#   New best validation loss: 10.3985
# Epoch 89/100 (0.80s)
#   Train Loss: 12.0606
#   Train Cosine Sim: 0.9897
#   Val Loss: 10.3985
#   Val Cosine Sim: 0.9900
#   Val STAGE_N Acc: 0.3089
#   LR: 1.00e-03
#
#   New best validation loss: 10.0173
# Epoch 90/100 (0.84s)
#   Train Loss: 11.3113
#   Train Cosine Sim: 0.9897
#   Val Loss: 10.0173
#   Val Cosine Sim: 0.9901
#   Val STAGE_N Acc: 0.3659
#   LR: 1.00e-03
#
#   New best validation loss: 9.4610
# Epoch 91/100 (0.83s)
#   Train Loss: 10.7753
#   Train Cosine Sim: 0.9900
#   Val Loss: 9.4610
#   Val Cosine Sim: 0.9903
#   Val STAGE_N Acc: 0.3659
#   LR: 1.00e-03
#
# Epoch 92/100 (0.65s)
#   Train Loss: 10.8333
#   Train Cosine Sim: 0.9895
#   Val Loss: 9.4972
#   Val Cosine Sim: 0.9905
#   Val STAGE_N Acc: 0.3659
#   LR: 1.00e-03
#
# Epoch 93/100 (0.58s)
#   Train Loss: 10.9805
#   Train Cosine Sim: 0.9896
#   Val Loss: 9.7830
#   Val Cosine Sim: 0.9906
#   Val STAGE_N Acc: 0.3008
#   LR: 1.00e-03
#
# Epoch 94/100 (0.53s)
#   Train Loss: 10.9263
#   Train Cosine Sim: 0.9899
#   Val Loss: 9.5337
#   Val Cosine Sim: 0.9907
#   Val STAGE_N Acc: 0.3089
#   LR: 1.00e-03
#
# Epoch 95/100 (0.51s)
#   Train Loss: 10.5855
#   Train Cosine Sim: 0.9903
#   Val Loss: 10.3381
#   Val Cosine Sim: 0.9904
#   Val STAGE_N Acc: 0.3902
#   LR: 1.00e-03
#
# Epoch 96/100 (0.49s)
#   Train Loss: 11.1717
#   Train Cosine Sim: 0.9902
#   Val Loss: 9.9072
#   Val Cosine Sim: 0.9906
#   Val STAGE_N Acc: 0.3984
#   LR: 1.00e-03
#
# Epoch 97/100 (0.57s)
#   Train Loss: 10.5197
#   Train Cosine Sim: 0.9900
#   Val Loss: 9.5580
#   Val Cosine Sim: 0.9906
#   Val STAGE_N Acc: 0.3496
#   LR: 1.00e-03
#
# Epoch 98/100 (0.52s)
#   Train Loss: 10.1595
#   Train Cosine Sim: 0.9904
#   Val Loss: 9.6121
#   Val Cosine Sim: 0.9908
#   Val STAGE_N Acc: 0.3821
#   LR: 1.00e-03
#
#   New best validation loss: 9.3549
# Epoch 99/100 (0.68s)
#   Train Loss: 10.1090
#   Train Cosine Sim: 0.9906
#   Val Loss: 9.3549
#   Val Cosine Sim: 0.9909
#   Val STAGE_N Acc: 0.3902
#   LR: 1.00e-03
#
# Epoch 100/100 (0.53s)
#   Train Loss: 11.0742
#   Train Cosine Sim: 0.9903
#   Val Loss: 9.4456
#   Val Cosine Sim: 0.9911
#   Val STAGE_N Acc: 0.4228
#   LR: 1.00e-03
#
# Training completed!
# Best validation loss: 9.3549
# Evaluating on test set...
# Loaded best model from epoch 98
#
# Test Results:
# Test Loss: 9.0437
# Test Cosine Sim: 0.9914
# STAGE_N - Accuracy: 0.3364, F1: 0.3086
#
# Results saved to: ./results/autoencoder_20250625_100744/autoencoder_20250625_100811

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD_w_TNM.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC_w_TNM.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 100 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints stage_m \
    --selection_metric auc \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cpu
# Creating data loaders...
# Stratification successful with endpoints: ['stage_m']
# Train samples: 517
# Validation samples: 123
# Test samples: 107
# Creating autoencoder model...
# Model parameters: 6,013,169
# Starting training...
# Starting training for 100 epochs...
# Model type: autoencoder
# Device: cpu
#   New best validation AUC: 0.5890
# Epoch 1/100 (0.90s)
#   Train Loss: 320.4993
#   Train Cosine Sim: 0.3742
#   Val Loss: 320.2413
#   Val Cosine Sim: 0.6325
#   Val STAGE_M AUC: 0.5890
#   LR: 1.00e-03
#
# Epoch 2/100 (0.54s)
#   Train Loss: 296.7101
#   Train Cosine Sim: 0.6623
#   Val Loss: 305.3348
#   Val Cosine Sim: 0.6962
#   Val STAGE_M AUC: 0.5497
#   LR: 1.00e-03
#
# Epoch 3/100 (0.62s)
#   Train Loss: 276.1246
#   Train Cosine Sim: 0.7046
#   Val Loss: 275.8315
#   Val Cosine Sim: 0.7186
#   Val STAGE_M AUC: 0.4636
#   LR: 1.00e-03
#
# Epoch 4/100 (0.57s)
#   Train Loss: 252.6396
#   Train Cosine Sim: 0.7264
#   Val Loss: 250.6246
#   Val Cosine Sim: 0.7375
#   Val STAGE_M AUC: 0.5357
#   LR: 1.00e-03
#
# Epoch 5/100 (0.52s)
#   Train Loss: 232.1631
#   Train Cosine Sim: 0.7437
#   Val Loss: 236.4226
#   Val Cosine Sim: 0.7528
#   Val STAGE_M AUC: 0.5705
#   LR: 1.00e-03
#
# Epoch 6/100 (0.52s)
#   Train Loss: 211.6401
#   Train Cosine Sim: 0.7581
#   Val Loss: 211.0352
#   Val Cosine Sim: 0.7670
#   Val STAGE_M AUC: 0.5692
#   LR: 1.00e-03
#
# Epoch 7/100 (0.50s)
#   Train Loss: 195.7535
#   Train Cosine Sim: 0.7730
#   Val Loss: 191.7504
#   Val Cosine Sim: 0.7802
#   Val STAGE_M AUC: 0.5503
#   LR: 1.00e-03
#
# Epoch 8/100 (0.49s)
#   Train Loss: 176.8044
#   Train Cosine Sim: 0.7857
#   Val Loss: 170.7509
#   Val Cosine Sim: 0.7933
#   Val STAGE_M AUC: 0.5416
#   LR: 1.00e-03
#
# Epoch 9/100 (0.51s)
#   Train Loss: 161.8389
#   Train Cosine Sim: 0.7984
#   Val Loss: 159.6265
#   Val Cosine Sim: 0.8048
#   Val STAGE_M AUC: 0.5568
#   LR: 1.00e-03
#
# Epoch 10/100 (0.50s)
#   Train Loss: 147.6584
#   Train Cosine Sim: 0.8103
#   Val Loss: 147.2600
#   Val Cosine Sim: 0.8159
#   Val STAGE_M AUC: 0.5656
#   LR: 1.00e-03
#
# Epoch 11/100 (0.51s)
#   Train Loss: 134.5939
#   Train Cosine Sim: 0.8221
#   Val Loss: 133.6033
#   Val Cosine Sim: 0.8261
#   Val STAGE_M AUC: 0.5821
#   LR: 1.00e-03
#
#   New best validation AUC: 0.6075
# Epoch 12/100 (0.67s)
#   Train Loss: 124.8047
#   Train Cosine Sim: 0.8310
#   Val Loss: 122.8113
#   Val Cosine Sim: 0.8360
#   Val STAGE_M AUC: 0.6075
#   LR: 1.00e-03
#
# Epoch 13/100 (0.51s)
#   Train Loss: 117.5331
#   Train Cosine Sim: 0.8400
#   Val Loss: 112.7341
#   Val Cosine Sim: 0.8451
#   Val STAGE_M AUC: 0.5974
#   LR: 1.00e-03
#
# Epoch 14/100 (0.72s)
#   Train Loss: 107.7907
#   Train Cosine Sim: 0.8488
#   Val Loss: 112.4420
#   Val Cosine Sim: 0.8531
#   Val STAGE_M AUC: 0.5289
#   LR: 1.00e-03
#
# Epoch 15/100 (0.73s)
#   Train Loss: 100.9573
#   Train Cosine Sim: 0.8574
#   Val Loss: 101.4269
#   Val Cosine Sim: 0.8609
#   Val STAGE_M AUC: 0.5581
#   LR: 1.00e-03
#
# Epoch 16/100 (1.04s)
#   Train Loss: 94.5920
#   Train Cosine Sim: 0.8632
#   Val Loss: 95.7942
#   Val Cosine Sim: 0.8676
#   Val STAGE_M AUC: 0.5536
#   LR: 1.00e-03
#
# Epoch 17/100 (0.72s)
#   Train Loss: 89.5296
#   Train Cosine Sim: 0.8705
#   Val Loss: 89.4783
#   Val Cosine Sim: 0.8735
#   Val STAGE_M AUC: 0.5315
#   LR: 1.00e-03
#
# Epoch 18/100 (0.67s)
#   Train Loss: 84.5800
#   Train Cosine Sim: 0.8757
#   Val Loss: 85.0369
#   Val Cosine Sim: 0.8789
#   Val STAGE_M AUC: 0.5500
#   LR: 1.00e-03
#
# Epoch 19/100 (0.86s)
#   Train Loss: 81.6673
#   Train Cosine Sim: 0.8813
#   Val Loss: 80.8121
#   Val Cosine Sim: 0.8838
#   Val STAGE_M AUC: 0.5662
#   LR: 1.00e-03
#
# Epoch 20/100 (0.92s)
#   Train Loss: 77.8877
#   Train Cosine Sim: 0.8860
#   Val Loss: 77.4851
#   Val Cosine Sim: 0.8884
#   Val STAGE_M AUC: 0.5945
#   LR: 1.00e-03
#
# Epoch 21/100 (0.93s)
#   Train Loss: 75.3242
#   Train Cosine Sim: 0.8899
#   Val Loss: 75.5285
#   Val Cosine Sim: 0.8928
#   Val STAGE_M AUC: 0.5688
#   LR: 1.00e-03
#
# Epoch 22/100 (0.87s)
#   Train Loss: 70.9995
#   Train Cosine Sim: 0.8944
#   Val Loss: 72.3095
#   Val Cosine Sim: 0.8969
#   Val STAGE_M AUC: 0.5825
#   LR: 1.00e-03
#
# Epoch 23/100 (0.66s)
#   Train Loss: 74.4159
#   Train Cosine Sim: 0.8986
#   Val Loss: 69.1437
#   Val Cosine Sim: 0.9010
#   Val STAGE_M AUC: 0.5789
#   LR: 5.00e-04
#
# Epoch 24/100 (0.85s)
#   Train Loss: 68.1163
#   Train Cosine Sim: 0.9022
#   Val Loss: 68.6064
#   Val Cosine Sim: 0.9033
#   Val STAGE_M AUC: 0.5906
#   LR: 5.00e-04
#
# Epoch 25/100 (0.78s)
#   Train Loss: 65.9658
#   Train Cosine Sim: 0.9036
#   Val Loss: 68.5302
#   Val Cosine Sim: 0.9049
#   Val STAGE_M AUC: 0.5169
#   LR: 5.00e-04
#
# Epoch 26/100 (0.64s)
#   Train Loss: 65.2023
#   Train Cosine Sim: 0.9051
#   Val Loss: 65.4992
#   Val Cosine Sim: 0.9068
#   Val STAGE_M AUC: 0.5662
#   LR: 5.00e-04
#
# Epoch 27/100 (0.61s)
#   Train Loss: 63.5620
#   Train Cosine Sim: 0.9070
#   Val Loss: 63.0051
#   Val Cosine Sim: 0.9085
#   Val STAGE_M AUC: 0.5877
#   LR: 5.00e-04
#
# Epoch 28/100 (0.65s)
#   Train Loss: 62.2561
#   Train Cosine Sim: 0.9090
#   Val Loss: 61.6508
#   Val Cosine Sim: 0.9100
#   Val STAGE_M AUC: 0.5601
#   LR: 5.00e-04
#
# Epoch 29/100 (0.64s)
#   Train Loss: 60.5277
#   Train Cosine Sim: 0.9108
#   Val Loss: 60.8191
#   Val Cosine Sim: 0.9118
#   Val STAGE_M AUC: 0.5519
#   LR: 5.00e-04
#
# Epoch 30/100 (0.59s)
#   Train Loss: 59.8704
#   Train Cosine Sim: 0.9122
#   Val Loss: 59.5618
#   Val Cosine Sim: 0.9135
#   Val STAGE_M AUC: 0.5218
#   LR: 5.00e-04
#
# Epoch 31/100 (0.53s)
#   Train Loss: 59.0426
#   Train Cosine Sim: 0.9132
#   Val Loss: 58.3469
#   Val Cosine Sim: 0.9149
#   Val STAGE_M AUC: 0.5490
#   LR: 5.00e-04
#
# Early stopping triggered after 20 epochs without improvement
# Restored best weights
# Epoch 32/100 (0.50s)
#   Train Loss: 57.5254
#   Train Cosine Sim: 0.9143
#   Val Loss: 57.4191
#   Val Cosine Sim: 0.9166
#   Val STAGE_M AUC: 0.5438
#   LR: 5.00e-04
#
# Early stopping triggered!
# Training completed!
# Best validation AUC: 0.6075
# Evaluating on test set...
# Loaded best model from epoch 11
#
# Test Results:
# Test Loss: 121.4766
# Test Cosine Sim: 0.8368
# STAGE_M - AUC: 0.4019, Accuracy: 0.7290, F1: 0.8432
#
# Results saved to: ./results/autoencoder_20250625_101224/autoencoder_20250625_101253

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python gridsearch.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --endpoints os24 \
    --model_type autoencoder \
    --save_dir ./gridsearch_results
# Out:
# Grid search will test 2304 combinations
# Results will be saved to: ./gridsearch_results/gridsearch_autoencoder_20250624_225310
# Starting grid search with 2304 combinations
#
# === Combination 1/2304 ===
# Parameters: {'attention_k': 11, 'latent_dim': 64, 'encoder_layers': [128, 64], 'predictor_layers': [64, 32], 'dropout_rate': 0.3, 'learning_rate': 0.0001, 'batch_size': 32, 'reconstruction_weight': 1.0, 'prediction_weight': 1.0}
# Stratification successful with endpoints: ['os24']
# Train samples: 522
# Validation samples: 118
# Test samples: 104
# Starting training for 50 epochs...
# Model type: autoencoder
# Device: cuda
#   New best validation loss: 326.0187
# Epoch 1/50 (1.01s)
#   Train Loss: 326.0317
#   Train Cosine Sim: 0.0477
#   Val Loss: 326.0187
#   Val Cosine Sim: 0.1222
#   Val OS24 AUC: 0.4507
#   LR: 1.00e-04
#
#   New best validation loss: 324.0114
# Epoch 2/50 (0.35s)
#   Train Loss: 324.1911
#   Train Cosine Sim: 0.1693
#   Val Loss: 324.0114
#   Val Cosine Sim: 0.2696
#   Val OS24 AUC: 0.4319
#   LR: 1.00e-04
#
#   New best validation loss: 322.9683
# Epoch 3/50 (0.34s)
#   Train Loss: 320.9557
#   Train Cosine Sim: 0.2779
#   Val Loss: 322.9683
#   Val Cosine Sim: 0.3683
#   Val OS24 AUC: 0.4971
#   LR: 1.00e-04
#
#   New best validation loss: 321.1163
# Epoch 4/50 (0.35s)
#   Train Loss: 318.8745
#   Train Cosine Sim: 0.3674
#   Val Loss: 321.1163
#   Val Cosine Sim: 0.4542
#   Val OS24 AUC: 0.4728
#   LR: 1.00e-04
#
#   New best validation loss: 319.4487
# Epoch 5/50 (0.34s)
#   Train Loss: 316.5040
#   Train Cosine Sim: 0.4386
#   Val Loss: 319.4487
#   Val Cosine Sim: 0.5079
#   Val OS24 AUC: 0.5054
#   LR: 1.00e-04
#
#   New best validation loss: 319.1148
# Epoch 6/50 (0.33s)
#   Train Loss: 314.1567
#   Train Cosine Sim: 0.4942
#   Val Loss: 319.1148
#   Val Cosine Sim: 0.5570
#   Val OS24 AUC: 0.5602
#   LR: 1.00e-04
#
#   New best validation loss: 316.3239
# Epoch 7/50 (0.34s)
#   Train Loss: 312.0248
#   Train Cosine Sim: 0.5354
#   Val Loss: 316.3239
#   Val Cosine Sim: 0.5920
#   Val OS24 AUC: 0.6196
#   LR: 1.00e-04
#
#   New best validation loss: 315.8991
# Epoch 8/50 (0.34s)
#   Train Loss: 309.1792
#   Train Cosine Sim: 0.5696
#   Val Loss: 315.8991
#   Val Cosine Sim: 0.6125
#   Val OS24 AUC: 0.6074
#   LR: 1.00e-04
#
#   New best validation loss: 313.3678
# Epoch 9/50 (0.34s)
#   Train Loss: 307.5841
#   Train Cosine Sim: 0.5943
#   Val Loss: 313.3678
#   Val Cosine Sim: 0.6314
#   Val OS24 AUC: 0.5936
#   LR: 1.00e-04
#
#   New best validation loss: 312.3548
# Epoch 10/50 (0.38s)
#   Train Loss: 305.0482
#   Train Cosine Sim: 0.6160
#   Val Loss: 312.3548
#   Val Cosine Sim: 0.6485
#   Val OS24 AUC: 0.6066
#   LR: 1.00e-04
#
#   New best validation loss: 311.5614
# Epoch 11/50 (0.34s)
#   Train Loss: 302.6761
#   Train Cosine Sim: 0.6318
#   Val Loss: 311.5614
#   Val Cosine Sim: 0.6578
#   Val OS24 AUC: 0.6179
#   LR: 1.00e-04
#
#   New best validation loss: 309.0092
# Epoch 12/50 (0.33s)
#   Train Loss: 300.5770
#   Train Cosine Sim: 0.6451
#   Val Loss: 309.0092
#   Val Cosine Sim: 0.6695
#   Val OS24 AUC: 0.5686
#   LR: 1.00e-04
#
#   New best validation loss: 308.0829
# Epoch 13/50 (0.33s)
#   Train Loss: 297.7560
#   Train Cosine Sim: 0.6562
#   Val Loss: 308.0829
#   Val Cosine Sim: 0.6764
#   Val OS24 AUC: 0.5669
#   LR: 1.00e-04
#
#   New best validation loss: 306.7760
# Epoch 14/50 (0.33s)
#   Train Loss: 295.5633
#   Train Cosine Sim: 0.6653
#   Val Loss: 306.7760
#   Val Cosine Sim: 0.6837
#   Val OS24 AUC: 0.5606
#   LR: 1.00e-04
#
#   New best validation loss: 305.4276
# Epoch 15/50 (0.34s)
#   Train Loss: 293.5185
#   Train Cosine Sim: 0.6725
#   Val Loss: 305.4276
#   Val Cosine Sim: 0.6887
#   Val OS24 AUC: 0.5844
#   LR: 1.00e-04
#
#   New best validation loss: 302.8320
# Epoch 16/50 (0.35s)
#   Train Loss: 290.6253
#   Train Cosine Sim: 0.6799
#   Val Loss: 302.8320
#   Val Cosine Sim: 0.6951
#   Val OS24 AUC: 0.6020
#   LR: 1.00e-04
#
#   New best validation loss: 302.5843
# Epoch 17/50 (0.34s)
#   Train Loss: 288.6206
#   Train Cosine Sim: 0.6858
#   Val Loss: 302.5843
#   Val Cosine Sim: 0.6996
#   Val OS24 AUC: 0.5853
#   LR: 1.00e-04
#
#   New best validation loss: 300.8370
# Epoch 18/50 (0.33s)
#   Train Loss: 286.1070
#   Train Cosine Sim: 0.6912
#   Val Loss: 300.8370
#   Val Cosine Sim: 0.7039
#   Val OS24 AUC: 0.5142
#   LR: 1.00e-04
#
#   New best validation loss: 298.3352
# Epoch 19/50 (0.33s)
#   Train Loss: 283.5646
#   Train Cosine Sim: 0.6964
#   Val Loss: 298.3352
#   Val Cosine Sim: 0.7081
#   Val OS24 AUC: 0.5447
#   LR: 1.00e-04
#
#   New best validation loss: 296.1083
# Epoch 20/50 (0.34s)
#   Train Loss: 281.1727
#   Train Cosine Sim: 0.7006
#   Val Loss: 296.1083
#   Val Cosine Sim: 0.7121
#   Val OS24 AUC: 0.5205
#   LR: 1.00e-04
#
#   New best validation loss: 294.2410
# Epoch 21/50 (0.33s)
#   Train Loss: 278.6666
#   Train Cosine Sim: 0.7046
#   Val Loss: 294.2410
#   Val Cosine Sim: 0.7156
#   Val OS24 AUC: 0.5205
#   LR: 1.00e-04
#
#   New best validation loss: 293.4727
# Epoch 22/50 (0.34s)
#   Train Loss: 276.8497
#   Train Cosine Sim: 0.7085
#   Val Loss: 293.4727
#   Val Cosine Sim: 0.7187
#   Val OS24 AUC: 0.5238
#   LR: 1.00e-04
#
#   New best validation loss: 291.5593
# Epoch 23/50 (0.33s)
#   Train Loss: 274.2161
#   Train Cosine Sim: 0.7114
#   Val Loss: 291.5593
#   Val Cosine Sim: 0.7207
#   Val OS24 AUC: 0.5569
#   LR: 1.00e-04
#
#   New best validation loss: 290.3141
# Epoch 24/50 (0.33s)
#   Train Loss: 272.4611
#   Train Cosine Sim: 0.7144
#   Val Loss: 290.3141
#   Val Cosine Sim: 0.7232
#   Val OS24 AUC: 0.6074
#   LR: 1.00e-04
#
#   New best validation loss: 288.1591
# Epoch 25/50 (0.33s)
#   Train Loss: 269.5442
#   Train Cosine Sim: 0.7174
#   Val Loss: 288.1591
#   Val Cosine Sim: 0.7258
#   Val OS24 AUC: 0.6237
#   LR: 1.00e-04
#
#   New best validation loss: 287.3350
# Epoch 26/50 (0.33s)
#   Train Loss: 266.8446
#   Train Cosine Sim: 0.7203
#   Val Loss: 287.3350
#   Val Cosine Sim: 0.7279
#   Val OS24 AUC: 0.5803
#   LR: 1.00e-04
#
#   New best validation loss: 285.6595
# Epoch 27/50 (0.34s)
#   Train Loss: 264.1730
#   Train Cosine Sim: 0.7229
#   Val Loss: 285.6595
#   Val Cosine Sim: 0.7302
#   Val OS24 AUC: 0.5911
#   LR: 1.00e-04
#
#   New best validation loss: 283.1522
# Epoch 28/50 (0.34s)
#   Train Loss: 262.5713
#   Train Cosine Sim: 0.7251
#   Val Loss: 283.1522
#   Val Cosine Sim: 0.7324
#   Val OS24 AUC: 0.5673
#   LR: 1.00e-04
#
#   New best validation loss: 281.4858
# Epoch 29/50 (0.33s)
#   Train Loss: 259.8419
#   Train Cosine Sim: 0.7278
#   Val Loss: 281.4858
#   Val Cosine Sim: 0.7347
#   Val OS24 AUC: 0.5707
#   LR: 1.00e-04
#
#   New best validation loss: 278.4936
# Epoch 30/50 (0.34s)
#   Train Loss: 257.7321
#   Train Cosine Sim: 0.7299
#   Val Loss: 278.4936
#   Val Cosine Sim: 0.7363
#   Val OS24 AUC: 0.5573
#   LR: 1.00e-04
#
#   New best validation loss: 276.1200
# Epoch 31/50 (0.33s)
#   Train Loss: 255.4591
#   Train Cosine Sim: 0.7322
#   Val Loss: 276.1200
#   Val Cosine Sim: 0.7383
#   Val OS24 AUC: 0.5631
#   LR: 1.00e-04
#
#   New best validation loss: 274.3762
# Epoch 32/50 (0.33s)
#   Train Loss: 252.4832
#   Train Cosine Sim: 0.7345
#   Val Loss: 274.3762
#   Val Cosine Sim: 0.7405
#   Val OS24 AUC: 0.5573
#   LR: 1.00e-04
#
#   New best validation loss: 269.8018
# Epoch 33/50 (0.34s)
#   Train Loss: 250.4240
#   Train Cosine Sim: 0.7365
#   Val Loss: 269.8018
#   Val Cosine Sim: 0.7427
#   Val OS24 AUC: 0.6221
#   LR: 1.00e-04
#
# Epoch 34/50 (0.29s)
#   Train Loss: 248.2684
#   Train Cosine Sim: 0.7384
#   Val Loss: 269.9297
#   Val Cosine Sim: 0.7443
#   Val OS24 AUC: 0.6296
#   LR: 1.00e-04
#
#   New best validation loss: 268.3164
# Epoch 35/50 (0.34s)
#   Train Loss: 246.1685
#   Train Cosine Sim: 0.7406
#   Val Loss: 268.3164
#   Val Cosine Sim: 0.7459
#   Val OS24 AUC: 0.6054
#   LR: 1.00e-04
#
#   New best validation loss: 267.2978
# Epoch 36/50 (0.34s)
#   Train Loss: 243.5921
#   Train Cosine Sim: 0.7426
#   Val Loss: 267.2978
#   Val Cosine Sim: 0.7477
#   Val OS24 AUC: 0.6275
#   LR: 1.00e-04
#
#   New best validation loss: 264.7760
# Epoch 37/50 (0.33s)
#   Train Loss: 240.8783
#   Train Cosine Sim: 0.7445
#   Val Loss: 264.7760
#   Val Cosine Sim: 0.7494
#   Val OS24 AUC: 0.6196
#   LR: 1.00e-04
#
#   New best validation loss: 262.6248
# Epoch 38/50 (0.33s)
#   Train Loss: 239.5569
#   Train Cosine Sim: 0.7463
#   Val Loss: 262.6248
#   Val Cosine Sim: 0.7513
#   Val OS24 AUC: 0.6137
#   LR: 1.00e-04
#
#   New best validation loss: 260.2203
# Epoch 39/50 (0.33s)
#   Train Loss: 236.9772
#   Train Cosine Sim: 0.7482
#   Val Loss: 260.2203
#   Val Cosine Sim: 0.7531
#   Val OS24 AUC: 0.6062
#   LR: 1.00e-04
#
#   New best validation loss: 259.2433
# Epoch 40/50 (0.34s)
#   Train Loss: 235.1160
#   Train Cosine Sim: 0.7500
#   Val Loss: 259.2433
#   Val Cosine Sim: 0.7548
#   Val OS24 AUC: 0.5870
#   LR: 1.00e-04
#   New best validation loss: 257.8743
# Epoch 41/50 (0.34s)
#   Train Loss: 232.4591
#   Train Cosine Sim: 0.7517
#   Val Loss: 257.8743
#   Val Cosine Sim: 0.7563
#   Val OS24 AUC: 0.5665
#   LR: 1.00e-04
#
#   New best validation loss: 255.8020
# Epoch 42/50 (0.34s)
#   Train Loss: 230.9215
#   Train Cosine Sim: 0.7535
#   Val Loss: 255.8020
#   Val Cosine Sim: 0.7577
#   Val OS24 AUC: 0.5602
#   LR: 1.00e-04
#
#   New best validation loss: 252.6970
# Epoch 43/50 (0.34s)
#   Train Loss: 227.6710
#   Train Cosine Sim: 0.7550
#   Val Loss: 252.6970
#   Val Cosine Sim: 0.7594
#   Val OS24 AUC: 0.5523
#   LR: 1.00e-04
#
#   New best validation loss: 252.5346
# Epoch 44/50 (0.33s)
#   Train Loss: 226.4706
#   Train Cosine Sim: 0.7569
#   Val Loss: 252.5346
#   Val Cosine Sim: 0.7608
#   Val OS24 AUC: 0.5635
#   LR: 1.00e-04
#
#   New best validation loss: 247.6840
# Epoch 45/50 (0.33s)
#   Train Loss: 224.4094
#   Train Cosine Sim: 0.7582
#   Val Loss: 247.6840
#   Val Cosine Sim: 0.7625
#   Val OS24 AUC: 0.5598
#   LR: 1.00e-04
#
#   New best validation loss: 245.0212
# Epoch 46/50 (0.33s)
#   Train Loss: 222.1296
#   Train Cosine Sim: 0.7598
#   Val Loss: 245.0212
#   Val Cosine Sim: 0.7639
#   Val OS24 AUC: 0.5631
#   LR: 1.00e-04
#
# Epoch 47/50 (0.29s)
#   Train Loss: 219.4150
#   Train Cosine Sim: 0.7617
#   Val Loss: 245.7490
#   Val Cosine Sim: 0.7652
#   Val OS24 AUC: 0.5514
#   LR: 1.00e-04
#
#   New best validation loss: 243.2006
# Epoch 48/50 (0.35s)
#   Train Loss: 217.4602
#   Train Cosine Sim: 0.7631
#   Val Loss: 243.2006
#   Val Cosine Sim: 0.7670
#   Val OS24 AUC: 0.5690
#   LR: 1.00e-04
#
#   New best validation loss: 240.8673
# Epoch 49/50 (0.34s)
#   Train Loss: 214.9492
#   Train Cosine Sim: 0.7646
#   Val Loss: 240.8673
#   Val Cosine Sim: 0.7682
#   Val OS24 AUC: 0.5631
#   LR: 1.00e-04
#
#   New best validation loss: 238.5146
# Epoch 50/50 (0.34s)
#   Train Loss: 213.6454
#   Train Cosine Sim: 0.7661
#   Val Loss: 238.5146
#   Val Cosine Sim: 0.7698
#   Val OS24 AUC: 0.5857
#   LR: 1.00e-04
#
# Training completed!
# Best validation loss: 238.5146
# Score: 0.4100, Val Loss: 238.5146
# Val OS24 AUC: 0.5857
#
# === Combination 2/2304 ===
# Parameters: {'attention_k': 11, 'latent_dim': 64, 'encoder_layers': [128, 64], 'predictor_layers': [64, 32], 'dropout_rate': 0.3, 'learning_rate': 0.0001, 'batch_size': 32, 'reconstruction_weight': 1.0, 'prediction_weight': 2.0}
# Stratification successful with endpoints: ['os24']
# Train samples: 522
# Validation samples: 118
# Test samples: 104
# Starting training for 50 epochs...
# Model type: autoencoder
# Device: cuda
#   New best validation loss: 327.5544
# Epoch 1/50 (0.45s)
#   Train Loss: 327.5390
#   Train Cosine Sim: 0.0477
#   Val Loss: 327.5544
#   Val Cosine Sim: 0.1205
#   Val OS24 AUC: 0.4356
#   LR: 1.00e-04
#
#   New best validation loss: 325.6761
# Epoch 2/50 (0.39s)
#   Train Loss: 325.6367
#   Train Cosine Sim: 0.1701
#   Val Loss: 325.6761
#   Val Cosine Sim: 0.2665
#   Val OS24 AUC: 0.5134
#   LR: 1.00e-04
#
#   New best validation loss: 324.6311
# Epoch 3/50 (0.37s)
#   Train Loss: 322.3764
#   Train Cosine Sim: 0.2780
#   Val Loss: 324.6311
#   Val Cosine Sim: 0.3649
#   Val OS24 AUC: 0.5196
#   LR: 1.00e-04
#
#   New best validation loss: 323.0464
# Epoch 4/50 (0.36s)
#   Train Loss: 320.2883
#   Train Cosine Sim: 0.3688
#   Val Loss: 323.0464
#   Val Cosine Sim: 0.4519
#   Val OS24 AUC: 0.5280
#   LR: 1.00e-04
#
#   New best validation loss: 321.6643
# Epoch 5/50 (0.37s)
#   Train Loss: 317.8265
#   Train Cosine Sim: 0.4393
#   Val Loss: 321.6643
#   Val Cosine Sim: 0.5154
#   Val OS24 AUC: 0.6150
#   LR: 1.00e-04
#
#   New best validation loss: 319.5395
# Epoch 6/50 (0.38s)
#   Train Loss: 315.5965
#   Train Cosine Sim: 0.4939
#   Val Loss: 319.5395
#   Val Cosine Sim: 0.5651
#   Val OS24 AUC: 0.5217
#   LR: 1.00e-04
#
#   New best validation loss: 318.2274
# Epoch 7/50 (0.37s)
#   Train Loss: 313.3499
#   Train Cosine Sim: 0.5366
#   Val Loss: 318.2274
#   Val Cosine Sim: 0.5928
#   Val OS24 AUC: 0.4783
#   LR: 1.00e-04
#
#   New best validation loss: 316.3885
# Epoch 8/50 (0.37s)
#   Train Loss: 310.6452
#   Train Cosine Sim: 0.5689
#   Val Loss: 316.3885
#   Val Cosine Sim: 0.6163
#   Val OS24 AUC: 0.5426
#   LR: 1.00e-04
#
#   New best validation loss: 313.8636
# Epoch 9/50 (0.36s)
#   Train Loss: 308.9307
#   Train Cosine Sim: 0.5957
#   Val Loss: 313.8636
#   Val Cosine Sim: 0.6339
#   Val OS24 AUC: 0.5059
#   LR: 1.00e-04
#
#   New best validation loss: 313.4178
# Epoch 10/50 (0.36s)
#   Train Loss: 306.3992
#   Train Cosine Sim: 0.6159
#   Val Loss: 313.4178
#   Val Cosine Sim: 0.6454
#   Val OS24 AUC: 0.4849
#   LR: 1.00e-04
#
#   New best validation loss: 312.5956
# Epoch 11/50 (0.37s)
#   Train Loss: 304.0150
#   Train Cosine Sim: 0.6315
#   Val Loss: 312.5956
#   Val Cosine Sim: 0.6582
#   Val OS24 AUC: 0.5201
#   LR: 1.00e-04
#
#   New best validation loss: 311.0026
# Epoch 12/50 (0.37s)
#   Train Loss: 302.0243
#   Train Cosine Sim: 0.6449
#   Val Loss: 311.0026
#   Val Cosine Sim: 0.6683
#   Val OS24 AUC: 0.5798
#   LR: 1.00e-04
#
#   New best validation loss: 309.2188
# Epoch 13/50 (0.37s)
#   Train Loss: 298.9724
#   Train Cosine Sim: 0.6565
#   Val Loss: 309.2188
#   Val Cosine Sim: 0.6780
#   Val OS24 AUC: 0.5493
#   LR: 1.00e-04
#
#   New best validation loss: 307.2198
# Epoch 14/50 (0.36s)
#   Train Loss: 296.8208
#   Train Cosine Sim: 0.6655
#   Val Loss: 307.2198
#   Val Cosine Sim: 0.6856
#   Val OS24 AUC: 0.5004
#   LR: 1.00e-04
#
#   New best validation loss: 305.8596
# Epoch 15/50 (0.37s)
#   Train Loss: 294.6936
#   Train Cosine Sim: 0.6731
#   Val Loss: 305.8596
#   Val Cosine Sim: 0.6907
#   Val OS24 AUC: 0.5159
#   LR: 1.00e-04
#
#   New best validation loss: 304.4778
# Epoch 16/50 (0.37s)
#   Train Loss: 291.7924
#   Train Cosine Sim: 0.6804
#   Val Loss: 304.4778
#   Val Cosine Sim: 0.6965
#   Val OS24 AUC: 0.5075
#   LR: 1.00e-04
#
#   New best validation loss: 302.8694
# Epoch 17/50 (0.38s)
#   Train Loss: 289.9355
#   Train Cosine Sim: 0.6862
#   Val Loss: 302.8694
#   Val Cosine Sim: 0.7014
#   Val OS24 AUC: 0.5004
#   LR: 1.00e-04
#
#   New best validation loss: 300.9583
# Epoch 18/50 (0.37s)
#   Train Loss: 287.3741
#   Train Cosine Sim: 0.6916
#   Val Loss: 300.9583
#   Val Cosine Sim: 0.7055
#   Val OS24 AUC: 0.5723
#   LR: 1.00e-04
#
#   New best validation loss: 297.9601
# Epoch 19/50 (0.36s)
#   Train Loss: 285.3959
#   Train Cosine Sim: 0.6961
#   Val Loss: 297.9601
#   Val Cosine Sim: 0.7098
#   Val OS24 AUC: 0.5874
#   LR: 1.00e-04
#
#   New best validation loss: 296.5660
# Epoch 20/50 (0.37s)
#   Train Loss: 282.8593
#   Train Cosine Sim: 0.7004
#   Val Loss: 296.5660
#   Val Cosine Sim: 0.7125
#   Val OS24 AUC: 0.5878
#   LR: 1.00e-04
#
#   New best validation loss: 296.2313
# Epoch 21/50 (0.37s)
#   Train Loss: 280.3638
#   Train Cosine Sim: 0.7044
#   Val Loss: 296.2313
#   Val Cosine Sim: 0.7155
#   Val OS24 AUC: 0.5301
#   LR: 1.00e-04
#
#   New best validation loss: 293.8065
# Epoch 22/50 (0.38s)
#   Train Loss: 278.1920
#   Train Cosine Sim: 0.7082
#   Val Loss: 293.8065
#   Val Cosine Sim: 0.7181
#   Val OS24 AUC: 0.4674
#   LR: 1.00e-04
#
#   New best validation loss: 292.6925
# Epoch 23/50 (0.37s)
#   Train Loss: 275.1826
#   Train Cosine Sim: 0.7115
#   Val Loss: 292.6925
#   Val Cosine Sim: 0.7211
#   Val OS24 AUC: 0.5130
#   LR: 1.00e-04
#
#   New best validation loss: 289.6701
# Epoch 24/50 (0.37s)
#   Train Loss: 273.4793
#   Train Cosine Sim: 0.7146
#   Val Loss: 289.6701
#   Val Cosine Sim: 0.7242
#   Val OS24 AUC: 0.5155
#   LR: 1.00e-04
#
#   New best validation loss: 288.2498
# Epoch 25/50 (0.37s)
#   Train Loss: 270.9104
#   Train Cosine Sim: 0.7177
#   Val Loss: 288.2498
#   Val Cosine Sim: 0.7263
#   Val OS24 AUC: 0.5385
#   LR: 1.00e-04
#
# Epoch 26/50 (0.32s)
#   Train Loss: 268.1972
#   Train Cosine Sim: 0.7206
#   Val Loss: 288.3756
#   Val Cosine Sim: 0.7280
#   Val OS24 AUC: 0.5803
#   LR: 1.00e-04
#
#   New best validation loss: 284.6866
# Epoch 27/50 (0.38s)
#   Train Loss: 265.2352
#   Train Cosine Sim: 0.7230
#   Val Loss: 284.6866
#   Val Cosine Sim: 0.7303
#   Val OS24 AUC: 0.5978
#   LR: 1.00e-04
#
#   New best validation loss: 283.1237
# Epoch 28/50 (0.37s)
#   Train Loss: 263.5483
#   Train Cosine Sim: 0.7254
#   Val Loss: 283.1237
#   Val Cosine Sim: 0.7326
#   Val OS24 AUC: 0.6183
#   LR: 1.00e-04
#
#   New best validation loss: 281.7068
# Epoch 29/50 (0.37s)
#   Train Loss: 260.7920
#   Train Cosine Sim: 0.7280
#   Val Loss: 281.7068
#   Val Cosine Sim: 0.7345
#   Val OS24 AUC: 0.6070
#   LR: 1.00e-04
#
#   New best validation loss: 278.9198
# Epoch 30/50 (0.38s)
#   Train Loss: 259.0518
#   Train Cosine Sim: 0.7302
#   Val Loss: 278.9198
#   Val Cosine Sim: 0.7369
#   Val OS24 AUC: 0.5418
#   LR: 1.00e-04
#
#   New best validation loss: 277.2539
# Epoch 31/50 (0.86s)
#   Train Loss: 256.6115
#   Train Cosine Sim: 0.7324
#   Val Loss: 277.2539
#   Val Cosine Sim: 0.7388
#   Val OS24 AUC: 0.5556
#   LR: 1.00e-04
#   New best validation loss: 274.5007
# Epoch 32/50 (0.37s)
#   Train Loss: 254.1179
#   Train Cosine Sim: 0.7346
#   Val Loss: 274.5007
#   Val Cosine Sim: 0.7409
#   Val OS24 AUC: 0.5698
#   LR: 1.00e-04
#
#   New best validation loss: 271.8943
# Epoch 33/50 (0.36s)
#   Train Loss: 251.6065
#   Train Cosine Sim: 0.7369
#   Val Loss: 271.8943
#   Val Cosine Sim: 0.7427
#   Val OS24 AUC: 0.5656
#   LR: 1.00e-04
#
#   New best validation loss: 271.1156
# Epoch 34/50 (0.37s)
#   Train Loss: 249.4521
#   Train Cosine Sim: 0.7386
#   Val Loss: 271.1156
#   Val Cosine Sim: 0.7447
#   Val OS24 AUC: 0.5648
#   LR: 1.00e-04
#
# ^C
# Traceback (most recent call last):
#   File "/share/project10/home/prelajarsela/Attention_based_reduction/gridsearch.py", line 346, in <module>
#     main()
#   File "/share/project10/home/prelajarsela/Attention_based_reduction/gridsearch.py", line 332, in main
#     results_df = grid_search.run_search(max_epochs=50)  # Shorter epochs for grid search
#   File "/share/project10/home/prelajarsela/Attention_based_reduction/gridsearch.py", line 125, in run_search
#     history = train_model(
#   File "/share/project10/home/prelajarsela/Attention_based_reduction/utils/train_loop.py", line 424, in train_model
#     val_losses, val_metrics = evaluate_model(
#   File "/share/project10/home/prelajarsela/Attention_based_reduction/utils/train_loop.py", line 217, in evaluate_model
#     for batch in dataloader:
#   File "/share/project10/home/prelajarsela/.conda/envs/ABR/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 733, in __next__
#     data = self._next_data()
#   File "/share/project10/home/prelajarsela/.conda/envs/ABR/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 789, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/share/project10/home/prelajarsela/.conda/envs/ABR/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 52, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/share/project10/home/prelajarsela/.conda/envs/ABR/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 52, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/share/project10/home/prelajarsela/Attention_based_reduction/utils/dataloader.py", line 71, in __getitem__
#     features = torch.stack(patient['features'])  # Shape: (176, 512)
# KeyboardInterrupt

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 50 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 2.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# Train samples: 522
# Validation samples: 118
# Test samples: 104
# Creating autoencoder model...
# Model parameters: 5,931,026
# Starting training...
# Starting training for 50 epochs...
# Model type: autoencoder
# Device: cuda
# Epoch 1/50 (1.29s)
#   Train Loss: 323.1098
#   Train Cosine Sim: 0.3768
#   Val Loss: 325.2148
#   Val Cosine Sim: 0.6376
#   Val OS24 AUC: 0.5234
#   LR: 1.00e-03
#
# Epoch 2/50 (0.41s)
#   Train Loss: 299.8287
#   Train Cosine Sim: 0.6647
#   Val Loss: 309.3645
#   Val Cosine Sim: 0.6990
#   Val OS24 AUC: 0.5874
#   LR: 1.00e-03
#
# Epoch 3/50 (0.49s)
#   Train Loss: 275.6618
#   Train Cosine Sim: 0.7048
#   Val Loss: 288.4811
#   Val Cosine Sim: 0.7209
#   Val OS24 AUC: 0.5263
#   LR: 1.00e-03
#
# Epoch 4/50 (0.41s)
#   Train Loss: 254.2345
#   Train Cosine Sim: 0.7256
#   Val Loss: 261.7235
#   Val Cosine Sim: 0.7386
#   Val OS24 AUC: 0.5765
#   LR: 1.00e-03
#
# Epoch 5/50 (0.40s)
#   Train Loss: 231.6341
#   Train Cosine Sim: 0.7437
#   Val Loss: 240.9340
#   Val Cosine Sim: 0.7540
#   Val OS24 AUC: 0.6104
#   LR: 1.00e-03
#
# Epoch 6/50 (0.40s)
#   Train Loss: 213.0773
#   Train Cosine Sim: 0.7598
#   Val Loss: 217.5118
#   Val Cosine Sim: 0.7690
#   Val OS24 AUC: 0.5999
#   LR: 1.00e-03
#
# Epoch 7/50 (0.40s)
#   Train Loss: 193.3182
#   Train Cosine Sim: 0.7743
#   Val Loss: 194.7031
#   Val Cosine Sim: 0.7827
#   Val OS24 AUC: 0.5560
#   LR: 1.00e-03
#
# Epoch 8/50 (0.40s)
#   Train Loss: 174.9367
#   Train Cosine Sim: 0.7876
#   Val Loss: 171.1035
#   Val Cosine Sim: 0.7959
#   Val OS24 AUC: 0.6413
#   LR: 1.00e-03
#
# Epoch 9/50 (0.41s)
#   Train Loss: 158.9773
#   Train Cosine Sim: 0.8009
#   Val Loss: 152.1146
#   Val Cosine Sim: 0.8087
#   Val OS24 AUC: 0.6145
#   LR: 1.00e-03
#
# Epoch 10/50 (0.42s)
#   Train Loss: 144.9946
#   Train Cosine Sim: 0.8134
#   Val Loss: 141.0888
#   Val Cosine Sim: 0.8203
#   Val OS24 AUC: 0.6191
#   LR: 1.00e-03
#
# Epoch 11/50 (0.42s)
#   Train Loss: 132.4261
#   Train Cosine Sim: 0.8245
#   Val Loss: 127.4384
#   Val Cosine Sim: 0.8308
#   Val OS24 AUC: 0.5326
#   LR: 1.00e-03
#
# Epoch 12/50 (0.42s)
#   Train Loss: 121.9089
#   Train Cosine Sim: 0.8349
#   Val Loss: 121.5401
#   Val Cosine Sim: 0.8401
#   Val OS24 AUC: 0.5606
#   LR: 1.00e-03
#
# Epoch 13/50 (0.41s)
#   Train Loss: 112.6868
#   Train Cosine Sim: 0.8442
#   Val Loss: 112.8579
#   Val Cosine Sim: 0.8492
#   Val OS24 AUC: 0.5916
#   LR: 1.00e-03
#
# Epoch 14/50 (0.41s)
#   Train Loss: 106.5274
#   Train Cosine Sim: 0.8524
#   Val Loss: 105.6774
#   Val Cosine Sim: 0.8571
#   Val OS24 AUC: 0.5916
#   LR: 1.00e-03
#
# Epoch 15/50 (0.44s)
#   Train Loss: 99.3431
#   Train Cosine Sim: 0.8603
#   Val Loss: 100.4595
#   Val Cosine Sim: 0.8637
#   Val OS24 AUC: 0.5631
#   LR: 1.00e-03
#
# Epoch 16/50 (0.40s)
#   Train Loss: 94.1760
#   Train Cosine Sim: 0.8668
#   Val Loss: 94.4474
#   Val Cosine Sim: 0.8702
#   Val OS24 AUC: 0.5552
#   LR: 1.00e-03
#
# Epoch 17/50 (0.39s)
#   Train Loss: 89.1002
#   Train Cosine Sim: 0.8725
#   Val Loss: 88.0541
#   Val Cosine Sim: 0.8762
#   Val OS24 AUC: 0.6225
#   LR: 1.00e-03
#
# Epoch 18/50 (0.41s)
#   Train Loss: 85.7977
#   Train Cosine Sim: 0.8785
#   Val Loss: 84.7629
#   Val Cosine Sim: 0.8818
#   Val OS24 AUC: 0.6760
#   LR: 1.00e-03
#
# Epoch 19/50 (0.40s)
#   Train Loss: 81.6782
#   Train Cosine Sim: 0.8835
#   Val Loss: 80.8369
#   Val Cosine Sim: 0.8867
#   Val OS24 AUC: 0.6095
#   LR: 1.00e-03
#
# Epoch 20/50 (0.40s)
#   Train Loss: 77.7933
#   Train Cosine Sim: 0.8883
#   Val Loss: 75.9324
#   Val Cosine Sim: 0.8912
#   Val OS24 AUC: 0.6664
#   LR: 1.00e-03
#
# Epoch 21/50 (0.40s)
#   Train Loss: 75.5952
#   Train Cosine Sim: 0.8931
#   Val Loss: 73.9626
#   Val Cosine Sim: 0.8956
#   Val OS24 AUC: 0.6714
#   LR: 1.00e-03
#
# Epoch 22/50 (0.40s)
#   Train Loss: 72.1825
#   Train Cosine Sim: 0.8971
#   Val Loss: 72.1580
#   Val Cosine Sim: 0.8995
#   Val OS24 AUC: 0.6538
#   LR: 1.00e-03
#
# Epoch 23/50 (0.40s)
#   Train Loss: 69.3742
#   Train Cosine Sim: 0.9010
#   Val Loss: 68.2883
#   Val Cosine Sim: 0.9029
#   Val OS24 AUC: 0.6697
#   LR: 1.00e-03
#
# Epoch 24/50 (0.40s)
#   Train Loss: 66.0737
#   Train Cosine Sim: 0.9041
#   Val Loss: 65.5981
#   Val Cosine Sim: 0.9066
#   Val OS24 AUC: 0.6509
#   LR: 1.00e-03
#
# Epoch 25/50 (0.43s)
#   Train Loss: 63.7292
#   Train Cosine Sim: 0.9077
#   Val Loss: 62.7895
#   Val Cosine Sim: 0.9102
#   Val OS24 AUC: 0.5753
#   LR: 1.00e-03
#
# Epoch 26/50 (0.41s)
#   Train Loss: 61.9332
#   Train Cosine Sim: 0.9113
#   Val Loss: 60.3059
#   Val Cosine Sim: 0.9138
#   Val OS24 AUC: 0.5723
#   LR: 1.00e-03
#
# Epoch 27/50 (0.44s)
#   Train Loss: 60.0801
#   Train Cosine Sim: 0.9147
#   Val Loss: 58.6806
#   Val Cosine Sim: 0.9169
#   Val OS24 AUC: 0.6012
#   LR: 1.00e-03
#
# Epoch 28/50 (0.45s)
#   Train Loss: 59.6222
#   Train Cosine Sim: 0.9180
#   Val Loss: 58.2417
#   Val Cosine Sim: 0.9198
#   Val OS24 AUC: 0.6129
#   LR: 1.00e-03
#
# Epoch 29/50 (0.44s)
#   Train Loss: 56.1824
#   Train Cosine Sim: 0.9204
#   Val Loss: 58.0054
#   Val Cosine Sim: 0.9225
#   Val OS24 AUC: 0.6150
#   LR: 1.00e-03
#
# Epoch 30/50 (0.44s)
#   Train Loss: 54.0707
#   Train Cosine Sim: 0.9234
#   Val Loss: 52.6216
#   Val Cosine Sim: 0.9257
#   Val OS24 AUC: 0.5962
#   LR: 1.00e-03
#
# Epoch 31/50 (0.43s)
#   Train Loss: 53.0144
#   Train Cosine Sim: 0.9263
#   Val Loss: 51.5608
#   Val Cosine Sim: 0.9282
#   Val OS24 AUC: 0.6572
#   LR: 1.00e-03
#
# Epoch 32/50 (0.41s)
#   Train Loss: 51.3651
#   Train Cosine Sim: 0.9285
#   Val Loss: 50.4579
#   Val Cosine Sim: 0.9304
#   Val OS24 AUC: 0.6497
#   LR: 1.00e-03
#
# Epoch 33/50 (0.42s)
#   Train Loss: 49.1947
#   Train Cosine Sim: 0.9314
#   Val Loss: 48.2403
#   Val Cosine Sim: 0.9330
#   Val OS24 AUC: 0.6313
#   LR: 1.00e-03
#
# Epoch 34/50 (0.40s)
#   Train Loss: 47.4532
#   Train Cosine Sim: 0.9334
#   Val Loss: 47.4483
#   Val Cosine Sim: 0.9351
#   Val OS24 AUC: 0.6396
#   LR: 1.00e-03
#
# Epoch 35/50 (0.41s)
#   Train Loss: 45.8850
#   Train Cosine Sim: 0.9358
#   Val Loss: 44.8335
#   Val Cosine Sim: 0.9378
#   Val OS24 AUC: 0.5456
#   LR: 1.00e-03
#
# Epoch 36/50 (0.41s)
#   Train Loss: 45.5794
#   Train Cosine Sim: 0.9380
#   Val Loss: 42.8735
#   Val Cosine Sim: 0.9404
#   Val OS24 AUC: 0.6877
#   LR: 1.00e-03
#
# Epoch 37/50 (0.41s)
#   Train Loss: 43.1920
#   Train Cosine Sim: 0.9413
#   Val Loss: 42.8697
#   Val Cosine Sim: 0.9422
#   Val OS24 AUC: 0.6325
#   LR: 1.00e-03
#
# Epoch 38/50 (0.41s)
#   Train Loss: 41.8729
#   Train Cosine Sim: 0.9435
#   Val Loss: 42.1109
#   Val Cosine Sim: 0.9448
#   Val OS24 AUC: 0.6438
#   LR: 1.00e-03
#
# Epoch 39/50 (0.41s)
#   Train Loss: 40.1929
#   Train Cosine Sim: 0.9458
#   Val Loss: 40.5280
#   Val Cosine Sim: 0.9466
#   Val OS24 AUC: 0.6589
#   LR: 1.00e-03
#
# Epoch 40/50 (0.40s)
#   Train Loss: 39.1215
#   Train Cosine Sim: 0.9471
#   Val Loss: 38.0220
#   Val Cosine Sim: 0.9487
#   Val OS24 AUC: 0.6154
#   LR: 1.00e-03
#
# Epoch 41/50 (0.39s)
#   Train Loss: 37.4653
#   Train Cosine Sim: 0.9491
#   Val Loss: 36.3232
#   Val Cosine Sim: 0.9510
#   Val OS24 AUC: 0.6079
#   LR: 1.00e-03
#
# Epoch 42/50 (0.40s)
#   Train Loss: 36.4774
#   Train Cosine Sim: 0.9515
#   Val Loss: 35.9935
#   Val Cosine Sim: 0.9530
#   Val OS24 AUC: 0.6409
#   LR: 1.00e-03
#
# Epoch 43/50 (0.40s)
#   Train Loss: 34.5882
#   Train Cosine Sim: 0.9535
#   Val Loss: 33.5889
#   Val Cosine Sim: 0.9552
#   Val OS24 AUC: 0.6204
#   LR: 1.00e-03
#
# Epoch 44/50 (0.40s)
#   Train Loss: 33.6838
#   Train Cosine Sim: 0.9555
#   Val Loss: 32.3298
#   Val Cosine Sim: 0.9569
#   Val OS24 AUC: 0.6066
#   LR: 1.00e-03
#
# Epoch 45/50 (0.40s)
#   Train Loss: 32.3920
#   Train Cosine Sim: 0.9570
#   Val Loss: 31.3012
#   Val Cosine Sim: 0.9587
#   Val OS24 AUC: 0.6166
#   LR: 1.00e-03
#
# Epoch 46/50 (0.40s)
#   Train Loss: 32.0137
#   Train Cosine Sim: 0.9584
#   Val Loss: 30.8232
#   Val Cosine Sim: 0.9603
#   Val OS24 AUC: 0.6375
#   LR: 1.00e-03
#
# Epoch 47/50 (0.40s)
#   Train Loss: 31.1514
#   Train Cosine Sim: 0.9604
#   Val Loss: 30.3625
#   Val Cosine Sim: 0.9619
#   Val OS24 AUC: 0.6292
#   LR: 1.00e-03
#
# Epoch 48/50 (0.41s)
#   Train Loss: 29.9613
#   Train Cosine Sim: 0.9620
#   Val Loss: 29.1825
#   Val Cosine Sim: 0.9634
#   Val OS24 AUC: 0.6074
#   LR: 1.00e-03
#
# Epoch 49/50 (0.40s)
#   Train Loss: 28.6885
#   Train Cosine Sim: 0.9634
#   Val Loss: 27.7319
#   Val Cosine Sim: 0.9647
#   Val OS24 AUC: 0.5890
#   LR: 1.00e-03
#
# Epoch 50/50 (0.40s)
#   Train Loss: 28.2192
#   Train Cosine Sim: 0.9644
#   Val Loss: 26.7309
#   Val Cosine Sim: 0.9662
#   Val OS24 AUC: 0.5322
#   LR: 1.00e-03
#
# Training completed!
# Best validation loss: 26.7309
# Evaluating on test set...
# Loaded best model from epoch 49
#
# Test Results:
# Test Loss: 26.3504
# Test Cosine Sim: 0.9663
# OS24 - AUC: 0.6122, Accuracy: 0.7596, F1: 0.0741
#
# Results saved to: ./results/autoencoder_20250624_104348/autoencoder_20250624_104403

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 11 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 100 \
    --batch_size 128 \
    --learning_rate 1e-2 \
    --weight_decay 1e-3 \
    --reconstruction_weight 1.0 \
    --prediction_weight 4.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# Train samples: 522
# Validation samples: 118
# Test samples: 104
# Creating autoencoder model...
# Model parameters: 3,123,986
# Starting training...
# Starting training for 100 epochs...
# Model type: autoencoder
# Device: cuda
# Epoch 1/100 (0.87s)
#   Train Loss: 305.3440
#   Train Cosine Sim: 0.4353
#   Val Loss: 210.0382
#   Val Cosine Sim: 0.7068
#   Val OS24 AUC: 0.4770
#   LR: 1.00e-02
#
# Epoch 2/100 (0.19s)
#   Train Loss: 226.0413
#   Train Cosine Sim: 0.7254
#   Val Loss: 594.9128
#   Val Cosine Sim: 0.7492
#   Val OS24 AUC: 0.4582
#   LR: 1.00e-02
#
# Epoch 3/100 (0.19s)
#   Train Loss: 161.0545
#   Train Cosine Sim: 0.7701
#   Val Loss: 2015.4127
#   Val Cosine Sim: 0.7869
#   Val OS24 AUC: 0.4607
#   LR: 1.00e-02
#
# Epoch 4/100 (0.19s)
#   Train Loss: 125.4789
#   Train Cosine Sim: 0.8070
#   Val Loss: 1238.2678
#   Val Cosine Sim: 0.8203
#   Val OS24 AUC: 0.4507
#   LR: 1.00e-02
#
# Epoch 5/100 (0.19s)
#   Train Loss: 106.8209
#   Train Cosine Sim: 0.8396
#   Val Loss: 370.9785
#   Val Cosine Sim: 0.8492
#   Val OS24 AUC: 0.4628
#   LR: 1.00e-02
#
# Epoch 6/100 (0.19s)
#   Train Loss: 94.0738
#   Train Cosine Sim: 0.8634
#   Val Loss: 255.8011
#   Val Cosine Sim: 0.8698
#   Val OS24 AUC: 0.4770
#   LR: 1.00e-02
#
# Epoch 7/100 (0.28s)
#   Train Loss: 80.4283
#   Train Cosine Sim: 0.8799
#   Val Loss: 115.3694
#   Val Cosine Sim: 0.8857
#   Val OS24 AUC: 0.4833
#   LR: 1.00e-02
#
# Epoch 8/100 (0.28s)
#   Train Loss: 71.1288
#   Train Cosine Sim: 0.8954
#   Val Loss: 113.1891
#   Val Cosine Sim: 0.9010
#   Val OS24 AUC: 0.4925
#   LR: 1.00e-02
#
# Epoch 9/100 (0.28s)
#   Train Loss: 64.7894
#   Train Cosine Sim: 0.9097
#   Val Loss: 82.7194
#   Val Cosine Sim: 0.9147
#   Val OS24 AUC: 0.5192
#   LR: 1.00e-02
#
# Epoch 10/100 (0.27s)
#   Train Loss: 57.1851
#   Train Cosine Sim: 0.9213
#   Val Loss: 59.8105
#   Val Cosine Sim: 0.9274
#   Val OS24 AUC: 0.5606
#   LR: 1.00e-02
#
# Epoch 11/100 (0.28s)
#   Train Loss: 51.0649
#   Train Cosine Sim: 0.9334
#   Val Loss: 46.5530
#   Val Cosine Sim: 0.9389
#   Val OS24 AUC: 0.5594
#   LR: 1.00e-02
#
# Epoch 12/100 (0.29s)
#   Train Loss: 45.6025
#   Train Cosine Sim: 0.9430
#   Val Loss: 41.5810
#   Val Cosine Sim: 0.9483
#   Val OS24 AUC: 0.5401
#   LR: 1.00e-02
#
# Epoch 13/100 (0.29s)
#   Train Loss: 39.6764
#   Train Cosine Sim: 0.9517
#   Val Loss: 37.2987
#   Val Cosine Sim: 0.9559
#   Val OS24 AUC: 0.4979
#   LR: 1.00e-02
#
# Epoch 14/100 (0.19s)
#   Train Loss: 32.7838
#   Train Cosine Sim: 0.9590
#   Val Loss: 38.9640
#   Val Cosine Sim: 0.9632
#   Val OS24 AUC: 0.4921
#   LR: 1.00e-02
#
# Epoch 15/100 (0.28s)
#   Train Loss: 31.9986
#   Train Cosine Sim: 0.9641
#   Val Loss: 31.5775
#   Val Cosine Sim: 0.9690
#   Val OS24 AUC: 0.4645
#   LR: 1.00e-02
#
# Epoch 16/100 (0.27s)
#   Train Loss: 27.7820
#   Train Cosine Sim: 0.9705
#   Val Loss: 26.1307
#   Val Cosine Sim: 0.9738
#   Val OS24 AUC: 0.4532
#   LR: 1.00e-02
#
# Epoch 17/100 (0.27s)
#   Train Loss: 25.0541
#   Train Cosine Sim: 0.9750
#   Val Loss: 26.0968
#   Val Cosine Sim: 0.9773
#   Val OS24 AUC: 0.4515
#   LR: 1.00e-02
#
# Epoch 18/100 (0.27s)
#   Train Loss: 21.9703
#   Train Cosine Sim: 0.9784
#   Val Loss: 22.4482
#   Val Cosine Sim: 0.9808
#   Val OS24 AUC: 0.4862
#   LR: 1.00e-02
#
# Epoch 19/100 (0.28s)
#   Train Loss: 20.2645
#   Train Cosine Sim: 0.9812
#   Val Loss: 18.2268
#   Val Cosine Sim: 0.9842
#   Val OS24 AUC: 0.5606
#   LR: 1.00e-02
#
# Epoch 20/100 (0.28s)
#   Train Loss: 18.3158
#   Train Cosine Sim: 0.9846
#   Val Loss: 15.5092
#   Val Cosine Sim: 0.9865
#   Val OS24 AUC: 0.5527
#   LR: 1.00e-02
#
# Epoch 21/100 (0.29s)
#   Train Loss: 16.9636
#   Train Cosine Sim: 0.9871
#   Val Loss: 13.6936
#   Val Cosine Sim: 0.9879
#   Val OS24 AUC: 0.5673
#   LR: 1.00e-02
#
# Epoch 22/100 (0.28s)
#   Train Loss: 14.3340
#   Train Cosine Sim: 0.9884
#   Val Loss: 12.3465
#   Val Cosine Sim: 0.9895
#   Val OS24 AUC: 0.5410
#   LR: 1.00e-02
#
# Epoch 23/100 (0.19s)
#   Train Loss: 14.5424
#   Train Cosine Sim: 0.9890
#   Val Loss: 13.1931
#   Val Cosine Sim: 0.9903
#   Val OS24 AUC: 0.4837
#   LR: 1.00e-02
#
# Epoch 24/100 (0.19s)
#   Train Loss: 15.5961
#   Train Cosine Sim: 0.9903
#   Val Loss: 14.7103
#   Val Cosine Sim: 0.9911
#   Val OS24 AUC: 0.4285
#   LR: 1.00e-02
#
# Epoch 25/100 (0.19s)
#   Train Loss: 14.7904
#   Train Cosine Sim: 0.9898
#   Val Loss: 14.8434
#   Val Cosine Sim: 0.9913
#   Val OS24 AUC: 0.4122
#   LR: 1.00e-02
#
# Epoch 26/100 (0.28s)
#   Train Loss: 13.8981
#   Train Cosine Sim: 0.9909
#   Val Loss: 12.1014
#   Val Cosine Sim: 0.9915
#   Val OS24 AUC: 0.4047
#   LR: 1.00e-02
#
# Epoch 27/100 (0.28s)
#   Train Loss: 12.9737
#   Train Cosine Sim: 0.9902
#   Val Loss: 11.6106
#   Val Cosine Sim: 0.9919
#   Val OS24 AUC: 0.4135
#   LR: 1.00e-02
#
# Epoch 28/100 (0.18s)
#   Train Loss: 15.9613
#   Train Cosine Sim: 0.9902
#   Val Loss: 12.3191
#   Val Cosine Sim: 0.9908
#   Val OS24 AUC: 0.4218
#   LR: 1.00e-02
#
# Epoch 29/100 (0.18s)
#   Train Loss: 13.6868
#   Train Cosine Sim: 0.9906
#   Val Loss: 11.6693
#   Val Cosine Sim: 0.9910
#   Val OS24 AUC: 0.4231
#   LR: 1.00e-02
#
# Epoch 30/100 (0.27s)
#   Train Loss: 12.9126
#   Train Cosine Sim: 0.9904
#   Val Loss: 11.3184
#   Val Cosine Sim: 0.9910
#   Val OS24 AUC: 0.4143
#   LR: 1.00e-02
#
# Epoch 31/100 (0.29s)
#   Train Loss: 14.7857
#   Train Cosine Sim: 0.9906
#   Val Loss: 11.0412
#   Val Cosine Sim: 0.9917
#   Val OS24 AUC: 0.4030
#   LR: 1.00e-02
#
# Epoch 32/100 (0.18s)
#   Train Loss: 11.9324
#   Train Cosine Sim: 0.9914
#   Val Loss: 12.4560
#   Val Cosine Sim: 0.9918
#   Val OS24 AUC: 0.4181
#   LR: 1.00e-02
#
# Epoch 33/100 (0.19s)
#   Train Loss: 12.5169
#   Train Cosine Sim: 0.9916
#   Val Loss: 11.7087
#   Val Cosine Sim: 0.9917
#   Val OS24 AUC: 0.4202
#   LR: 1.00e-02
#
# Epoch 34/100 (0.27s)
#   Train Loss: 14.2451
#   Train Cosine Sim: 0.9903
#   Val Loss: 11.0357
#   Val Cosine Sim: 0.9917
#   Val OS24 AUC: 0.4214
#   LR: 1.00e-02
#
# Epoch 35/100 (0.26s)
#   Train Loss: 13.5257
#   Train Cosine Sim: 0.9913
#   Val Loss: 10.9031
#   Val Cosine Sim: 0.9917
#   Val OS24 AUC: 0.4465
#   LR: 1.00e-02
#
# Epoch 36/100 (0.18s)
#   Train Loss: 12.4104
#   Train Cosine Sim: 0.9906
#   Val Loss: 11.7648
#   Val Cosine Sim: 0.9919
#   Val OS24 AUC: 0.4691
#   LR: 1.00e-02
#
# Epoch 37/100 (0.18s)
#   Train Loss: 13.6026
#   Train Cosine Sim: 0.9897
#   Val Loss: 11.7512
#   Val Cosine Sim: 0.9912
#   Val OS24 AUC: 0.5017
#   LR: 1.00e-02
#
# Epoch 38/100 (0.18s)
#   Train Loss: 12.1926
#   Train Cosine Sim: 0.9908
#   Val Loss: 11.4182
#   Val Cosine Sim: 0.9916
#   Val OS24 AUC: 0.5452
#   LR: 1.00e-02
#
# Epoch 39/100 (0.18s)
#   Train Loss: 12.9385
#   Train Cosine Sim: 0.9897
#   Val Loss: 11.5457
#   Val Cosine Sim: 0.9911
#   Val OS24 AUC: 0.5401
#   LR: 1.00e-02
#
# Epoch 40/100 (0.19s)
#   Train Loss: 13.4747
#   Train Cosine Sim: 0.9907
#   Val Loss: 10.9738
#   Val Cosine Sim: 0.9914
#   Val OS24 AUC: 0.5389
#   LR: 1.00e-02
#
# Epoch 41/100 (0.28s)
#   Train Loss: 12.5286
#   Train Cosine Sim: 0.9910
#   Val Loss: 10.0372
#   Val Cosine Sim: 0.9924
#   Val OS24 AUC: 0.5151
#   LR: 1.00e-02
#
# Epoch 42/100 (0.21s)
#   Train Loss: 12.5859
#   Train Cosine Sim: 0.9921
#   Val Loss: 10.9693
#   Val Cosine Sim: 0.9918
#   Val OS24 AUC: 0.4895
#   LR: 1.00e-02
#
# Epoch 43/100 (0.20s)
#   Train Loss: 15.7261
#   Train Cosine Sim: 0.9908
#   Val Loss: 12.3412
#   Val Cosine Sim: 0.9917
#   Val OS24 AUC: 0.5025
#   LR: 1.00e-02
#
# Epoch 44/100 (0.20s)
#   Train Loss: 14.0779
#   Train Cosine Sim: 0.9908
#   Val Loss: 13.3804
#   Val Cosine Sim: 0.9918
#   Val OS24 AUC: 0.4954
#   LR: 1.00e-02
#
# Epoch 45/100 (0.19s)
#   Train Loss: 13.6796
#   Train Cosine Sim: 0.9908
#   Val Loss: 15.7069
#   Val Cosine Sim: 0.9912
#   Val OS24 AUC: 0.5096
#   LR: 1.00e-02
#
# Epoch 46/100 (0.20s)
#   Train Loss: 15.2425
#   Train Cosine Sim: 0.9910
#   Val Loss: 12.2796
#   Val Cosine Sim: 0.9915
#   Val OS24 AUC: 0.5259
#   LR: 1.00e-02
#
# Epoch 47/100 (0.19s)
#   Train Loss: 13.6559
#   Train Cosine Sim: 0.9908
#   Val Loss: 11.4732
#   Val Cosine Sim: 0.9913
#   Val OS24 AUC: 0.5339
#   LR: 1.00e-02
#
# Epoch 48/100 (0.19s)
#   Train Loss: 13.7119
#   Train Cosine Sim: 0.9913
#   Val Loss: 11.1946
#   Val Cosine Sim: 0.9915
#   Val OS24 AUC: 0.5431
#   LR: 1.00e-02
#
# Epoch 49/100 (0.19s)
#   Train Loss: 13.5198
#   Train Cosine Sim: 0.9903
#   Val Loss: 11.8429
#   Val Cosine Sim: 0.9911
#   Val OS24 AUC: 0.5548
#   LR: 1.00e-02
#
# Epoch 50/100 (0.19s)
#   Train Loss: 14.9852
#   Train Cosine Sim: 0.9891
#   Val Loss: 10.8309
#   Val Cosine Sim: 0.9920
#   Val OS24 AUC: 0.5945
#   LR: 1.00e-02
#
# Epoch 51/100 (0.20s)
#   Train Loss: 11.2128
#   Train Cosine Sim: 0.9916
#   Val Loss: 10.3617
#   Val Cosine Sim: 0.9912
#   Val OS24 AUC: 0.6095
#   LR: 1.00e-02
#
# Epoch 52/100 (0.20s)
#   Train Loss: 13.1782
#   Train Cosine Sim: 0.9902
#   Val Loss: 10.5376
#   Val Cosine Sim: 0.9920
#   Val OS24 AUC: 0.5656
#   LR: 5.00e-03
# Epoch 53/100 (0.19s)
#   Train Loss: 12.4864
#   Train Cosine Sim: 0.9912
#   Val Loss: 11.1558
#   Val Cosine Sim: 0.9925
#   Val OS24 AUC: 0.5535
#   LR: 5.00e-03
#
# Epoch 54/100 (0.20s)
#   Train Loss: 12.2682
#   Train Cosine Sim: 0.9919
#   Val Loss: 10.2005
#   Val Cosine Sim: 0.9929
#   Val OS24 AUC: 0.5564
#   LR: 5.00e-03
#
# Epoch 55/100 (0.20s)
#   Train Loss: 10.8935
#   Train Cosine Sim: 0.9923
#   Val Loss: 10.0530
#   Val Cosine Sim: 0.9927
#   Val OS24 AUC: 0.5477
#   LR: 5.00e-03
#
# Epoch 56/100 (0.20s)
#   Train Loss: 12.4975
#   Train Cosine Sim: 0.9924
#   Val Loss: 10.7018
#   Val Cosine Sim: 0.9926
#   Val OS24 AUC: 0.5477
#   LR: 5.00e-03
#
# Epoch 57/100 (0.20s)
#   Train Loss: 14.3272
#   Train Cosine Sim: 0.9912
#   Val Loss: 11.2391
#   Val Cosine Sim: 0.9926
#   Val OS24 AUC: 0.5380
#   LR: 5.00e-03
#
# Epoch 58/100 (0.28s)
#   Train Loss: 13.8475
#   Train Cosine Sim: 0.9915
#   Val Loss: 9.9862
#   Val Cosine Sim: 0.9931
#   Val OS24 AUC: 0.5309
#   LR: 5.00e-03
#
# Epoch 59/100 (0.19s)
#   Train Loss: 12.2272
#   Train Cosine Sim: 0.9915
#   Val Loss: 10.2599
#   Val Cosine Sim: 0.9925
#   Val OS24 AUC: 0.5452
#   LR: 5.00e-03
#
# Epoch 60/100 (0.28s)
#   Train Loss: 11.3543
#   Train Cosine Sim: 0.9921
#   Val Loss: 9.8646
#   Val Cosine Sim: 0.9932
#   Val OS24 AUC: 0.5472
#   LR: 5.00e-03
#
# Epoch 61/100 (0.19s)
#   Train Loss: 11.5964
#   Train Cosine Sim: 0.9924
#   Val Loss: 10.3907
#   Val Cosine Sim: 0.9928
#   Val OS24 AUC: 0.5167
#   LR: 5.00e-03
#
# Epoch 62/100 (0.19s)
#   Train Loss: 11.5745
#   Train Cosine Sim: 0.9916
#   Val Loss: 9.9926
#   Val Cosine Sim: 0.9931
#   Val OS24 AUC: 0.4916
#   LR: 5.00e-03
#
# Epoch 63/100 (0.28s)
#   Train Loss: 10.8558
#   Train Cosine Sim: 0.9928
#   Val Loss: 9.8198
#   Val Cosine Sim: 0.9930
#   Val OS24 AUC: 0.4699
#   LR: 5.00e-03
#
# Epoch 64/100 (0.28s)
#   Train Loss: 10.8038
#   Train Cosine Sim: 0.9922
#   Val Loss: 9.7773
#   Val Cosine Sim: 0.9927
#   Val OS24 AUC: 0.4423
#   LR: 5.00e-03
#
# Epoch 65/100 (0.28s)
#   Train Loss: 13.6184
#   Train Cosine Sim: 0.9922
#   Val Loss: 9.7395
#   Val Cosine Sim: 0.9933
#   Val OS24 AUC: 0.4214
#   LR: 5.00e-03
#
# Epoch 66/100 (0.19s)
#   Train Loss: 13.4827
#   Train Cosine Sim: 0.9919
#   Val Loss: 10.1781
#   Val Cosine Sim: 0.9927
#   Val OS24 AUC: 0.4636
#   LR: 5.00e-03
#
# Epoch 67/100 (0.19s)
#   Train Loss: 11.0081
#   Train Cosine Sim: 0.9929
#   Val Loss: 10.0575
#   Val Cosine Sim: 0.9926
#   Val OS24 AUC: 0.4866
#   LR: 5.00e-03
#
# Epoch 68/100 (0.19s)
#   Train Loss: 11.3106
#   Train Cosine Sim: 0.9926
#   Val Loss: 10.5497
#   Val Cosine Sim: 0.9923
#   Val OS24 AUC: 0.4741
#   LR: 5.00e-03
#
# Epoch 69/100 (0.19s)
#   Train Loss: 11.9506
#   Train Cosine Sim: 0.9929
#   Val Loss: 10.3422
#   Val Cosine Sim: 0.9929
#   Val OS24 AUC: 0.4695
#   LR: 5.00e-03
#
# Epoch 70/100 (0.19s)
#   Train Loss: 10.4223
#   Train Cosine Sim: 0.9925
#   Val Loss: 10.2932
#   Val Cosine Sim: 0.9928
#   Val OS24 AUC: 0.4691
#   LR: 5.00e-03
#
# Epoch 71/100 (0.19s)
#   Train Loss: 11.2802
#   Train Cosine Sim: 0.9923
#   Val Loss: 9.7901
#   Val Cosine Sim: 0.9931
#   Val OS24 AUC: 0.4611
#   LR: 5.00e-03
#
# Epoch 72/100 (0.28s)
#   Train Loss: 10.5204
#   Train Cosine Sim: 0.9928
#   Val Loss: 9.2935
#   Val Cosine Sim: 0.9935
#   Val OS24 AUC: 0.4473
#   LR: 5.00e-03
#
# Epoch 73/100 (0.28s)
#   Train Loss: 10.5927
#   Train Cosine Sim: 0.9931
#   Val Loss: 9.2279
#   Val Cosine Sim: 0.9936
#   Val OS24 AUC: 0.4444
#   LR: 5.00e-03
#
# Epoch 74/100 (0.19s)
#   Train Loss: 10.0271
#   Train Cosine Sim: 0.9931
#   Val Loss: 9.4768
#   Val Cosine Sim: 0.9935
#   Val OS24 AUC: 0.4674
#   LR: 5.00e-03
#
# Epoch 75/100 (0.19s)
#   Train Loss: 9.7294
#   Train Cosine Sim: 0.9932
#   Val Loss: 9.9607
#   Val Cosine Sim: 0.9932
#   Val OS24 AUC: 0.5054
#   LR: 5.00e-03
#
# Epoch 76/100 (0.19s)
#   Train Loss: 10.7517
#   Train Cosine Sim: 0.9931
#   Val Loss: 9.4458
#   Val Cosine Sim: 0.9935
#   Val OS24 AUC: 0.5146
#   LR: 5.00e-03
#
# Epoch 77/100 (0.28s)
#   Train Loss: 10.7783
#   Train Cosine Sim: 0.9935
#   Val Loss: 9.1451
#   Val Cosine Sim: 0.9937
#   Val OS24 AUC: 0.5564
#   LR: 5.00e-03
#
# Epoch 78/100 (0.28s)
#   Train Loss: 11.7557
#   Train Cosine Sim: 0.9924
#   Val Loss: 9.1431
#   Val Cosine Sim: 0.9937
#   Val OS24 AUC: 0.5899
#   LR: 5.00e-03
#
# Epoch 79/100 (0.19s)
#   Train Loss: 10.9160
#   Train Cosine Sim: 0.9931
#   Val Loss: 9.9001
#   Val Cosine Sim: 0.9930
#   Val OS24 AUC: 0.6083
#   LR: 5.00e-03
#
# Epoch 80/100 (0.19s)
#   Train Loss: 11.3645
#   Train Cosine Sim: 0.9924
#   Val Loss: 9.9696
#   Val Cosine Sim: 0.9934
#   Val OS24 AUC: 0.6012
#   LR: 5.00e-03
#
# Epoch 81/100 (0.19s)
#   Train Loss: 11.5220
#   Train Cosine Sim: 0.9932
#   Val Loss: 9.5064
#   Val Cosine Sim: 0.9934
#   Val OS24 AUC: 0.5836
#   LR: 5.00e-03
#
# Epoch 82/100 (0.19s)
#   Train Loss: 10.8424
#   Train Cosine Sim: 0.9929
#   Val Loss: 9.6081
#   Val Cosine Sim: 0.9933
#   Val OS24 AUC: 0.5723
#   LR: 5.00e-03
#
# Epoch 83/100 (0.19s)
#   Train Loss: 11.0451
#   Train Cosine Sim: 0.9934
#   Val Loss: 9.3695
#   Val Cosine Sim: 0.9935
#   Val OS24 AUC: 0.5698
#   LR: 5.00e-03
#
# Epoch 84/100 (0.28s)
#   Train Loss: 13.0885
#   Train Cosine Sim: 0.9929
#   Val Loss: 9.0257
#   Val Cosine Sim: 0.9936
#   Val OS24 AUC: 0.5656
#   LR: 5.00e-03
#
# Epoch 85/100 (0.19s)
#   Train Loss: 10.4946
#   Train Cosine Sim: 0.9933
#   Val Loss: 9.3008
#   Val Cosine Sim: 0.9933
#   Val OS24 AUC: 0.4954
#   LR: 5.00e-03
#
# Epoch 86/100 (0.20s)
#   Train Loss: 11.0788
#   Train Cosine Sim: 0.9925
#   Val Loss: 9.1777
#   Val Cosine Sim: 0.9934
#   Val OS24 AUC: 0.4841
#   LR: 5.00e-03
#
# Epoch 87/100 (0.19s)
#   Train Loss: 10.3337
#   Train Cosine Sim: 0.9931
#   Val Loss: 9.0981
#   Val Cosine Sim: 0.9936
#   Val OS24 AUC: 0.4745
#   LR: 5.00e-03
#
# Epoch 88/100 (0.20s)
#   Train Loss: 12.5452
#   Train Cosine Sim: 0.9921
#   Val Loss: 9.2814
#   Val Cosine Sim: 0.9935
#   Val OS24 AUC: 0.4870
#   LR: 5.00e-03
#
# Epoch 89/100 (0.19s)
#   Train Loss: 11.0952
#   Train Cosine Sim: 0.9924
#   Val Loss: 9.8361
#   Val Cosine Sim: 0.9930
#   Val OS24 AUC: 0.5088
#   LR: 5.00e-03
#
# Epoch 90/100 (0.19s)
#   Train Loss: 11.3355
#   Train Cosine Sim: 0.9924
#   Val Loss: 11.7646
#   Val Cosine Sim: 0.9909
#   Val OS24 AUC: 0.5339
#   LR: 5.00e-03
#
# Epoch 91/100 (0.19s)
#   Train Loss: 12.1144
#   Train Cosine Sim: 0.9907
#   Val Loss: 10.6212
#   Val Cosine Sim: 0.9922
#   Val OS24 AUC: 0.5393
#   LR: 5.00e-03
#
# Epoch 92/100 (0.19s)
#   Train Loss: 10.7995
#   Train Cosine Sim: 0.9928
#   Val Loss: 10.0525
#   Val Cosine Sim: 0.9928
#   Val OS24 AUC: 0.5322
#   LR: 5.00e-03
#
# Epoch 93/100 (0.19s)
#   Train Loss: 11.3681
#   Train Cosine Sim: 0.9912
#   Val Loss: 9.9652
#   Val Cosine Sim: 0.9928
#   Val OS24 AUC: 0.5288
#   LR: 5.00e-03
#
# Epoch 94/100 (0.20s)
#   Train Loss: 10.7622
#   Train Cosine Sim: 0.9930
#   Val Loss: 9.6877
#   Val Cosine Sim: 0.9930
#   Val OS24 AUC: 0.5443
#   LR: 5.00e-03
#
# Epoch 95/100 (0.19s)
#   Train Loss: 12.2304
#   Train Cosine Sim: 0.9929
#   Val Loss: 10.3283
#   Val Cosine Sim: 0.9925
#   Val OS24 AUC: 0.5531
#   LR: 2.50e-03
#
# Epoch 96/100 (0.19s)
#   Train Loss: 11.2642
#   Train Cosine Sim: 0.9923
#   Val Loss: 10.5145
#   Val Cosine Sim: 0.9927
#   Val OS24 AUC: 0.5464
#   LR: 2.50e-03
#
# Epoch 97/100 (0.19s)
#   Train Loss: 10.1681
#   Train Cosine Sim: 0.9932
#   Val Loss: 10.0297
#   Val Cosine Sim: 0.9934
#   Val OS24 AUC: 0.5539
#   LR: 2.50e-03
#
# Epoch 98/100 (0.20s)
#   Train Loss: 10.5512
#   Train Cosine Sim: 0.9936
#   Val Loss: 9.6290
#   Val Cosine Sim: 0.9935
#   Val OS24 AUC: 0.5744
#   LR: 2.50e-03
#
# Epoch 99/100 (0.19s)
#   Train Loss: 9.9506
#   Train Cosine Sim: 0.9928
#   Val Loss: 9.0819
#   Val Cosine Sim: 0.9935
#   Val OS24 AUC: 0.6229
#   LR: 2.50e-03
#
# Epoch 100/100 (0.28s)
#   Train Loss: 10.1904
#   Train Cosine Sim: 0.9938
#   Val Loss: 8.8618
#   Val Cosine Sim: 0.9938
#   Val OS24 AUC: 0.6233
#   LR: 2.50e-03
#
# Training completed!
# Best validation loss: 8.8618
# Evaluating on test set...
# Loaded best model from epoch 99
#
# Test Results:
# Test Loss: 9.1031
# Test Cosine Sim: 0.9939
# OS24 - AUC: 0.5251, Accuracy: 0.7596, F1: 0.0000
#
# Results saved to: ./results/autoencoder_20250624_110727/autoencoder_20250624_110742

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 22 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 100 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 4.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# Train samples: 522
# Validation samples: 118
# Test samples: 104
# Creating autoencoder model...
# Model parameters: 6,013,202
# Starting training...
# Starting training for 100 epochs...
# Model type: autoencoder
# Device: cuda
# Epoch 1/100 (0.97s)
#   Train Loss: 327.2419
#   Train Cosine Sim: 0.3731
#   Val Loss: 325.9478
#   Val Cosine Sim: 0.6382
#   Val OS24 AUC: 0.4544
#   LR: 1.00e-03
#
# Epoch 2/100 (0.43s)
#   Train Loss: 302.2098
#   Train Cosine Sim: 0.6618
#   Val Loss: 307.7251
#   Val Cosine Sim: 0.6973
#   Val OS24 AUC: 0.5284
#   LR: 1.00e-03
#
# Epoch 3/100 (0.41s)
#   Train Loss: 279.1624
#   Train Cosine Sim: 0.7032
#   Val Loss: 281.0288
#   Val Cosine Sim: 0.7195
#   Val OS24 AUC: 0.5707
#   LR: 1.00e-03
#
# Epoch 4/100 (0.41s)
#   Train Loss: 255.9531
#   Train Cosine Sim: 0.7254
#   Val Loss: 257.9652
#   Val Cosine Sim: 0.7377
#   Val OS24 AUC: 0.6049
#   LR: 1.00e-03
#
# Epoch 5/100 (0.41s)
#   Train Loss: 234.1986
#   Train Cosine Sim: 0.7434
#   Val Loss: 235.1545
#   Val Cosine Sim: 0.7537
#   Val OS24 AUC: 0.5849
#   LR: 1.00e-03
#
# Epoch 6/100 (0.41s)
#   Train Loss: 212.7745
#   Train Cosine Sim: 0.7593
#   Val Loss: 211.0043
#   Val Cosine Sim: 0.7688
#   Val OS24 AUC: 0.5330
#   LR: 1.00e-03
#
# Epoch 7/100 (0.41s)
#   Train Loss: 193.2867
#   Train Cosine Sim: 0.7751
#   Val Loss: 189.3079
#   Val Cosine Sim: 0.7833
#   Val OS24 AUC: 0.5100
#   LR: 1.00e-03
#
# Epoch 8/100 (0.42s)
#   Train Loss: 175.3990
#   Train Cosine Sim: 0.7882
#   Val Loss: 175.2756
#   Val Cosine Sim: 0.7965
#   Val OS24 AUC: 0.5406
#   LR: 1.00e-03
#
# Epoch 9/100 (0.41s)
#   Train Loss: 159.9032
#   Train Cosine Sim: 0.8022
#   Val Loss: 156.5584
#   Val Cosine Sim: 0.8098
#   Val OS24 AUC: 0.5803
#   LR: 1.00e-03
#
# Epoch 10/100 (0.40s)
#   Train Loss: 145.7978
#   Train Cosine Sim: 0.8145
#   Val Loss: 144.4443
#   Val Cosine Sim: 0.8206
#   Val OS24 AUC: 0.4983
#   LR: 1.00e-03
#
# Epoch 11/100 (0.40s)
#   Train Loss: 134.2989
#   Train Cosine Sim: 0.8253
#   Val Loss: 130.9589
#   Val Cosine Sim: 0.8312
#   Val OS24 AUC: 0.5410
#   LR: 1.00e-03
#
# Epoch 12/100 (0.43s)
#   Train Loss: 123.7766
#   Train Cosine Sim: 0.8356
#   Val Loss: 124.5768
#   Val Cosine Sim: 0.8405
#   Val OS24 AUC: 0.5786
#   LR: 1.00e-03
#
# Epoch 13/100 (0.41s)
#   Train Loss: 115.1959
#   Train Cosine Sim: 0.8442
#   Val Loss: 116.0478
#   Val Cosine Sim: 0.8491
#   Val OS24 AUC: 0.5803
#   LR: 1.00e-03
#
# Epoch 14/100 (0.40s)
#   Train Loss: 107.8855
#   Train Cosine Sim: 0.8525
#   Val Loss: 105.7589
#   Val Cosine Sim: 0.8571
#   Val OS24 AUC: 0.5991
#   LR: 1.00e-03
#
# Epoch 15/100 (0.42s)
#   Train Loss: 101.0972
#   Train Cosine Sim: 0.8602
#   Val Loss: 102.3551
#   Val Cosine Sim: 0.8646
#   Val OS24 AUC: 0.6191
#   LR: 1.00e-03
#
# Epoch 16/100 (0.39s)
#   Train Loss: 95.6887
#   Train Cosine Sim: 0.8673
#   Val Loss: 98.9507
#   Val Cosine Sim: 0.8710
#   Val OS24 AUC: 0.6058
#   LR: 1.00e-03
#
# Epoch 17/100 (0.40s)
#   Train Loss: 91.5253
#   Train Cosine Sim: 0.8730
#   Val Loss: 89.8757
#   Val Cosine Sim: 0.8765
#   Val OS24 AUC: 0.6020
#   LR: 1.00e-03
#
# Epoch 18/100 (0.40s)
#   Train Loss: 86.6982
#   Train Cosine Sim: 0.8783
#   Val Loss: 86.5561
#   Val Cosine Sim: 0.8815
#   Val OS24 AUC: 0.5995
#   LR: 1.00e-03
#
# Epoch 19/100 (0.41s)
#   Train Loss: 82.4655
#   Train Cosine Sim: 0.8834
#   Val Loss: 83.2199
#   Val Cosine Sim: 0.8862
#   Val OS24 AUC: 0.5790
#   LR: 1.00e-03
#
# Epoch 20/100 (0.39s)
#   Train Loss: 79.5730
#   Train Cosine Sim: 0.8881
#   Val Loss: 79.4901
#   Val Cosine Sim: 0.8908
#   Val OS24 AUC: 0.5890
#   LR: 1.00e-03
#
# Epoch 21/100 (0.40s)
#   Train Loss: 75.9935
#   Train Cosine Sim: 0.8927
#   Val Loss: 76.2553
#   Val Cosine Sim: 0.8951
#   Val OS24 AUC: 0.5844
#   LR: 1.00e-03
#
# Epoch 22/100 (0.40s)
#   Train Loss: 75.3653
#   Train Cosine Sim: 0.8969
#   Val Loss: 75.2210
#   Val Cosine Sim: 0.8991
#   Val OS24 AUC: 0.5380
#   LR: 1.00e-03
#
# Epoch 23/100 (0.40s)
#   Train Loss: 71.2600
#   Train Cosine Sim: 0.9004
#   Val Loss: 73.0456
#   Val Cosine Sim: 0.9028
#   Val OS24 AUC: 0.5121
#   LR: 1.00e-03
#
# Epoch 24/100 (0.40s)
#   Train Loss: 69.8190
#   Train Cosine Sim: 0.9042
#   Val Loss: 70.6955
#   Val Cosine Sim: 0.9066
#   Val OS24 AUC: 0.6020
#   LR: 1.00e-03
#
# Epoch 25/100 (0.41s)
#   Train Loss: 65.6227
#   Train Cosine Sim: 0.9073
#   Val Loss: 68.0168
#   Val Cosine Sim: 0.9098
#   Val OS24 AUC: 0.5890
#   LR: 1.00e-03
#
# Epoch 26/100 (0.40s)
#   Train Loss: 65.2313
#   Train Cosine Sim: 0.9100
#   Val Loss: 63.6763
#   Val Cosine Sim: 0.9130
#   Val OS24 AUC: 0.5882
#   LR: 1.00e-03
#
# Epoch 27/100 (0.40s)
#   Train Loss: 61.8630
#   Train Cosine Sim: 0.9138
#   Val Loss: 61.4929
#   Val Cosine Sim: 0.9160
#   Val OS24 AUC: 0.6179
#   LR: 1.00e-03
#
# Epoch 28/100 (0.26s)
#   Train Loss: 62.4356
#   Train Cosine Sim: 0.9171
#   Val Loss: 62.0476
#   Val Cosine Sim: 0.9196
#   Val OS24 AUC: 0.6237
#   LR: 1.00e-03
#
# Epoch 29/100 (0.40s)
#   Train Loss: 58.3931
#   Train Cosine Sim: 0.9205
#   Val Loss: 59.2237
#   Val Cosine Sim: 0.9225
#   Val OS24 AUC: 0.5548
#   LR: 1.00e-03
#
# Epoch 30/100 (0.41s)
#   Train Loss: 55.8892
#   Train Cosine Sim: 0.9233
#   Val Loss: 57.0834
#   Val Cosine Sim: 0.9249
#   Val OS24 AUC: 0.5535
#   LR: 1.00e-03
#
# Epoch 31/100 (0.40s)
#   Train Loss: 54.8127
#   Train Cosine Sim: 0.9259
#   Val Loss: 56.6915
#   Val Cosine Sim: 0.9280
#   Val OS24 AUC: 0.5598
#   LR: 1.00e-03
#
# Epoch 32/100 (0.40s)
#   Train Loss: 52.7374
#   Train Cosine Sim: 0.9284
#   Val Loss: 53.2416
#   Val Cosine Sim: 0.9303
#   Val OS24 AUC: 0.4946
#   LR: 1.00e-03
#
# Epoch 33/100 (0.40s)
#   Train Loss: 51.7745
#   Train Cosine Sim: 0.9311
#   Val Loss: 51.1809
#   Val Cosine Sim: 0.9326
#   Val OS24 AUC: 0.5648
#   LR: 1.00e-03
#
# Epoch 34/100 (0.41s)
#   Train Loss: 49.7182
#   Train Cosine Sim: 0.9332
#   Val Loss: 50.6313
#   Val Cosine Sim: 0.9353
#   Val OS24 AUC: 0.5431
#   LR: 1.00e-03
#
# Epoch 35/100 (0.40s)
#   Train Loss: 48.5769
#   Train Cosine Sim: 0.9359
#   Val Loss: 48.1035
#   Val Cosine Sim: 0.9377
#   Val OS24 AUC: 0.5372
#   LR: 1.00e-03
#
# Epoch 36/100 (0.26s)
#   Train Loss: 46.7911
#   Train Cosine Sim: 0.9386
#   Val Loss: 48.5766
#   Val Cosine Sim: 0.9404
#   Val OS24 AUC: 0.4941
#   LR: 1.00e-03
#
# Epoch 37/100 (0.41s)
#   Train Loss: 44.6991
#   Train Cosine Sim: 0.9409
#   Val Loss: 47.2023
#   Val Cosine Sim: 0.9427
#   Val OS24 AUC: 0.4891
#   LR: 1.00e-03
#
# Epoch 38/100 (0.40s)
#   Train Loss: 43.0803
#   Train Cosine Sim: 0.9430
#   Val Loss: 44.6255
#   Val Cosine Sim: 0.9448
#   Val OS24 AUC: 0.5046
#   LR: 1.00e-03
#
# Epoch 39/100 (0.40s)
#   Train Loss: 42.0953
#   Train Cosine Sim: 0.9451
#   Val Loss: 42.3478
#   Val Cosine Sim: 0.9470
#   Val OS24 AUC: 0.5222
#   LR: 1.00e-03
#
# Epoch 40/100 (0.26s)
#   Train Loss: 40.9348
#   Train Cosine Sim: 0.9474
#   Val Loss: 42.4448
#   Val Cosine Sim: 0.9488
#   Val OS24 AUC: 0.5360
#   LR: 1.00e-03
#
# Epoch 41/100 (0.41s)
#   Train Loss: 39.1693
#   Train Cosine Sim: 0.9490
#   Val Loss: 41.4842
#   Val Cosine Sim: 0.9507
#   Val OS24 AUC: 0.5046
#   LR: 1.00e-03
#
# Epoch 42/100 (0.40s)
#   Train Loss: 38.4014
#   Train Cosine Sim: 0.9507
#   Val Loss: 39.2975
#   Val Cosine Sim: 0.9528
#   Val OS24 AUC: 0.5360
#   LR: 1.00e-03
#
# Epoch 43/100 (0.39s)
#   Train Loss: 37.0715
#   Train Cosine Sim: 0.9529
#   Val Loss: 38.0927
#   Val Cosine Sim: 0.9547
#   Val OS24 AUC: 0.5656
#   LR: 1.00e-03
#
# Epoch 44/100 (0.39s)
#   Train Loss: 36.0481
#   Train Cosine Sim: 0.9547
#   Val Loss: 36.3443
#   Val Cosine Sim: 0.9567
#   Val OS24 AUC: 0.5360
#   LR: 1.00e-03
#
# Epoch 45/100 (0.39s)
#   Train Loss: 34.9020
#   Train Cosine Sim: 0.9566
#   Val Loss: 35.2829
#   Val Cosine Sim: 0.9582
#   Val OS24 AUC: 0.5732
#   LR: 1.00e-03
#
# Epoch 46/100 (0.40s)
#   Train Loss: 33.2488
#   Train Cosine Sim: 0.9583
#   Val Loss: 35.0417
#   Val Cosine Sim: 0.9601
#   Val OS24 AUC: 0.5130
#   LR: 1.00e-03
#
# Epoch 47/100 (0.39s)
#   Train Loss: 31.9761
#   Train Cosine Sim: 0.9600
#   Val Loss: 33.8817
#   Val Cosine Sim: 0.9615
#   Val OS24 AUC: 0.5360
#   LR: 1.00e-03
#
# Epoch 48/100 (0.25s)
#   Train Loss: 30.7918
#   Train Cosine Sim: 0.9616
#   Val Loss: 35.1099
#   Val Cosine Sim: 0.9630
#   Val OS24 AUC: 0.5293
#   LR: 1.00e-03
#
# Epoch 49/100 (0.42s)
#   Train Loss: 30.4650
#   Train Cosine Sim: 0.9632
#   Val Loss: 31.7361
#   Val Cosine Sim: 0.9646
#   Val OS24 AUC: 0.5807
#   LR: 1.00e-03
#
# Epoch 50/100 (0.40s)
#   Train Loss: 29.3467
#   Train Cosine Sim: 0.9642
#   Val Loss: 30.4287
#   Val Cosine Sim: 0.9658
#   Val OS24 AUC: 0.5506
#   LR: 1.00e-03
#
# Epoch 51/100 (0.40s)
#   Train Loss: 27.8683
#   Train Cosine Sim: 0.9655
#   Val Loss: 28.9288
#   Val Cosine Sim: 0.9670
#   Val OS24 AUC: 0.5748
#   LR: 1.00e-03
#
# Epoch 52/100 (0.39s)
#   Train Loss: 27.7554
#   Train Cosine Sim: 0.9667
#   Val Loss: 28.9221
#   Val Cosine Sim: 0.9684
#   Val OS24 AUC: 0.5008
#   LR: 1.00e-03
# Epoch 53/100 (0.40s)
#   Train Loss: 26.0046
#   Train Cosine Sim: 0.9682
#   Val Loss: 28.0089
#   Val Cosine Sim: 0.9694
#   Val OS24 AUC: 0.5376
#   LR: 1.00e-03
#
# Epoch 54/100 (0.47s)
#   Train Loss: 25.0010
#   Train Cosine Sim: 0.9697
#   Val Loss: 27.3098
#   Val Cosine Sim: 0.9707
#   Val OS24 AUC: 0.5184
#   LR: 1.00e-03
#
# Epoch 55/100 (0.40s)
#   Train Loss: 24.4414
#   Train Cosine Sim: 0.9708
#   Val Loss: 26.7073
#   Val Cosine Sim: 0.9722
#   Val OS24 AUC: 0.5431
#   LR: 1.00e-03
#
# Epoch 56/100 (0.40s)
#   Train Loss: 24.8354
#   Train Cosine Sim: 0.9722
#   Val Loss: 26.0688
#   Val Cosine Sim: 0.9735
#   Val OS24 AUC: 0.5293
#   LR: 1.00e-03
#
# Epoch 57/100 (0.26s)
#   Train Loss: 24.1125
#   Train Cosine Sim: 0.9730
#   Val Loss: 26.2008
#   Val Cosine Sim: 0.9745
#   Val OS24 AUC: 0.5334
#   LR: 1.00e-03
#
# Epoch 58/100 (0.41s)
#   Train Loss: 22.4883
#   Train Cosine Sim: 0.9741
#   Val Loss: 24.5515
#   Val Cosine Sim: 0.9755
#   Val OS24 AUC: 0.5556
#   LR: 1.00e-03
#
# Epoch 59/100 (0.27s)
#   Train Loss: 21.1169
#   Train Cosine Sim: 0.9753
#   Val Loss: 25.6947
#   Val Cosine Sim: 0.9763
#   Val OS24 AUC: 0.5372
#   LR: 1.00e-03
#
# Epoch 60/100 (0.43s)
#   Train Loss: 20.9519
#   Train Cosine Sim: 0.9760
#   Val Loss: 23.1451
#   Val Cosine Sim: 0.9773
#   Val OS24 AUC: 0.5230
#   LR: 1.00e-03
#
# Epoch 61/100 (0.26s)
#   Train Loss: 20.7403
#   Train Cosine Sim: 0.9773
#   Val Loss: 23.2139
#   Val Cosine Sim: 0.9783
#   Val OS24 AUC: 0.5410
#   LR: 1.00e-03
#
# Epoch 62/100 (0.41s)
#   Train Loss: 19.6406
#   Train Cosine Sim: 0.9778
#   Val Loss: 21.8872
#   Val Cosine Sim: 0.9791
#   Val OS24 AUC: 0.5368
#   LR: 1.00e-03
#
# Epoch 63/100 (0.26s)
#   Train Loss: 20.5333
#   Train Cosine Sim: 0.9788
#   Val Loss: 22.5126
#   Val Cosine Sim: 0.9800
#   Val OS24 AUC: 0.5121
#   LR: 1.00e-03
#
# Epoch 64/100 (0.27s)
#   Train Loss: 20.6083
#   Train Cosine Sim: 0.9793
#   Val Loss: 23.2356
#   Val Cosine Sim: 0.9803
#   Val OS24 AUC: 0.5167
#   LR: 1.00e-03
#
# Epoch 65/100 (0.41s)
#   Train Loss: 18.7004
#   Train Cosine Sim: 0.9798
#   Val Loss: 21.1361
#   Val Cosine Sim: 0.9813
#   Val OS24 AUC: 0.5460
#   LR: 1.00e-03
#
# Epoch 66/100 (0.26s)
#   Train Loss: 17.4843
#   Train Cosine Sim: 0.9809
#   Val Loss: 23.6419
#   Val Cosine Sim: 0.9820
#   Val OS24 AUC: 0.5548
#   LR: 1.00e-03
#
# Epoch 67/100 (0.41s)
#   Train Loss: 17.9691
#   Train Cosine Sim: 0.9816
#   Val Loss: 19.1749
#   Val Cosine Sim: 0.9827
#   Val OS24 AUC: 0.5769
#   LR: 1.00e-03
#
# Epoch 68/100 (0.27s)
#   Train Loss: 17.2955
#   Train Cosine Sim: 0.9821
#   Val Loss: 19.3300
#   Val Cosine Sim: 0.9832
#   Val OS24 AUC: 0.5397
#   LR: 1.00e-03
#
# Epoch 69/100 (0.27s)
#   Train Loss: 16.3443
#   Train Cosine Sim: 0.9827
#   Val Loss: 19.2381
#   Val Cosine Sim: 0.9837
#   Val OS24 AUC: 0.5163
#   LR: 1.00e-03
#
# Epoch 70/100 (0.40s)
#   Train Loss: 15.4191
#   Train Cosine Sim: 0.9832
#   Val Loss: 17.6538
#   Val Cosine Sim: 0.9844
#   Val OS24 AUC: 0.5372
#   LR: 1.00e-03
#
# Epoch 71/100 (0.39s)
#   Train Loss: 15.3021
#   Train Cosine Sim: 0.9838
#   Val Loss: 17.0666
#   Val Cosine Sim: 0.9849
#   Val OS24 AUC: 0.5573
#   LR: 1.00e-03
#
# Epoch 72/100 (0.25s)
#   Train Loss: 14.6719
#   Train Cosine Sim: 0.9845
#   Val Loss: 17.6053
#   Val Cosine Sim: 0.9855
#   Val OS24 AUC: 0.5142
#   LR: 1.00e-03
#
# Epoch 73/100 (0.26s)
#   Train Loss: 15.9689
#   Train Cosine Sim: 0.9846
#   Val Loss: 17.7368
#   Val Cosine Sim: 0.9859
#   Val OS24 AUC: 0.5038
#   LR: 1.00e-03
#
# Epoch 74/100 (0.27s)
#   Train Loss: 14.9967
#   Train Cosine Sim: 0.9853
#   Val Loss: 24.3098
#   Val Cosine Sim: 0.9858
#   Val OS24 AUC: 0.5230
#   LR: 1.00e-03
#
# Epoch 75/100 (0.27s)
#   Train Loss: 14.7262
#   Train Cosine Sim: 0.9856
#   Val Loss: 17.3066
#   Val Cosine Sim: 0.9864
#   Val OS24 AUC: 0.5727
#   LR: 1.00e-03
#
# Epoch 76/100 (0.40s)
#   Train Loss: 14.4707
#   Train Cosine Sim: 0.9856
#   Val Loss: 16.3179
#   Val Cosine Sim: 0.9870
#   Val OS24 AUC: 0.5523
#   LR: 1.00e-03
#
# Epoch 77/100 (0.40s)
#   Train Loss: 13.0119
#   Train Cosine Sim: 0.9865
#   Val Loss: 15.9737
#   Val Cosine Sim: 0.9875
#   Val OS24 AUC: 0.4962
#   LR: 1.00e-03
#
# Epoch 78/100 (0.27s)
#   Train Loss: 13.6546
#   Train Cosine Sim: 0.9868
#   Val Loss: 16.6660
#   Val Cosine Sim: 0.9879
#   Val OS24 AUC: 0.5272
#   LR: 1.00e-03
#
# Epoch 79/100 (0.27s)
#   Train Loss: 12.7375
#   Train Cosine Sim: 0.9873
#   Val Loss: 16.7953
#   Val Cosine Sim: 0.9883
#   Val OS24 AUC: 0.5564
#   LR: 1.00e-03
#
# Epoch 80/100 (0.27s)
#   Train Loss: 12.6843
#   Train Cosine Sim: 0.9876
#   Val Loss: 16.8260
#   Val Cosine Sim: 0.9884
#   Val OS24 AUC: 0.5535
#   LR: 1.00e-03
#
# Epoch 81/100 (0.41s)
#   Train Loss: 12.6984
#   Train Cosine Sim: 0.9878
#   Val Loss: 15.6123
#   Val Cosine Sim: 0.9887
#   Val OS24 AUC: 0.5552
#   LR: 1.00e-03
#
# Epoch 82/100 (0.41s)
#   Train Loss: 12.4791
#   Train Cosine Sim: 0.9881
#   Val Loss: 14.4837
#   Val Cosine Sim: 0.9891
#   Val OS24 AUC: 0.5727
#   LR: 1.00e-03
#
# Epoch 83/100 (0.27s)
#   Train Loss: 11.8424
#   Train Cosine Sim: 0.9882
#   Val Loss: 15.4237
#   Val Cosine Sim: 0.9894
#   Val OS24 AUC: 0.5615
#   LR: 1.00e-03
#
# Epoch 84/100 (0.42s)
#   Train Loss: 12.2152
#   Train Cosine Sim: 0.9887
#   Val Loss: 14.2659
#   Val Cosine Sim: 0.9895
#   Val OS24 AUC: 0.5957
#   LR: 1.00e-03
#
# Epoch 85/100 (0.26s)
#   Train Loss: 11.4672
#   Train Cosine Sim: 0.9889
#   Val Loss: 14.7867
#   Val Cosine Sim: 0.9896
#   Val OS24 AUC: 0.5025
#   LR: 1.00e-03
#
# Epoch 86/100 (0.41s)
#   Train Loss: 10.9176
#   Train Cosine Sim: 0.9892
#   Val Loss: 13.6011
#   Val Cosine Sim: 0.9900
#   Val OS24 AUC: 0.5514
#   LR: 1.00e-03
#
# Epoch 87/100 (0.26s)
#   Train Loss: 10.7599
#   Train Cosine Sim: 0.9894
#   Val Loss: 13.6820
#   Val Cosine Sim: 0.9903
#   Val OS24 AUC: 0.5535
#   LR: 1.00e-03
#
# Epoch 88/100 (0.42s)
#   Train Loss: 10.3822
#   Train Cosine Sim: 0.9894
#   Val Loss: 13.2496
#   Val Cosine Sim: 0.9905
#   Val OS24 AUC: 0.5681
#   LR: 1.00e-03
#
# Epoch 89/100 (0.42s)
#   Train Loss: 10.4788
#   Train Cosine Sim: 0.9897
#   Val Loss: 13.2351
#   Val Cosine Sim: 0.9906
#   Val OS24 AUC: 0.5594
#   LR: 1.00e-03
#
# Epoch 90/100 (0.26s)
#   Train Loss: 10.4378
#   Train Cosine Sim: 0.9898
#   Val Loss: 13.6713
#   Val Cosine Sim: 0.9906
#   Val OS24 AUC: 0.5322
#   LR: 1.00e-03
#
# Epoch 91/100 (0.26s)
#   Train Loss: 10.0914
#   Train Cosine Sim: 0.9901
#   Val Loss: 14.3593
#   Val Cosine Sim: 0.9906
#   Val OS24 AUC: 0.5364
#   LR: 1.00e-03
#
# Epoch 92/100 (0.27s)
#   Train Loss: 10.1202
#   Train Cosine Sim: 0.9899
#   Val Loss: 16.6124
#   Val Cosine Sim: 0.9908
#   Val OS24 AUC: 0.5042
#   LR: 1.00e-03
#
# Epoch 93/100 (0.27s)
#   Train Loss: 10.2168
#   Train Cosine Sim: 0.9902
#   Val Loss: 14.8044
#   Val Cosine Sim: 0.9911
#   Val OS24 AUC: 0.5138
#   LR: 1.00e-03
#
# Epoch 94/100 (0.27s)
#   Train Loss: 9.5544
#   Train Cosine Sim: 0.9904
#   Val Loss: 13.9691
#   Val Cosine Sim: 0.9911
#   Val OS24 AUC: 0.5326
#   LR: 1.00e-03
#
# Epoch 95/100 (0.41s)
#   Train Loss: 9.4005
#   Train Cosine Sim: 0.9905
#   Val Loss: 12.8887
#   Val Cosine Sim: 0.9913
#   Val OS24 AUC: 0.5397
#   LR: 1.00e-03
#
# Epoch 96/100 (0.26s)
#   Train Loss: 9.3174
#   Train Cosine Sim: 0.9904
#   Val Loss: 13.4182
#   Val Cosine Sim: 0.9914
#   Val OS24 AUC: 0.5619
#   LR: 1.00e-03
#
# Epoch 97/100 (0.26s)
#   Train Loss: 9.2737
#   Train Cosine Sim: 0.9908
#   Val Loss: 13.0432
#   Val Cosine Sim: 0.9915
#   Val OS24 AUC: 0.5615
#   LR: 1.00e-03
#
# Epoch 98/100 (0.27s)
#   Train Loss: 10.0359
#   Train Cosine Sim: 0.9908
#   Val Loss: 16.2291
#   Val Cosine Sim: 0.9915
#   Val OS24 AUC: 0.5585
#   LR: 1.00e-03
#
# Epoch 99/100 (0.43s)
#   Train Loss: 10.3963
#   Train Cosine Sim: 0.9902
#   Val Loss: 12.6456
#   Val Cosine Sim: 0.9916
#   Val OS24 AUC: 0.5560
#   LR: 1.00e-03
#
# Epoch 100/100 (0.27s)
#   Train Loss: 9.3178
#   Train Cosine Sim: 0.9908
#   Val Loss: 13.7209
#   Val Cosine Sim: 0.9914
#   Val OS24 AUC: 0.5171
#   LR: 1.00e-03
#
# Training completed!
# Best validation loss: 12.6456
# Evaluating on test set...
# Loaded best model from epoch 98
#
# Test Results:
# Test Loss: 14.6153
# Test Cosine Sim: 0.9918
# OS24 - AUC: 0.3833, Accuracy: 0.6923, F1: 0.1579
#
# Results saved to: ./results/autoencoder_20250624_105031/autoencoder_20250624_105046

# %%
# !source /share/data/apps/anaconda3/bin/activate && conda activate ABR && python main_autoencoder.py \
    --pkl_files /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/VHIO.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/INT.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/GHD.pkl /share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/SZMC.pkl \
    --train_test_split_json /share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json \
    --model_type autoencoder \
    --attention_k 44 \
    --latent_dim 512 \
    --encoder_layers 256 128 \
    --predictor_layers 64 32 \
    --dropout_rate 0.3 \
    --epochs 100 \
    --batch_size 64 \
    --learning_rate 1e-3 \
    --weight_decay 1e-4 \
    --reconstruction_weight 1.0 \
    --prediction_weight 4.0 \
    --val_split 0.2 \
    --endpoints os24 \
    --save_dir ./results/autoencoder_$(date +%Y%m%d_%H%M%S)
# Out:
# Using device: cuda
# Creating data loaders...
# Train samples: 522
# Validation samples: 118
# Test samples: 104
# Creating autoencoder model...
# Model parameters: 11,791,634
# Starting training...
# Starting training for 100 epochs...
# Model type: autoencoder
# Device: cuda
# Epoch 1/100 (1.02s)
#   Train Loss: 351.9576
#   Train Cosine Sim: 0.3825
#   Val Loss: 353.0273
#   Val Cosine Sim: 0.6442
#   Val OS24 AUC: 0.5957
#   LR: 1.00e-03
#
# Epoch 2/100 (0.53s)
#   Train Loss: 325.9444
#   Train Cosine Sim: 0.6691
#   Val Loss: 333.8978
#   Val Cosine Sim: 0.7041
#   Val OS24 AUC: 0.5886
#   LR: 1.00e-03
#
# Epoch 3/100 (0.53s)
#   Train Loss: 301.1027
#   Train Cosine Sim: 0.7100
#   Val Loss: 303.8120
#   Val Cosine Sim: 0.7262
#   Val OS24 AUC: 0.5727
#   LR: 1.00e-03
#
# Epoch 4/100 (0.54s)
#   Train Loss: 276.7336
#   Train Cosine Sim: 0.7312
#   Val Loss: 276.0435
#   Val Cosine Sim: 0.7434
#   Val OS24 AUC: 0.5506
#   LR: 1.00e-03
#
# Epoch 5/100 (0.54s)
#   Train Loss: 253.6260
#   Train Cosine Sim: 0.7485
#   Val Loss: 253.7070
#   Val Cosine Sim: 0.7590
#   Val OS24 AUC: 0.5038
#   LR: 1.00e-03
#
# Epoch 6/100 (0.53s)
#   Train Loss: 231.9126
#   Train Cosine Sim: 0.7643
#   Val Loss: 226.8040
#   Val Cosine Sim: 0.7736
#   Val OS24 AUC: 0.5247
#   LR: 1.00e-03
#
# Epoch 7/100 (0.54s)
#   Train Loss: 210.6207
#   Train Cosine Sim: 0.7778
#   Val Loss: 205.0574
#   Val Cosine Sim: 0.7868
#   Val OS24 AUC: 0.5840
#   LR: 1.00e-03
#
# Epoch 8/100 (0.56s)
#   Train Loss: 191.7524
#   Train Cosine Sim: 0.7916
#   Val Loss: 183.1665
#   Val Cosine Sim: 0.7995
#   Val OS24 AUC: 0.6171
#   LR: 1.00e-03
#
# Epoch 9/100 (0.53s)
#   Train Loss: 173.9346
#   Train Cosine Sim: 0.8037
#   Val Loss: 168.0153
#   Val Cosine Sim: 0.8114
#   Val OS24 AUC: 0.6008
#   LR: 1.00e-03
#
# Epoch 10/100 (0.51s)
#   Train Loss: 157.5657
#   Train Cosine Sim: 0.8154
#   Val Loss: 153.1694
#   Val Cosine Sim: 0.8227
#   Val OS24 AUC: 0.5669
#   LR: 1.00e-03
#
# Epoch 11/100 (0.52s)
#   Train Loss: 145.5740
#   Train Cosine Sim: 0.8270
#   Val Loss: 143.1074
#   Val Cosine Sim: 0.8334
#   Val OS24 AUC: 0.5180
#   LR: 1.00e-03
#
# Epoch 12/100 (0.52s)
#   Train Loss: 134.9421
#   Train Cosine Sim: 0.8370
#   Val Loss: 134.6591
#   Val Cosine Sim: 0.8428
#   Val OS24 AUC: 0.5117
#   LR: 1.00e-03
#
# Epoch 13/100 (0.54s)
#   Train Loss: 123.9421
#   Train Cosine Sim: 0.8464
#   Val Loss: 124.1036
#   Val Cosine Sim: 0.8516
#   Val OS24 AUC: 0.5523
#   LR: 1.00e-03
#
# Epoch 14/100 (0.53s)
#   Train Loss: 115.9886
#   Train Cosine Sim: 0.8542
#   Val Loss: 115.3816
#   Val Cosine Sim: 0.8590
#   Val OS24 AUC: 0.5982
#   LR: 1.00e-03
#
# Epoch 15/100 (0.51s)
#   Train Loss: 108.7011
#   Train Cosine Sim: 0.8617
#   Val Loss: 110.3497
#   Val Cosine Sim: 0.8661
#   Val OS24 AUC: 0.5874
#   LR: 1.00e-03
#
# Epoch 16/100 (0.52s)
#   Train Loss: 102.8450
#   Train Cosine Sim: 0.8680
#   Val Loss: 104.1426
#   Val Cosine Sim: 0.8722
#   Val OS24 AUC: 0.5602
#   LR: 1.00e-03
#
# Epoch 17/100 (0.52s)
#   Train Loss: 100.9654
#   Train Cosine Sim: 0.8735
#   Val Loss: 103.9568
#   Val Cosine Sim: 0.8773
#   Val OS24 AUC: 0.5577
#   LR: 1.00e-03
#
# Epoch 18/100 (0.27s)
#   Train Loss: 95.2910
#   Train Cosine Sim: 0.8791
#   Val Loss: 104.1063
#   Val Cosine Sim: 0.8821
#   Val OS24 AUC: 0.5769
#   LR: 1.00e-03
#
# Epoch 19/100 (0.54s)
#   Train Loss: 91.1228
#   Train Cosine Sim: 0.8841
#   Val Loss: 91.6698
#   Val Cosine Sim: 0.8869
#   Val OS24 AUC: 0.5903
#   LR: 1.00e-03
#
# Epoch 20/100 (1.47s)
#   Train Loss: 86.3397
#   Train Cosine Sim: 0.8883
#   Val Loss: 85.9042
#   Val Cosine Sim: 0.8914
#   Val OS24 AUC: 0.5230
#   LR: 1.00e-03
#
# Epoch 21/100 (0.55s)
#   Train Loss: 81.9991
#   Train Cosine Sim: 0.8926
#   Val Loss: 82.0272
#   Val Cosine Sim: 0.8955
#   Val OS24 AUC: 0.5109
#   LR: 1.00e-03
#
# Epoch 22/100 (0.57s)
#   Train Loss: 79.4922
#   Train Cosine Sim: 0.8969
#   Val Loss: 79.1137
#   Val Cosine Sim: 0.8994
#   Val OS24 AUC: 0.5092
#   LR: 1.00e-03
#
# Epoch 23/100 (0.55s)
#   Train Loss: 77.3434
#   Train Cosine Sim: 0.9004
#   Val Loss: 78.3608
#   Val Cosine Sim: 0.9029
#   Val OS24 AUC: 0.4912
#   LR: 1.00e-03
#
# Epoch 24/100 (0.53s)
#   Train Loss: 73.1345
#   Train Cosine Sim: 0.9037
#   Val Loss: 75.0190
#   Val Cosine Sim: 0.9065
#   Val OS24 AUC: 0.5355
#   LR: 1.00e-03
#
# Epoch 25/100 (0.54s)
#   Train Loss: 71.4724
#   Train Cosine Sim: 0.9074
#   Val Loss: 71.6925
#   Val Cosine Sim: 0.9099
#   Val OS24 AUC: 0.5360
#   LR: 1.00e-03
#
# Epoch 26/100 (0.54s)
#   Train Loss: 68.3150
#   Train Cosine Sim: 0.9106
#   Val Loss: 68.7350
#   Val Cosine Sim: 0.9133
#   Val OS24 AUC: 0.5527
#   LR: 1.00e-03
#
# Epoch 27/100 (0.53s)
#   Train Loss: 65.9022
#   Train Cosine Sim: 0.9141
#   Val Loss: 65.9922
#   Val Cosine Sim: 0.9164
#   Val OS24 AUC: 0.5765
#   LR: 1.00e-03
#
# Epoch 28/100 (0.57s)
#   Train Loss: 63.9007
#   Train Cosine Sim: 0.9172
#   Val Loss: 62.8202
#   Val Cosine Sim: 0.9191
#   Val OS24 AUC: 0.6430
#   LR: 1.00e-03
#
# Epoch 29/100 (0.51s)
#   Train Loss: 62.3521
#   Train Cosine Sim: 0.9192
#   Val Loss: 61.6154
#   Val Cosine Sim: 0.9217
#   Val OS24 AUC: 0.5765
#   LR: 1.00e-03
#
# Epoch 30/100 (0.53s)
#   Train Loss: 60.2458
#   Train Cosine Sim: 0.9224
#   Val Loss: 60.1844
#   Val Cosine Sim: 0.9245
#   Val OS24 AUC: 0.5610
#   LR: 1.00e-03
#
# Epoch 31/100 (0.54s)
#   Train Loss: 60.2369
#   Train Cosine Sim: 0.9256
#   Val Loss: 59.1091
#   Val Cosine Sim: 0.9271
#   Val OS24 AUC: 0.5673
#   LR: 1.00e-03
#
# Epoch 32/100 (0.52s)
#   Train Loss: 57.9949
#   Train Cosine Sim: 0.9271
#   Val Loss: 58.9369
#   Val Cosine Sim: 0.9294
#   Val OS24 AUC: 0.5623
#   LR: 1.00e-03
#
# Epoch 33/100 (0.53s)
#   Train Loss: 54.4297
#   Train Cosine Sim: 0.9300
#   Val Loss: 56.9028
#   Val Cosine Sim: 0.9318
#   Val OS24 AUC: 0.5443
#   LR: 1.00e-03
#
# Epoch 34/100 (0.53s)
#   Train Loss: 53.2306
#   Train Cosine Sim: 0.9327
#   Val Loss: 53.8669
#   Val Cosine Sim: 0.9343
#   Val OS24 AUC: 0.5426
#   LR: 1.00e-03
#
# Epoch 35/100 (0.51s)
#   Train Loss: 52.1599
#   Train Cosine Sim: 0.9342
#   Val Loss: 52.7170
#   Val Cosine Sim: 0.9365
#   Val OS24 AUC: 0.5167
#   LR: 1.00e-03
#
# Epoch 36/100 (0.52s)
#   Train Loss: 50.7703
#   Train Cosine Sim: 0.9371
#   Val Loss: 50.7609
#   Val Cosine Sim: 0.9389
#   Val OS24 AUC: 0.5201
#   LR: 1.00e-03
#
# Epoch 37/100 (0.54s)
#   Train Loss: 48.1146
#   Train Cosine Sim: 0.9390
#   Val Loss: 48.3929
#   Val Cosine Sim: 0.9412
#   Val OS24 AUC: 0.5234
#   LR: 1.00e-03
#
# Epoch 38/100 (0.56s)
#   Train Loss: 47.2245
#   Train Cosine Sim: 0.9416
#   Val Loss: 47.1877
#   Val Cosine Sim: 0.9434
#   Val OS24 AUC: 0.5765
#   LR: 1.00e-03
#
# Epoch 39/100 (0.53s)
#   Train Loss: 45.9966
#   Train Cosine Sim: 0.9435
#   Val Loss: 46.3644
#   Val Cosine Sim: 0.9453
#   Val OS24 AUC: 0.4879
#   LR: 1.00e-03
#
# Epoch 40/100 (0.52s)
#   Train Loss: 43.8570
#   Train Cosine Sim: 0.9455
#   Val Loss: 45.6577
#   Val Cosine Sim: 0.9471
#   Val OS24 AUC: 0.5272
#   LR: 1.00e-03
#
# Epoch 41/100 (0.53s)
#   Train Loss: 43.4408
#   Train Cosine Sim: 0.9467
#   Val Loss: 43.8674
#   Val Cosine Sim: 0.9488
#   Val OS24 AUC: 0.5564
#   LR: 1.00e-03
#
# Epoch 42/100 (0.52s)
#   Train Loss: 41.2486
#   Train Cosine Sim: 0.9490
#   Val Loss: 42.7651
#   Val Cosine Sim: 0.9506
#   Val OS24 AUC: 0.5410
#   LR: 1.00e-03
#
# Epoch 43/100 (0.53s)
#   Train Loss: 40.2033
#   Train Cosine Sim: 0.9506
#   Val Loss: 41.5386
#   Val Cosine Sim: 0.9523
#   Val OS24 AUC: 0.5376
#   LR: 1.00e-03
#
# Epoch 44/100 (0.53s)
#   Train Loss: 39.0184
#   Train Cosine Sim: 0.9523
#   Val Loss: 39.8805
#   Val Cosine Sim: 0.9539
#   Val OS24 AUC: 0.5573
#   LR: 1.00e-03
#
# Epoch 45/100 (0.58s)
#   Train Loss: 37.8068
#   Train Cosine Sim: 0.9539
#   Val Loss: 38.8788
#   Val Cosine Sim: 0.9555
#   Val OS24 AUC: 0.5309
#   LR: 1.00e-03
#
# Epoch 46/100 (0.52s)
#   Train Loss: 36.0501
#   Train Cosine Sim: 0.9555
#   Val Loss: 37.2314
#   Val Cosine Sim: 0.9571
#   Val OS24 AUC: 0.5773
#   LR: 1.00e-03
#
# Epoch 47/100 (0.78s)
#   Train Loss: 36.5938
#   Train Cosine Sim: 0.9567
#   Val Loss: 36.2786
#   Val Cosine Sim: 0.9586
#   Val OS24 AUC: 0.5874
#   LR: 1.00e-03
#
# Epoch 48/100 (0.57s)
#   Train Loss: 35.3296
#   Train Cosine Sim: 0.9582
#   Val Loss: 36.0113
#   Val Cosine Sim: 0.9601
#   Val OS24 AUC: 0.5489
#   LR: 1.00e-03
#
# Epoch 49/100 (0.56s)
#   Train Loss: 33.1875
#   Train Cosine Sim: 0.9599
#   Val Loss: 35.5448
#   Val Cosine Sim: 0.9612
#   Val OS24 AUC: 0.5355
#   LR: 1.00e-03
#
# Epoch 50/100 (0.54s)
#   Train Loss: 32.2802
#   Train Cosine Sim: 0.9605
#   Val Loss: 33.1766
#   Val Cosine Sim: 0.9627
#   Val OS24 AUC: 0.5468
#   LR: 1.00e-03
#
# Epoch 51/100 (0.55s)
#   Train Loss: 31.4207
#   Train Cosine Sim: 0.9620
#   Val Loss: 32.2509
#   Val Cosine Sim: 0.9641
#   Val OS24 AUC: 0.5648
#   LR: 1.00e-03
#
# Epoch 52/100 (0.55s)
#   Train Loss: 30.5747
#   Train Cosine Sim: 0.9639
#   Val Loss: 31.6653
#   Val Cosine Sim: 0.9654
#   Val OS24 AUC: 0.5017
#   LR: 1.00e-03
# Epoch 53/100 (0.53s)
#   Train Loss: 30.4990
#   Train Cosine Sim: 0.9649
#   Val Loss: 30.7046
#   Val Cosine Sim: 0.9666
#   Val OS24 AUC: 0.5017
#   LR: 1.00e-03
#
# Epoch 54/100 (0.52s)
#   Train Loss: 28.5276
#   Train Cosine Sim: 0.9664
#   Val Loss: 30.4536
#   Val Cosine Sim: 0.9678
#   Val OS24 AUC: 0.4900
#   LR: 1.00e-03
#
# Epoch 55/100 (0.26s)
#   Train Loss: 27.4229
#   Train Cosine Sim: 0.9674
#   Val Loss: 31.2899
#   Val Cosine Sim: 0.9687
#   Val OS24 AUC: 0.5050
#   LR: 1.00e-03
#
# Epoch 56/100 (0.54s)
#   Train Loss: 27.3856
#   Train Cosine Sim: 0.9682
#   Val Loss: 28.1419
#   Val Cosine Sim: 0.9698
#   Val OS24 AUC: 0.6196
#   LR: 1.00e-03
#
# Epoch 57/100 (0.25s)
#   Train Loss: 26.3866
#   Train Cosine Sim: 0.9692
#   Val Loss: 28.6839
#   Val Cosine Sim: 0.9707
#   Val OS24 AUC: 0.5301
#   LR: 1.00e-03
#
# Epoch 58/100 (0.27s)
#   Train Loss: 25.6102
#   Train Cosine Sim: 0.9707
#   Val Loss: 31.0370
#   Val Cosine Sim: 0.9717
#   Val OS24 AUC: 0.5916
#   LR: 1.00e-03
#
# Epoch 59/100 (0.52s)
#   Train Loss: 25.4418
#   Train Cosine Sim: 0.9712
#   Val Loss: 26.5099
#   Val Cosine Sim: 0.9729
#   Val OS24 AUC: 0.5907
#   LR: 1.00e-03
#
# Epoch 60/100 (0.51s)
#   Train Loss: 24.7501
#   Train Cosine Sim: 0.9723
#   Val Loss: 25.9126
#   Val Cosine Sim: 0.9738
#   Val OS24 AUC: 0.5815
#   LR: 1.00e-03
#
# Epoch 61/100 (0.26s)
#   Train Loss: 23.6119
#   Train Cosine Sim: 0.9732
#   Val Loss: 26.7820
#   Val Cosine Sim: 0.9748
#   Val OS24 AUC: 0.5242
#   LR: 1.00e-03
#
# Epoch 62/100 (0.52s)
#   Train Loss: 22.9701
#   Train Cosine Sim: 0.9745
#   Val Loss: 24.5559
#   Val Cosine Sim: 0.9754
#   Val OS24 AUC: 0.5531
#   LR: 1.00e-03
#
# Epoch 63/100 (0.31s)
#   Train Loss: 22.9928
#   Train Cosine Sim: 0.9747
#   Val Loss: 24.8437
#   Val Cosine Sim: 0.9761
#   Val OS24 AUC: 0.5330
#   LR: 1.00e-03
#
# Epoch 64/100 (0.51s)
#   Train Loss: 22.4008
#   Train Cosine Sim: 0.9756
#   Val Loss: 24.4440
#   Val Cosine Sim: 0.9769
#   Val OS24 AUC: 0.5360
#   LR: 1.00e-03
#
# Epoch 65/100 (0.26s)
#   Train Loss: 20.9527
#   Train Cosine Sim: 0.9762
#   Val Loss: 24.8793
#   Val Cosine Sim: 0.9777
#   Val OS24 AUC: 0.5468
#   LR: 1.00e-03
#
# Epoch 66/100 (0.53s)
#   Train Loss: 20.7738
#   Train Cosine Sim: 0.9772
#   Val Loss: 23.7693
#   Val Cosine Sim: 0.9783
#   Val OS24 AUC: 0.5577
#   LR: 1.00e-03
#
# Epoch 67/100 (0.54s)
#   Train Loss: 20.9233
#   Train Cosine Sim: 0.9775
#   Val Loss: 22.8954
#   Val Cosine Sim: 0.9790
#   Val OS24 AUC: 0.5422
#   LR: 1.00e-03
#
# Epoch 68/100 (0.51s)
#   Train Loss: 19.6497
#   Train Cosine Sim: 0.9784
#   Val Loss: 22.1679
#   Val Cosine Sim: 0.9794
#   Val OS24 AUC: 0.5773
#   LR: 1.00e-03
#
# Epoch 69/100 (0.25s)
#   Train Loss: 18.9790
#   Train Cosine Sim: 0.9792
#   Val Loss: 22.4673
#   Val Cosine Sim: 0.9802
#   Val OS24 AUC: 0.4962
#   LR: 1.00e-03
#
# Epoch 70/100 (0.52s)
#   Train Loss: 18.7875
#   Train Cosine Sim: 0.9794
#   Val Loss: 22.1631
#   Val Cosine Sim: 0.9808
#   Val OS24 AUC: 0.4954
#   LR: 1.00e-03
#
# Epoch 71/100 (0.24s)
#   Train Loss: 18.6636
#   Train Cosine Sim: 0.9800
#   Val Loss: 22.7088
#   Val Cosine Sim: 0.9811
#   Val OS24 AUC: 0.5063
#   LR: 1.00e-03
#
# Epoch 72/100 (0.49s)
#   Train Loss: 18.3390
#   Train Cosine Sim: 0.9804
#   Val Loss: 20.7989
#   Val Cosine Sim: 0.9815
#   Val OS24 AUC: 0.5234
#   LR: 1.00e-03
#
# Epoch 73/100 (0.51s)
#   Train Loss: 20.2795
#   Train Cosine Sim: 0.9805
#   Val Loss: 20.7031
#   Val Cosine Sim: 0.9820
#   Val OS24 AUC: 0.5155
#   LR: 1.00e-03
#
# Epoch 74/100 (0.49s)
#   Train Loss: 18.9588
#   Train Cosine Sim: 0.9812
#   Val Loss: 20.6379
#   Val Cosine Sim: 0.9824
#   Val OS24 AUC: 0.5347
#   LR: 1.00e-03
#
# Epoch 75/100 (0.47s)
#   Train Loss: 17.3965
#   Train Cosine Sim: 0.9816
#   Val Loss: 20.1783
#   Val Cosine Sim: 0.9825
#   Val OS24 AUC: 0.5548
#   LR: 1.00e-03
#
# Epoch 76/100 (0.47s)
#   Train Loss: 17.1050
#   Train Cosine Sim: 0.9816
#   Val Loss: 19.0943
#   Val Cosine Sim: 0.9831
#   Val OS24 AUC: 0.4967
#   LR: 1.00e-03
#
# Epoch 77/100 (0.48s)
#   Train Loss: 16.7374
#   Train Cosine Sim: 0.9823
#   Val Loss: 18.9638
#   Val Cosine Sim: 0.9835
#   Val OS24 AUC: 0.5025
#   LR: 1.00e-03
#
# Epoch 78/100 (0.22s)
#   Train Loss: 15.8606
#   Train Cosine Sim: 0.9825
#   Val Loss: 19.4556
#   Val Cosine Sim: 0.9838
#   Val OS24 AUC: 0.5502
#   LR: 1.00e-03
#
# Epoch 79/100 (0.22s)
#   Train Loss: 15.6653
#   Train Cosine Sim: 0.9831
#   Val Loss: 19.2144
#   Val Cosine Sim: 0.9841
#   Val OS24 AUC: 0.5426
#   LR: 1.00e-03
#
# Epoch 80/100 (0.47s)
#   Train Loss: 15.5532
#   Train Cosine Sim: 0.9833
#   Val Loss: 18.3766
#   Val Cosine Sim: 0.9843
#   Val OS24 AUC: 0.5205
#   LR: 1.00e-03
#
# Epoch 81/100 (0.48s)
#   Train Loss: 15.1305
#   Train Cosine Sim: 0.9835
#   Val Loss: 18.1493
#   Val Cosine Sim: 0.9847
#   Val OS24 AUC: 0.5351
#   LR: 1.00e-03
#
# Epoch 82/100 (0.48s)
#   Train Loss: 15.1565
#   Train Cosine Sim: 0.9840
#   Val Loss: 17.8731
#   Val Cosine Sim: 0.9850
#   Val OS24 AUC: 0.5426
#   LR: 1.00e-03
#
# Epoch 83/100 (0.22s)
#   Train Loss: 14.7803
#   Train Cosine Sim: 0.9840
#   Val Loss: 18.0614
#   Val Cosine Sim: 0.9850
#   Val OS24 AUC: 0.5627
#   LR: 1.00e-03
#
# Epoch 84/100 (0.48s)
#   Train Loss: 14.6712
#   Train Cosine Sim: 0.9843
#   Val Loss: 17.4481
#   Val Cosine Sim: 0.9852
#   Val OS24 AUC: 0.5966
#   LR: 1.00e-03
#
# Epoch 85/100 (0.49s)
#   Train Loss: 14.3988
#   Train Cosine Sim: 0.9848
#   Val Loss: 17.4052
#   Val Cosine Sim: 0.9856
#   Val OS24 AUC: 0.5640
#   LR: 1.00e-03
#
# Epoch 86/100 (0.22s)
#   Train Loss: 13.7636
#   Train Cosine Sim: 0.9845
#   Val Loss: 17.4219
#   Val Cosine Sim: 0.9858
#   Val OS24 AUC: 0.5569
#   LR: 1.00e-03
#
# Epoch 87/100 (0.48s)
#   Train Loss: 14.6391
#   Train Cosine Sim: 0.9846
#   Val Loss: 17.3837
#   Val Cosine Sim: 0.9861
#   Val OS24 AUC: 0.5506
#   LR: 1.00e-03
#
# Epoch 88/100 (0.22s)
#   Train Loss: 14.2031
#   Train Cosine Sim: 0.9853
#   Val Loss: 18.3277
#   Val Cosine Sim: 0.9862
#   Val OS24 AUC: 0.5560
#   LR: 1.00e-03
#
# Epoch 89/100 (0.23s)
#   Train Loss: 13.4090
#   Train Cosine Sim: 0.9854
#   Val Loss: 18.4338
#   Val Cosine Sim: 0.9863
#   Val OS24 AUC: 0.5686
#   LR: 1.00e-03
#
# Epoch 90/100 (0.49s)
#   Train Loss: 13.7631
#   Train Cosine Sim: 0.9852
#   Val Loss: 16.8964
#   Val Cosine Sim: 0.9864
#   Val OS24 AUC: 0.5778
#   LR: 1.00e-03
#
# Epoch 91/100 (0.22s)
#   Train Loss: 13.4112
#   Train Cosine Sim: 0.9858
#   Val Loss: 17.5655
#   Val Cosine Sim: 0.9865
#   Val OS24 AUC: 0.5322
#   LR: 1.00e-03
#
# Epoch 92/100 (0.22s)
#   Train Loss: 13.0093
#   Train Cosine Sim: 0.9855
#   Val Loss: 17.5748
#   Val Cosine Sim: 0.9869
#   Val OS24 AUC: 0.4962
#   LR: 1.00e-03
#
# Epoch 93/100 (0.22s)
#   Train Loss: 12.2769
#   Train Cosine Sim: 0.9861
#   Val Loss: 19.3714
#   Val Cosine Sim: 0.9870
#   Val OS24 AUC: 0.5008
#   LR: 1.00e-03
#
# Epoch 94/100 (0.22s)
#   Train Loss: 13.4932
#   Train Cosine Sim: 0.9857
#   Val Loss: 17.5294
#   Val Cosine Sim: 0.9871
#   Val OS24 AUC: 0.5134
#   LR: 1.00e-03
#
# Epoch 95/100 (0.22s)
#   Train Loss: 12.3669
#   Train Cosine Sim: 0.9861
#   Val Loss: 17.9956
#   Val Cosine Sim: 0.9870
#   Val OS24 AUC: 0.4624
#   LR: 1.00e-03
#
# Epoch 96/100 (0.22s)
#   Train Loss: 12.3604
#   Train Cosine Sim: 0.9864
#   Val Loss: 17.5393
#   Val Cosine Sim: 0.9873
#   Val OS24 AUC: 0.4808
#   LR: 1.00e-03
#
# Epoch 97/100 (0.22s)
#   Train Loss: 12.1917
#   Train Cosine Sim: 0.9865
#   Val Loss: 17.4119
#   Val Cosine Sim: 0.9874
#   Val OS24 AUC: 0.4841
#   LR: 1.00e-03
#
# Epoch 98/100 (0.22s)
#   Train Loss: 12.3365
#   Train Cosine Sim: 0.9866
#   Val Loss: 17.2428
#   Val Cosine Sim: 0.9875
#   Val OS24 AUC: 0.4954
#   LR: 1.00e-03
#
# Epoch 99/100 (0.22s)
#   Train Loss: 12.6279
#   Train Cosine Sim: 0.9862
#   Val Loss: 17.6405
#   Val Cosine Sim: 0.9875
#   Val OS24 AUC: 0.5017
#   LR: 1.00e-03
#
# Epoch 100/100 (0.22s)
#   Train Loss: 12.3419
#   Train Cosine Sim: 0.9865
#   Val Loss: 17.4937
#   Val Cosine Sim: 0.9873
#   Val OS24 AUC: 0.5171
#   LR: 1.00e-03
#
# Training completed!
# Best validation loss: 16.8964
# Evaluating on test set...
# Loaded best model from epoch 89
#
# Test Results:
# Test Loss: 18.0438
# Test Cosine Sim: 0.9867
# OS24 - AUC: 0.4263, Accuracy: 0.6827, F1: 0.1538
#
# Results saved to: ./results/autoencoder_20250624_104923/autoencoder_20250624_104941

# %% [markdown]
# # ML Prediction from Reduced Features
#
# ## This notebook predicts clinical endpoints from autoencoder-extracted features using scikit-learn.
#
# ## Configuration

# %%
# CONFIGURATION - CHANGE THESE
TARGET_ENDPOINT = 'OS_6'  # Options: 'OS_6', 'OS_24', 'STAGE_T', 'STAGE_N', 'STAGE_M'
FEATURES_CSV = '/share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/I3LUNG_reduced_features_AUC_sel.csv' #'/share/project10/home/prelajarsela/CT-FM/PKLs_fixed_dim/I3LUNG_reduced_features.csv'
TRAIN_TEST_JSON = '/share/project10/data/CTs_I3LUNG_COHORT23/train_test_split.json'
VAL_SPLIT = 0.2

print(f"Target endpoint: {TARGET_ENDPOINT}")
# Out:
# Target endpoint: OS_6

# %% [markdown]
# ## Imports and Setup

# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score, accuracy_score, roc_curve, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
def load_data(csv_path: str, train_test_json: str):
    """Load features and apply train/test split"""
    # Load features
    df = pd.read_csv(csv_path)
    print(f"Loaded {len(df)} patients with {len([c for c in df.columns if c.startswith('feature_')])} features")
    
    # Load train/test split
    with open(train_test_json, 'r') as f:
        split_data = json.load(f)
    
    # Filter for target endpoint availability
    df = df.dropna(subset=[TARGET_ENDPOINT])
    print(f"After filtering for {TARGET_ENDPOINT}: {len(df)} patients")
    
    # Apply train/test split
    train_subjects = set(split_data['TRAIN_SET'])
    test_subjects = set(split_data['TEST_SET'])
    
    train_df = df[df['Subject'].isin(train_subjects)].copy()
    test_df = df[df['Subject'].isin(test_subjects)].copy()
    
    return train_df, test_df

def stratified_split_by_center(train_df, test_size=0.2):
    """Split train into train/val with center stratification"""
    strat_labels = []
    for _, row in train_df.iterrows():
        center = row['Center']
        label = int(row[TARGET_ENDPOINT])
        if TARGET_ENDPOINT in ['STAGE_T', 'STAGE_N']:
            label = int(label > 0)
        strat_labels.append(f"{center}_{label}")
    
    try:
        train_idx, val_idx = train_test_split(
            range(len(train_df)), test_size=test_size, 
            stratify=strat_labels, random_state=42
        )
        print("Using stratified split by center and label")
    except ValueError:
        train_idx, val_idx = train_test_split(
            range(len(train_df)), test_size=test_size, random_state=42
        )
        print("Using random split (stratification failed)")
    
    return train_df.iloc[train_idx], train_df.iloc[val_idx]

def prepare_features(df):
    """Extract features and targets"""
    feature_cols = [col for col in df.columns if col.startswith('feature_')]
    X = df[feature_cols].values
    y = df[TARGET_ENDPOINT].values
    
    # Convert to binary for staging endpoints
    if TARGET_ENDPOINT in ['STAGE_T', 'STAGE_N']:
        y = (y > 0).astype(int)
    
    return X, y.astype(int)

# Load and split data
train_df, test_df = load_data(FEATURES_CSV, TRAIN_TEST_JSON)
train_df, val_df = stratified_split_by_center(train_df, VAL_SPLIT)

print(f"\nDataset sizes:")
print(f"  Train: {len(train_df)}")
print(f"  Val: {len(val_df)}")
print(f"  Test: {len(test_df)}")
# Out:
# Loaded 757 patients with 512 features
# After filtering for OS_6: 740 patients
# Using stratified split by center and label
#
# Dataset sizes:
#   Train: 502
#   Val: 126
#   Test: 112

# %% [markdown]
# ## Feature Preparation and EDA

# %%
# Prepare features
X_train, y_train = prepare_features(train_df)
X_val, y_val = prepare_features(val_df)
X_test, y_test = prepare_features(test_df)

print(f"Feature dimensions: {X_train.shape[1]}")
print(f"Class distributions:")
print(f"  Train: {np.bincount(y_train)} (class 0: {np.bincount(y_train)[0]}, class 1: {np.bincount(y_train)[1]})")
print(f"  Val: {np.bincount(y_val)} (class 0: {np.bincount(y_val)[0]}, class 1: {np.bincount(y_val)[1]})")
print(f"  Test: {np.bincount(y_test)} (class 0: {np.bincount(y_test)[0]}, class 1: {np.bincount(y_test)[1]})")
# Out:
# Feature dimensions: 512
# Class distributions:
#   Train: [170 332] (class 0: 170, class 1: 332)
#   Val: [43 83] (class 0: 43, class 1: 83)
#   Test: [38 74] (class 0: 38, class 1: 74)

# %%
# Visualize class distribution
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
datasets = [('Train', y_train), ('Val', y_val), ('Test', y_test)]

for i, (name, y) in enumerate(datasets):
    counts = np.bincount(y)
    axes[i].bar(['Class 0', 'Class 1'], counts, alpha=0.7)
    axes[i].set_title(f'{name} Set - {TARGET_ENDPOINT}')
    axes[i].set_ylabel('Count')
    for j, count in enumerate(counts):
        axes[i].text(j, count + 0.5, str(count), ha='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model Definition and Grid Search

# %%
def remove_correlated_features(X_train, X_val, X_test, threshold=0.95):
    """Remove highly correlated features using Spearman correlation"""
    from scipy.stats import spearmanr
    
    # Calculate Spearman correlation matrix
    corr_matrix = np.abs(spearmanr(X_train).correlation)
    
    # Find features to remove
    upper_tri = np.triu(np.ones_like(corr_matrix, dtype=bool), k=1)
    high_corr_pairs = np.where((corr_matrix > threshold) & upper_tri)
    features_to_remove = set()
    
    for i, j in zip(high_corr_pairs[0], high_corr_pairs[1]):
        # Remove the feature with lower variance
        if np.var(X_train[:, i]) < np.var(X_train[:, j]):
            features_to_remove.add(i)
        else:
            features_to_remove.add(j)
    
    # Keep features
    keep_features = [i for i in range(X_train.shape[1]) if i not in features_to_remove]
    
    print(f"Removed {len(features_to_remove)} highly correlated features (threshold={threshold})")
    print(f"Kept {len(keep_features)} features")
    
    return X_train[:, keep_features], X_val[:, keep_features], X_test[:, keep_features]

def create_pipelines():
    """Create ML pipelines with feature selection and regularization"""
    from sklearn.feature_selection import SelectKBest, f_classif, RFE
    from sklearn.ensemble import ExtraTreesClassifier, GradientBoostingClassifier
    from sklearn.linear_model import ElasticNet
    from sklearn.naive_bayes import GaussianNB
    
    pipelines = {
        'LogisticRegression_L1': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=50)),
            ('clf', LogisticRegression(random_state=42, max_iter=2000, penalty='l1', solver='liblinear'))
        ]),
        'LogisticRegression_L2': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=50)),
            ('clf', LogisticRegression(random_state=42, max_iter=2000, penalty='l2'))
        ]),
        'ElasticNet': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=50)),
            ('clf', LogisticRegression(random_state=42, max_iter=2000, penalty='elasticnet', solver='saga', l1_ratio=0.5))
        ]),
        'RandomForest': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=100)),
            ('clf', RandomForestClassifier(random_state=42, n_jobs=-1))
        ]),
        'ExtraTrees': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=100)),
            ('clf', ExtraTreesClassifier(random_state=42, n_jobs=-1))
        ]),
        'GradientBoosting': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=80)),
            ('clf', GradientBoostingClassifier(random_state=42))
        ]),
        'SVM_RBF': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=60)),
            ('clf', SVC(random_state=42, probability=True, kernel='rbf'))
        ]),
        'SVM_Linear': Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectKBest(f_classif, k=60)),
            ('clf', SVC(random_state=42, probability=True, kernel='linear'))
        ])
    }
    
    param_grids = {
        'LogisticRegression_L1': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__C': [0.001, 0.01, 0.1, 1.0]
        },
        'LogisticRegression_L2': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__C': [0.001, 0.01, 0.1, 1.0]
        },
        'ElasticNet': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__C': [0.001, 0.01, 0.1, 1.0],
            'clf__l1_ratio': [0.1, 0.5, 0.9]
        },
        'RandomForest': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__n_estimators': [50, 100],
            'clf__max_depth': [3, 5, 10],
            'clf__min_samples_split': [10, 20],
            'clf__min_samples_leaf': [5, 10]
        },
        'ExtraTrees': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__n_estimators': [50, 100],
            'clf__max_depth': [3, 5, 10],
            'clf__min_samples_split': [10, 20],
            'clf__min_samples_leaf': [5, 10]
        },
        'GradientBoosting': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__n_estimators': [50, 100],
            'clf__max_depth': [3, 5],
            'clf__learning_rate': [0.01, 0.1, 0.2],
            'clf__min_samples_split': [10, 20]
        },
        'SVM_RBF': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__C': [0.001, 0.01, 0.1, 1.0],
            'clf__gamma': ['scale', 'auto']
        },
        'SVM_Linear': {
            'selector__k': [20, 40, 60, 100, 200, 300],
            'clf__C': [0.001, 0.01, 0.1, 1.0]
        }
    }
    
    return pipelines, param_grids

def evaluate_model(model, X, y):
    """Evaluate model and return metrics"""
    y_pred = model.predict(X)
    y_prob = model.predict_proba(X)[:, 1]
    
    auc = roc_auc_score(y, y_prob) if len(np.unique(y)) > 1 else 0.5
    acc = accuracy_score(y, y_pred)
    
    return {'auc': auc, 'accuracy': acc, 'y_pred': y_pred, 'y_prob': y_prob}

pipelines, param_grids = create_pipelines()
print("Created pipelines for:", list(pipelines.keys()))
# Out:
# Created pipelines for: ['LogisticRegression_L1', 'LogisticRegression_L2', 'ElasticNet', 'RandomForest', 'ExtraTrees', 'GradientBoosting', 'SVM_RBF', 'SVM_Linear']

# %% [markdown]
# ## Training and Evaluation

# %%
results = {}
best_models = {}
cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Grid search for each algorithm
for name, pipeline in pipelines.items():
    print(f"\n{'='*50}")
    print(f"Training {name}...")
    
    # Grid search with cross-validation
    grid_search = GridSearchCV(
        pipeline, param_grids[name], cv=cv, 
        scoring='roc_auc', n_jobs=-1, verbose=0
    )
    
    grid_search.fit(X_train, y_train)
    best_model = grid_search.best_estimator_
    best_models[name] = best_model
    
    # Evaluate on all sets
    train_metrics = evaluate_model(best_model, X_train, y_train)
    val_metrics = evaluate_model(best_model, X_val, y_val)
    test_metrics = evaluate_model(best_model, X_test, y_test)
    
    results[name] = {
        'best_params': grid_search.best_params_,
        'train_auc': train_metrics['auc'],
        'val_auc': val_metrics['auc'], 
        'test_auc': test_metrics['auc'],
        'train_acc': train_metrics['accuracy'],
        'val_acc': val_metrics['accuracy'],
        'test_acc': test_metrics['accuracy'],
        'train_pred': train_metrics['y_pred'],
        'val_pred': val_metrics['y_pred'],
        'test_pred': test_metrics['y_pred'],
        'train_prob': train_metrics['y_prob'],
        'val_prob': val_metrics['y_prob'],
        'test_prob': test_metrics['y_prob']
    }
    
    print(f"Best params: {grid_search.best_params_}")
    print(f"AUCs - Train: {train_metrics['auc']:.3f}, Val: {val_metrics['auc']:.3f}, Test: {test_metrics['auc']:.3f}")
    print(f"Accs - Train: {train_metrics['accuracy']:.3f}, Val: {val_metrics['accuracy']:.3f}, Test: {test_metrics['accuracy']:.3f}")
# Out:
# ==================================================
# Training LogisticRegression_L1...
# Best params: {'clf__C': 1.0, 'selector__k': 20}
# AUCs - Train: 0.651, Val: 0.601, Test: 0.580
# Accs - Train: 0.679, Val: 0.667, Test: 0.661
#
# ==================================================
# Training LogisticRegression_L2...
# Best params: {'clf__C': 0.1, 'selector__k': 20}
# AUCs - Train: 0.644, Val: 0.593, Test: 0.583
# Accs - Train: 0.677, Val: 0.690, Test: 0.679
#
# ==================================================
# Training ElasticNet...
# /share/project10/home/prelajarsela/.conda/envs/CT-FM_env/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best params: {'clf__C': 0.1, 'clf__l1_ratio': 0.1, 'selector__k': 60}
# AUCs - Train: 0.657, Val: 0.592, Test: 0.544
# Accs - Train: 0.689, Val: 0.667, Test: 0.661
#
# ==================================================
# Training RandomForest...
# Best params: {'clf__max_depth': 3, 'clf__min_samples_leaf': 10, 'clf__min_samples_split': 10, 'clf__n_estimators': 100, 'selector__k': 20}
# AUCs - Train: 0.773, Val: 0.556, Test: 0.603
# Accs - Train: 0.695, Val: 0.659, Test: 0.688
#
# ==================================================
# Training ExtraTrees...
# Best params: {'clf__max_depth': 3, 'clf__min_samples_leaf': 5, 'clf__min_samples_split': 20, 'clf__n_estimators': 100, 'selector__k': 20}
# AUCs - Train: 0.679, Val: 0.579, Test: 0.579
# Accs - Train: 0.677, Val: 0.651, Test: 0.661
#
# ==================================================
# Training GradientBoosting...
# Best params: {'clf__learning_rate': 0.01, 'clf__max_depth': 3, 'clf__min_samples_split': 10, 'clf__n_estimators': 50, 'selector__k': 40}
# AUCs - Train: 0.802, Val: 0.529, Test: 0.492
# Accs - Train: 0.709, Val: 0.635, Test: 0.652
#
# ==================================================
# Training SVM_RBF...
# Best params: {'clf__C': 0.1, 'clf__gamma': 'scale', 'selector__k': 20}
# AUCs - Train: 0.813, Val: 0.562, Test: 0.559
# Accs - Train: 0.661, Val: 0.659, Test: 0.661
#
# ==================================================
# Training SVM_Linear...
# Best params: {'clf__C': 0.01, 'selector__k': 60}
# AUCs - Train: 0.668, Val: 0.536, Test: 0.519
# Accs - Train: 0.661, Val: 0.659, Test: 0.661

# %% [markdown]
# ## Results Summary

# %%
# Create results summary
summary_df = pd.DataFrame({
    'Model': list(results.keys()),
    'Train_AUC': [results[m]['train_auc'] for m in results.keys()],
    'Val_AUC': [results[m]['val_auc'] for m in results.keys()],
    'Test_AUC': [results[m]['test_auc'] for m in results.keys()],
    'Train_Acc': [results[m]['train_acc'] for m in results.keys()],
    'Val_Acc': [results[m]['val_acc'] for m in results.keys()],
    'Test_Acc': [results[m]['test_acc'] for m in results.keys()]
})

print(f"Results Summary for {TARGET_ENDPOINT}:")
print("="*60)
print(summary_df.round(3).to_string(index=False))

best_model_name = summary_df.loc[summary_df['Val_AUC'].idxmax(), 'Model']
print(f"\nBest model by validation AUC: {best_model_name}")
# Out:
# Results Summary for OS_6:
# ============================================================
#                 Model  Train_AUC  Val_AUC  Test_AUC  Train_Acc  Val_Acc  Test_Acc
# LogisticRegression_L1      0.651    0.601     0.580      0.679    0.667     0.661
# LogisticRegression_L2      0.644    0.593     0.583      0.677    0.690     0.679
#            ElasticNet      0.657    0.592     0.544      0.689    0.667     0.661
#          RandomForest      0.773    0.556     0.603      0.695    0.659     0.688
#            ExtraTrees      0.679    0.579     0.579      0.677    0.651     0.661
#      GradientBoosting      0.802    0.529     0.492      0.709    0.635     0.652
#               SVM_RBF      0.813    0.562     0.559      0.661    0.659     0.661
#            SVM_Linear      0.668    0.536     0.519      0.661    0.659     0.661
#
# Best model by validation AUC: LogisticRegression_L1

# %% [markdown]
# ## Visualization

# %%
# Plot performance comparison
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# AUC comparison
x_pos = np.arange(len(summary_df))
width = 0.25

axes[0].bar(x_pos - width, summary_df['Train_AUC'], width, label='Train', alpha=0.8)
axes[0].bar(x_pos, summary_df['Val_AUC'], width, label='Val', alpha=0.8)
axes[0].bar(x_pos + width, summary_df['Test_AUC'], width, label='Test', alpha=0.8)
axes[0].set_xlabel('Model')
axes[0].set_ylabel('AUC')
axes[0].set_title(f'AUC Comparison - {TARGET_ENDPOINT}')
axes[0].set_xticks(x_pos)
axes[0].set_xticklabels(summary_df['Model'], rotation=45)
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Accuracy comparison  
axes[1].bar(x_pos - width, summary_df['Train_Acc'], width, label='Train', alpha=0.8)
axes[1].bar(x_pos, summary_df['Val_Acc'], width, label='Val', alpha=0.8)
axes[1].bar(x_pos + width, summary_df['Test_Acc'], width, label='Test', alpha=0.8)
axes[1].set_xlabel('Model')
axes[1].set_ylabel('Accuracy')
axes[1].set_title(f'Accuracy Comparison - {TARGET_ENDPOINT}')
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(summary_df['Model'], rotation=45)
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## OS_6 (dim: 256)

# %%
# ROC curves for best model
best_result = results[best_model_name]

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
datasets = [('Train', y_train, best_result['train_prob']), 
            ('Val', y_val, best_result['val_prob']),
            ('Test', y_test, best_result['test_prob'])]

for i, (name, y_true, y_prob) in enumerate(datasets):
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc = roc_auc_score(y_true, y_prob)
    
    axes[i].plot(fpr, tpr, linewidth=3, label=f'ROC (AUC = {roc_auc:.3f})')
    axes[i].plot([0, 1], [0, 1], 'k--', alpha=0.5)
    axes[i].set_xlim([0.0, 1.0])
    axes[i].set_ylim([0.0, 1.05])
    axes[i].set_xlabel('False Positive Rate')
    axes[i].set_ylabel('True Positive Rate')
    axes[i].set_title(f'{name} Set - {best_model_name}')
    axes[i].legend()
    axes[i].grid(True, alpha=0.3)

plt.suptitle(f'ROC Curves for {TARGET_ENDPOINT}', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## OS_24 (dim: 256)

# %%
# ROC curves for best model
best_result = results[best_model_name]

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
datasets = [('Train', y_train, best_result['train_prob']), 
            ('Val', y_val, best_result['val_prob']),
            ('Test', y_test, best_result['test_prob'])]

for i, (name, y_true, y_prob) in enumerate(datasets):
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc = roc_auc_score(y_true, y_prob)
    
    axes[i].plot(fpr, tpr, linewidth=3, label=f'ROC (AUC = {roc_auc:.3f})')
    axes[i].plot([0, 1], [0, 1], 'k--', alpha=0.5)
    axes[i].set_xlim([0.0, 1.0])
    axes[i].set_ylim([0.0, 1.05])
    axes[i].set_xlabel('False Positive Rate')
    axes[i].set_ylabel('True Positive Rate')
    axes[i].set_title(f'{name} Set - {best_model_name}')
    axes[i].legend()
    axes[i].grid(True, alpha=0.3)

plt.suptitle(f'ROC Curves for {TARGET_ENDPOINT}', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## OS_6 (dim: 512)

# %%
# ROC curves for best model
best_result = results[best_model_name]

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
datasets = [('Train', y_train, best_result['train_prob']), 
            ('Val', y_val, best_result['val_prob']),
            ('Test', y_test, best_result['test_prob'])]

for i, (name, y_true, y_prob) in enumerate(datasets):
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc = roc_auc_score(y_true, y_prob)
    
    axes[i].plot(fpr, tpr, linewidth=3, label=f'ROC (AUC = {roc_auc:.3f})')
    axes[i].plot([0, 1], [0, 1], 'k--', alpha=0.5)
    axes[i].set_xlim([0.0, 1.0])
    axes[i].set_ylim([0.0, 1.05])
    axes[i].set_xlabel('False Positive Rate')
    axes[i].set_ylabel('True Positive Rate')
    axes[i].set_title(f'{name} Set - {best_model_name}')
    axes[i].legend()
    axes[i].grid(True, alpha=0.3)

plt.suptitle(f'ROC Curves for {TARGET_ENDPOINT}', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## OS_24 (dim: 512)

# %%
# ROC curves for best model
best_result = results[best_model_name]

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
datasets = [('Train', y_train, best_result['train_prob']), 
            ('Val', y_val, best_result['val_prob']),
            ('Test', y_test, best_result['test_prob'])]

for i, (name, y_true, y_prob) in enumerate(datasets):
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc = roc_auc_score(y_true, y_prob)
    
    axes[i].plot(fpr, tpr, linewidth=3, label=f'ROC (AUC = {roc_auc:.3f})')
    axes[i].plot([0, 1], [0, 1], 'k--', alpha=0.5)
    axes[i].set_xlim([0.0, 1.0])
    axes[i].set_ylim([0.0, 1.05])
    axes[i].set_xlabel('False Positive Rate')
    axes[i].set_ylabel('True Positive Rate')
    axes[i].set_title(f'{name} Set - {best_model_name}')
    axes[i].legend()
    axes[i].grid(True, alpha=0.3)

plt.suptitle(f'ROC Curves for {TARGET_ENDPOINT}', fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Confusion matrices for best model
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
datasets = [('Train', y_train, best_result['train_pred']), 
            ('Val', y_val, best_result['val_pred']),
            ('Test', y_test, best_result['test_pred'])]

for i, (name, y_true, y_pred) in enumerate(datasets):
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[i],
               xticklabels=['Negative', 'Positive'],
               yticklabels=['Negative', 'Positive'])
    axes[i].set_title(f'{name} Set - {best_model_name}')
    axes[i].set_xlabel('Predicted')
    axes[i].set_ylabel('Actual')

plt.suptitle(f'Confusion Matrices for {TARGET_ENDPOINT}', fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Save results to JSON
final_results = {
    'target_endpoint': TARGET_ENDPOINT,
    'dataset_sizes': {'train': len(train_df), 'val': len(val_df), 'test': len(test_df)},
    'feature_dims': X_train.shape[1],
    'best_model': best_model_name,
    'summary': summary_df.to_dict('records')
}

output_file = f'ml_results_{TARGET_ENDPOINT}.json'
with open(output_file, 'w') as f:
    json.dump(final_results, f, indent=2)

print(f"Results saved to: {output_file}")
print(f"\nFinal Summary for {TARGET_ENDPOINT}:")
print(f"Best model: {best_model_name}")
print(f"Test AUC: {results[best_model_name]['test_auc']:.3f}")
print(f"Test Accuracy: {results[best_model_name]['test_acc']:.3f}")
